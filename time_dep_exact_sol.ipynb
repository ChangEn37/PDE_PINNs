# %% [markdown]
# u(x,y,t)=(x+y)*phi. Domain: square [-1,1]^2 with moving crack from (0,0) to (1,alpha(t)). f = (x+y)*phi_t - 2(phi_x+phi_y)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FFMpegWriter

# Settings
torch.set_default_dtype(torch.float64)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

X_MIN, X_MAX = -1.0, 1.0
Y_MIN, Y_MAX = -1.0, 1.0
T_MIN, T_MAX = 0.0, 0.25  

N_f = 1000       
N_b_outer = 1000 
N_b_crack = 1000 
N_ic = 1000 # initial condition points on domain at t=0
N_ic_out = 1000  # initial condition points on domain at t=0
N_ic_crack = 1000   # initial condition points on domain at t=0
epochs = 2500
lambda_bc = 1.0
lambda_ic = 1.0
lambda_zz = 1.0
lambda_zz3 = 1.0
# Out:
# Device: cpu

# %%
# MLP 
class MLP(nn.Module):
    def __init__(self, layers):
        super().__init__()
        self.net = nn.ModuleList()
        for i in range(len(layers)-1):
            self.net.append(nn.Linear(layers[i], layers[i+1]))
        self.activation = torch.tanh
        for m in self.net:
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight) #????
                nn.init.zeros_(m.bias)

    def forward(self, inp):
        z = inp
        for layer in self.net[:-1]:
            z = self.activation(layer(z))
        z = self.net[-1](z)
        return z

#
layers = [4, 64, 64, 1]
model = MLP(layers).to(device)   

# optimizer
optimizer = optim.LBFGS(model.parameters(), lr=1.0, max_iter=20, history_size=50, line_search_fn="strong_wolfe")

# %%
def alpha(t):
    return (np.pi / 4.0) * torch.sin(2.0 * np.pi * t)

def compute_phi_and_derivs(x, y, t):
    eps = 1e-12
    x = x.view(-1, 1).to(device)
    y = y.view(-1, 1).to(device)
    t = t.view(-1, 1).to(device)
    a = alpha(t)  # α(t)
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=eps))
    inside = torch.clamp(r - (x * torch.cos(a) + y * torch.sin(a)), min=eps)
    phi = torch.sqrt(0.5 * inside)
    sqrt_term = torch.sqrt(inside)
    phi_x = (torch.sqrt(torch.tensor(2.0, dtype=torch.float64)) *
             (x / r - torch.cos(a))) / (4.0 * sqrt_term)
    phi_y = (torch.sqrt(torch.tensor(2.0, dtype=torch.float64)) *
             (y / r - torch.sin(a))) / (4.0 * sqrt_term)
    phi_t = (torch.sqrt(torch.tensor(2.0, dtype=torch.float64)) / 4.0) * (x * torch.sin(a) - y * torch.cos(a)) / sqrt_term *(np.pi**2 / 2.0) * torch.cos(2 * np.pi * t)
    u_true = (x + y) * phi
    return phi, phi_x, phi_y, phi_t, u_true

def partials_U_wrt_inputs(model, x, y, phi, t):
    # ensure column shapes
    x = x.view(-1,1)
    y = y.view(-1,1)
    phi = phi.view(-1,1)
    t = t.view(-1,1)

    inp = torch.cat([x, y, phi, t], dim=1).to(device)
    inp.requires_grad_(True)
    U = model(inp)  # (N,1)

    grads = torch.autograd.grad(U, inp, grad_outputs=torch.ones_like(U),
                                create_graph=True, retain_graph=True)[0]  # (N,4)
    U_x = grads[:,0:1]
    U_y = grads[:,1:2]
    U_z = grads[:,2:3]   
    U_t = grads[:,3:4]   
    return U, inp, U_x, U_y, U_z, U_t

def second_partials_U(model, inp, U_x, U_y, U_z):
    # inp shape (N,4)
    grad_Ux = torch.autograd.grad(U_x, inp, grad_outputs=torch.ones_like(U_x),
                                  create_graph=True, retain_graph=True)[0]
    grad_Uy = torch.autograd.grad(U_y, inp, grad_outputs=torch.ones_like(U_y),
                                  create_graph=True, retain_graph=True)[0]
    grad_Uz = torch.autograd.grad(U_z, inp, grad_outputs=torch.ones_like(U_z),
                                  create_graph=True, retain_graph=True)[0]

    U_xx = grad_Ux[:,0:1]
    U_xz = grad_Ux[:,2:3]
    U_yy = grad_Uy[:,1:2]
    U_yz = grad_Uy[:,2:3]
    U_zz = grad_Uz[:,2:3]

    return U_xx, U_yy, U_xz, U_yz, U_zz

def compute_residual_time(model, x, y, t):
    x = x.clone().detach().requires_grad_(True).to(device)
    y = y.clone().detach().requires_grad_(True).to(device)
    t = t.clone().detach().requires_grad_(True).to(device)

    phi, phi_x, phi_y, phi_t, _ = compute_phi_and_derivs(x, y, t)

    U, inp, U_x, U_y, U_z, U_t = partials_U_wrt_inputs(model, x, y, phi, t)
    U_xx, U_yy, U_xz, U_yz, U_zz = second_partials_U(model, inp, U_x, U_y, U_z)

    r = torch.sqrt(torch.clamp(x**2 + y**2, min=1e-12))
    laplace_U = U_xx + U_yy
    lap = laplace_U + 2.0 * (U_xz * phi_x + U_yz * phi_y) + (1/(4*r)) * U_zz
    ut = U_z * phi_t + U_t
    residual = ut - lap - (x+y) * phi_t + 2.0 * (phi_x + phi_y)
    return residual, U, U_zz, U_xz, U_yz

# compute tip constraint 
def compute_zz_uN(model, t):
    if not torch.is_tensor(t):
        t = torch.tensor([[t]], dtype=torch.float64, device=device)
    else:
        t = t.view(-1,1).to(dtype=torch.float64, device=device)

    x = torch.zeros_like(t)
    y = torch.zeros_like(t)

    phi, phi_x, phi_y, phi_t, _ = compute_phi_and_derivs(x, y, t)
    U, inp, U_x, U_y, U_z, U_t = partials_U_wrt_inputs(model, x, y, phi, t)

    grad_Uz = torch.autograd.grad(U_z, inp, grad_outputs=torch.ones_like(U_z),
                                  create_graph=True, retain_graph=True)[0]
    U_zz = grad_Uz[:,2:3]
    U_xz = grad_Uz[:,0:1]
    U_yz = grad_Uz[:,1:2]
    return torch.mean(U_zz**2 + U_xz**2 + U_yz**2) 

def compute_xyz_uN(model, x, y, t):
    phi, phi_x, phi_y, phi_t, _ = compute_phi_and_derivs(x, y, t)
    U, inp, U_x, U_y, U_z, U_t = partials_U_wrt_inputs(model, x, y, phi, t)
    grad_Uz = torch.autograd.grad(U_z, inp, grad_outputs=torch.ones_like(U_z),
                                  create_graph=True, retain_graph=True)[0]
    U_xz = grad_Uz[:,0:1]
    U_yz = grad_Uz[:,1:2]

    return torch.mean(U_xz**2+U_yz**2)  # shape (N,1)

def sample_collocation(N): 
    x = torch.rand(N*2,1) * (X_MAX - X_MIN) + X_MIN 
    y = torch.rand(N*2,1) * (Y_MAX - Y_MIN) + Y_MIN 
    t = torch.rand(N*2,1) * (T_MAX - T_MIN) + T_MIN 
    a = alpha(t) # shape (N*2,1) 
    # 裂縫 y = α(t)*x  點到直線距離 
    dist_to_crack = torch.abs(y - a * x) / torch.sqrt(1 + a**2) 
    # mask 
    mask_crack = (dist_to_crack < 1e-8) 
    x, y, t = x[~mask_crack][:N], y[~mask_crack][:N], t[~mask_crack][:N] 
    return x.to(device), y.to(device), t.to(device)

def sample_outer_boundary(N):
    per_side = max(4, N // 4)
    xs, ys = [], []

    ys.append(torch.linspace(Y_MIN, Y_MAX, per_side).unsqueeze(1)); xs.append(torch.ones_like(ys[-1]) * X_MIN)
    ys.append(torch.linspace(Y_MIN, Y_MAX, per_side).unsqueeze(1)); xs.append(torch.ones_like(ys[-1]) * X_MAX)
    xs.append(torch.linspace(X_MIN, X_MAX, per_side).unsqueeze(1)); ys.append(torch.ones_like(xs[-1]) * Y_MIN)
    xs.append(torch.linspace(X_MIN, X_MAX, per_side).unsqueeze(1)); ys.append(torch.ones_like(xs[-1]) * Y_MAX)

    x = torch.cat(xs, dim=0)[:N]
    y = torch.cat(ys, dim=0)[:N]
    t = torch.rand(N, 1, device=device, dtype=torch.float64) * (T_MAX - T_MIN) + T_MIN

    return x.to(device), y.to(device), t

def sample_crack_boundary(N):
    t = torch.rand(N, 1, device=device, dtype=torch.float64) * (T_MAX - T_MIN) + T_MIN
    x_vals = torch.linspace(0, 1, N, device=device, dtype=torch.float64).unsqueeze(1)
    y_vals = x_vals * alpha(t)
    return x_vals, y_vals, t

def sampling_points(N_f, N_b_crack, N_b_outer):
    x_f, y_f, t_f = sample_collocation(N_f)
    x_b_out, y_b_out, t_b_out = sample_outer_boundary(N_b_outer)
    x_b_crack, y_b_crack, t_b_crack = sample_crack_boundary(N_b_crack)

    x_f = x_f.view(-1,1); y_f = y_f.view(-1,1); t_f = t_f.view(-1,1)
    x_b_out = x_b_out.view(-1,1); y_b_out = y_b_out.view(-1,1); t_b_out = t_b_out.view(-1,1)
    x_b_crack = x_b_crack.view(-1,1); y_b_crack = y_b_crack.view(-1,1); t_b_crack = t_b_crack.view(-1,1)
    
    x_b = torch.cat([x_b_out, x_b_crack])
    y_b = torch.cat([y_b_out, y_b_crack])
    t_b = torch.cat([t_b_out, t_b_crack])

    phi_b, _, _, _, g_b = compute_phi_and_derivs(x_b, y_b, t_b)
    inp_bc = torch.cat([x_b, y_b, phi_b, t_b.detach()], dim=1)

    return x_f, y_f, t_f, x_b_out, y_b_out, t_b_out, x_b_crack, y_b_crack, t_b_crack, inp_bc, g_b 

# simpler phi (for inference / plotting, no grad) 
def compute_phi(x, y, t):
    eps = 1e-12
    x = x.view(-1,1).to(device)
    y = y.view(-1,1).to(device)
    t = t.view(-1,1).to(device)
    a = alpha(t)
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=eps))
    inside = 0.5 * (r - (x * torch.cos(a) + y * torch.sin(a)))
    inside = torch.clamp(inside, min=1e-12)
    u_true = (x + y) * torch.sqrt(inside)
    return torch.sqrt(inside), u_true

# %%
# training points 
x_f, y_f, t_f, x_b_out, y_b_out, t_b_out, x_b_crack, y_b_crack, t_b_crack, inp_bc, g_b = sampling_points(N_f, N_b_crack, N_b_outer)
x_ic_f, y_ic_f, _, x_ic_out, y_ic_out, _, _, _, _, _, _ = sampling_points(N_ic, N_ic_out, N_ic_crack)
x_ic = torch.cat([x_ic_f, x_ic_out]); y_ic = torch.cat([y_ic_f, y_ic_out]); t_ic = torch.zeros_like(x_ic)
phi_ic, _, _, _, g_ic = compute_phi_and_derivs(x_ic, y_ic, t_ic)
inp_ic = torch.cat([x_ic, y_ic, phi_ic, t_ic], dim=1)
(
    x_f_val, y_f_val, t_f_val,
    x_b_out_val, y_b_out_val, t_b_out_val,
    x_b_crack_val, y_b_crack_val, t_b_crack_val,
    inp_bc_val, g_b_val,
) = sampling_points(N_f, N_b_crack, N_b_outer)
x_ic_f_val, y_ic_f_val, _, x_ic_out_val, y_ic_out_val, _, _, _, _, _, _ = sampling_points(N_ic, N_ic_out, N_ic_crack)
x_ic_val = torch.cat([x_ic_f_val, x_ic_out_val]); y_ic_val = torch.cat([y_ic_f_val, y_ic_out_val]); t_ic_val = torch.zeros_like(x_ic_val)
phi_ic_val, _, _, _, g_ic_val = compute_phi_and_derivs(x_ic_val, y_ic_val, t_ic_val)
inp_ic_val = torch.cat([x_ic_val, y_ic_val, phi_ic_val, t_ic_val], dim=1)


print("Start training (time-dependent PINN)")

loss_history = []
val_history = []

for ep in range(epochs):
    def closure():
        optimizer.zero_grad()
        residual_f, _, _, _, _ = compute_residual_time(model, x_f, y_f, t_f)
        loss_pde = torch.mean(residual_f**2)
        u_bc = model(inp_bc)
        loss_bc = torch.mean((u_bc - g_b)**2)
        u_ic_pred = model(inp_ic)
        loss_ic = torch.mean((u_ic_pred - g_ic)**2)
        loss_zz = compute_zz_uN(model, t_b_crack)
        loss_yxz = compute_xyz_uN(model, x_b_crack, y_b_crack, t_b_crack)
        loss = (loss_pde
        + lambda_bc * loss_bc
        + lambda_ic * loss_ic
        + lambda_zz * loss_zz
        + lambda_zz3 * loss_yxz)
        loss.backward()
        return loss

    loss = optimizer.step(closure)
    loss_history.append(loss.item())
        # resampling 
    if ep % 50 == 0 and ep > 0:
        print(f"\n[Resample] epoch {ep}: regenerating PDE/BC/IC points...\n")

        x_f, y_f, t_f, x_b_out, y_b_out, t_b_out, x_b_crack, y_b_crack, t_b_crack, inp_bc, g_b = sampling_points(N_f, N_b_crack, N_b_outer)
        x_ic_f, y_ic_f, _, x_ic_out, y_ic_out, _, _, _, _, _, _ = sampling_points(N_ic, N_ic_out, N_ic_crack)
        x_ic = torch.cat([x_ic_f, x_ic_out], dim=0); y_ic = torch.cat([y_ic_f, y_ic_out], dim=0); t_ic = torch.zeros_like(x_ic)
        phi_ic, _, _, _, g_ic = compute_phi_and_derivs(x_ic, y_ic, t_ic)
        inp_ic = torch.cat([x_ic, y_ic, phi_ic, t_ic], dim=1)    

    if ep % 10 == 0 or ep == epochs-1:
        # validation 
            res_val, _, _, _, _ = compute_residual_time(model, x_f_val, y_f_val, t_f_val)
            loss_pde_val = torch.mean(res_val**2)
            u_bc_val = model(inp_bc_val)
            loss_bc_val = torch.mean((u_bc_val - g_b_val)**2)
            u_ic_pred_val = model(inp_ic_val)
            loss_ic_val = torch.mean((u_ic_pred_val - g_ic_val)**2)
            loss_zz_val = compute_zz_uN(model, t_b_crack_val)
            loss_yxz_val = compute_xyz_uN(model, x_b_crack_val, y_b_crack_val, t_b_crack_val)
            loss_val = (
                loss_pde_val
                + lambda_bc * loss_bc_val
                + lambda_ic * loss_ic_val
                + lambda_zz * loss_zz_val
                + lambda_zz3 * loss_yxz_val)
            val_history.append(loss_val.item())
            # training loss 細項, print 用
            res_f, _, _, _, _ = compute_residual_time(model, x_f, y_f, t_f)
            loss_pde = torch.mean(res_f**2)
            loss_bc = torch.mean((model(inp_bc) - g_b)**2)
            loss_ic = torch.mean((model(inp_ic) - g_ic)**2)
            loss_zz = compute_zz_uN(model, t_b_crack)
            loss_yxz = compute_xyz_uN(model, x_b_crack, y_b_crack, t_b_crack)

            print(
            f"Epoch {ep:4d} | "
            f"TrainLoss={loss.item():.3e} "
            f"(pde={loss_pde:.2e}, bc={loss_bc:.2e}, ic={loss_ic:.2e}, "
            f"zz={loss_zz:.2e}, yxz={loss_yxz:.2e},| "
            f"ValLoss={loss_val.item():.3e} "
            f"(pde={loss_pde_val:.2e}, bc={loss_bc_val:.2e}, ic={loss_ic_val:.2e}, "
            f"zz={loss_zz_val:.2e}, yxz={loss_yxz_val:.2e},)")            

print("Training finished.")
# Out:
# Start training (time-dependent PINN)
# Epoch    0 | TrainLoss=3.880e+00 (pde=1.42e-01, bc=6.10e-02, ic=2.92e-02, zz=7.41e-03, yxz=1.67e-02,| ValLoss=2.542e-01 (pde=1.39e-01, bc=6.20e-02, ic=2.93e-02, zz=7.48e-03, yxz=1.62e-02,)
# Epoch   10 | TrainLoss=3.832e-02 (pde=1.78e-02, bc=1.15e-02, ic=4.49e-03, zz=5.20e-04, yxz=3.06e-03,| ValLoss=3.918e-02 (pde=1.98e-02, bc=1.15e-02, ic=4.36e-03, zz=4.79e-04, yxz=3.03e-03,)
# Epoch   20 | TrainLoss=2.797e-02 (pde=1.13e-02, bc=1.05e-02, ic=3.65e-03, zz=2.25e-04, yxz=1.44e-03,| ValLoss=3.008e-02 (pde=1.44e-02, bc=1.05e-02, ic=3.57e-03, zz=2.12e-04, yxz=1.41e-03,)
# Epoch   30 | TrainLoss=2.114e-02 (pde=8.82e-03, bc=7.62e-03, ic=2.91e-03, zz=2.83e-04, yxz=1.14e-03,| ValLoss=2.673e-02 (pde=1.49e-02, bc=7.58e-03, ic=2.89e-03, zz=2.84e-04, yxz=1.09e-03,)
# Epoch   40 | TrainLoss=1.810e-02 (pde=7.68e-03, bc=6.58e-03, ic=2.38e-03, zz=3.79e-04, yxz=8.19e-04,| ValLoss=2.607e-02 (pde=1.60e-02, bc=6.51e-03, ic=2.39e-03, zz=3.87e-04, yxz=8.19e-04,)
#
# [Resample] epoch 50: regenerating PDE/BC/IC points...
#
# Epoch   50 | TrainLoss=1.517e-02 (pde=1.46e-02, bc=5.58e-03, ic=1.68e-03, zz=1.57e-04, yxz=7.68e-04,| ValLoss=2.559e-02 (pde=1.76e-02, bc=5.35e-03, ic=1.83e-03, zz=1.48e-04, yxz=7.02e-04,)
# Epoch   60 | TrainLoss=1.739e-02 (pde=7.85e-03, bc=5.97e-03, ic=1.84e-03, zz=1.61e-04, yxz=1.30e-03,| ValLoss=2.555e-02 (pde=1.64e-02, bc=5.69e-03, ic=2.05e-03, zz=1.57e-04, yxz=1.25e-03,)
# Epoch   70 | TrainLoss=1.484e-02 (pde=6.52e-03, bc=4.89e-03, ic=1.61e-03, zz=2.14e-04, yxz=1.41e-03,| ValLoss=2.552e-02 (pde=1.75e-02, bc=4.62e-03, ic=1.80e-03, zz=2.08e-04, yxz=1.37e-03,)
# Epoch   80 | TrainLoss=1.287e-02 (pde=5.87e-03, bc=4.27e-03, ic=1.27e-03, zz=1.36e-04, yxz=1.19e-03,| ValLoss=2.613e-02 (pde=1.94e-02, bc=4.01e-03, ic=1.40e-03, zz=1.36e-04, yxz=1.19e-03,)
# Epoch   90 | TrainLoss=1.130e-02 (pde=5.46e-03, bc=3.43e-03, ic=9.06e-04, zz=2.24e-04, yxz=1.06e-03,| ValLoss=2.575e-02 (pde=2.02e-02, bc=3.21e-03, ic=1.00e-03, zz=2.29e-04, yxz=1.09e-03,)
#
# [Resample] epoch 100: regenerating PDE/BC/IC points...
#
# Epoch  100 | TrainLoss=9.955e-03 (pde=2.89e-02, bc=2.95e-03, ic=7.48e-04, zz=2.25e-04, yxz=1.19e-03,| ValLoss=2.570e-02 (pde=2.07e-02, bc=2.86e-03, ic=7.48e-04, zz=2.22e-04, yxz=1.20e-03,)
# Epoch  110 | TrainLoss=1.791e-02 (pde=9.23e-03, bc=5.24e-03, ic=1.33e-03, zz=3.06e-04, yxz=1.42e-03,| ValLoss=2.064e-02 (pde=1.26e-02, bc=5.11e-03, ic=1.33e-03, zz=2.92e-04, yxz=1.35e-03,)
# Epoch  120 | TrainLoss=1.534e-02 (pde=7.03e-03, bc=4.90e-03, ic=1.68e-03, zz=1.58e-04, yxz=1.38e-03,| ValLoss=1.936e-02 (pde=1.14e-02, bc=4.76e-03, ic=1.68e-03, zz=1.50e-04, yxz=1.34e-03,)
# Epoch  130 | TrainLoss=1.363e-02 (pde=6.03e-03, bc=4.34e-03, ic=1.88e-03, zz=2.38e-04, yxz=1.02e-03,| ValLoss=1.805e-02 (pde=1.07e-02, bc=4.17e-03, ic=1.89e-03, zz=2.40e-04, yxz=1.01e-03,)
# Epoch  140 | TrainLoss=1.215e-02 (pde=4.68e-03, bc=4.05e-03, ic=1.92e-03, zz=2.69e-04, yxz=1.12e-03,| ValLoss=1.569e-02 (pde=8.51e-03, bc=3.90e-03, ic=1.93e-03, zz=2.62e-04, yxz=1.09e-03,)
#
# [Resample] epoch 150: regenerating PDE/BC/IC points...
#
# Epoch  150 | TrainLoss=1.086e-02 (pde=7.66e-03, bc=3.46e-03, ic=1.22e-03, zz=2.02e-04, yxz=1.41e-03,| ValLoss=1.618e-02 (pde=9.84e-03, bc=3.53e-03, ic=1.32e-03, zz=2.00e-04, yxz=1.29e-03,)
# Epoch  160 | TrainLoss=9.992e-03 (pde=4.47e-03, bc=3.05e-03, ic=1.01e-03, zz=3.32e-04, yxz=9.04e-04,| ValLoss=1.561e-02 (pde=1.00e-02, bc=3.10e-03, ic=1.08e-03, zz=3.34e-04, yxz=1.09e-03,)
# Epoch  170 | TrainLoss=8.289e-03 (pde=3.66e-03, bc=2.83e-03, ic=7.05e-04, zz=2.37e-04, yxz=7.60e-04,| ValLoss=1.630e-02 (pde=1.14e-02, bc=2.90e-03, ic=7.52e-04, zz=2.40e-04, yxz=9.69e-04,)
# Epoch  180 | TrainLoss=7.104e-03 (pde=2.85e-03, bc=2.55e-03, ic=5.27e-04, zz=2.21e-04, yxz=8.26e-04,| ValLoss=1.624e-02 (pde=1.17e-02, bc=2.65e-03, ic=5.56e-04, zz=2.22e-04, yxz=1.07e-03,)
# Epoch  190 | TrainLoss=6.138e-03 (pde=2.40e-03, bc=2.21e-03, ic=4.81e-04, zz=2.45e-04, yxz=7.24e-04,| ValLoss=1.835e-02 (pde=1.42e-02, bc=2.32e-03, ic=5.07e-04, zz=2.48e-04, yxz=1.03e-03,)
#
# [Resample] epoch 200: regenerating PDE/BC/IC points...
#
# Epoch  200 | TrainLoss=5.540e-03 (pde=1.79e-02, bc=2.13e-03, ic=4.05e-04, zz=1.51e-04, yxz=8.19e-04,| ValLoss=1.949e-02 (pde=1.60e-02, bc=2.11e-03, ic=4.41e-04, zz=1.55e-04, yxz=8.08e-04,)
# Epoch  210 | TrainLoss=9.353e-03 (pde=4.52e-03, bc=3.09e-03, ic=7.39e-04, zz=1.62e-04, yxz=6.83e-04,| ValLoss=1.268e-02 (pde=7.95e-03, bc=3.08e-03, ic=8.07e-04, zz=1.61e-04, yxz=6.77e-04,)
# Epoch  220 | TrainLoss=8.104e-03 (pde=4.14e-03, bc=2.56e-03, ic=5.87e-04, zz=1.37e-04, yxz=5.95e-04,| ValLoss=1.155e-02 (pde=7.61e-03, bc=2.54e-03, ic=6.36e-04, zz=1.40e-04, yxz=6.25e-04,)
# Epoch  230 | TrainLoss=7.410e-03 (pde=3.46e-03, bc=2.60e-03, ic=5.61e-04, zz=1.46e-04, yxz=5.70e-04,| ValLoss=1.032e-02 (pde=6.39e-03, bc=2.57e-03, ic=6.09e-04, zz=1.49e-04, yxz=5.94e-04,)
# Epoch  240 | TrainLoss=6.852e-03 (pde=3.18e-03, bc=2.41e-03, ic=5.56e-04, zz=9.26e-05, yxz=5.51e-04,| ValLoss=1.085e-02 (pde=7.20e-03, bc=2.38e-03, ic=5.92e-04, zz=9.29e-05, yxz=5.82e-04,)
#
# [Resample] epoch 250: regenerating PDE/BC/IC points...
#
# Epoch  250 | TrainLoss=6.248e-03 (pde=7.13e-03, bc=2.40e-03, ic=5.95e-04, zz=6.08e-05, yxz=6.04e-04,| ValLoss=1.188e-02 (pde=8.30e-03, bc=2.31e-03, ic=5.87e-04, zz=6.26e-05, yxz=6.20e-04,)
# Epoch  260 | TrainLoss=6.448e-03 (pde=2.87e-03, bc=2.39e-03, ic=5.22e-04, zz=1.22e-04, yxz=4.56e-04,| ValLoss=1.044e-02 (pde=6.98e-03, bc=2.32e-03, ic=5.14e-04, zz=1.27e-04, yxz=4.94e-04,)
# Epoch  270 | TrainLoss=5.732e-03 (pde=2.42e-03, bc=2.31e-03, ic=4.23e-04, zz=1.12e-04, yxz=3.94e-04,| ValLoss=1.014e-02 (pde=6.95e-03, bc=2.24e-03, ic=4.18e-04, zz=1.16e-04, yxz=4.22e-04,)
# Epoch  280 | TrainLoss=5.182e-03 (pde=2.20e-03, bc=2.12e-03, ic=3.80e-04, zz=8.21e-05, yxz=3.73e-04,| ValLoss=1.053e-02 (pde=7.60e-03, bc=2.05e-03, ic=3.71e-04, zz=8.66e-05, yxz=4.19e-04,)
# Epoch  290 | TrainLoss=4.826e-03 (pde=2.04e-03, bc=1.98e-03, ic=3.65e-04, zz=9.32e-05, yxz=3.09e-04,| ValLoss=9.092e-03 (pde=6.40e-03, bc=1.91e-03, ic=3.55e-04, zz=9.54e-05, yxz=3.36e-04,)
#
# [Resample] epoch 300: regenerating PDE/BC/IC points...
#
# Epoch  300 | TrainLoss=4.462e-03 (pde=2.93e-02, bc=1.81e-03, ic=2.69e-04, zz=8.28e-05, yxz=3.28e-04,| ValLoss=9.036e-03 (pde=6.55e-03, bc=1.79e-03, ic=2.68e-04, zz=9.44e-05, yxz=3.37e-04,)
# Epoch  310 | TrainLoss=6.736e-03 (pde=3.52e-03, bc=2.08e-03, ic=4.31e-04, zz=9.00e-05, yxz=4.49e-04,| ValLoss=8.445e-03 (pde=5.39e-03, bc=2.05e-03, ic=4.42e-04, zz=1.03e-04, yxz=4.61e-04,)
# Epoch  320 | TrainLoss=5.639e-03 (pde=2.71e-03, bc=1.90e-03, ic=3.80e-04, zz=8.59e-05, yxz=4.97e-04,| ValLoss=1.067e-02 (pde=7.80e-03, bc=1.88e-03, ic=3.89e-04, zz=9.68e-05, yxz=5.07e-04,)
# Epoch  330 | TrainLoss=5.090e-03 (pde=2.37e-03, bc=1.84e-03, ic=2.93e-04, zz=1.02e-04, yxz=4.37e-04,| ValLoss=1.161e-02 (pde=8.95e-03, bc=1.80e-03, ic=2.96e-04, zz=1.16e-04, yxz=4.44e-04,)
# Epoch  340 | TrainLoss=4.719e-03 (pde=2.10e-03, bc=1.77e-03, ic=2.58e-04, zz=8.52e-05, yxz=4.85e-04,| ValLoss=1.216e-02 (pde=9.57e-03, bc=1.74e-03, ic=2.55e-04, zz=9.78e-05, yxz=5.01e-04,)
#
# [Resample] epoch 350: regenerating PDE/BC/IC points...
#
# Epoch  350 | TrainLoss=4.426e-03 (pde=1.02e-02, bc=1.68e-03, ic=2.58e-04, zz=9.34e-05, yxz=4.25e-04,| ValLoss=1.287e-02 (pde=1.04e-02, bc=1.69e-03, ic=2.56e-04, zz=9.10e-05, yxz=4.55e-04,)
# Epoch  360 | TrainLoss=4.598e-03 (pde=2.13e-03, bc=1.77e-03, ic=2.34e-04, zz=9.50e-05, yxz=3.15e-04,| ValLoss=1.164e-02 (pde=9.22e-03, bc=1.77e-03, ic=2.31e-04, zz=9.46e-05, yxz=3.30e-04,)
# Epoch  370 | TrainLoss=4.044e-03 (pde=1.72e-03, bc=1.65e-03, ic=2.08e-04, zz=8.12e-05, yxz=3.45e-04,| ValLoss=1.191e-02 (pde=9.62e-03, bc=1.64e-03, ic=2.06e-04, zz=8.00e-05, yxz=3.62e-04,)
# Epoch  380 | TrainLoss=3.638e-03 (pde=1.36e-03, bc=1.59e-03, ic=1.97e-04, zz=6.29e-05, yxz=3.86e-04,| ValLoss=1.201e-02 (pde=9.75e-03, bc=1.59e-03, ic=1.93e-04, zz=6.36e-05, yxz=4.15e-04,)
# Epoch  390 | TrainLoss=3.299e-03 (pde=1.14e-03, bc=1.51e-03, ic=1.95e-04, zz=4.60e-05, yxz=3.84e-04,| ValLoss=1.244e-02 (pde=1.03e-02, bc=1.51e-03, ic=1.91e-04, zz=4.58e-05, yxz=4.02e-04,)
#
# [Resample] epoch 400: regenerating PDE/BC/IC points...
#
# Epoch  400 | TrainLoss=3.108e-03 (pde=3.20e-02, bc=1.53e-03, ic=1.73e-04, zz=3.81e-05, yxz=3.82e-04,| ValLoss=1.272e-02 (pde=1.07e-02, bc=1.46e-03, ic=1.73e-04, zz=3.81e-05, yxz=3.63e-04,)
# Epoch  410 | TrainLoss=5.570e-03 (pde=2.75e-03, bc=1.92e-03, ic=2.52e-04, zz=6.81e-05, yxz=4.66e-04,| ValLoss=6.914e-03 (pde=4.31e-03, bc=1.82e-03, ic=2.62e-04, zz=6.38e-05, yxz=4.50e-04,)
# Epoch  420 | TrainLoss=4.788e-03 (pde=2.27e-03, bc=1.78e-03, ic=2.68e-04, zz=4.10e-05, yxz=3.90e-04,| ValLoss=7.397e-03 (pde=5.00e-03, bc=1.69e-03, ic=2.79e-04, zz=3.98e-05, yxz=3.87e-04,)
# Epoch  430 | TrainLoss=4.360e-03 (pde=1.95e-03, bc=1.76e-03, ic=2.07e-04, zz=3.98e-05, yxz=3.39e-04,| ValLoss=7.708e-03 (pde=5.43e-03, bc=1.69e-03, ic=2.14e-04, zz=3.95e-05, yxz=3.34e-04,)
# Epoch  440 | TrainLoss=4.041e-03 (pde=1.82e-03, bc=1.62e-03, ic=1.96e-04, zz=4.46e-05, yxz=3.37e-04,| ValLoss=8.240e-03 (pde=6.10e-03, bc=1.56e-03, ic=2.00e-04, zz=4.50e-05, yxz=3.32e-04,)
#
# [Resample] epoch 450: regenerating PDE/BC/IC points...
#
# Epoch  450 | TrainLoss=3.833e-03 (pde=1.43e-02, bc=1.51e-03, ic=1.69e-04, zz=4.47e-05, yxz=2.81e-04,| ValLoss=8.689e-03 (pde=6.63e-03, bc=1.57e-03, ic=1.68e-04, zz=4.82e-05, yxz=2.74e-04,)
# Epoch  460 | TrainLoss=4.748e-03 (pde=2.39e-03, bc=1.61e-03, ic=1.99e-04, zz=6.71e-05, yxz=3.79e-04,| ValLoss=1.260e-02 (pde=1.03e-02, bc=1.67e-03, ic=1.99e-04, zz=7.23e-05, yxz=3.93e-04,)
# Epoch  470 | TrainLoss=3.953e-03 (pde=1.71e-03, bc=1.53e-03, ic=2.00e-04, zz=6.23e-05, yxz=4.04e-04,| ValLoss=1.320e-02 (pde=1.09e-02, bc=1.55e-03, ic=1.99e-04, zz=6.81e-05, yxz=4.95e-04,)
# Epoch  480 | TrainLoss=3.502e-03 (pde=1.47e-03, bc=1.40e-03, ic=1.51e-04, zz=7.20e-05, yxz=3.85e-04,| ValLoss=1.425e-02 (pde=1.21e-02, bc=1.42e-03, ic=1.52e-04, zz=7.87e-05, yxz=4.81e-04,)
# Epoch  490 | TrainLoss=3.207e-03 (pde=1.29e-03, bc=1.35e-03, ic=1.60e-04, zz=4.94e-05, yxz=3.31e-04,| ValLoss=1.490e-02 (pde=1.29e-02, bc=1.37e-03, ic=1.63e-04, zz=5.38e-05, yxz=3.97e-04,)
#
# [Resample] epoch 500: regenerating PDE/BC/IC points...
#
# Epoch  500 | TrainLoss=3.045e-03 (pde=1.72e-02, bc=1.42e-03, ic=1.49e-04, zz=5.33e-05, yxz=4.01e-04,| ValLoss=1.539e-02 (pde=1.35e-02, bc=1.36e-03, ic=1.53e-04, zz=5.43e-05, yxz=3.57e-04,)
# Epoch  510 | TrainLoss=5.271e-03 (pde=2.70e-03, bc=1.80e-03, ic=2.96e-04, zz=4.46e-05, yxz=3.37e-04,| ValLoss=8.290e-03 (pde=5.85e-03, bc=1.73e-03, ic=3.06e-04, zz=4.53e-05, yxz=3.55e-04,)
# Epoch  520 | TrainLoss=4.673e-03 (pde=2.25e-03, bc=1.77e-03, ic=2.20e-04, zz=4.33e-05, yxz=3.38e-04,| ValLoss=8.120e-03 (pde=5.78e-03, bc=1.72e-03, ic=2.34e-04, zz=4.32e-05, yxz=3.46e-04,)
# Epoch  530 | TrainLoss=4.254e-03 (pde=1.88e-03, bc=1.68e-03, ic=2.58e-04, zz=4.38e-05, yxz=3.61e-04,| ValLoss=7.912e-03 (pde=5.58e-03, bc=1.63e-03, ic=2.72e-04, zz=4.29e-05, yxz=3.82e-04,)
# Epoch  540 | TrainLoss=3.920e-03 (pde=1.77e-03, bc=1.57e-03, ic=1.53e-04, zz=5.18e-05, yxz=3.48e-04,| ValLoss=8.050e-03 (pde=5.97e-03, bc=1.51e-03, ic=1.60e-04, zz=5.14e-05, yxz=3.54e-04,)
#
# [Resample] epoch 550: regenerating PDE/BC/IC points...
#
# Epoch  550 | TrainLoss=3.605e-03 (pde=1.01e-02, bc=1.45e-03, ic=1.48e-04, zz=5.15e-05, yxz=3.99e-04,| ValLoss=8.199e-03 (pde=6.21e-03, bc=1.42e-03, ic=1.42e-04, zz=5.25e-05, yxz=3.78e-04,)
# Epoch  560 | TrainLoss=4.931e-03 (pde=2.46e-03, bc=1.75e-03, ic=1.96e-04, zz=5.33e-05, yxz=3.80e-04,| ValLoss=1.213e-02 (pde=9.78e-03, bc=1.72e-03, ic=2.01e-04, zz=5.66e-05, yxz=3.79e-04,)
# Epoch  570 | TrainLoss=4.054e-03 (pde=1.88e-03, bc=1.51e-03, ic=2.06e-04, zz=6.46e-05, yxz=3.31e-04,| ValLoss=1.774e-02 (pde=1.56e-02, bc=1.50e-03, ic=2.07e-04, zz=7.03e-05, yxz=3.22e-04,)
# Epoch  580 | TrainLoss=3.605e-03 (pde=1.66e-03, bc=1.41e-03, ic=1.78e-04, zz=4.12e-05, yxz=2.81e-04,| ValLoss=2.222e-02 (pde=2.03e-02, bc=1.40e-03, ic=1.72e-04, zz=4.40e-05, yxz=2.80e-04,)
# Epoch  590 | TrainLoss=3.324e-03 (pde=1.45e-03, bc=1.39e-03, ic=1.61e-04, zz=5.18e-05, yxz=2.40e-04,| ValLoss=2.703e-02 (pde=2.52e-02, bc=1.37e-03, ic=1.57e-04, zz=5.62e-05, yxz=2.48e-04,)
#
# [Resample] epoch 600: regenerating PDE/BC/IC points...
#
# Epoch  600 | TrainLoss=3.108e-03 (pde=2.14e-02, bc=1.41e-03, ic=1.39e-04, zz=4.50e-05, yxz=2.29e-04,| ValLoss=2.713e-02 (pde=2.53e-02, bc=1.35e-03, ic=1.47e-04, zz=4.85e-05, yxz=2.47e-04,)
# Epoch  610 | TrainLoss=4.577e-03 (pde=2.16e-03, bc=1.74e-03, ic=1.63e-04, zz=5.02e-05, yxz=3.05e-04,| ValLoss=9.437e-03 (pde=7.23e-03, bc=1.66e-03, ic=1.63e-04, zz=5.46e-05, yxz=3.28e-04,)
# Epoch  620 | TrainLoss=3.822e-03 (pde=1.69e-03, bc=1.56e-03, ic=1.79e-04, zz=4.86e-05, yxz=3.13e-04,| ValLoss=8.266e-03 (pde=6.21e-03, bc=1.49e-03, ic=1.79e-04, zz=5.22e-05, yxz=3.34e-04,)
# Epoch  630 | TrainLoss=3.446e-03 (pde=1.39e-03, bc=1.51e-03, ic=1.32e-04, zz=5.10e-05, yxz=3.29e-04,| ValLoss=8.623e-03 (pde=6.64e-03, bc=1.45e-03, ic=1.31e-04, zz=5.44e-05, yxz=3.48e-04,)
# Epoch  640 | TrainLoss=3.125e-03 (pde=1.17e-03, bc=1.42e-03, ic=1.22e-04, zz=4.63e-05, yxz=3.43e-04,| ValLoss=9.281e-03 (pde=7.39e-03, bc=1.37e-03, ic=1.21e-04, zz=4.94e-05, yxz=3.60e-04,)
#
# [Resample] epoch 650: regenerating PDE/BC/IC points...
#
# Epoch  650 | TrainLoss=2.924e-03 (pde=9.23e-03, bc=1.31e-03, ic=1.43e-04, zz=5.44e-05, yxz=3.62e-04,| ValLoss=9.480e-03 (pde=7.64e-03, bc=1.31e-03, ic=1.33e-04, zz=5.23e-05, yxz=3.45e-04,)
# Epoch  660 | TrainLoss=5.843e-03 (pde=3.35e-03, bc=1.71e-03, ic=2.13e-04, zz=3.59e-05, yxz=4.33e-04,| ValLoss=6.681e-03 (pde=4.32e-03, bc=1.70e-03, ic=2.08e-04, zz=3.59e-05, yxz=4.26e-04,)
# Epoch  670 | TrainLoss=5.026e-03 (pde=2.83e-03, bc=1.51e-03, ic=1.90e-04, zz=4.31e-05, yxz=3.84e-04,| ValLoss=7.042e-03 (pde=4.93e-03, bc=1.50e-03, ic=1.90e-04, zz=4.38e-05, yxz=3.76e-04,)
# Epoch  680 | TrainLoss=4.447e-03 (pde=2.40e-03, bc=1.44e-03, ic=1.69e-04, zz=5.42e-05, yxz=3.48e-04,| ValLoss=7.865e-03 (pde=5.86e-03, bc=1.43e-03, ic=1.70e-04, zz=5.43e-05, yxz=3.45e-04,)
# Epoch  690 | TrainLoss=4.031e-03 (pde=1.98e-03, bc=1.37e-03, ic=1.90e-04, zz=5.80e-05, yxz=3.93e-04,| ValLoss=8.858e-03 (pde=6.86e-03, bc=1.36e-03, ic=1.94e-04, zz=5.72e-05, yxz=3.88e-04,)
#
# [Resample] epoch 700: regenerating PDE/BC/IC points...
#
# Epoch  700 | TrainLoss=3.761e-03 (pde=2.60e-01, bc=1.38e-03, ic=1.51e-04, zz=6.02e-05, yxz=3.85e-04,| ValLoss=9.052e-03 (pde=7.10e-03, bc=1.34e-03, ic=1.77e-04, zz=5.89e-05, yxz=3.75e-04,)
# Epoch  710 | TrainLoss=3.301e-03 (pde=1.26e-03, bc=1.39e-03, ic=1.55e-04, zz=6.87e-05, yxz=3.45e-04,| ValLoss=7.695e-03 (pde=5.75e-03, bc=1.37e-03, ic=1.60e-04, zz=6.81e-05, yxz=3.53e-04,)
# Epoch  720 | TrainLoss=2.671e-03 (pde=9.22e-04, bc=1.32e-03, ic=1.19e-04, zz=3.40e-05, yxz=2.54e-04,| ValLoss=1.100e-02 (pde=9.30e-03, bc=1.30e-03, ic=1.19e-04, zz=3.33e-05, yxz=2.57e-04,)
# Epoch  730 | TrainLoss=2.494e-03 (pde=8.11e-04, bc=1.30e-03, ic=1.07e-04, zz=3.05e-05, yxz=2.38e-04,| ValLoss=1.277e-02 (pde=1.11e-02, bc=1.27e-03, ic=1.08e-04, zz=2.99e-05, yxz=2.48e-04,)
# Epoch  740 | TrainLoss=2.358e-03 (pde=7.27e-04, bc=1.27e-03, ic=1.05e-04, zz=2.84e-05, yxz=2.14e-04,| ValLoss=1.433e-02 (pde=1.27e-02, bc=1.24e-03, ic=1.06e-04, zz=2.80e-05, yxz=2.20e-04,)
#
# [Resample] epoch 750: regenerating PDE/BC/IC points...
#
# Epoch  750 | TrainLoss=2.266e-03 (pde=2.30e-03, bc=1.25e-03, ic=1.01e-04, zz=2.86e-05, yxz=1.99e-04,| ValLoss=1.553e-02 (pde=1.40e-02, bc=1.21e-03, ic=9.40e-05, zz=2.90e-05, yxz=1.93e-04,)
# Epoch  760 | TrainLoss=2.568e-03 (pde=9.89e-04, bc=1.24e-03, ic=1.07e-04, zz=2.74e-05, yxz=1.76e-04,| ValLoss=1.440e-02 (pde=1.29e-02, bc=1.21e-03, ic=1.00e-04, zz=2.88e-05, yxz=1.90e-04,)
# Epoch  770 | TrainLoss=2.372e-03 (pde=8.33e-04, bc=1.23e-03, ic=1.11e-04, zz=2.36e-05, yxz=1.59e-04,| ValLoss=1.481e-02 (pde=1.33e-02, bc=1.20e-03, ic=1.04e-04, zz=2.47e-05, yxz=1.75e-04,)
# Epoch  780 | TrainLoss=2.195e-03 (pde=6.62e-04, bc=1.22e-03, ic=1.02e-04, zz=2.17e-05, yxz=1.66e-04,| ValLoss=1.503e-02 (pde=1.35e-02, bc=1.20e-03, ic=9.51e-05, zz=2.27e-05, yxz=1.86e-04,)
# Epoch  790 | TrainLoss=2.073e-03 (pde=6.00e-04, bc=1.21e-03, ic=1.02e-04, zz=1.73e-05, yxz=1.43e-04,| ValLoss=1.708e-02 (pde=1.56e-02, bc=1.18e-03, ic=9.46e-05, zz=1.84e-05, yxz=1.64e-04,)
#
# [Resample] epoch 800: regenerating PDE/BC/IC points...
#
# Epoch  800 | TrainLoss=1.988e-03 (pde=2.62e-02, bc=1.18e-03, ic=9.10e-05, zz=1.45e-05, yxz=1.48e-04,| ValLoss=2.028e-02 (pde=1.89e-02, bc=1.15e-03, ic=8.88e-05, zz=1.54e-05, yxz=1.55e-04,)
# Epoch  810 | TrainLoss=6.192e-03 (pde=3.51e-03, bc=1.72e-03, ic=1.68e-04, zz=7.59e-05, yxz=5.71e-04,| ValLoss=9.196e-03 (pde=6.65e-03, bc=1.69e-03, ic=1.63e-04, zz=7.93e-05, yxz=6.06e-04,)
# Epoch  820 | TrainLoss=5.355e-03 (pde=3.05e-03, bc=1.50e-03, ic=1.57e-04, zz=4.16e-05, yxz=5.74e-04,| ValLoss=9.658e-03 (pde=7.32e-03, bc=1.49e-03, ic=1.50e-04, zz=4.30e-05, yxz=6.52e-04,)
# Epoch  830 | TrainLoss=4.907e-03 (pde=2.62e-03, bc=1.46e-03, ic=1.93e-04, zz=3.97e-05, yxz=5.63e-04,| ValLoss=9.709e-03 (pde=7.39e-03, bc=1.46e-03, ic=1.82e-04, zz=4.14e-05, yxz=6.28e-04,)
# Epoch  840 | TrainLoss=4.518e-03 (pde=2.28e-03, bc=1.37e-03, ic=1.76e-04, zz=4.57e-05, yxz=6.13e-04,| ValLoss=1.070e-02 (pde=8.40e-03, bc=1.38e-03, ic=1.71e-04, zz=4.68e-05, yxz=6.96e-04,)
#
# [Resample] epoch 850: regenerating PDE/BC/IC points...
#
# Epoch  850 | TrainLoss=4.206e-03 (pde=9.82e-03, bc=1.46e-03, ic=1.62e-04, zz=9.14e-05, yxz=6.71e-04,| ValLoss=1.045e-02 (pde=8.10e-03, bc=1.39e-03, ic=1.59e-04, zz=9.27e-05, yxz=7.05e-04,)
# Epoch  860 | TrainLoss=5.417e-03 (pde=2.97e-03, bc=1.56e-03, ic=2.37e-04, zz=7.66e-05, yxz=4.16e-04,| ValLoss=8.885e-03 (pde=6.64e-03, bc=1.47e-03, ic=2.36e-04, zz=8.54e-05, yxz=4.52e-04,)
# Epoch  870 | TrainLoss=4.562e-03 (pde=2.36e-03, bc=1.58e-03, ic=1.89e-04, zz=5.27e-05, yxz=3.35e-04,| ValLoss=7.950e-03 (pde=5.83e-03, bc=1.50e-03, ic=1.90e-04, zz=5.95e-05, yxz=3.67e-04,)
# Epoch  880 | TrainLoss=4.202e-03 (pde=1.99e-03, bc=1.55e-03, ic=1.93e-04, zz=6.29e-05, yxz=3.76e-04,| ValLoss=8.743e-03 (pde=6.61e-03, bc=1.46e-03, ic=1.96e-04, zz=6.82e-05, yxz=4.07e-04,)
# Epoch  890 | TrainLoss=3.950e-03 (pde=1.78e-03, bc=1.53e-03, ic=1.98e-04, zz=6.44e-05, yxz=3.59e-04,| ValLoss=8.652e-03 (pde=6.55e-03, bc=1.44e-03, ic=2.00e-04, zz=7.29e-05, yxz=3.91e-04,)
#
# [Resample] epoch 900: regenerating PDE/BC/IC points...
#
# Epoch  900 | TrainLoss=3.606e-03 (pde=5.99e-02, bc=1.43e-03, ic=1.50e-04, zz=4.71e-05, yxz=3.71e-04,| ValLoss=7.889e-03 (pde=5.91e-03, bc=1.42e-03, ic=1.46e-04, zz=4.84e-05, yxz=3.56e-04,)
# Epoch  910 | TrainLoss=3.019e-03 (pde=1.11e-03, bc=1.37e-03, ic=1.25e-04, zz=4.70e-05, yxz=2.61e-04,| ValLoss=6.907e-03 (pde=5.09e-03, bc=1.39e-03, ic=1.16e-04, zz=4.83e-05, yxz=2.64e-04,)
# Epoch  920 | TrainLoss=2.448e-03 (pde=7.55e-04, bc=1.30e-03, ic=1.33e-04, zz=3.31e-05, yxz=2.01e-04,| ValLoss=7.939e-03 (pde=6.26e-03, bc=1.30e-03, ic=1.26e-04, zz=3.26e-05, yxz=2.19e-04,)
# Epoch  930 | TrainLoss=2.253e-03 (pde=6.64e-04, bc=1.25e-03, ic=1.11e-04, zz=3.16e-05, yxz=1.86e-04,| ValLoss=9.078e-03 (pde=7.48e-03, bc=1.25e-03, ic=1.06e-04, zz=3.07e-05, yxz=2.12e-04,)
# Epoch  940 | TrainLoss=2.141e-03 (pde=6.05e-04, bc=1.19e-03, ic=1.11e-04, zz=4.09e-05, yxz=1.79e-04,| ValLoss=9.695e-03 (pde=8.14e-03, bc=1.19e-03, ic=1.07e-04, zz=4.10e-05, yxz=2.24e-04,)
#
# [Resample] epoch 950: regenerating PDE/BC/IC points...
#
# Epoch  950 | TrainLoss=2.025e-03 (pde=1.92e-02, bc=1.18e-03, ic=8.49e-05, zz=3.47e-05, yxz=2.49e-04,| ValLoss=1.050e-02 (pde=8.98e-03, bc=1.16e-03, ic=8.47e-05, zz=3.66e-05, yxz=2.40e-04,)
# Epoch  960 | TrainLoss=2.761e-03 (pde=1.02e-03, bc=1.31e-03, ic=1.08e-04, zz=5.11e-05, yxz=2.25e-04,| ValLoss=1.305e-02 (pde=1.14e-02, bc=1.29e-03, ic=1.05e-04, zz=5.38e-05, yxz=2.40e-04,)
# Epoch  970 | TrainLoss=2.460e-03 (pde=8.14e-04, bc=1.24e-03, ic=1.20e-04, zz=6.69e-05, yxz=1.99e-04,| ValLoss=1.395e-02 (pde=1.23e-02, bc=1.22e-03, ic=1.17e-04, zz=6.97e-05, yxz=2.15e-04,)
# Epoch  980 | TrainLoss=2.310e-03 (pde=6.88e-04, bc=1.24e-03, ic=1.23e-04, zz=4.82e-05, yxz=2.00e-04,| ValLoss=1.400e-02 (pde=1.24e-02, bc=1.22e-03, ic=1.20e-04, zz=5.19e-05, yxz=2.11e-04,)
# Epoch  990 | TrainLoss=2.172e-03 (pde=6.22e-04, bc=1.22e-03, ic=9.70e-05, zz=4.27e-05, yxz=1.76e-04,| ValLoss=1.404e-02 (pde=1.25e-02, bc=1.20e-03, ic=9.47e-05, zz=4.52e-05, yxz=1.83e-04,)
#
# [Resample] epoch 1000: regenerating PDE/BC/IC points...
#
# Epoch 1000 | TrainLoss=2.076e-03 (pde=6.43e-03, bc=1.17e-03, ic=1.04e-04, zz=3.82e-05, yxz=1.69e-04,| ValLoss=1.472e-02 (pde=1.32e-02, bc=1.17e-03, ic=1.01e-04, zz=3.98e-05, yxz=1.67e-04,)
# Epoch 1010 | TrainLoss=4.677e-03 (pde=2.50e-03, bc=1.45e-03, ic=1.62e-04, zz=7.80e-05, yxz=3.97e-04,| ValLoss=9.958e-03 (pde=7.84e-03, bc=1.45e-03, ic=1.60e-04, zz=7.95e-05, yxz=4.30e-04,)
# Epoch 1020 | TrainLoss=4.162e-03 (pde=2.14e-03, bc=1.38e-03, ic=1.28e-04, zz=8.23e-05, yxz=4.09e-04,| ValLoss=9.985e-03 (pde=7.97e-03, bc=1.38e-03, ic=1.28e-04, zz=8.43e-05, yxz=4.24e-04,)
# Epoch 1030 | TrainLoss=3.915e-03 (pde=1.91e-03, bc=1.34e-03, ic=1.53e-04, zz=9.16e-05, yxz=3.94e-04,| ValLoss=9.922e-03 (pde=7.91e-03, bc=1.35e-03, ic=1.53e-04, zz=9.47e-05, yxz=4.17e-04,)
# Epoch 1040 | TrainLoss=3.691e-03 (pde=1.76e-03, bc=1.27e-03, ic=1.63e-04, zz=9.86e-05, yxz=3.76e-04,| ValLoss=1.096e-02 (pde=9.00e-03, bc=1.27e-03, ic=1.65e-04, zz=1.01e-04, yxz=4.18e-04,)
#
# [Resample] epoch 1050: regenerating PDE/BC/IC points...
#
# Epoch 1050 | TrainLoss=3.459e-03 (pde=1.10e-02, bc=1.32e-03, ic=1.31e-04, zz=8.48e-05, yxz=4.02e-04,| ValLoss=1.154e-02 (pde=9.65e-03, bc=1.24e-03, ic=1.31e-04, zz=8.43e-05, yxz=4.35e-04,)
# Epoch 1060 | TrainLoss=7.160e-03 (pde=4.48e-03, bc=1.76e-03, ic=2.38e-04, zz=2.16e-04, yxz=3.71e-04,| ValLoss=8.249e-03 (pde=5.75e-03, bc=1.66e-03, ic=2.37e-04, zz=2.14e-04, yxz=3.87e-04,)
# Epoch 1070 | TrainLoss=6.267e-03 (pde=3.65e-03, bc=1.73e-03, ic=2.95e-04, zz=1.90e-04, yxz=3.58e-04,| ValLoss=8.724e-03 (pde=6.22e-03, bc=1.65e-03, ic=2.94e-04, zz=1.95e-04, yxz=3.68e-04,)
# Epoch 1080 | TrainLoss=5.869e-03 (pde=3.39e-03, bc=1.65e-03, ic=2.62e-04, zz=2.01e-04, yxz=3.31e-04,| ValLoss=1.113e-02 (pde=8.74e-03, bc=1.57e-03, ic=2.68e-04, zz=2.05e-04, yxz=3.45e-04,)
# Epoch 1090 | TrainLoss=5.581e-03 (pde=3.10e-03, bc=1.67e-03, ic=2.85e-04, zz=1.43e-04, yxz=3.54e-04,| ValLoss=1.123e-02 (pde=8.83e-03, bc=1.59e-03, ic=2.89e-04, zz=1.46e-04, yxz=3.72e-04,)
#
# [Resample] epoch 1100: regenerating PDE/BC/IC points...
#
# Epoch 1100 | TrainLoss=5.325e-03 (pde=1.07e-02, bc=1.74e-03, ic=2.46e-04, zz=9.55e-05, yxz=3.36e-04,| ValLoss=1.163e-02 (pde=9.32e-03, bc=1.62e-03, ic=2.51e-04, zz=9.73e-05, yxz=3.35e-04,)
# Epoch 1110 | TrainLoss=6.140e-03 (pde=3.64e-03, bc=1.68e-03, ic=1.89e-04, zz=1.00e-04, yxz=3.92e-04,| ValLoss=8.838e-03 (pde=6.51e-03, bc=1.57e-03, ic=1.90e-04, zz=9.88e-05, yxz=4.76e-04,)
# Epoch 1120 | TrainLoss=5.065e-03 (pde=2.75e-03, bc=1.55e-03, ic=2.37e-04, zz=7.63e-05, yxz=3.71e-04,| ValLoss=9.248e-03 (pde=7.07e-03, bc=1.44e-03, ic=2.37e-04, zz=7.75e-05, yxz=4.22e-04,)
# Epoch 1130 | TrainLoss=4.422e-03 (pde=2.34e-03, bc=1.46e-03, ic=1.73e-04, zz=4.82e-05, yxz=3.64e-04,| ValLoss=9.168e-03 (pde=7.15e-03, bc=1.36e-03, ic=1.74e-04, zz=4.85e-05, yxz=4.30e-04,)
# Epoch 1140 | TrainLoss=4.086e-03 (pde=2.11e-03, bc=1.38e-03, ic=1.80e-04, zz=4.72e-05, yxz=3.44e-04,| ValLoss=1.000e-02 (pde=8.02e-03, bc=1.30e-03, ic=1.82e-04, zz=4.79e-05, yxz=4.59e-04,)
#
# [Resample] epoch 1150: regenerating PDE/BC/IC points...
#
# Epoch 1150 | TrainLoss=3.753e-03 (pde=2.99e-02, bc=1.24e-03, ic=1.96e-04, zz=5.52e-05, yxz=3.16e-04,| ValLoss=9.659e-03 (pde=7.79e-03, bc=1.23e-03, ic=1.94e-04, zz=5.35e-05, yxz=3.89e-04,)
# Epoch 1160 | TrainLoss=3.080e-03 (pde=1.23e-03, bc=1.31e-03, ic=1.81e-04, zz=3.67e-05, yxz=2.63e-04,| ValLoss=7.577e-03 (pde=5.77e-03, bc=1.32e-03, ic=1.81e-04, zz=3.44e-05, yxz=2.80e-04,)
# Epoch 1170 | TrainLoss=2.601e-03 (pde=9.07e-04, bc=1.28e-03, ic=1.67e-04, zz=3.67e-05, yxz=1.92e-04,| ValLoss=8.194e-03 (pde=6.50e-03, bc=1.28e-03, ic=1.65e-04, zz=3.64e-05, yxz=2.15e-04,)
# Epoch 1180 | TrainLoss=2.430e-03 (pde=8.37e-04, bc=1.24e-03, ic=1.43e-04, zz=3.02e-05, yxz=1.67e-04,| ValLoss=8.802e-03 (pde=7.21e-03, bc=1.24e-03, ic=1.39e-04, zz=2.90e-05, yxz=1.88e-04,)
# Epoch 1190 | TrainLoss=2.306e-03 (pde=7.45e-04, bc=1.21e-03, ic=1.39e-04, zz=3.03e-05, yxz=1.75e-04,| ValLoss=9.014e-03 (pde=7.46e-03, bc=1.20e-03, ic=1.32e-04, zz=2.97e-05, yxz=1.92e-04,)
#
# [Resample] epoch 1200: regenerating PDE/BC/IC points...
#
# Epoch 1200 | TrainLoss=2.221e-03 (pde=5.25e-03, bc=1.21e-03, ic=1.13e-04, zz=3.12e-05, yxz=1.90e-04,| ValLoss=9.444e-03 (pde=7.92e-03, bc=1.17e-03, ic=1.12e-04, zz=3.41e-05, yxz=2.07e-04,)
# Epoch 1210 | TrainLoss=3.354e-03 (pde=1.40e-03, bc=1.40e-03, ic=2.07e-04, zz=2.86e-05, yxz=2.28e-04,| ValLoss=8.389e-03 (pde=6.53e-03, bc=1.37e-03, ic=2.07e-04, zz=3.51e-05, yxz=2.51e-04,)
# Epoch 1220 | TrainLoss=2.864e-03 (pde=1.17e-03, bc=1.30e-03, ic=1.70e-04, zz=2.98e-05, yxz=1.77e-04,| ValLoss=9.177e-03 (pde=7.50e-03, bc=1.28e-03, ic=1.70e-04, zz=3.32e-05, yxz=2.00e-04,)
# Epoch 1230 | TrainLoss=2.675e-03 (pde=1.09e-03, bc=1.26e-03, ic=1.41e-04, zz=1.73e-05, yxz=1.46e-04,| ValLoss=1.011e-02 (pde=8.54e-03, bc=1.23e-03, ic=1.39e-04, zz=2.17e-05, yxz=1.67e-04,)
# Epoch 1240 | TrainLoss=2.482e-03 (pde=9.60e-04, bc=1.24e-03, ic=1.12e-04, zz=1.97e-05, yxz=1.34e-04,| ValLoss=1.042e-02 (pde=8.90e-03, bc=1.22e-03, ic=1.10e-04, zz=2.57e-05, yxz=1.66e-04,)
#
# [Resample] epoch 1250: regenerating PDE/BC/IC points...
#
# Epoch 1250 | TrainLoss=2.355e-03 (pde=1.04e-01, bc=1.23e-03, ic=1.15e-04, zz=3.13e-05, yxz=1.57e-04,| ValLoss=1.115e-02 (pde=9.66e-03, bc=1.17e-03, ic=1.12e-04, zz=3.32e-05, yxz=1.72e-04,)
# Epoch 1260 | TrainLoss=7.747e-03 (pde=4.69e-03, bc=1.84e-03, ic=2.80e-04, zz=1.41e-04, yxz=5.87e-04,| ValLoss=6.874e-03 (pde=4.09e-03, bc=1.78e-03, ic=2.75e-04, zz=1.39e-04, yxz=5.91e-04,)
# Epoch 1270 | TrainLoss=6.174e-03 (pde=3.50e-03, bc=1.76e-03, ic=2.61e-04, zz=6.12e-05, yxz=5.07e-04,| ValLoss=7.058e-03 (pde=4.51e-03, bc=1.71e-03, ic=2.65e-04, zz=6.04e-05, yxz=5.14e-04,)
# Epoch 1280 | TrainLoss=5.348e-03 (pde=2.82e-03, bc=1.61e-03, ic=3.07e-04, zz=5.06e-05, yxz=5.00e-04,| ValLoss=8.101e-03 (pde=5.65e-03, bc=1.57e-03, ic=3.12e-04, zz=5.16e-05, yxz=5.16e-04,)
# Epoch 1290 | TrainLoss=4.705e-03 (pde=2.36e-03, bc=1.61e-03, ic=2.66e-04, zz=4.02e-05, yxz=3.79e-04,| ValLoss=7.984e-03 (pde=5.69e-03, bc=1.55e-03, ic=2.68e-04, zz=4.07e-05, yxz=4.26e-04,)
#
# [Resample] epoch 1300: regenerating PDE/BC/IC points...
#
# Epoch 1300 | TrainLoss=4.314e-03 (pde=8.16e-03, bc=1.59e-03, ic=2.18e-04, zz=3.97e-05, yxz=4.20e-04,| ValLoss=9.005e-03 (pde=6.71e-03, bc=1.55e-03, ic=2.20e-04, zz=4.03e-05, yxz=4.89e-04,)
# Epoch 1310 | TrainLoss=3.790e-03 (pde=1.67e-03, bc=1.46e-03, ic=2.52e-04, zz=4.19e-05, yxz=2.50e-04,| ValLoss=9.307e-03 (pde=7.30e-03, bc=1.45e-03, ic=2.51e-04, zz=4.70e-05, yxz=2.61e-04,)
# Epoch 1320 | TrainLoss=2.995e-03 (pde=1.07e-03, bc=1.37e-03, ic=2.30e-04, zz=6.45e-05, yxz=2.23e-04,| ValLoss=1.073e-02 (pde=8.82e-03, bc=1.36e-03, ic=2.22e-04, zz=6.46e-05, yxz=2.69e-04,)
# Epoch 1330 | TrainLoss=2.579e-03 (pde=8.53e-04, bc=1.31e-03, ic=1.53e-04, zz=4.39e-05, yxz=1.93e-04,| ValLoss=1.136e-02 (pde=9.62e-03, bc=1.30e-03, ic=1.48e-04, zz=4.76e-05, yxz=2.40e-04,)
# Epoch 1340 | TrainLoss=2.316e-03 (pde=6.85e-04, bc=1.23e-03, ic=1.30e-04, zz=5.16e-05, yxz=1.96e-04,| ValLoss=1.253e-02 (pde=1.08e-02, bc=1.23e-03, ic=1.27e-04, zz=5.84e-05, yxz=2.75e-04,)
#
# [Resample] epoch 1350: regenerating PDE/BC/IC points...
#
# Epoch 1350 | TrainLoss=2.181e-03 (pde=1.56e-02, bc=1.28e-03, ic=1.17e-04, zz=5.49e-05, yxz=2.02e-04,| ValLoss=1.240e-02 (pde=1.07e-02, bc=1.21e-03, ic=1.18e-04, zz=6.36e-05, yxz=2.82e-04,)
# Epoch 1360 | TrainLoss=2.945e-03 (pde=1.13e-03, bc=1.27e-03, ic=2.03e-04, zz=3.72e-05, yxz=1.72e-04,| ValLoss=9.198e-03 (pde=7.53e-03, bc=1.22e-03, ic=2.15e-04, zz=4.20e-05, yxz=1.94e-04,)
# Epoch 1370 | TrainLoss=2.418e-03 (pde=8.45e-04, bc=1.24e-03, ic=1.31e-04, zz=2.84e-05, yxz=1.39e-04,| ValLoss=9.399e-03 (pde=7.87e-03, bc=1.20e-03, ic=1.36e-04, zz=3.34e-05, yxz=1.67e-04,)
# Epoch 1380 | TrainLoss=2.217e-03 (pde=7.29e-04, bc=1.21e-03, ic=9.14e-05, zz=3.83e-05, yxz=1.32e-04,| ValLoss=9.557e-03 (pde=8.07e-03, bc=1.17e-03, ic=9.49e-05, zz=4.23e-05, yxz=1.81e-04,)
# Epoch 1390 | TrainLoss=2.067e-03 (pde=6.18e-04, bc=1.20e-03, ic=9.14e-05, zz=2.86e-05, yxz=1.19e-04,| ValLoss=9.047e-03 (pde=7.60e-03, bc=1.15e-03, ic=9.40e-05, zz=3.28e-05, yxz=1.67e-04,)
#
# [Resample] epoch 1400: regenerating PDE/BC/IC points...
#
# Epoch 1400 | TrainLoss=1.982e-03 (pde=1.89e-02, bc=1.16e-03, ic=8.50e-05, zz=2.63e-05, yxz=1.49e-04,| ValLoss=8.934e-03 (pde=7.52e-03, bc=1.13e-03, ic=8.84e-05, zz=2.96e-05, yxz=1.56e-04,)
# Epoch 1410 | TrainLoss=4.182e-03 (pde=2.10e-03, bc=1.42e-03, ic=1.67e-04, zz=3.74e-05, yxz=4.00e-04,| ValLoss=7.593e-03 (pde=5.57e-03, bc=1.41e-03, ic=1.66e-04, zz=4.01e-05, yxz=4.07e-04,)
# Epoch 1420 | TrainLoss=3.697e-03 (pde=1.77e-03, bc=1.44e-03, ic=1.07e-04, zz=3.16e-05, yxz=3.26e-04,| ValLoss=7.546e-03 (pde=5.63e-03, bc=1.44e-03, ic=1.11e-04, zz=3.24e-05, yxz=3.32e-04,)
# Epoch 1430 | TrainLoss=3.411e-03 (pde=1.55e-03, bc=1.39e-03, ic=1.19e-04, zz=3.69e-05, yxz=2.90e-04,| ValLoss=8.242e-03 (pde=6.40e-03, bc=1.37e-03, ic=1.20e-04, zz=3.88e-05, yxz=3.09e-04,)
# Epoch 1440 | TrainLoss=3.179e-03 (pde=1.33e-03, bc=1.36e-03, ic=1.27e-04, zz=2.14e-05, yxz=3.25e-04,| ValLoss=8.638e-03 (pde=6.82e-03, bc=1.34e-03, ic=1.27e-04, zz=2.34e-05, yxz=3.32e-04,)
#
# [Resample] epoch 1450: regenerating PDE/BC/IC points...
#
# Epoch 1450 | TrainLoss=2.990e-03 (pde=1.19e-02, bc=1.30e-03, ic=1.24e-04, zz=2.95e-05, yxz=3.30e-04,| ValLoss=8.973e-03 (pde=7.19e-03, bc=1.30e-03, ic=1.27e-04, zz=3.26e-05, yxz=3.21e-04,)
# Epoch 1460 | TrainLoss=4.884e-03 (pde=2.69e-03, bc=1.54e-03, ic=1.99e-04, zz=3.69e-05, yxz=3.27e-04,| ValLoss=7.006e-03 (pde=4.88e-03, bc=1.53e-03, ic=2.06e-04, zz=4.11e-05, yxz=3.42e-04,)
# Epoch 1470 | TrainLoss=4.273e-03 (pde=2.21e-03, bc=1.50e-03, ic=2.00e-04, zz=3.67e-05, yxz=2.90e-04,| ValLoss=8.202e-03 (pde=6.16e-03, bc=1.50e-03, ic=2.07e-04, zz=3.80e-05, yxz=2.97e-04,)
# Epoch 1480 | TrainLoss=3.905e-03 (pde=1.97e-03, bc=1.47e-03, ic=1.68e-04, zz=3.37e-05, yxz=2.46e-04,| ValLoss=9.533e-03 (pde=7.60e-03, bc=1.47e-03, ic=1.76e-04, zz=3.44e-05, yxz=2.46e-04,)
# Epoch 1490 | TrainLoss=3.612e-03 (pde=1.61e-03, bc=1.51e-03, ic=2.03e-04, zz=3.30e-05, yxz=2.36e-04,| ValLoss=1.113e-02 (pde=9.11e-03, bc=1.51e-03, ic=2.15e-04, zz=3.64e-05, yxz=2.47e-04,)
#
# [Resample] epoch 1500: regenerating PDE/BC/IC points...
#
# Epoch 1500 | TrainLoss=3.387e-03 (pde=4.55e-03, bc=1.45e-03, ic=1.85e-04, zz=4.08e-05, yxz=2.45e-04,| ValLoss=1.301e-02 (pde=1.11e-02, bc=1.40e-03, ic=2.04e-04, zz=4.04e-05, yxz=2.18e-04,)
# Epoch 1510 | TrainLoss=2.539e-03 (pde=8.01e-04, bc=1.31e-03, ic=1.36e-04, zz=3.47e-05, yxz=1.84e-04,| ValLoss=7.848e-03 (pde=6.22e-03, bc=1.26e-03, ic=1.43e-04, zz=3.42e-05, yxz=1.88e-04,)
# Epoch 1520 | TrainLoss=2.214e-03 (pde=6.23e-04, bc=1.24e-03, ic=1.36e-04, zz=2.02e-05, yxz=1.75e-04,| ValLoss=1.084e-02 (pde=9.31e-03, bc=1.19e-03, ic=1.43e-04, zz=1.98e-05, yxz=1.75e-04,)
# Epoch 1530 | TrainLoss=2.032e-03 (pde=5.11e-04, bc=1.21e-03, ic=1.09e-04, zz=1.94e-05, yxz=1.71e-04,| ValLoss=1.270e-02 (pde=1.12e-02, bc=1.17e-03, ic=1.13e-04, zz=1.91e-05, yxz=1.71e-04,)
# Epoch 1540 | TrainLoss=1.945e-03 (pde=4.74e-04, bc=1.17e-03, ic=1.01e-04, zz=2.45e-05, yxz=1.66e-04,| ValLoss=1.482e-02 (pde=1.34e-02, bc=1.15e-03, ic=1.03e-04, zz=2.43e-05, yxz=1.67e-04,)
#
# [Resample] epoch 1550: regenerating PDE/BC/IC points...
#
# Epoch 1550 | TrainLoss=1.872e-03 (pde=2.05e-02, bc=1.12e-03, ic=9.10e-05, zz=1.38e-05, yxz=1.42e-04,| ValLoss=1.728e-02 (pde=1.59e-02, bc=1.12e-03, ic=9.18e-05, zz=1.66e-05, yxz=1.59e-04,)
# Epoch 1560 | TrainLoss=4.941e-03 (pde=2.60e-03, bc=1.59e-03, ic=2.34e-04, zz=2.34e-05, yxz=3.70e-04,| ValLoss=8.280e-03 (pde=5.97e-03, bc=1.59e-03, ic=2.39e-04, zz=3.06e-05, yxz=4.52e-04,)
# Epoch 1570 | TrainLoss=4.139e-03 (pde=2.03e-03, bc=1.53e-03, ic=2.32e-04, zz=2.67e-05, yxz=2.87e-04,| ValLoss=9.931e-03 (pde=7.75e-03, bc=1.54e-03, ic=2.37e-04, zz=3.09e-05, yxz=3.67e-04,)
# Epoch 1580 | TrainLoss=3.806e-03 (pde=1.74e-03, bc=1.51e-03, ic=2.52e-04, zz=2.15e-05, yxz=2.50e-04,| ValLoss=1.002e-02 (pde=7.91e-03, bc=1.53e-03, ic=2.56e-04, zz=2.68e-05, yxz=2.97e-04,)
# Epoch 1590 | TrainLoss=3.484e-03 (pde=1.48e-03, bc=1.51e-03, ic=2.21e-04, zz=2.75e-05, yxz=2.18e-04,| ValLoss=9.914e-03 (pde=7.88e-03, bc=1.53e-03, ic=2.26e-04, zz=3.32e-05, yxz=2.44e-04,)
#
# [Resample] epoch 1600: regenerating PDE/BC/IC points...
#
# Epoch 1600 | TrainLoss=3.243e-03 (pde=1.25e-02, bc=1.48e-03, ic=1.78e-04, zz=2.42e-05, yxz=2.37e-04,| ValLoss=1.063e-02 (pde=8.72e-03, bc=1.47e-03, ic=1.84e-04, zz=2.57e-05, yxz=2.34e-04,)
# Epoch 1610 | TrainLoss=4.674e-03 (pde=2.23e-03, bc=1.69e-03, ic=2.59e-04, zz=8.04e-05, yxz=3.28e-04,| ValLoss=6.583e-03 (pde=4.23e-03, bc=1.67e-03, ic=2.58e-04, zz=8.23e-05, yxz=3.39e-04,)
# Epoch 1620 | TrainLoss=4.022e-03 (pde=1.89e-03, bc=1.47e-03, ic=2.35e-04, zz=6.04e-05, yxz=3.34e-04,| ValLoss=6.610e-03 (pde=4.50e-03, bc=1.45e-03, ic=2.38e-04, zz=6.50e-05, yxz=3.65e-04,)
# Epoch 1630 | TrainLoss=3.640e-03 (pde=1.57e-03, bc=1.44e-03, ic=2.04e-04, zz=7.07e-05, yxz=3.26e-04,| ValLoss=6.612e-03 (pde=4.56e-03, bc=1.41e-03, ic=2.08e-04, zz=7.89e-05, yxz=3.53e-04,)
# Epoch 1640 | TrainLoss=3.426e-03 (pde=1.41e-03, bc=1.44e-03, ic=1.57e-04, zz=7.19e-05, yxz=3.23e-04,| ValLoss=6.851e-03 (pde=4.86e-03, bc=1.41e-03, ic=1.61e-04, zz=7.95e-05, yxz=3.44e-04,)
#
# [Resample] epoch 1650: regenerating PDE/BC/IC points...
#
# Epoch 1650 | TrainLoss=3.223e-03 (pde=4.20e-03, bc=1.34e-03, ic=1.70e-04, zz=5.92e-05, yxz=2.92e-04,| ValLoss=7.009e-03 (pde=5.09e-03, bc=1.35e-03, ic=1.79e-04, zz=6.61e-05, yxz=3.27e-04,)
# Epoch 1660 | TrainLoss=3.446e-03 (pde=1.54e-03, bc=1.40e-03, ic=1.44e-04, zz=5.52e-05, yxz=2.44e-04,| ValLoss=6.457e-03 (pde=4.57e-03, bc=1.40e-03, ic=1.50e-04, zz=6.02e-05, yxz=2.79e-04,)
# Epoch 1670 | TrainLoss=3.082e-03 (pde=1.23e-03, bc=1.35e-03, ic=1.32e-04, zz=3.96e-05, yxz=2.93e-04,| ValLoss=6.148e-03 (pde=4.26e-03, bc=1.35e-03, ic=1.36e-04, zz=4.45e-05, yxz=3.50e-04,)
# Epoch 1680 | TrainLoss=2.869e-03 (pde=1.10e-03, bc=1.29e-03, ic=1.20e-04, zz=3.22e-05, yxz=2.97e-04,| ValLoss=6.230e-03 (pde=4.44e-03, bc=1.31e-03, ic=1.22e-04, zz=3.64e-05, yxz=3.23e-04,)
# Epoch 1690 | TrainLoss=2.717e-03 (pde=1.05e-03, bc=1.25e-03, ic=1.11e-04, zz=3.09e-05, yxz=2.60e-04,| ValLoss=6.191e-03 (pde=4.50e-03, bc=1.26e-03, ic=1.13e-04, zz=3.53e-05, yxz=2.83e-04,)
#
# [Resample] epoch 1700: regenerating PDE/BC/IC points...
#
# Epoch 1700 | TrainLoss=2.557e-03 (pde=8.76e-03, bc=1.23e-03, ic=9.66e-05, zz=3.68e-05, yxz=3.03e-04,| ValLoss=5.605e-03 (pde=4.00e-03, bc=1.19e-03, ic=9.73e-05, zz=3.41e-05, yxz=2.81e-04,)
# Epoch 1710 | TrainLoss=5.252e-03 (pde=2.93e-03, bc=1.59e-03, ic=2.17e-04, zz=5.94e-05, yxz=3.38e-04,| ValLoss=4.755e-03 (pde=2.58e-03, bc=1.54e-03, ic=2.19e-04, zz=5.63e-05, yxz=3.55e-04,)
# Epoch 1720 | TrainLoss=4.421e-03 (pde=2.19e-03, bc=1.47e-03, ic=2.29e-04, zz=3.91e-05, yxz=4.28e-04,| ValLoss=4.685e-03 (pde=2.53e-03, bc=1.43e-03, ic=2.42e-04, zz=3.73e-05, yxz=4.48e-04,)
# Epoch 1730 | TrainLoss=3.998e-03 (pde=1.77e-03, bc=1.48e-03, ic=2.07e-04, zz=4.47e-05, yxz=4.75e-04,| ValLoss=5.622e-03 (pde=3.43e-03, bc=1.44e-03, ic=2.21e-04, zz=4.32e-05, yxz=4.96e-04,)
# Epoch 1740 | TrainLoss=3.749e-03 (pde=1.68e-03, bc=1.41e-03, ic=1.80e-04, zz=3.59e-05, yxz=4.07e-04,| ValLoss=5.870e-03 (pde=3.84e-03, bc=1.37e-03, ic=1.92e-04, zz=3.59e-05, yxz=4.27e-04,)
#
# [Resample] epoch 1750: regenerating PDE/BC/IC points...
#
# Epoch 1750 | TrainLoss=3.491e-03 (pde=5.98e-03, bc=1.36e-03, ic=1.52e-04, zz=3.21e-05, yxz=4.68e-04,| ValLoss=6.347e-03 (pde=4.43e-03, bc=1.32e-03, ic=1.64e-04, zz=3.45e-05, yxz=4.05e-04,)
# Epoch 1760 | TrainLoss=2.973e-03 (pde=1.18e-03, bc=1.31e-03, ic=1.37e-04, zz=4.55e-05, yxz=2.41e-04,| ValLoss=5.889e-03 (pde=4.18e-03, bc=1.26e-03, ic=1.42e-04, zz=5.78e-05, yxz=2.50e-04,)
# Epoch 1770 | TrainLoss=2.599e-03 (pde=9.59e-04, bc=1.24e-03, ic=1.34e-04, zz=4.84e-05, yxz=1.93e-04,| ValLoss=6.666e-03 (pde=5.07e-03, bc=1.20e-03, ic=1.39e-04, zz=5.87e-05, yxz=2.02e-04,)
# Epoch 1780 | TrainLoss=2.388e-03 (pde=7.71e-04, bc=1.25e-03, ic=1.16e-04, zz=3.72e-05, yxz=1.98e-04,| ValLoss=7.516e-03 (pde=5.96e-03, bc=1.20e-03, ic=1.18e-04, zz=4.56e-05, yxz=1.92e-04,)
# Epoch 1790 | TrainLoss=2.227e-03 (pde=6.83e-04, bc=1.23e-03, ic=9.72e-05, zz=4.05e-05, yxz=1.67e-04,| ValLoss=8.784e-03 (pde=7.29e-03, bc=1.18e-03, ic=9.86e-05, zz=4.90e-05, yxz=1.71e-04,)
#
# [Resample] epoch 1800: regenerating PDE/BC/IC points...
#
# Epoch 1800 | TrainLoss=2.135e-03 (pde=1.73e-02, bc=1.22e-03, ic=9.08e-05, zz=5.52e-05, yxz=1.65e-04,| ValLoss=9.288e-03 (pde=7.79e-03, bc=1.19e-03, ic=8.72e-05, zz=5.72e-05, yxz=1.67e-04,)
# Epoch 1810 | TrainLoss=5.940e-03 (pde=3.50e-03, bc=1.69e-03, ic=2.47e-04, zz=9.98e-05, yxz=3.22e-04,| ValLoss=5.366e-03 (pde=3.01e-03, bc=1.64e-03, ic=2.48e-04, zz=9.99e-05, yxz=3.64e-04,)
# Epoch 1820 | TrainLoss=5.138e-03 (pde=2.99e-03, bc=1.47e-03, ic=2.14e-04, zz=4.02e-05, yxz=3.64e-04,| ValLoss=6.190e-03 (pde=4.10e-03, bc=1.44e-03, ic=2.13e-04, zz=4.16e-05, yxz=3.96e-04,)
# Epoch 1830 | TrainLoss=4.750e-03 (pde=2.68e-03, bc=1.43e-03, ic=1.99e-04, zz=5.58e-05, yxz=3.50e-04,| ValLoss=6.321e-03 (pde=4.30e-03, bc=1.40e-03, ic=1.96e-04, zz=5.83e-05, yxz=3.57e-04,)
# Epoch 1840 | TrainLoss=4.353e-03 (pde=2.33e-03, bc=1.38e-03, ic=1.70e-04, zz=4.42e-05, yxz=3.89e-04,| ValLoss=6.695e-03 (pde=4.73e-03, bc=1.35e-03, ic=1.68e-04, zz=4.53e-05, yxz=3.97e-04,)
#
# [Resample] epoch 1850: regenerating PDE/BC/IC points...
#
# Epoch 1850 | TrainLoss=4.087e-03 (pde=1.21e-02, bc=1.34e-03, ic=1.54e-04, zz=3.94e-05, yxz=3.91e-04,| ValLoss=6.455e-03 (pde=4.55e-03, bc=1.32e-03, ic=1.61e-04, zz=4.33e-05, yxz=3.84e-04,)
# Epoch 1860 | TrainLoss=3.153e-03 (pde=1.43e-03, bc=1.23e-03, ic=1.91e-04, zz=2.69e-05, yxz=2.24e-04,| ValLoss=5.236e-03 (pde=3.56e-03, bc=1.21e-03, ic=1.97e-04, zz=2.83e-05, yxz=2.40e-04,)
# Epoch 1870 | TrainLoss=2.789e-03 (pde=1.16e-03, bc=1.27e-03, ic=1.29e-04, zz=2.09e-05, yxz=1.86e-04,| ValLoss=4.864e-03 (pde=3.25e-03, bc=1.26e-03, ic=1.36e-04, zz=2.24e-05, yxz=1.95e-04,)
# Epoch 1880 | TrainLoss=2.554e-03 (pde=9.82e-04, bc=1.23e-03, ic=1.13e-04, zz=1.91e-05, yxz=1.84e-04,| ValLoss=5.162e-03 (pde=3.60e-03, bc=1.22e-03, ic=1.19e-04, zz=2.07e-05, yxz=2.08e-04,)
# Epoch 1890 | TrainLoss=2.364e-03 (pde=8.48e-04, bc=1.19e-03, ic=1.09e-04, zz=2.32e-05, yxz=1.87e-04,| ValLoss=5.245e-03 (pde=3.73e-03, bc=1.17e-03, ic=1.13e-04, zz=2.54e-05, yxz=2.11e-04,)
#
# [Resample] epoch 1900: regenerating PDE/BC/IC points...
#
# Epoch 1900 | TrainLoss=2.281e-03 (pde=3.76e-03, bc=1.18e-03, ic=9.09e-05, zz=2.80e-05, yxz=2.33e-04,| ValLoss=5.390e-03 (pde=3.88e-03, bc=1.15e-03, ic=8.89e-05, zz=2.91e-05, yxz=2.45e-04,)
# Epoch 1910 | TrainLoss=3.944e-03 (pde=2.19e-03, bc=1.36e-03, ic=1.36e-04, zz=2.47e-05, yxz=2.22e-04,| ValLoss=3.910e-03 (pde=2.18e-03, bc=1.33e-03, ic=1.38e-04, zz=2.66e-05, yxz=2.29e-04,)
# Epoch 1920 | TrainLoss=3.787e-03 (pde=1.96e-03, bc=1.42e-03, ic=1.69e-04, zz=1.81e-05, yxz=2.15e-04,| ValLoss=4.002e-03 (pde=2.19e-03, bc=1.40e-03, ic=1.71e-04, zz=1.95e-05, yxz=2.29e-04,)
# Epoch 1930 | TrainLoss=3.665e-03 (pde=1.85e-03, bc=1.43e-03, ic=1.69e-04, zz=1.71e-05, yxz=1.86e-04,| ValLoss=4.190e-03 (pde=2.39e-03, bc=1.42e-03, ic=1.74e-04, zz=1.84e-05, yxz=1.87e-04,)
# Epoch 1940 | TrainLoss=3.584e-03 (pde=1.75e-03, bc=1.45e-03, ic=1.76e-04, zz=1.67e-05, yxz=1.83e-04,| ValLoss=4.298e-03 (pde=2.47e-03, bc=1.44e-03, ic=1.83e-04, zz=1.80e-05, yxz=1.84e-04,)
#
# [Resample] epoch 1950: regenerating PDE/BC/IC points...
#
# Epoch 1950 | TrainLoss=3.525e-03 (pde=5.77e-03, bc=1.46e-03, ic=1.96e-04, zz=1.81e-05, yxz=1.91e-04,| ValLoss=4.429e-03 (pde=2.58e-03, bc=1.44e-03, ic=2.03e-04, zz=1.80e-05, yxz=1.82e-04,)
# Epoch 1960 | TrainLoss=3.600e-03 (pde=1.69e-03, bc=1.38e-03, ic=1.06e-04, zz=4.77e-05, yxz=2.93e-04,| ValLoss=5.577e-03 (pde=3.79e-03, bc=1.34e-03, ic=1.06e-04, zz=4.74e-05, yxz=2.94e-04,)
# Epoch 1970 | TrainLoss=3.139e-03 (pde=1.39e-03, bc=1.27e-03, ic=1.32e-04, zz=5.28e-05, yxz=2.68e-04,| ValLoss=6.171e-03 (pde=4.46e-03, bc=1.24e-03, ic=1.28e-04, zz=5.32e-05, yxz=2.90e-04,)
# Epoch 1980 | TrainLoss=2.836e-03 (pde=1.13e-03, bc=1.26e-03, ic=1.21e-04, zz=5.24e-05, yxz=2.40e-04,| ValLoss=6.990e-03 (pde=5.33e-03, bc=1.23e-03, ic=1.17e-04, zz=5.10e-05, yxz=2.69e-04,)
# Epoch 1990 | TrainLoss=2.644e-03 (pde=1.00e-03, bc=1.22e-03, ic=1.20e-04, zz=4.33e-05, yxz=2.48e-04,| ValLoss=7.503e-03 (pde=5.86e-03, bc=1.19e-03, ic=1.17e-04, zz=4.31e-05, yxz=2.94e-04,)
#
# [Resample] epoch 2000: regenerating PDE/BC/IC points...
#
# Epoch 2000 | TrainLoss=2.527e-03 (pde=7.10e-03, bc=1.22e-03, ic=8.56e-05, zz=3.48e-05, yxz=2.58e-04,| ValLoss=8.305e-03 (pde=6.70e-03, bc=1.19e-03, ic=8.80e-05, zz=3.72e-05, yxz=2.88e-04,)
# Epoch 2010 | TrainLoss=3.717e-03 (pde=1.82e-03, bc=1.35e-03, ic=1.55e-04, zz=3.46e-05, yxz=2.73e-04,| ValLoss=7.485e-03 (pde=5.69e-03, bc=1.31e-03, ic=1.54e-04, zz=3.66e-05, yxz=2.92e-04,)
# Epoch 2020 | TrainLoss=3.239e-03 (pde=1.46e-03, bc=1.29e-03, ic=1.80e-04, zz=4.97e-05, yxz=2.39e-04,| ValLoss=8.537e-03 (pde=6.77e-03, bc=1.26e-03, ic=1.76e-04, zz=5.21e-05, yxz=2.72e-04,)
# Epoch 2030 | TrainLoss=3.001e-03 (pde=1.33e-03, bc=1.24e-03, ic=1.40e-04, zz=4.85e-05, yxz=2.19e-04,| ValLoss=1.001e-02 (pde=8.36e-03, bc=1.22e-03, ic=1.41e-04, zz=5.02e-05, yxz=2.46e-04,)
# Epoch 2040 | TrainLoss=2.824e-03 (pde=1.23e-03, bc=1.19e-03, ic=1.49e-04, zz=4.20e-05, yxz=2.02e-04,| ValLoss=1.380e-02 (pde=1.22e-02, bc=1.17e-03, ic=1.52e-04, zz=4.43e-05, yxz=2.28e-04,)
#
# [Resample] epoch 2050: regenerating PDE/BC/IC points...
#
# Epoch 2050 | TrainLoss=2.647e-03 (pde=1.90e-02, bc=1.10e-03, ic=1.33e-04, zz=4.10e-05, yxz=2.34e-04,| ValLoss=1.717e-02 (pde=1.56e-02, bc=1.14e-03, ic=1.36e-04, zz=3.79e-05, yxz=2.40e-04,)
# Epoch 2060 | TrainLoss=3.277e-03 (pde=1.40e-03, bc=1.32e-03, ic=1.87e-04, zz=3.32e-05, yxz=2.10e-04,| ValLoss=5.252e-03 (pde=3.46e-03, bc=1.35e-03, ic=1.88e-04, zz=3.22e-05, yxz=2.22e-04,)
# Epoch 2070 | TrainLoss=2.723e-03 (pde=1.10e-03, bc=1.23e-03, ic=1.50e-04, zz=4.03e-05, yxz=1.86e-04,| ValLoss=5.633e-03 (pde=4.00e-03, bc=1.25e-03, ic=1.47e-04, zz=4.08e-05, yxz=1.99e-04,)
# Epoch 2080 | TrainLoss=2.560e-03 (pde=1.02e-03, bc=1.21e-03, ic=1.00e-04, zz=3.17e-05, yxz=1.84e-04,| ValLoss=6.506e-03 (pde=4.95e-03, bc=1.23e-03, ic=9.47e-05, zz=3.05e-05, yxz=1.93e-04,)
# Epoch 2090 | TrainLoss=2.457e-03 (pde=9.56e-04, bc=1.17e-03, ic=9.91e-05, zz=3.62e-05, yxz=1.88e-04,| ValLoss=7.425e-03 (pde=5.90e-03, bc=1.20e-03, ic=9.38e-05, zz=3.38e-05, yxz=1.97e-04,)
#
# [Resample] epoch 2100: regenerating PDE/BC/IC points...
#
# Epoch 2100 | TrainLoss=2.387e-03 (pde=1.33e-02, bc=1.22e-03, ic=9.59e-05, zz=3.43e-05, yxz=1.85e-04,| ValLoss=8.089e-03 (pde=6.60e-03, bc=1.17e-03, ic=9.30e-05, zz=3.59e-05, yxz=1.91e-04,)
# Epoch 2110 | TrainLoss=4.349e-03 (pde=2.12e-03, bc=1.46e-03, ic=2.44e-04, zz=3.61e-05, yxz=3.27e-04,| ValLoss=5.235e-03 (pde=3.23e-03, bc=1.39e-03, ic=2.39e-04, zz=4.10e-05, yxz=3.40e-04,)
# Epoch 2120 | TrainLoss=3.665e-03 (pde=1.74e-03, bc=1.41e-03, ic=1.47e-04, zz=5.00e-05, yxz=2.57e-04,| ValLoss=4.979e-03 (pde=3.16e-03, bc=1.34e-03, ic=1.46e-04, zz=5.66e-05, yxz=2.73e-04,)
# Epoch 2130 | TrainLoss=3.368e-03 (pde=1.66e-03, bc=1.29e-03, ic=1.34e-04, zz=4.39e-05, yxz=2.20e-04,| ValLoss=4.996e-03 (pde=3.35e-03, bc=1.22e-03, ic=1.30e-04, zz=5.22e-05, yxz=2.41e-04,)
# Epoch 2140 | TrainLoss=3.181e-03 (pde=1.52e-03, bc=1.26e-03, ic=1.18e-04, zz=4.70e-05, yxz=2.22e-04,| ValLoss=5.157e-03 (pde=3.55e-03, bc=1.19e-03, ic=1.14e-04, zz=5.54e-05, yxz=2.42e-04,)
#
# [Resample] epoch 2150: regenerating PDE/BC/IC points...
#
# Epoch 2150 | TrainLoss=3.030e-03 (pde=3.83e-02, bc=1.21e-03, ic=1.12e-04, zz=5.33e-05, yxz=2.31e-04,| ValLoss=5.355e-03 (pde=3.80e-03, bc=1.16e-03, ic=1.11e-04, zz=5.54e-05, yxz=2.29e-04,)
# Epoch 2160 | TrainLoss=3.167e-03 (pde=1.35e-03, bc=1.26e-03, ic=1.71e-04, zz=5.52e-05, yxz=2.39e-04,| ValLoss=5.537e-03 (pde=3.84e-03, bc=1.21e-03, ic=1.68e-04, zz=5.61e-05, yxz=2.54e-04,)
# Epoch 2170 | TrainLoss=2.757e-03 (pde=1.11e-03, bc=1.24e-03, ic=1.41e-04, zz=4.89e-05, yxz=1.83e-04,| ValLoss=5.280e-03 (pde=3.68e-03, bc=1.19e-03, ic=1.41e-04, zz=5.05e-05, yxz=2.15e-04,)
# Epoch 2180 | TrainLoss=2.492e-03 (pde=9.07e-04, bc=1.22e-03, ic=1.36e-04, zz=4.41e-05, yxz=1.64e-04,| ValLoss=5.581e-03 (pde=4.02e-03, bc=1.18e-03, ic=1.34e-04, zz=4.60e-05, yxz=1.98e-04,)
# Epoch 2190 | TrainLoss=2.391e-03 (pde=8.17e-04, bc=1.22e-03, ic=1.29e-04, zz=4.09e-05, yxz=1.75e-04,| ValLoss=5.538e-03 (pde=3.99e-03, bc=1.17e-03, ic=1.27e-04, zz=4.25e-05, yxz=2.06e-04,)
#
# [Resample] epoch 2200: regenerating PDE/BC/IC points...
#
# Epoch 2200 | TrainLoss=2.297e-03 (pde=9.87e-03, bc=1.16e-03, ic=1.33e-04, zz=3.56e-05, yxz=2.07e-04,| ValLoss=6.189e-03 (pde=4.66e-03, bc=1.13e-03, ic=1.25e-04, zz=3.97e-05, yxz=2.30e-04,)
# Epoch 2210 | TrainLoss=4.292e-03 (pde=2.31e-03, bc=1.24e-03, ic=1.03e-04, zz=5.91e-05, yxz=3.63e-04,| ValLoss=1.432e-02 (pde=1.25e-02, bc=1.21e-03, ic=1.00e-04, zz=6.17e-05, yxz=4.15e-04,)
# Epoch 2220 | TrainLoss=2.745e-03 (pde=1.15e-03, bc=1.15e-03, ic=8.55e-05, zz=2.69e-05, yxz=2.38e-04,| ValLoss=2.078e-02 (pde=1.92e-02, bc=1.14e-03, ic=8.51e-05, zz=3.07e-05, yxz=2.73e-04,)
# Epoch 2230 | TrainLoss=2.328e-03 (pde=8.76e-04, bc=1.12e-03, ic=8.76e-05, zz=2.64e-05, yxz=1.99e-04,| ValLoss=2.152e-02 (pde=2.01e-02, bc=1.12e-03, ic=8.62e-05, zz=2.87e-05, yxz=2.14e-04,)
# Epoch 2240 | TrainLoss=2.084e-03 (pde=7.01e-04, bc=1.10e-03, ic=8.25e-05, zz=2.21e-05, yxz=1.71e-04,| ValLoss=2.250e-02 (pde=2.11e-02, bc=1.09e-03, ic=8.16e-05, zz=2.48e-05, yxz=1.81e-04,)
#
# [Resample] epoch 2250: regenerating PDE/BC/IC points...
#
# Epoch 2250 | TrainLoss=1.937e-03 (pde=1.67e-02, bc=1.09e-03, ic=6.08e-05, zz=2.35e-05, yxz=1.63e-04,| ValLoss=2.339e-02 (pde=2.21e-02, bc=1.08e-03, ic=5.89e-05, zz=2.50e-05, yxz=1.61e-04,)
# Epoch 2260 | TrainLoss=3.691e-03 (pde=1.92e-03, bc=1.28e-03, ic=1.01e-04, zz=6.26e-05, yxz=2.49e-04,| ValLoss=6.286e-03 (pde=4.58e-03, bc=1.25e-03, ic=9.95e-05, zz=7.12e-05, yxz=2.82e-04,)
# Epoch 2270 | TrainLoss=3.044e-03 (pde=1.38e-03, bc=1.17e-03, ic=1.37e-04, zz=7.86e-05, yxz=2.31e-04,| ValLoss=6.569e-03 (pde=4.95e-03, bc=1.14e-03, ic=1.39e-04, zz=9.08e-05, yxz=2.56e-04,)
# Epoch 2280 | TrainLoss=2.703e-03 (pde=1.12e-03, bc=1.14e-03, ic=1.24e-04, zz=6.81e-05, yxz=2.29e-04,| ValLoss=6.987e-03 (pde=5.43e-03, bc=1.11e-03, ic=1.27e-04, zz=7.60e-05, yxz=2.51e-04,)
# Epoch 2290 | TrainLoss=2.533e-03 (pde=1.02e-03, bc=1.11e-03, ic=1.05e-04, zz=6.14e-05, yxz=2.23e-04,| ValLoss=7.621e-03 (pde=6.11e-03, bc=1.08e-03, ic=1.10e-04, zz=7.04e-05, yxz=2.49e-04,)
#
# [Resample] epoch 2300: regenerating PDE/BC/IC points...
#
# Epoch 2300 | TrainLoss=2.398e-03 (pde=4.35e-03, bc=1.08e-03, ic=1.02e-04, zz=6.99e-05, yxz=2.56e-04,| ValLoss=8.147e-03 (pde=6.66e-03, bc=1.07e-03, ic=9.88e-05, zz=6.46e-05, yxz=2.52e-04,)
# Epoch 2310 | TrainLoss=2.484e-03 (pde=1.03e-03, bc=1.10e-03, ic=9.26e-05, zz=3.62e-05, yxz=1.97e-04,| ValLoss=9.919e-03 (pde=8.48e-03, bc=1.10e-03, ic=9.09e-05, zz=3.39e-05, yxz=2.15e-04,)
# Epoch 2320 | TrainLoss=2.219e-03 (pde=8.20e-04, bc=1.10e-03, ic=8.28e-05, zz=3.25e-05, yxz=1.68e-04,| ValLoss=1.106e-02 (pde=9.66e-03, bc=1.11e-03, ic=8.13e-05, zz=3.11e-05, yxz=1.75e-04,)
# Epoch 2330 | TrainLoss=2.085e-03 (pde=7.07e-04, bc=1.08e-03, ic=8.48e-05, zz=2.79e-05, yxz=1.72e-04,| ValLoss=1.218e-02 (pde=1.08e-02, bc=1.08e-03, ic=8.34e-05, zz=2.72e-05, yxz=1.91e-04,)
# Epoch 2340 | TrainLoss=1.994e-03 (pde=6.29e-04, bc=1.06e-03, ic=8.43e-05, zz=2.87e-05, yxz=1.79e-04,| ValLoss=1.245e-02 (pde=1.11e-02, bc=1.07e-03, ic=8.20e-05, zz=2.74e-05, yxz=1.89e-04,)
#
# [Resample] epoch 2350: regenerating PDE/BC/IC points...
#
# Epoch 2350 | TrainLoss=1.932e-03 (pde=4.34e-03, bc=1.04e-03, ic=9.33e-05, zz=2.59e-05, yxz=1.95e-04,| ValLoss=1.316e-02 (pde=1.18e-02, bc=1.03e-03, ic=8.86e-05, zz=2.62e-05, yxz=1.92e-04,)
# Epoch 2360 | TrainLoss=2.558e-03 (pde=1.04e-03, bc=1.13e-03, ic=1.02e-04, zz=4.24e-05, yxz=2.00e-04,| ValLoss=7.184e-03 (pde=5.73e-03, bc=1.10e-03, ic=9.64e-05, zz=4.04e-05, yxz=2.14e-04,)
# Epoch 2370 | TrainLoss=2.290e-03 (pde=8.38e-04, bc=1.08e-03, ic=1.03e-04, zz=4.02e-05, yxz=2.15e-04,| ValLoss=7.303e-03 (pde=5.87e-03, bc=1.06e-03, ic=9.66e-05, zz=3.95e-05, yxz=2.31e-04,)
# Epoch 2380 | TrainLoss=2.164e-03 (pde=7.46e-04, bc=1.09e-03, ic=9.17e-05, zz=3.34e-05, yxz=1.98e-04,| ValLoss=7.100e-03 (pde=5.69e-03, bc=1.08e-03, ic=8.57e-05, zz=3.43e-05, yxz=2.14e-04,)
# Epoch 2390 | TrainLoss=2.079e-03 (pde=6.63e-04, bc=1.10e-03, ic=9.22e-05, zz=3.52e-05, yxz=1.89e-04,| ValLoss=7.120e-03 (pde=5.71e-03, bc=1.08e-03, ic=8.59e-05, zz=3.65e-05, yxz=2.08e-04,)
#
# [Resample] epoch 2400: regenerating PDE/BC/IC points...
#
# Epoch 2400 | TrainLoss=2.036e-03 (pde=9.66e-03, bc=1.10e-03, ic=9.55e-05, zz=3.49e-05, yxz=1.98e-04,| ValLoss=7.515e-03 (pde=6.12e-03, bc=1.06e-03, ic=9.02e-05, zz=3.68e-05, yxz=2.15e-04,)
# Epoch 2410 | TrainLoss=4.161e-03 (pde=2.36e-03, bc=1.23e-03, ic=1.36e-04, zz=5.98e-05, yxz=3.03e-04,| ValLoss=9.655e-03 (pde=7.99e-03, bc=1.17e-03, ic=1.26e-04, zz=6.54e-05, yxz=3.03e-04,)
# Epoch 2420 | TrainLoss=3.752e-03 (pde=2.01e-03, bc=1.22e-03, ic=1.15e-04, zz=6.13e-05, yxz=3.04e-04,| ValLoss=1.044e-02 (pde=8.80e-03, bc=1.15e-03, ic=1.06e-04, zz=6.66e-05, yxz=3.15e-04,)
# Epoch 2430 | TrainLoss=3.456e-03 (pde=1.74e-03, bc=1.19e-03, ic=1.13e-04, zz=4.45e-05, yxz=3.40e-04,| ValLoss=1.264e-02 (pde=1.10e-02, bc=1.14e-03, ic=1.04e-04, zz=4.93e-05, yxz=3.53e-04,)
# Epoch 2440 | TrainLoss=3.225e-03 (pde=1.57e-03, bc=1.14e-03, ic=1.26e-04, zz=4.52e-05, yxz=3.23e-04,| ValLoss=1.282e-02 (pde=1.12e-02, bc=1.09e-03, ic=1.16e-04, zz=5.07e-05, yxz=3.28e-04,)
#
# [Resample] epoch 2450: regenerating PDE/BC/IC points...
#
# Epoch 2450 | TrainLoss=3.049e-03 (pde=1.11e-02, bc=1.10e-03, ic=1.00e-04, zz=7.27e-05, yxz=3.29e-04,| ValLoss=1.439e-02 (pde=1.28e-02, bc=1.06e-03, ic=9.68e-05, zz=7.13e-05, yxz=3.29e-04,)
# Epoch 2460 | TrainLoss=4.273e-03 (pde=2.15e-03, bc=1.29e-03, ic=1.87e-04, zz=5.99e-05, yxz=3.92e-04,| ValLoss=9.896e-03 (pde=8.06e-03, bc=1.23e-03, ic=1.78e-04, zz=6.03e-05, yxz=3.70e-04,)
# Epoch 2470 | TrainLoss=3.278e-03 (pde=1.63e-03, bc=1.23e-03, ic=1.43e-04, zz=2.97e-05, yxz=2.12e-04,| ValLoss=1.215e-02 (pde=1.06e-02, bc=1.17e-03, ic=1.39e-04, zz=3.00e-05, yxz=2.06e-04,)
# Epoch 2480 | TrainLoss=2.990e-03 (pde=1.43e-03, bc=1.20e-03, ic=1.26e-04, zz=2.57e-05, yxz=1.81e-04,| ValLoss=1.224e-02 (pde=1.08e-02, bc=1.15e-03, ic=1.21e-04, zz=2.63e-05, yxz=1.77e-04,)
# Epoch 2490 | TrainLoss=2.814e-03 (pde=1.31e-03, bc=1.19e-03, ic=1.23e-04, zz=1.97e-05, yxz=1.55e-04,| ValLoss=1.222e-02 (pde=1.08e-02, bc=1.13e-03, ic=1.19e-04, zz=2.01e-05, yxz=1.62e-04,)
# Epoch 2499 | TrainLoss=2.706e-03 (pde=1.23e-03, bc=1.16e-03, ic=1.41e-04, zz=2.09e-05, yxz=1.42e-04,| ValLoss=1.201e-02 (pde=1.06e-02, bc=1.11e-03, ic=1.37e-04, zz=2.13e-05, yxz=1.46e-04,)
# Training finished.

# %%
# test 
t0 = 0.0
nx = 100
xs = np.linspace(X_MIN, X_MAX, nx)
ys = np.linspace(Y_MIN, Y_MAX, nx)
Xg, Yg = np.meshgrid(xs, ys)

x_grid = torch.from_numpy(Xg.flatten()[:,None]).to(device).double()
y_grid = torch.from_numpy(Yg.flatten()[:,None]).to(device).double()
t_grid = torch.full_like(x_grid, t0).to(device)  # 全部時間都固定為 t0

with torch.no_grad():
    phi_grid, u_true = compute_phi(x_grid, y_grid, t_grid)

# 預測 u
with torch.no_grad():
    inp_grid = torch.cat([x_grid, y_grid, phi_grid, t_grid], dim=1)
    u_pred = model(inp_grid).cpu().numpy().reshape(nx, nx)
    u_true = u_true.cpu().numpy().reshape(nx, nx)

# 逐點相對誤差
u_true_norm = np.max(np.abs(u_true))   # 真實解的 inf norm
error_rel = np.abs(u_pred - u_true) / (u_true_norm)
error_rel2 = np.abs(u_pred - u_true) / np.linalg.norm(u_true.flatten(), ord=2) # 分母是 true 的 L2 norm
error_abs = np.abs(u_pred - u_true)

# 整體相對誤差 ||u_pred - u_true||_2 / ||u_true||_2
error_tensor = torch.from_numpy(np.abs(u_pred - u_true)).double()
u_tensor = torch.from_numpy(np.abs(u_true)).double()
relL2 = torch.norm(error_tensor) / torch.norm(u_tensor)
print("Relative L2 error (grid):", relL2.item())

# 畫圖
fig, axs = plt.subplots(1, 3, figsize=(18,5))

im0 = axs[0].contourf(Xg, Yg, u_pred, 50, cmap='viridis')
fig.colorbar(im0, ax=axs[0])
axs[0].set_title('PINN Prediction $u_N$')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')

im1 = axs[1].contourf(Xg, Yg, u_true, 50, cmap='viridis')
fig.colorbar(im1, ax=axs[1])
axs[1].set_title('Analytical Solution $\\phi$')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')

im2 = axs[2].contourf(Xg, Yg, error_rel, 50, cmap='hot')
fig.colorbar(im2, ax=axs[2])
axs[2].set_title('Relative Error')
axs[2].set_xlabel('x')
axs[2].set_ylabel('y')

plt.tight_layout()
plt.show()
# Out:
# Relative L2 error (grid): 0.023667368879350455

# %%
fig, axs = plt.subplots(1, 3, figsize=(18,5))

im0 = axs[0].contourf(Xg, Yg, u_pred, 50, cmap='viridis')
fig.colorbar(im0, ax=axs[0])
axs[0].set_title(f'Prediction $u_N(x,y,t={t0:.2f})$')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].set_aspect('equal')


ax1 = fig.add_subplot(132, projection='3d')
ax1.plot_surface(Xg, Yg, u_pred, cmap='viridis', edgecolor='none')
ax1.set_title(f'Surface view ($t={t0:.2f}$)')
ax1.set_xlabel('x'); ax1.set_ylabel('y')
ax1.view_init(elev=70, azim=45)
#ax1.set_zlim(0, 0.2)

ax2 = fig.add_subplot(133, projection='3d')
ax2.contour3D(Xg, Yg, u_pred, 50, cmap='viridis')
ax2.set_title(f'3D contours ($t={t0:.2f}$)')
ax2.set_xlabel('x'); ax2.set_ylabel('y')
ax2.view_init(elev=70, azim=45)
#ax2.set_zlim(0, 0.2)

plt.tight_layout()
plt.show()

# %%
# loss 
epochs_arr = np.arange(len(loss_history))
val_epochs = np.linspace(0, len(loss_history)-1, len(val_history))
plt.figure(figsize=(8,5))
plt.semilogy(epochs_arr, loss_history, label='Training Loss')
plt.semilogy(val_epochs, val_history, label='Validation Loss (every 10 ep)')
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
