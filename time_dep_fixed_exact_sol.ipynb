# %% [markdown]
# 裂縫固定水平線, time-dependent heat equation, u = (x^2+y^2)*phi, f = r^2 * phi_t - 6*phi.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
rc('animation', html='jshtml')

torch.set_default_dtype(torch.float64)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

X_MIN, X_MAX = -1.0, 1.0
Y_MIN, Y_MAX = -1.0, 1.0
T_MIN, T_MAX = 0.0, 0.25  

N_f = 1000       
N_b_outer = 1000
N_b_crack = 1000
N_ic = 1000 # initial condition points on domain at t=0
N_ic_out = 1000  # initial condition points on domain at t=0
N_ic_crack = 1000   # initial condition points on domain at t=0
epochs = 1500
lambda_bc = 1.0
lambda_ic = 1.0
lambda_zz = 1.0
lambda_zz3 = 1.0

def compute_phi_and_derivs(x, y, t):
    x = x.view(-1, 1).to(device)
    y = y.view(-1, 1).to(device)
    t = t.view(-1, 1).to(device)
    angle = torch.tensor(np.pi * 0.0 / 4.0, dtype=x.dtype, device=x.device)
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=1e-12))
    inside = r - (x * torch.cos(angle) + y * torch.sin(angle))
    phi = torch.sqrt(0.5 * inside)
    sqrt_term = torch.sqrt(inside)
    phi_x = (torch.sqrt(torch.tensor(2.0, dtype=torch.float64)) *
             (x / r - torch.cos(angle))) / (4.0 * sqrt_term)
    phi_y = (torch.sqrt(torch.tensor(2.0, dtype=torch.float64)) *
             (y / r - torch.sin(angle))) / (4.0 * sqrt_term)
    u_true = (x**2 + y**2)  * phi

    return phi, phi_x, phi_y, u_true
# Out:
# Device: cpu

# %%
# MLP 
class MLP(nn.Module):
    def __init__(self, layers):
        super().__init__()
        self.net = nn.ModuleList()
        for i in range(len(layers)-1):
            self.net.append(nn.Linear(layers[i], layers[i+1]))
        self.activation = torch.tanh
        for m in self.net:
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight) #????
                nn.init.zeros_(m.bias)

    def forward(self, inp):
        z = inp
        for layer in self.net[:-1]:
            z = self.activation(layer(z))
        z = self.net[-1](z)
        return z

def partials_U_wrt_inputs(model, x, y, phi, t):
    x = x.view(-1,1)
    y = y.view(-1,1)
    phi = phi.view(-1,1)
    t = t.view(-1,1)

    inp = torch.cat([x, y, phi, t], dim=1).to(device)
    inp.requires_grad_(True)
    U = model(inp)  # (N,1)

    grads = torch.autograd.grad(U, inp, grad_outputs=torch.ones_like(U),
                                create_graph=True, retain_graph=True)[0]  # (N,4)
    U_x = grads[:,0:1]
    U_y = grads[:,1:2]
    U_z = grads[:,2:3]   
    U_t = grads[:,3:4]   
    return U, inp, U_x, U_y, U_z, U_t

def second_partials_U(model, inp, U_x, U_y, U_z):
    grad_Ux = torch.autograd.grad(U_x, inp, grad_outputs=torch.ones_like(U_x),
                                  create_graph=True, retain_graph=True)[0]
    grad_Uy = torch.autograd.grad(U_y, inp, grad_outputs=torch.ones_like(U_y),
                                  create_graph=True, retain_graph=True)[0]
    grad_Uz = torch.autograd.grad(U_z, inp, grad_outputs=torch.ones_like(U_z),
                                  create_graph=True, retain_graph=True)[0]

    U_xx = grad_Ux[:,0:1]
    U_xz = grad_Ux[:,2:3]
    U_yy = grad_Uy[:,1:2]
    U_yz = grad_Uy[:,2:3]
    U_zz = grad_Uz[:,2:3]

    return U_xx, U_yy, U_xz, U_yz, U_zz

def compute_residual_time(model, x, y, t):
    x = x.clone().detach().requires_grad_(True).to(device)
    y = y.clone().detach().requires_grad_(True).to(device)
    t = t.clone().detach().requires_grad_(True).to(device)

    phi, phi_x, phi_y, _ = compute_phi_and_derivs(x, y, t)
    U, inp, U_x, U_y, U_z, U_t = partials_U_wrt_inputs(model, x, y, phi, t)
    U_xx, U_yy, U_xz, U_yz, U_zz = second_partials_U(model, inp, U_x, U_y, U_z)

    r = torch.sqrt(torch.clamp(x**2 + y**2, min=1e-12))
    laplace_U = U_xx + U_yy
    lap = laplace_U + 2.0 * (U_xz * phi_x + U_yz * phi_y) + (1/(4*r)) * U_zz
    ut =  U_t
    residual = ut - lap + 6.0 * phi
    return residual, U, U_zz, U_xz, U_yz

# compute tip constraint 
def compute_zz_uN(model, t): # 在原點 U_xz=0, U_yz=0, U_zz=0 
    if not torch.is_tensor(t):
        t = torch.tensor([[t]], dtype=torch.float64, device=device)
    else:
        t = t.view(-1,1).to(dtype=torch.float64, device=device)

    x = torch.zeros_like(t)
    y = torch.zeros_like(t)

    phi, _, _, _ = compute_phi_and_derivs(x, y, t)
    _, inp, _, _, U_z, _ = partials_U_wrt_inputs(model, x, y, phi, t)

    grad_Uz = torch.autograd.grad(U_z, inp, grad_outputs=torch.ones_like(U_z),
                                  create_graph=True, retain_graph=True)[0]
    U_zz = grad_Uz[:,2:3]
    U_xz = grad_Uz[:,0:1]
    U_yz = grad_Uz[:,1:2]
    return torch.mean(U_zz**2 + U_xz**2 + U_yz**2)   


def compute_xyz_uN(model,x, y, t): # 在線上 U_xz=0, U_yz=0 
    if not torch.is_tensor(t):
        t = torch.tensor([[t]], dtype=torch.float64, device=device)
    else:
        t = t.view(-1,1).to(dtype=torch.float64, device=device)
    phi, phi_x, phi_y, _ = compute_phi_and_derivs(x, y, t)
    U, inp, U_x, U_y, U_z, U_t = partials_U_wrt_inputs(model, x, y, phi, t)
    grad_Uz = torch.autograd.grad(U_z, inp, grad_outputs=torch.ones_like(U_z),
                                  create_graph=True, retain_graph=True)[0]
    U_xz = grad_Uz[:,0:1]
    U_yz = grad_Uz[:,1:2]

    return torch.mean(U_xz**2+U_yz**2)   



# sampling
def sample_collocation(N): 
    x = torch.rand(N*2,1) * (X_MAX - X_MIN) + X_MIN 
    y = torch.rand(N*2,1) * (Y_MAX - Y_MIN) + Y_MIN 
    t = torch.rand(N*2,1) * (T_MAX - T_MIN) + T_MIN 
    # 點到 y=0 的距離 : |y|
    dist_to_crack = torch.abs(y)
    # mask 
    mask_crack = (dist_to_crack < 1e-8) 
    x, y, t = x[~mask_crack][:N], y[~mask_crack][:N], t[~mask_crack][:N] 
    return x.to(device), y.to(device), t.to(device)

def sample_outer_boundary(N):
    per_side = max(4, N // 4)
    xs, ys = [], []

    ys.append(torch.linspace(Y_MIN, Y_MAX, per_side).unsqueeze(1)); xs.append(torch.ones_like(ys[-1]) * X_MIN)
    ys.append(torch.linspace(Y_MIN, Y_MAX, per_side).unsqueeze(1)); xs.append(torch.ones_like(ys[-1]) * X_MAX)
    xs.append(torch.linspace(X_MIN, X_MAX, per_side).unsqueeze(1)); ys.append(torch.ones_like(xs[-1]) * Y_MIN)
    xs.append(torch.linspace(X_MIN, X_MAX, per_side).unsqueeze(1)); ys.append(torch.ones_like(xs[-1]) * Y_MAX)

    x = torch.cat(xs, dim=0)[:N]
    y = torch.cat(ys, dim=0)[:N]
    t = torch.rand(N, 1, device=device, dtype=torch.float64) * (T_MAX - T_MIN) + T_MIN

    return x.to(device), y.to(device), t


def sample_crack_boundary(N):
    t = torch.rand(N, 1, device=device, dtype=torch.float64) * (T_MAX - T_MIN) + T_MIN
    x_vals = torch.linspace(0, 1, N, device=device, dtype=torch.float64).unsqueeze(1)
    y_vals = x_vals * 0.0  
    return x_vals, y_vals, t


# model (input: x,y,phi,t) 
layers = [4, 64, 64, 1]
model = MLP(layers).to(device)

# %%
# training points 
x_f, y_f, t_f = sample_collocation(N_f)
x_b_out, y_b_out, t_b_out = sample_outer_boundary(N_b_outer)
x_b_crack, y_b_crack, t_b_crack = sample_crack_boundary(N_b_crack)
# move tensors to device
x_b_out = x_b_out.to(device); y_b_out = y_b_out.to(device); t_b_out = t_b_out.to(device)
x_b_crack = x_b_crack.to(device); y_b_crack = y_b_crack.to(device); t_b_crack = t_b_crack.to(device)
# cat
x_b = torch.cat([x_b_out, x_b_crack])
y_b = torch.cat([y_b_out, y_b_crack])
t_b = torch.cat([t_b_out, t_b_crack])
#
phi_b, _, _, g_b= compute_phi_and_derivs(x_b, y_b, t_b)
inp_bc = torch.cat([x_b, y_b, phi_b, t_b], dim=1)

# initial condition t=0
x_ic_f, y_ic_f = sample_collocation(N_ic)[0:2] 
x_ic_out, y_ic_out = sample_outer_boundary(N_ic_out)[0:2]  
x_ic_f = x_ic_f.view(-1,1)  
x_ic_out = x_ic_out.view(-1,1)  
x_ic = torch.cat([x_ic_f, x_ic_out])
y_ic_f = y_ic_f.view(-1,1)  
y_ic_out = y_ic_out.view(-1,1)  
y_ic = torch.cat([y_ic_f, y_ic_out])
t_ic = torch.zeros_like(x_ic).to(device)
##
phi_ic, _, _, u_ic = compute_phi_and_derivs(x_ic, y_ic, t_ic)
inp_ic = torch.cat([x_ic, y_ic, phi_ic, t_ic], dim=1)
##
# validation
x_f_val, y_f_val, t_f_val = sample_collocation(500)
x_b_out_val, y_b_out_val, t_b_out_val = sample_outer_boundary(200)
x_b_crack_val, y_b_crack_val, t_b_crack_val = sample_crack_boundary(100)
x_f_val = x_f_val.view(-1,1)  
x_b_out_val = x_b_out_val.view(-1,1)  
x_b_crack_val = x_b_crack_val.view(-1,1)
x_b_val = torch.cat([x_b_out_val, x_b_crack_val])
y_f_val = y_f_val.view(-1,1)  
y_b_out_val = y_b_out_val.view(-1,1)  
y_b_crack_val = y_b_crack_val.view(-1,1)
y_b_val = torch.cat([y_b_out_val, y_b_crack_val])
t_f_val = t_f_val.view(-1,1)  
t_b_out_val = t_b_out_val.view(-1,1)  
t_b_crack_val = t_b_crack_val.view(-1,1)
t_b_val = torch.cat([t_b_out_val, t_b_crack_val])
phi_b_val, _, _, g_b_val = compute_phi_and_derivs(x_b_val, y_b_val, t_b_val)
inp_bc_val = torch.cat([x_b_val, y_b_val, phi_b_val, t_b_val], dim=1)
###
x_ic_f_val, y_ic_f_val = sample_collocation(500)[0:2] 
x_ic_out_val, y_ic_out_val = sample_outer_boundary(200)[0:2]  
x_ic_f_val = x_ic_f_val.view(-1,1)  
x_ic_out_val = x_ic_out_val.view(-1,1)  
x_ic_val = torch.cat([x_ic_f_val, x_ic_out_val])
y_ic_f_val = y_ic_f_val.view(-1,1)  
y_ic_out_val = y_ic_out_val.view(-1,1)  
y_ic_val = torch.cat([y_ic_f_val, y_ic_out_val])
t_ic_val = torch.zeros_like(x_ic_val).to(device)
phi_ic_val, _, _, u0_val = compute_phi_and_derivs(x_ic_val, y_ic_val, t_ic_val)
inp_ic_val = torch.cat([x_ic_val, y_ic_val, phi_ic_val, t_ic_val], dim=1)
###
# optimizer
optimizer = optim.LBFGS(model.parameters(), lr=1.0, max_iter=20, history_size=50, line_search_fn="strong_wolfe")

print("Start training (time-dependent PINN)")

loss_history = []
val_history = []

for ep in range(epochs):
    def closure():
        optimizer.zero_grad()
        residual_f, _, Uzz_f, Uxz_f, Uyz_f = compute_residual_time(model, x_f, y_f, t_f)
        loss_pde = torch.mean(residual_f**2)
        u_bc = model(inp_bc)
        loss_bc = torch.mean((u_bc - g_b)**2)
        u_ic_pred = model(inp_ic)
        loss_ic = torch.mean((u_ic_pred - u_ic)**2)
        loss_zz = compute_zz_uN(model, t_b_crack)
        loss_yxz = compute_xyz_uN(model, x_b_crack, y_b_crack, t_b_crack)

        loss = (loss_pde
        + lambda_bc * (loss_bc)
        + lambda_ic * loss_ic
        + lambda_zz * loss_zz
        + lambda_zz3 * loss_yxz)
        loss.backward()
        return loss

    loss = optimizer.step(closure)
    loss_history.append(loss.item())
        # resampling 
    if ep % 50 == 0 and ep > 0:
        print(f"\n[Resample] epoch {ep}: regenerating PDE/BC/IC points...\n")

        # PDE collocation
        x_f, y_f, t_f = sample_collocation(N_f)

        # Outer boundary
        x_b_out, y_b_out, t_b_out = sample_outer_boundary(N_b_outer)

        # Crack boundary
        x_b_crack, y_b_crack, t_b_crack = sample_crack_boundary(N_b_crack)

        # Combine BC
        x_b = torch.cat([x_b_out, x_b_crack])
        y_b = torch.cat([y_b_out, y_b_crack])
        t_b = torch.cat([t_b_out, t_b_crack])
        phi_b, _, _, g_b = compute_phi_and_derivs(x_b, y_b, t_b)
        inp_bc = torch.cat([x_b, y_b, phi_b, t_b], dim=1)

        # Initial condition t=0
        x_ic_f, y_ic_f = sample_collocation(N_ic)[0:2]
        x_ic_out, y_ic_out = sample_outer_boundary(N_ic_out)[0:2]

        x_ic = torch.cat([
            x_ic_f.view(-1,1),
            x_ic_out.view(-1,1),
        ])
        y_ic = torch.cat([
            y_ic_f.view(-1,1),
            y_ic_out.view(-1,1),
        ])
        t_ic = torch.zeros_like(x_ic)
        phi_ic, _, _, u_ic = compute_phi_and_derivs(x_ic, y_ic, t_ic)
        inp_ic = torch.cat([x_ic, y_ic, phi_ic, t_ic], dim=1)


    if ep % 10 == 0 or ep == epochs-1:

        # validation
        res_val, _, Uzz_val, Uxz_val, Uyz_val = compute_residual_time(model, x_f_val, y_f_val, t_f_val)
        loss_pde_val = torch.mean(res_val**2)
        u_bc_val = model(inp_bc_val)
        loss_bc_val = torch.mean((u_bc_val - g_b_val)**2)
        u_ic_pred_val = model(inp_ic_val)
        loss_ic_val = torch.mean((u_ic_pred_val - u0_val)**2)
        loss_zz_val = compute_zz_uN(model, t_b_crack_val)
        loss_yxz_val = compute_xyz_uN(model, x_b_crack_val, y_b_crack_val,  t_b_crack_val)
        loss_val = (
            loss_pde_val
            + lambda_bc * loss_bc_val
            + lambda_ic * loss_ic_val
            + lambda_zz * loss_zz_val
            + lambda_zz3 *  loss_yxz_val)
        val_history.append(loss_val.item())

        # training loss 細項
        res_f, _, _, _, _ = compute_residual_time(model, x_f, y_f, t_f)
        loss_pde = torch.mean(res_f**2)
        loss_bc = torch.mean((model(inp_bc) - g_b)**2)
        loss_ic = torch.mean((model(inp_ic) - u_ic)**2)
        loss_zz = compute_zz_uN(model, t_b_crack)
        loss_yxz = compute_xyz_uN(model, x_b_crack, y_b_crack, t_b_crack)
        

        # 
        print(
            f"Epoch {ep:4d} | "
            f"TrainLoss={loss.item():.3e} "
            f"(pde={loss_pde:.2e}, bc={loss_bc:.2e}, ic={loss_ic:.2e}, "
            f"zz={loss_zz:.2e}, yxz={loss_yxz:.2e}, ) | "
            f"ValLoss={loss_val.item():.3e} "
            f"(pde={loss_pde_val:.2e}, bc={loss_bc_val:.2e}, ic={loss_ic_val:.2e}, "
            f"zz={loss_zz_val:.2e}, yxz={loss_yxz_val:.2e}, )")



print("Training finished.")
# Out:
# Start training (time-dependent PINN)
# Epoch    0 | TrainLoss=1.452e+01 (pde=1.07e-01, bc=2.00e-01, ic=1.68e-01, zz=9.53e-03, yxz=1.15e-03, ) | ValLoss=5.838e-01 (pde=1.12e-01, bc=2.55e-01, ic=2.06e-01, zz=1.01e-02, yxz=1.14e-03, )
# Epoch   10 | TrainLoss=6.930e-03 (pde=2.60e-03, bc=2.37e-03, ic=9.28e-04, zz=6.40e-05, yxz=9.67e-05, ) | ValLoss=6.065e-03 (pde=2.69e-03, bc=2.43e-03, ic=7.97e-04, zz=5.62e-05, yxz=9.76e-05, )
# Epoch  120 | TrainLoss=7.500e-04 (pde=1.07e-04, bc=5.03e-04, ic=1.33e-04, zz=4.66e-07, yxz=4.53e-06, ) | ValLoss=9.551e-04 (pde=4.43e-04, bc=4.17e-04, ic=9.06e-05, zz=4.68e-07, yxz=4.38e-06, )
# Epoch  130 | TrainLoss=7.214e-04 (pde=9.07e-05, bc=4.97e-04, ic=1.26e-04, zz=1.84e-07, yxz=3.84e-06, ) | ValLoss=8.482e-04 (pde=3.48e-04, bc=4.10e-04, ic=8.64e-05, zz=1.60e-07, yxz=3.90e-06, )
# Epoch  140 | TrainLoss=6.925e-04 (pde=7.45e-05, bc=4.87e-04, ic=1.24e-04, zz=1.15e-07, yxz=3.98e-06, ) | ValLoss=7.845e-04 (pde=2.91e-04, bc=4.03e-04, ic=8.54e-05, zz=1.17e-07, yxz=4.24e-06, )
#
# [Resample] epoch 150: regenerating PDE/BC/IC points...
#
# Epoch  150 | TrainLoss=6.711e-04 (pde=8.42e-05, bc=4.80e-04, ic=1.23e-04, zz=5.05e-07, yxz=4.90e-06, ) | ValLoss=6.272e-04 (pde=1.44e-04, bc=3.96e-04, ic=8.23e-05, zz=5.16e-07, yxz=5.03e-06, )
# Epoch  160 | TrainLoss=6.588e-04 (pde=5.81e-05, bc=4.72e-04, ic=1.21e-04, zz=7.85e-07, yxz=5.17e-06, ) | ValLoss=5.702e-04 (pde=9.30e-05, bc=3.90e-04, ic=8.05e-05, zz=9.20e-07, yxz=5.78e-06, )
# Epoch  170 | TrainLoss=6.414e-04 (pde=5.02e-05, bc=4.61e-04, ic=1.22e-04, zz=3.02e-07, yxz=5.98e-06, ) | ValLoss=5.449e-04 (pde=7.42e-05, bc=3.82e-04, ic=8.21e-05, zz=3.27e-07, yxz=6.81e-06, )
# Epoch  180 | TrainLoss=6.288e-04 (pde=4.83e-05, bc=4.56e-04, ic=1.17e-04, zz=3.01e-07, yxz=6.65e-06, ) | ValLoss=5.261e-04 (pde=6.68e-05, bc=3.73e-04, ic=7.84e-05, zz=2.86e-07, yxz=7.50e-06, )
# Epoch  190 | TrainLoss=6.173e-04 (pde=4.54e-05, bc=4.52e-04, ic=1.11e-04, zz=3.65e-07, yxz=7.92e-06, ) | ValLoss=5.177e-04 (pde=6.80e-05, bc=3.67e-04, ic=7.43e-05, zz=3.77e-07, yxz=8.46e-06, )
#
# [Resample] epoch 200: regenerating PDE/BC/IC points...
#
# Epoch  200 | TrainLoss=6.057e-04 (pde=7.60e-05, bc=4.41e-04, ic=1.09e-04, zz=2.77e-07, yxz=7.94e-06, ) | ValLoss=5.105e-04 (pde=7.01e-05, bc=3.59e-04, ic=7.32e-05, zz=3.15e-07, yxz=8.22e-06, )
# Epoch  210 | TrainLoss=6.065e-04 (pde=5.21e-05, bc=4.43e-04, ic=1.03e-04, zz=2.19e-07, yxz=6.65e-06, ) | ValLoss=5.022e-04 (pde=6.77e-05, bc=3.58e-04, ic=6.98e-05, zz=2.24e-07, yxz=6.86e-06, )
# Epoch  620 | TrainLoss=4.925e-04 (pde=1.55e-05, bc=3.97e-04, ic=7.65e-05, zz=1.16e-07, yxz=2.89e-06, ) | ValLoss=4.701e-04 (pde=9.88e-05, bc=3.11e-04, ic=5.71e-05, zz=1.10e-07, yxz=2.97e-06, )
# Epoch  630 | TrainLoss=4.910e-04 (pde=1.54e-05, bc=3.97e-04, ic=7.59e-05, zz=1.22e-07, yxz=2.71e-06, ) | ValLoss=4.876e-04 (pde=1.18e-04, bc=3.10e-04, ic=5.67e-05, zz=1.24e-07, yxz=2.80e-06, )
# Epoch  640 | TrainLoss=4.895e-04 (pde=1.55e-05, bc=3.96e-04, ic=7.52e-05, zz=9.15e-08, yxz=2.40e-06, ) | ValLoss=5.134e-04 (pde=1.45e-04, bc=3.09e-04, ic=5.61e-05, zz=8.63e-08, yxz=2.44e-06, )
#
# [Resample] epoch 650: regenerating PDE/BC/IC points...
#
# Epoch  650 | TrainLoss=4.883e-04 (pde=3.84e-05, bc=3.93e-04, ic=7.67e-05, zz=1.02e-07, yxz=2.23e-06, ) | ValLoss=5.370e-04 (pde=1.71e-04, bc=3.08e-04, ic=5.55e-05, zz=1.13e-07, yxz=2.27e-06, )
# Epoch  660 | TrainLoss=4.996e-04 (pde=2.20e-05, bc=3.98e-04, ic=7.61e-05, zz=1.51e-07, yxz=2.75e-06, ) | ValLoss=4.618e-04 (pde=9.19e-05, bc=3.12e-04, ic=5.53e-05, zz=1.56e-07, yxz=2.82e-06, )
# Epoch  670 | TrainLoss=4.967e-04 (pde=1.99e-05, bc=3.99e-04, ic=7.48e-05, zz=1.03e-07, yxz=2.29e-06, ) | ValLoss=4.631e-04 (pde=9.36e-05, bc=3.12e-04, ic=5.46e-05, zz=1.10e-07, yxz=2.34e-06, )
# Epoch  680 | TrainLoss=4.953e-04 (pde=1.87e-05, bc=4.01e-04, ic=7.34e-05, zz=1.43e-07, yxz=2.16e-06, ) | ValLoss=4.513e-04 (pde=8.18e-05, bc=3.13e-04, ic=5.39e-05, zz=1.60e-07, yxz=2.21e-06, )
# Epoch  690 | TrainLoss=4.940e-04 (pde=1.86e-05, bc=4.00e-04, ic=7.27e-05, zz=1.22e-07, yxz=2.01e-06, ) | ValLoss=4.702e-04 (pde=1.02e-04, bc=3.13e-04, ic=5.37e-05, zz=1.37e-07, yxz=2.08e-06, )
#
# [Resample] epoch 700: regenerating PDE/BC/IC points...
#
# Epoch  700 | TrainLoss=4.932e-04 (pde=3.42e-05, bc=4.06e-04, ic=7.03e-05, zz=9.37e-08, yxz=2.02e-06, ) | ValLoss=4.597e-04 (pde=9.06e-05, bc=3.13e-04, ic=5.37e-05, zz=1.06e-07, yxz=2.08e-06, )
# Epoch  710 | TrainLoss=4.931e-04 (pde=1.69e-05, bc=4.00e-04, ic=7.37e-05, zz=2.01e-07, yxz=2.38e-06, ) | ValLoss=5.031e-04 (pde=1.35e-04, bc=3.10e-04, ic=5.55e-05, zz=2.22e-07, yxz=2.44e-06, )
# Epoch  720 | TrainLoss=4.904e-04 (pde=1.74e-05, bc=3.97e-04, ic=7.39e-05, zz=1.15e-07, yxz=2.07e-06, ) | ValLoss=5.639e-04 (pde=1.99e-04, bc=3.07e-04, ic=5.57e-05, zz=1.28e-07, yxz=2.14e-06, )
# Epoch  730 | TrainLoss=4.884e-04 (pde=1.71e-05, bc=3.96e-04, ic=7.35e-05, zz=9.65e-08, yxz=1.98e-06, ) | ValLoss=5.775e-04 (pde=2.14e-04, bc=3.06e-04, ic=5.52e-05, zz=1.04e-07, yxz=2.04e-06, )
# Epoch  740 | TrainLoss=4.872e-04 (pde=1.74e-05, bc=3.95e-04, ic=7.25e-05, zz=9.82e-08, yxz=1.90e-06, ) | ValLoss=5.994e-04 (pde=2.37e-04, bc=3.06e-04, ic=5.47e-05, zz=1.07e-07, yxz=1.97e-06, )
#
# [Resample] epoch 750: regenerating PDE/BC/IC points...
#
# Epoch  750 | TrainLoss=4.858e-04 (pde=9.14e-05, bc=3.90e-04, ic=7.43e-05, zz=7.73e-08, yxz=1.89e-06, ) | ValLoss=6.106e-04 (pde=2.49e-04, bc=3.05e-04, ic=5.48e-05, zz=7.99e-08, yxz=1.96e-06, )
# Epoch  760 | TrainLoss=5.052e-04 (pde=2.80e-05, bc=3.99e-04, ic=7.54e-05, zz=1.14e-07, yxz=2.61e-06, ) | ValLoss=4.209e-04 (pde=4.83e-05, bc=3.14e-04, ic=5.59e-05, zz=1.34e-07, yxz=2.78e-06, )
# Epoch  770 | TrainLoss=5.018e-04 (pde=2.52e-05, bc=4.00e-04, ic=7.46e-05, zz=8.70e-08, yxz=2.18e-06, ) | ValLoss=4.132e-04 (pde=4.07e-05, bc=3.14e-04, ic=5.59e-05, zz=1.09e-07, yxz=2.25e-06, )
# Epoch  780 | TrainLoss=4.996e-04 (pde=2.41e-05, bc=3.99e-04, ic=7.36e-05, zz=9.25e-08, yxz=2.39e-06, ) | ValLoss=4.091e-04 (pde=3.72e-05, bc=3.14e-04, ic=5.53e-05, zz=1.15e-07, yxz=2.58e-06, )
# Epoch  790 | TrainLoss=4.983e-04 (pde=2.26e-05, bc=4.00e-04, ic=7.33e-05, zz=1.02e-07, yxz=2.39e-06, ) | ValLoss=4.065e-04 (pde=3.37e-05, bc=3.15e-04, ic=5.53e-05, zz=1.21e-07, yxz=2.61e-06, )
#
# [Resample] epoch 800: regenerating PDE/BC/IC points...
#
# Epoch  800 | TrainLoss=4.966e-04 (pde=2.29e-05, bc=3.99e-04, ic=7.38e-05, zz=1.35e-07, yxz=2.29e-06, ) | ValLoss=4.059e-04 (pde=3.31e-05, bc=3.15e-04, ic=5.54e-05, zz=1.41e-07, yxz=2.43e-06, )
# Epoch  810 | TrainLoss=4.872e-04 (pde=1.55e-05, bc=3.98e-04, ic=7.07e-05, zz=1.26e-07, yxz=2.26e-06, ) | ValLoss=4.374e-04 (pde=7.04e-05, bc=3.12e-04, ic=5.28e-05, zz=1.25e-07, yxz=2.32e-06, )
# Epoch  820 | TrainLoss=4.854e-04 (pde=1.58e-05, bc=3.97e-04, ic=7.05e-05, zz=4.72e-08, yxz=2.07e-06, ) | ValLoss=4.611e-04 (pde=9.61e-05, bc=3.10e-04, ic=5.28e-05, zz=5.19e-08, yxz=2.15e-06, )
# Epoch  830 | TrainLoss=4.838e-04 (pde=1.66e-05, bc=3.97e-04, ic=6.83e-05, zz=1.21e-07, yxz=1.98e-06, ) | ValLoss=4.754e-04 (pde=1.12e-04, bc=3.10e-04, ic=5.16e-05, zz=1.27e-07, yxz=2.07e-06, )
# Epoch  840 | TrainLoss=4.827e-04 (pde=1.65e-05, bc=3.96e-04, ic=6.81e-05, zz=6.60e-08, yxz=1.88e-06, ) | ValLoss=4.788e-04 (pde=1.16e-04, bc=3.10e-04, ic=5.15e-05, zz=6.93e-08, yxz=1.98e-06, )
#
# [Resample] epoch 850: regenerating PDE/BC/IC points...
#
# Epoch  850 | TrainLoss=4.816e-04 (pde=4.28e-05, bc=3.94e-04, ic=6.82e-05, zz=4.91e-08, yxz=1.95e-06, ) | ValLoss=4.932e-04 (pde=1.31e-04, bc=3.09e-04, ic=5.08e-05, zz=5.16e-08, yxz=2.06e-06, )
# Epoch  860 | TrainLoss=4.887e-04 (pde=1.91e-05, bc=3.93e-04, ic=7.36e-05, zz=4.04e-08, yxz=2.26e-06, ) | ValLoss=4.669e-04 (pde=1.00e-04, bc=3.10e-04, ic=5.44e-05, zz=4.60e-08, yxz=2.45e-06, )
# Epoch  870 | TrainLoss=4.863e-04 (pde=1.74e-05, bc=3.94e-04, ic=7.25e-05, zz=2.21e-08, yxz=2.03e-06, ) | ValLoss=4.558e-04 (pde=8.95e-05, bc=3.10e-04, ic=5.40e-05, zz=2.29e-08, yxz=2.17e-06, )
# Epoch  880 | TrainLoss=4.845e-04 (pde=1.70e-05, bc=3.94e-04, ic=7.17e-05, zz=3.05e-08, yxz=1.95e-06, ) | ValLoss=4.575e-04 (pde=9.07e-05, bc=3.11e-04, ic=5.38e-05, zz=3.47e-08, yxz=2.04e-06, )
# Epoch  890 | TrainLoss=4.834e-04 (pde=1.64e-05, bc=3.94e-04, ic=7.10e-05, zz=4.68e-08, yxz=1.99e-06, ) | ValLoss=4.628e-04 (pde=9.60e-05, bc=3.11e-04, ic=5.37e-05, zz=5.47e-08, yxz=2.13e-06, )
#
# [Resample] epoch 900: regenerating PDE/BC/IC points...
#
# Epoch  900 | TrainLoss=4.824e-04 (pde=3.32e-05, bc=4.00e-04, ic=7.16e-05, zz=3.34e-08, yxz=1.84e-06, ) | ValLoss=4.648e-04 (pde=9.85e-05, bc=3.11e-04, ic=5.38e-05, zz=3.48e-08, yxz=1.90e-06, )
# Epoch  910 | TrainLoss=4.944e-04 (pde=2.15e-05, bc=3.98e-04, ic=7.27e-05, zz=3.30e-08, yxz=1.98e-06, ) | ValLoss=4.287e-04 (pde=6.29e-05, bc=3.10e-04, ic=5.37e-05, zz=2.78e-08, yxz=2.07e-06, )
# Epoch  920 | TrainLoss=4.923e-04 (pde=2.03e-05, bc=3.97e-04, ic=7.28e-05, zz=5.16e-08, yxz=1.83e-06, ) | ValLoss=4.248e-04 (pde=5.99e-05, bc=3.09e-04, ic=5.34e-05, zz=5.91e-08, yxz=1.87e-06, )
# Epoch  930 | TrainLoss=4.913e-04 (pde=1.88e-05, bc=3.97e-04, ic=7.32e-05, zz=4.29e-08, yxz=1.90e-06, ) | ValLoss=4.138e-04 (pde=4.86e-05, bc=3.10e-04, ic=5.36e-05, zz=4.89e-08, yxz=1.97e-06, )
# Epoch  940 | TrainLoss=4.905e-04 (pde=1.77e-05, bc=3.97e-04, ic=7.40e-05, zz=2.56e-08, yxz=1.77e-06, ) | ValLoss=4.086e-04 (pde=4.34e-05, bc=3.09e-04, ic=5.41e-05, zz=2.32e-08, yxz=1.83e-06, )
#
# [Resample] epoch 950: regenerating PDE/BC/IC points...
#
# Epoch  950 | TrainLoss=4.897e-04 (pde=2.35e-05, bc=3.99e-04, ic=7.73e-05, zz=4.11e-08, yxz=1.73e-06, ) | ValLoss=4.055e-04 (pde=4.07e-05, bc=3.09e-04, ic=5.41e-05, zz=4.00e-08, yxz=1.81e-06, )
# Epoch  960 | TrainLoss=4.908e-04 (pde=1.51e-05, bc=3.97e-04, ic=7.67e-05, zz=4.16e-08, yxz=1.83e-06, ) | ValLoss=4.619e-04 (pde=9.91e-05, bc=3.07e-04, ic=5.40e-05, zz=4.47e-08, yxz=1.90e-06, )
# Epoch  970 | TrainLoss=4.891e-04 (pde=1.53e-05, bc=3.94e-04, ic=7.79e-05, zz=3.03e-08, yxz=1.78e-06, ) | ValLoss=4.954e-04 (pde=1.34e-04, bc=3.05e-04, ic=5.42e-05, zz=3.12e-08, yxz=1.86e-06, )
# Epoch  980 | TrainLoss=4.878e-04 (pde=1.43e-05, bc=3.93e-04, ic=7.90e-05, zz=3.44e-08, yxz=1.67e-06, ) | ValLoss=5.008e-04 (pde=1.40e-04, bc=3.04e-04, ic=5.45e-05, zz=3.90e-08, yxz=1.79e-06, )
# Epoch  990 | TrainLoss=4.870e-04 (pde=1.41e-05, bc=3.92e-04, ic=7.94e-05, zz=3.45e-08, yxz=1.62e-06, ) | ValLoss=5.049e-04 (pde=1.45e-04, bc=3.04e-04, ic=5.46e-05, zz=3.31e-08, yxz=1.68e-06, )
#
# [Resample] epoch 1000: regenerating PDE/BC/IC points...
#
# Epoch 1000 | TrainLoss=4.862e-04 (pde=6.36e-05, bc=3.91e-04, ic=7.59e-05, zz=5.17e-08, yxz=1.73e-06, ) | ValLoss=5.467e-04 (pde=1.88e-04, bc=3.03e-04, ic=5.42e-05, zz=5.10e-08, yxz=1.76e-06, )
# Epoch 1010 | TrainLoss=5.042e-04 (pde=2.72e-05, bc=3.99e-04, ic=7.56e-05, zz=3.93e-08, yxz=2.05e-06, ) | ValLoss=4.316e-04 (pde=6.43e-05, bc=3.10e-04, ic=5.50e-05, zz=3.58e-08, yxz=2.13e-06, )
# Epoch 1020 | TrainLoss=4.999e-04 (pde=2.33e-05, bc=3.97e-04, ic=7.76e-05, zz=3.51e-08, yxz=2.00e-06, ) | ValLoss=4.262e-04 (pde=5.96e-05, bc=3.09e-04, ic=5.60e-05, zz=3.99e-08, yxz=2.09e-06, )
# Epoch 1030 | TrainLoss=4.979e-04 (pde=2.10e-05, bc=3.97e-04, ic=7.83e-05, zz=1.50e-08, yxz=1.78e-06, ) | ValLoss=4.140e-04 (pde=4.71e-05, bc=3.09e-04, ic=5.60e-05, zz=1.49e-08, yxz=1.82e-06, )
# Epoch 1040 | TrainLoss=4.965e-04 (pde=1.96e-05, bc=3.98e-04, ic=7.74e-05, zz=3.21e-08, yxz=1.72e-06, ) | ValLoss=4.112e-04 (pde=4.43e-05, bc=3.10e-04, ic=5.54e-05, zz=3.37e-08, yxz=1.73e-06, )
#
# [Resample] epoch 1050: regenerating PDE/BC/IC points...
#
# Epoch 1050 | TrainLoss=4.952e-04 (pde=2.35e-05, bc=3.97e-04, ic=7.79e-05, zz=4.03e-08, yxz=1.74e-06, ) | ValLoss=4.081e-04 (pde=4.14e-05, bc=3.09e-04, ic=5.57e-05, zz=3.82e-08, yxz=1.84e-06, )
# Epoch 1060 | TrainLoss=4.912e-04 (pde=1.48e-05, bc=3.98e-04, ic=7.55e-05, zz=1.19e-07, yxz=2.14e-06, ) | ValLoss=4.203e-04 (pde=5.53e-05, bc=3.08e-04, ic=5.43e-05, zz=1.12e-07, yxz=2.21e-06, )
# Epoch 1070 | TrainLoss=4.896e-04 (pde=1.44e-05, bc=3.97e-04, ic=7.62e-05, zz=4.66e-08, yxz=1.78e-06, ) | ValLoss=4.206e-04 (pde=5.61e-05, bc=3.08e-04, ic=5.47e-05, zz=4.40e-08, yxz=1.85e-06, )
# Epoch 1080 | TrainLoss=4.889e-04 (pde=1.47e-05, bc=3.96e-04, ic=7.61e-05, zz=3.06e-08, yxz=1.65e-06, ) | ValLoss=4.259e-04 (pde=6.22e-05, bc=3.07e-04, ic=5.46e-05, zz=2.82e-08, yxz=1.75e-06, )
# Epoch 1090 | TrainLoss=4.883e-04 (pde=1.45e-05, bc=3.96e-04, ic=7.63e-05, zz=3.71e-08, yxz=1.68e-06, ) | ValLoss=4.256e-04 (pde=6.22e-05, bc=3.07e-04, ic=5.46e-05, zz=3.94e-08, yxz=1.80e-06, )
#
# [Resample] epoch 1100: regenerating PDE/BC/IC points...
#
# Epoch 1100 | TrainLoss=4.880e-04 (pde=2.78e-05, bc=3.94e-04, ic=7.59e-05, zz=4.26e-08, yxz=1.66e-06, ) | ValLoss=4.267e-04 (pde=6.36e-05, bc=3.07e-04, ic=5.47e-05, zz=4.51e-08, yxz=1.75e-06, )
# Epoch 1110 | TrainLoss=4.830e-04 (pde=1.40e-05, bc=3.93e-04, ic=7.32e-05, zz=3.95e-08, yxz=2.04e-06, ) | ValLoss=4.615e-04 (pde=1.01e-04, bc=3.06e-04, ic=5.29e-05, zz=4.26e-08, yxz=2.14e-06, )
# Epoch 1120 | TrainLoss=4.804e-04 (pde=1.52e-05, bc=3.91e-04, ic=7.20e-05, zz=2.48e-08, yxz=1.83e-06, ) | ValLoss=5.625e-04 (pde=2.04e-04, bc=3.04e-04, ic=5.22e-05, zz=2.59e-08, yxz=1.91e-06, )
# Epoch 1130 | TrainLoss=4.790e-04 (pde=1.56e-05, bc=3.90e-04, ic=7.08e-05, zz=5.09e-08, yxz=1.99e-06, ) | ValLoss=6.317e-04 (pde=2.75e-04, bc=3.04e-04, ic=5.15e-05, zz=5.17e-08, yxz=2.03e-06, )
# Epoch 1140 | TrainLoss=4.778e-04 (pde=1.68e-05, bc=3.89e-04, ic=6.97e-05, zz=4.33e-08, yxz=1.97e-06, ) | ValLoss=7.136e-04 (pde=3.58e-04, bc=3.03e-04, ic=5.07e-05, zz=4.61e-08, yxz=2.08e-06, )
#
# [Resample] epoch 1150: regenerating PDE/BC/IC points...
#
# Epoch 1150 | TrainLoss=4.766e-04 (pde=8.87e-05, bc=3.90e-04, ic=6.96e-05, zz=3.78e-08, yxz=1.93e-06, ) | ValLoss=7.763e-04 (pde=4.22e-04, bc=3.02e-04, ic=5.01e-05, zz=4.04e-08, yxz=2.00e-06, )
# Epoch 1160 | TrainLoss=4.946e-04 (pde=1.95e-05, bc=3.95e-04, ic=7.73e-05, zz=3.67e-08, yxz=1.91e-06, ) | ValLoss=4.020e-04 (pde=3.67e-05, bc=3.08e-04, ic=5.53e-05, zz=3.41e-08, yxz=2.17e-06, )
# Epoch 1170 | TrainLoss=4.924e-04 (pde=1.79e-05, bc=3.97e-04, ic=7.56e-05, zz=2.52e-08, yxz=1.99e-06, ) | ValLoss=4.138e-04 (pde=4.84e-05, bc=3.09e-04, ic=5.46e-05, zz=2.19e-08, yxz=2.23e-06, )
# Epoch 1180 | TrainLoss=4.908e-04 (pde=1.74e-05, bc=3.97e-04, ic=7.47e-05, zz=3.46e-08, yxz=1.94e-06, ) | ValLoss=4.268e-04 (pde=6.16e-05, bc=3.09e-04, ic=5.44e-05, zz=3.68e-08, yxz=2.08e-06, )
# Epoch 1190 | TrainLoss=4.898e-04 (pde=1.68e-05, bc=3.96e-04, ic=7.48e-05, zz=6.33e-08, yxz=1.94e-06, ) | ValLoss=4.446e-04 (pde=7.95e-05, bc=3.08e-04, ic=5.45e-05, zz=6.68e-08, yxz=2.12e-06, )
#
# [Resample] epoch 1200: regenerating PDE/BC/IC points...
#
# Epoch 1200 | TrainLoss=4.889e-04 (pde=3.06e-05, bc=3.98e-04, ic=7.75e-05, zz=8.36e-08, yxz=2.03e-06, ) | ValLoss=4.499e-04 (pde=8.57e-05, bc=3.07e-04, ic=5.47e-05, zz=8.11e-08, yxz=1.97e-06, )
# Epoch 1210 | TrainLoss=4.916e-04 (pde=1.36e-05, bc=3.96e-04, ic=8.04e-05, zz=4.50e-08, yxz=1.61e-06, ) | ValLoss=4.315e-04 (pde=6.73e-05, bc=3.06e-04, ic=5.62e-05, zz=4.23e-08, yxz=1.56e-06, )
# Epoch 1220 | TrainLoss=4.902e-04 (pde=1.38e-05, bc=3.93e-04, ic=8.12e-05, zz=5.37e-08, yxz=1.72e-06, ) | ValLoss=4.548e-04 (pde=9.11e-05, bc=3.05e-04, ic=5.66e-05, zz=5.44e-08, yxz=1.65e-06, )
# Epoch 1230 | TrainLoss=4.891e-04 (pde=1.39e-05, bc=3.92e-04, ic=8.17e-05, zz=2.86e-08, yxz=1.78e-06, ) | ValLoss=4.858e-04 (pde=1.23e-04, bc=3.04e-04, ic=5.69e-05, zz=2.59e-08, yxz=1.73e-06, )
# Epoch 1240 | TrainLoss=4.887e-04 (pde=1.40e-05, bc=3.92e-04, ic=8.15e-05, zz=2.60e-08, yxz=1.70e-06, ) | ValLoss=4.917e-04 (pde=1.29e-04, bc=3.04e-04, ic=5.67e-05, zz=2.32e-08, yxz=1.59e-06, )
#
# [Resample] epoch 1250: regenerating PDE/BC/IC points...
#
# Epoch 1250 | TrainLoss=4.887e-04 (pde=2.13e-05, bc=3.89e-04, ic=7.65e-05, zz=2.68e-08, yxz=1.68e-06, ) | ValLoss=4.917e-04 (pde=1.29e-04, bc=3.04e-04, ic=5.67e-05, zz=2.32e-08, yxz=1.59e-06, )
# Epoch 1260 | TrainLoss=4.806e-04 (pde=1.31e-05, bc=3.90e-04, ic=7.57e-05, zz=5.62e-08, yxz=1.61e-06, ) | ValLoss=4.341e-04 (pde=7.06e-05, bc=3.05e-04, ic=5.66e-05, zz=5.93e-08, yxz=1.63e-06, )
# Epoch 1270 | TrainLoss=4.796e-04 (pde=1.32e-05, bc=3.89e-04, ic=7.59e-05, zz=4.41e-08, yxz=1.65e-06, ) | ValLoss=4.515e-04 (pde=8.87e-05, bc=3.04e-04, ic=5.67e-05, zz=4.01e-08, yxz=1.64e-06, )
# Epoch 1280 | TrainLoss=4.787e-04 (pde=1.40e-05, bc=3.88e-04, ic=7.51e-05, zz=3.78e-08, yxz=1.53e-06, ) | ValLoss=4.727e-04 (pde=1.11e-04, bc=3.04e-04, ic=5.62e-05, zz=3.32e-08, yxz=1.54e-06, )
# Epoch 1290 | TrainLoss=4.782e-04 (pde=1.42e-05, bc=3.87e-04, ic=7.52e-05, zz=2.24e-08, yxz=1.57e-06, ) | ValLoss=4.846e-04 (pde=1.24e-04, bc=3.03e-04, ic=5.61e-05, zz=1.93e-08, yxz=1.61e-06, )
#
# [Resample] epoch 1300: regenerating PDE/BC/IC points...
#
# Epoch 1300 | TrainLoss=4.782e-04 (pde=2.89e-05, bc=3.87e-04, ic=7.53e-05, zz=2.11e-08, yxz=1.56e-06, ) | ValLoss=4.846e-04 (pde=1.24e-04, bc=3.03e-04, ic=5.61e-05, zz=1.93e-08, yxz=1.61e-06, )
# Epoch 1310 | TrainLoss=4.824e-04 (pde=1.51e-05, bc=3.93e-04, ic=7.17e-05, zz=6.51e-08, yxz=2.07e-06, ) | ValLoss=4.412e-04 (pde=7.76e-05, bc=3.07e-04, ic=5.39e-05, zz=7.14e-08, yxz=2.22e-06, )
# Epoch 1320 | TrainLoss=4.809e-04 (pde=1.49e-05, bc=3.94e-04, ic=7.00e-05, zz=6.60e-08, yxz=1.74e-06, ) | ValLoss=4.351e-04 (pde=7.19e-05, bc=3.08e-04, ic=5.34e-05, zz=7.95e-08, yxz=1.80e-06, )
# Epoch 1330 | TrainLoss=4.801e-04 (pde=1.47e-05, bc=3.95e-04, ic=6.87e-05, zz=6.10e-08, yxz=1.66e-06, ) | ValLoss=4.422e-04 (pde=7.89e-05, bc=3.08e-04, ic=5.30e-05, zz=7.36e-08, yxz=1.77e-06, )
# Epoch 1340 | TrainLoss=4.794e-04 (pde=1.47e-05, bc=3.94e-04, ic=6.85e-05, zz=8.66e-08, yxz=1.70e-06, ) | ValLoss=4.450e-04 (pde=8.21e-05, bc=3.08e-04, ic=5.29e-05, zz=9.84e-08, yxz=1.84e-06, )
#
# [Resample] epoch 1350: regenerating PDE/BC/IC points...
#
# Epoch 1350 | TrainLoss=4.789e-04 (pde=3.46e-05, bc=3.99e-04, ic=7.49e-05, zz=1.28e-07, yxz=1.69e-06, ) | ValLoss=4.515e-04 (pde=8.91e-05, bc=3.08e-04, ic=5.27e-05, zz=1.38e-07, yxz=1.78e-06, )
# Epoch 1360 | TrainLoss=4.889e-04 (pde=1.52e-05, bc=3.96e-04, ic=7.61e-05, zz=2.92e-08, yxz=1.86e-06, ) | ValLoss=4.781e-04 (pde=1.18e-04, bc=3.05e-04, ic=5.29e-05, zz=2.65e-08, yxz=1.90e-06, )
# Epoch 1370 | TrainLoss=4.877e-04 (pde=1.47e-05, bc=3.95e-04, ic=7.64e-05, zz=3.23e-08, yxz=1.68e-06, ) | ValLoss=4.929e-04 (pde=1.34e-04, bc=3.04e-04, ic=5.30e-05, zz=3.19e-08, yxz=1.75e-06, )
# Epoch 1380 | TrainLoss=4.868e-04 (pde=1.44e-05, bc=3.95e-04, ic=7.54e-05, zz=4.65e-08, yxz=1.60e-06, ) | ValLoss=5.063e-04 (pde=1.48e-04, bc=3.04e-04, ic=5.24e-05, zz=5.23e-08, yxz=1.64e-06, )
# Epoch 1390 | TrainLoss=4.862e-04 (pde=1.43e-05, bc=3.96e-04, ic=7.46e-05, zz=3.51e-08, yxz=1.50e-06, ) | ValLoss=5.070e-04 (pde=1.49e-04, bc=3.05e-04, ic=5.18e-05, zz=3.79e-08, yxz=1.54e-06, )
#
# [Resample] epoch 1400: regenerating PDE/BC/IC points...
#
# Epoch 1400 | TrainLoss=4.857e-04 (pde=2.23e-05, bc=3.95e-04, ic=7.43e-05, zz=3.91e-08, yxz=1.59e-06, ) | ValLoss=5.202e-04 (pde=1.63e-04, bc=3.04e-04, ic=5.17e-05, zz=4.81e-08, yxz=1.60e-06, )
# Epoch 1410 | TrainLoss=4.866e-04 (pde=1.53e-05, bc=3.90e-04, ic=7.91e-05, zz=4.82e-08, yxz=1.59e-06, ) | ValLoss=4.841e-04 (pde=1.24e-04, bc=3.04e-04, ic=5.51e-05, zz=5.89e-08, yxz=1.59e-06, )
# Epoch 1420 | TrainLoss=4.855e-04 (pde=1.49e-05, bc=3.90e-04, ic=7.94e-05, zz=2.45e-08, yxz=1.55e-06, ) | ValLoss=4.774e-04 (pde=1.17e-04, bc=3.04e-04, ic=5.54e-05, zz=3.06e-08, yxz=1.59e-06, )
# Epoch 1430 | TrainLoss=4.847e-04 (pde=1.51e-05, bc=3.89e-04, ic=7.89e-05, zz=2.51e-08, yxz=1.54e-06, ) | ValLoss=4.915e-04 (pde=1.31e-04, bc=3.03e-04, ic=5.53e-05, zz=2.80e-08, yxz=1.64e-06, )
# Epoch 1440 | TrainLoss=4.840e-04 (pde=1.52e-05, bc=3.89e-04, ic=7.81e-05, zz=5.35e-08, yxz=1.57e-06, ) | ValLoss=5.045e-04 (pde=1.45e-04, bc=3.03e-04, ic=5.48e-05, zz=6.46e-08, yxz=1.66e-06, )
#
# [Resample] epoch 1450: regenerating PDE/BC/IC points...
#
# Epoch 1450 | TrainLoss=4.836e-04 (pde=3.49e-05, bc=3.90e-04, ic=8.04e-05, zz=2.81e-08, yxz=1.52e-06, ) | ValLoss=5.062e-04 (pde=1.47e-04, bc=3.03e-04, ic=5.47e-05, zz=3.05e-08, yxz=1.61e-06, )
# Epoch 1460 | TrainLoss=4.925e-04 (pde=1.81e-05, bc=3.95e-04, ic=7.79e-05, zz=8.04e-08, yxz=1.60e-06, ) | ValLoss=4.619e-04 (pde=1.01e-04, bc=3.06e-04, ic=5.31e-05, zz=8.77e-08, yxz=1.61e-06, )
# Epoch 1470 | TrainLoss=4.905e-04 (pde=1.67e-05, bc=3.94e-04, ic=7.76e-05, zz=5.25e-08, yxz=1.65e-06, ) | ValLoss=4.594e-04 (pde=9.78e-05, bc=3.07e-04, ic=5.28e-05, zz=6.05e-08, yxz=1.71e-06, )
# Epoch 1480 | TrainLoss=4.895e-04 (pde=1.58e-05, bc=3.95e-04, ic=7.69e-05, zz=6.70e-08, yxz=1.70e-06, ) | ValLoss=4.527e-04 (pde=9.08e-05, bc=3.07e-04, ic=5.27e-05, zz=6.59e-08, yxz=1.78e-06, )
# Epoch 1490 | TrainLoss=4.891e-04 (pde=1.56e-05, bc=3.95e-04, ic=7.65e-05, zz=4.00e-08, yxz=1.66e-06, ) | ValLoss=4.502e-04 (pde=8.83e-05, bc=3.08e-04, ic=5.25e-05, zz=4.06e-08, yxz=1.74e-06, )
# Epoch 1499 | TrainLoss=4.890e-04 (pde=1.56e-05, bc=3.95e-04, ic=7.65e-05, zz=4.15e-08, yxz=1.72e-06, ) | ValLoss=4.500e-04 (pde=8.81e-05, bc=3.08e-04, ic=5.26e-05, zz=4.21e-08, yxz=1.79e-06, )
# Training finished.

# %%
# test 
t0 = 0.14
nx = 100
xs = np.linspace(X_MIN, X_MAX, nx)
ys = np.linspace(Y_MIN, Y_MAX, nx)
Xg, Yg = np.meshgrid(xs, ys)

x_grid = torch.from_numpy(Xg.flatten()[:,None]).to(device).double()
y_grid = torch.from_numpy(Yg.flatten()[:,None]).to(device).double()
t_grid = torch.full_like(x_grid, t0).to(device)  # 全部時間都固定為 t0

def compute_phi(x, y, t):
    x = x.view(-1,1).to(device)
    y = y.view(-1,1).to(device)
    t = t.view(-1,1).to(device)
    angle = torch.tensor(np.pi * 0.0 / 4.0, dtype=x.dtype, device=x.device)
    #r = torch.sqrt(x**2 + y**2)
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=1e-12))
    inside = r - (x * torch.cos(angle) + y * torch.sin(angle))
    u_true = (x**2 + y**2)  * torch.sqrt( 0.5 * inside)
    return torch.sqrt( 0.5 * inside), u_true


with torch.no_grad():
    phi_grid, u_true_grid = compute_phi(x_grid, y_grid, t_grid)


# 預測 u
with torch.no_grad():
    inp_grid = torch.cat([x_grid, y_grid, phi_grid, t_grid], dim=1)
    u_pred = model(inp_grid)
    u_pred = u_pred.cpu().numpy().reshape(nx, nx)
    u_true_grid = u_true_grid.cpu().numpy().reshape(nx, nx)

# 逐點相對誤差
u_true_norm = np.max(np.abs(u_true_grid))   # 真實解的 inf norm
error_rel = np.abs(u_pred - u_true_grid) / (u_true_norm)
error_rel2 = np.abs(u_pred - u_true_grid) / np.linalg.norm(u_true_grid.flatten(), ord=2) # 分母是 true 的 L2 norm
error_abs = np.abs(u_pred - u_true_grid)

# 整體相對誤差 ||u_pred - u_true||_2 / ||u_true||_2
error_tensor = torch.from_numpy(np.abs(u_pred - u_true_grid)).double()
u_tensor = torch.from_numpy(np.abs(u_true_grid)).double()
relL2 = torch.norm(error_tensor) / torch.norm(u_tensor)
print("Relative L2 error (grid):", relL2.item())

# 畫圖
fig, axs = plt.subplots(1, 3, figsize=(18,5))

im0 = axs[0].contourf(Xg, Yg, u_pred, 50, cmap='viridis')
fig.colorbar(im0, ax=axs[0])
axs[0].set_title('PINN Prediction $u_N$')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')

im1 = axs[1].contourf(Xg, Yg, u_true_grid, 50, cmap='viridis')
fig.colorbar(im1, ax=axs[1])
axs[1].set_title('Analytical Solution $\\phi$')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')

im2 = axs[2].contourf(Xg, Yg, error_rel, 50, cmap='hot')
fig.colorbar(im2, ax=axs[2])
axs[2].set_title('Relative Error')
axs[2].set_xlabel('x')
axs[2].set_ylabel('y')

plt.tight_layout()
plt.show()
# Out:
# Relative L2 error (grid): 0.011971386300623409

# %%
# loss 
epochs_arr = np.arange(len(loss_history))
val_epochs = np.linspace(0, len(loss_history)-1, len(val_history))
plt.figure(figsize=(8,5))
plt.semilogy(epochs_arr, loss_history, label='Training Loss')
plt.semilogy(val_epochs, val_history, label='Validation Loss (every 10 ep)')
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
