# %% [markdown]
# 裂縫固定水平線, time-dependent heat equation, u = (x^2+y^2)*phi, f = r^2 * phi_t - 6*phi.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
rc('animation', html='jshtml')

torch.set_default_dtype(torch.float64)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

X_MIN, X_MAX = -1.0, 1.0
Y_MIN, Y_MAX = -1.0, 1.0
T_MIN, T_MAX = 0.0, 0.25  

N_f = 1000       
N_b_outer = 1000
N_b_crack = 1000
N_ic = 1000 # initial condition points on domain at t=0
N_ic_out = 1000  # initial condition points on domain at t=0
N_ic_crack = 1000   # initial condition points on domain at t=0
epochs = 2500
lambda_bc = 1.0
lambda_ic = 1.0
lambda_zz = 1.0
lambda_zz3 = 1.0

def compute_phi_and_derivs(x, y, t):
    x = x.view(-1, 1).to(device)
    y = y.view(-1, 1).to(device)
    t = t.view(-1, 1).to(device)
    angle = torch.tensor(np.pi * 0.0 / 4.0, dtype=x.dtype, device=x.device)
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=1e-12))
    inside = r - (x * torch.cos(angle) + y * torch.sin(angle))
    phi = torch.sqrt(0.5 * inside)
    sqrt_term = torch.sqrt(inside)
    phi_x = (torch.sqrt(torch.tensor(2.0, dtype=torch.float64)) *
             (x / r - torch.cos(angle))) / (4.0 * sqrt_term)
    phi_y = (torch.sqrt(torch.tensor(2.0, dtype=torch.float64)) *
             (y / r - torch.sin(angle))) / (4.0 * sqrt_term)
    u_true = (r**2 + t**2)  * phi

    return phi, phi_x, phi_y, u_true
# Out:
# Device: cpu

# %%
# MLP 
class MLP(nn.Module):
    def __init__(self, layers):
        super().__init__()
        self.net = nn.ModuleList()
        for i in range(len(layers)-1):
            self.net.append(nn.Linear(layers[i], layers[i+1]))
        self.activation = torch.tanh
        for m in self.net:
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight) #????
                nn.init.zeros_(m.bias)

    def forward(self, inp):
        z = inp
        for layer in self.net[:-1]:
            z = self.activation(layer(z))
        z = self.net[-1](z)
        return z

def partials_U_wrt_inputs(model, x, y, phi, t):
    x = x.view(-1,1)
    y = y.view(-1,1)
    phi = phi.view(-1,1)
    t = t.view(-1,1)

    inp = torch.cat([x, y, phi, t], dim=1).to(device)
    inp.requires_grad_(True)
    U = model(inp)  # (N,1)

    grads = torch.autograd.grad(U, inp, grad_outputs=torch.ones_like(U),
                                create_graph=True, retain_graph=True)[0]  # (N,4)
    U_x = grads[:,0:1]
    U_y = grads[:,1:2]
    U_z = grads[:,2:3]   
    U_t = grads[:,3:4]   
    return U, inp, U_x, U_y, U_z, U_t

def second_partials_U(model, inp, U_x, U_y, U_z):
    grad_Ux = torch.autograd.grad(U_x, inp, grad_outputs=torch.ones_like(U_x),
                                  create_graph=True, retain_graph=True)[0]
    grad_Uy = torch.autograd.grad(U_y, inp, grad_outputs=torch.ones_like(U_y),
                                  create_graph=True, retain_graph=True)[0]
    grad_Uz = torch.autograd.grad(U_z, inp, grad_outputs=torch.ones_like(U_z),
                                  create_graph=True, retain_graph=True)[0]

    U_xx = grad_Ux[:,0:1]
    U_xz = grad_Ux[:,2:3]
    U_yy = grad_Uy[:,1:2]
    U_yz = grad_Uy[:,2:3]
    U_zz = grad_Uz[:,2:3]

    return U_xx, U_yy, U_xz, U_yz, U_zz

def compute_residual_time(model, x, y, t):
    x = x.clone().detach().requires_grad_(True).to(device)
    y = y.clone().detach().requires_grad_(True).to(device)
    t = t.clone().detach().requires_grad_(True).to(device)

    phi, phi_x, phi_y, _ = compute_phi_and_derivs(x, y, t)
    U, inp, U_x, U_y, U_z, U_t = partials_U_wrt_inputs(model, x, y, phi, t)
    U_xx, U_yy, U_xz, U_yz, U_zz = second_partials_U(model, inp, U_x, U_y, U_z)

    r = torch.sqrt(torch.clamp(x**2 + y**2, min=1e-12))
    laplace_U = U_xx + U_yy
    lap = laplace_U + 2.0 * (U_xz * phi_x + U_yz * phi_y) + (1/(4*r)) * U_zz
    ut =  U_t
    residual = ut - lap - 2*t* phi + 6.0 * phi
    return residual, U, U_zz, U_xz, U_yz

# compute tip constraint 
def compute_zz_uN(model, t): # 在原點 U_xz=0, U_yz=0, U_zz=0 
    if not torch.is_tensor(t):
        t = torch.tensor([[t]], dtype=torch.float64, device=device)
    else:
        t = t.view(-1,1).to(dtype=torch.float64, device=device)

    x = torch.zeros_like(t)
    y = torch.zeros_like(t)

    phi, _, _, _ = compute_phi_and_derivs(x, y, t)
    _, inp, _, _, U_z, _ = partials_U_wrt_inputs(model, x, y, phi, t)

    grad_Uz = torch.autograd.grad(U_z, inp, grad_outputs=torch.ones_like(U_z),
                                  create_graph=True, retain_graph=True)[0]
    U_zz = grad_Uz[:,2:3]
    U_xz = grad_Uz[:,0:1]
    U_yz = grad_Uz[:,1:2]
    return torch.mean(U_zz**2 + U_xz**2 + U_yz**2)   


def compute_xyz_uN(model,x, y, t): # 在線上 U_xz=0, U_yz=0 
    if not torch.is_tensor(t):
        t = torch.tensor([[t]], dtype=torch.float64, device=device)
    else:
        t = t.view(-1,1).to(dtype=torch.float64, device=device)
    phi, phi_x, phi_y, _ = compute_phi_and_derivs(x, y, t)
    U, inp, U_x, U_y, U_z, U_t = partials_U_wrt_inputs(model, x, y, phi, t)
    grad_Uz = torch.autograd.grad(U_z, inp, grad_outputs=torch.ones_like(U_z),
                                  create_graph=True, retain_graph=True)[0]
    U_xz = grad_Uz[:,0:1]
    U_yz = grad_Uz[:,1:2]

    return torch.mean(U_xz**2+U_yz**2)   



# sampling
def sample_collocation(N): 
    x = torch.rand(N*2,1) * (X_MAX - X_MIN) + X_MIN 
    y = torch.rand(N*2,1) * (Y_MAX - Y_MIN) + Y_MIN 
    t = torch.rand(N*2,1) * (T_MAX - T_MIN) + T_MIN 
    # 點到 y=0 的距離 : |y|
    dist_to_crack = torch.abs(y)
    # mask 
    mask_crack = (dist_to_crack < 1e-8) 
    x, y, t = x[~mask_crack][:N], y[~mask_crack][:N], t[~mask_crack][:N] 
    return x.to(device), y.to(device), t.to(device)

def sample_outer_boundary(N):
    per_side = max(4, N // 4)
    xs, ys = [], []

    ys.append(torch.linspace(Y_MIN, Y_MAX, per_side).unsqueeze(1)); xs.append(torch.ones_like(ys[-1]) * X_MIN)
    ys.append(torch.linspace(Y_MIN, Y_MAX, per_side).unsqueeze(1)); xs.append(torch.ones_like(ys[-1]) * X_MAX)
    xs.append(torch.linspace(X_MIN, X_MAX, per_side).unsqueeze(1)); ys.append(torch.ones_like(xs[-1]) * Y_MIN)
    xs.append(torch.linspace(X_MIN, X_MAX, per_side).unsqueeze(1)); ys.append(torch.ones_like(xs[-1]) * Y_MAX)

    x = torch.cat(xs, dim=0)[:N]
    y = torch.cat(ys, dim=0)[:N]
    t = torch.rand(N, 1, device=device, dtype=torch.float64) * (T_MAX - T_MIN) + T_MIN

    return x.to(device), y.to(device), t


def sample_crack_boundary(N):
    t = torch.rand(N, 1, device=device, dtype=torch.float64) * (T_MAX - T_MIN) + T_MIN
    x_vals = torch.linspace(0, 1, N, device=device, dtype=torch.float64).unsqueeze(1)
    y_vals = x_vals * 0.0  
    return x_vals, y_vals, t


# model (input: x,y,phi,t) 
layers = [4, 64, 64, 1]
model = MLP(layers).to(device)

# %%
# training points 
x_f, y_f, t_f = sample_collocation(N_f)
x_b_out, y_b_out, t_b_out = sample_outer_boundary(N_b_outer)
x_b_crack, y_b_crack, t_b_crack = sample_crack_boundary(N_b_crack)
# move tensors to device
x_b_out = x_b_out.to(device); y_b_out = y_b_out.to(device); t_b_out = t_b_out.to(device)
x_b_crack = x_b_crack.to(device); y_b_crack = y_b_crack.to(device); t_b_crack = t_b_crack.to(device)
# cat
x_b = torch.cat([x_b_out, x_b_crack])
y_b = torch.cat([y_b_out, y_b_crack])
t_b = torch.cat([t_b_out, t_b_crack])
#
phi_b, _, _, g_b= compute_phi_and_derivs(x_b, y_b, t_b)
inp_bc = torch.cat([x_b, y_b, phi_b, t_b], dim=1)

# initial condition t=0
x_ic_f, y_ic_f = sample_collocation(N_ic)[0:2] 
x_ic_out, y_ic_out = sample_outer_boundary(N_ic_out)[0:2]  
x_ic_f = x_ic_f.view(-1,1)  
x_ic_out = x_ic_out.view(-1,1)  
x_ic = torch.cat([x_ic_f, x_ic_out])
y_ic_f = y_ic_f.view(-1,1)  
y_ic_out = y_ic_out.view(-1,1)  
y_ic = torch.cat([y_ic_f, y_ic_out])
t_ic = torch.zeros_like(x_ic).to(device)
##
phi_ic, _, _, u_ic = compute_phi_and_derivs(x_ic, y_ic, t_ic)
inp_ic = torch.cat([x_ic, y_ic, phi_ic, t_ic], dim=1)
##
# validation
x_f_val, y_f_val, t_f_val = sample_collocation(500)
x_b_out_val, y_b_out_val, t_b_out_val = sample_outer_boundary(200)
x_b_crack_val, y_b_crack_val, t_b_crack_val = sample_crack_boundary(100)
x_f_val = x_f_val.view(-1,1)  
x_b_out_val = x_b_out_val.view(-1,1)  
x_b_crack_val = x_b_crack_val.view(-1,1)
x_b_val = torch.cat([x_b_out_val, x_b_crack_val])
y_f_val = y_f_val.view(-1,1)  
y_b_out_val = y_b_out_val.view(-1,1)  
y_b_crack_val = y_b_crack_val.view(-1,1)
y_b_val = torch.cat([y_b_out_val, y_b_crack_val])
t_f_val = t_f_val.view(-1,1)  
t_b_out_val = t_b_out_val.view(-1,1)  
t_b_crack_val = t_b_crack_val.view(-1,1)
t_b_val = torch.cat([t_b_out_val, t_b_crack_val])
phi_b_val, _, _, g_b_val = compute_phi_and_derivs(x_b_val, y_b_val, t_b_val)
inp_bc_val = torch.cat([x_b_val, y_b_val, phi_b_val, t_b_val], dim=1)
###
x_ic_f_val, y_ic_f_val = sample_collocation(500)[0:2] 
x_ic_out_val, y_ic_out_val = sample_outer_boundary(200)[0:2]  
x_ic_f_val = x_ic_f_val.view(-1,1)  
x_ic_out_val = x_ic_out_val.view(-1,1)  
x_ic_val = torch.cat([x_ic_f_val, x_ic_out_val])
y_ic_f_val = y_ic_f_val.view(-1,1)  
y_ic_out_val = y_ic_out_val.view(-1,1)  
y_ic_val = torch.cat([y_ic_f_val, y_ic_out_val])
t_ic_val = torch.zeros_like(x_ic_val).to(device)
phi_ic_val, _, _, u0_val = compute_phi_and_derivs(x_ic_val, y_ic_val, t_ic_val)
inp_ic_val = torch.cat([x_ic_val, y_ic_val, phi_ic_val, t_ic_val], dim=1)
###
# optimizer
optimizer = optim.LBFGS(model.parameters(), lr=1.0, max_iter=20, history_size=50, line_search_fn="strong_wolfe")

print("Start training (time-dependent PINN)")

loss_history = []
val_history = []

for ep in range(epochs):
    def closure():
        optimizer.zero_grad()
        residual_f, _, Uzz_f, Uxz_f, Uyz_f = compute_residual_time(model, x_f, y_f, t_f)
        loss_pde = torch.mean(residual_f**2)
        u_bc = model(inp_bc)
        loss_bc = torch.mean((u_bc - g_b)**2)
        u_ic_pred = model(inp_ic)
        loss_ic = torch.mean((u_ic_pred - u_ic)**2)
        loss_zz = compute_zz_uN(model, t_b_crack)
        loss_yxz = compute_xyz_uN(model, x_b_crack, y_b_crack, t_b_crack)

        loss = (loss_pde
        + lambda_bc * (loss_bc)
        + lambda_ic * loss_ic
        + lambda_zz * loss_zz
        + lambda_zz3 * loss_yxz)
        loss.backward()
        return loss

    loss = optimizer.step(closure)
    loss_history.append(loss.item())
        # resampling 
    if ep % 50 == 0 and ep > 0:
        print(f"\n[Resample] epoch {ep}: regenerating PDE/BC/IC points...\n")

        # PDE collocation
        x_f, y_f, t_f = sample_collocation(N_f)

        # Outer boundary
        x_b_out, y_b_out, t_b_out = sample_outer_boundary(N_b_outer)

        # Crack boundary
        x_b_crack, y_b_crack, t_b_crack = sample_crack_boundary(N_b_crack)

        # Combine BC
        x_b = torch.cat([x_b_out, x_b_crack])
        y_b = torch.cat([y_b_out, y_b_crack])
        t_b = torch.cat([t_b_out, t_b_crack])
        phi_b, _, _, g_b = compute_phi_and_derivs(x_b, y_b, t_b)
        inp_bc = torch.cat([x_b, y_b, phi_b, t_b], dim=1)

        # Initial condition t=0
        x_ic_f, y_ic_f = sample_collocation(N_ic)[0:2]
        x_ic_out, y_ic_out = sample_outer_boundary(N_ic_out)[0:2]

        x_ic = torch.cat([
            x_ic_f.view(-1,1),
            x_ic_out.view(-1,1),
        ])
        y_ic = torch.cat([
            y_ic_f.view(-1,1),
            y_ic_out.view(-1,1),
        ])
        t_ic = torch.zeros_like(x_ic)
        phi_ic, _, _, u_ic = compute_phi_and_derivs(x_ic, y_ic, t_ic)
        inp_ic = torch.cat([x_ic, y_ic, phi_ic, t_ic], dim=1)


    if ep % 10 == 0 or ep == epochs-1:

        # validation
        res_val, _, Uzz_val, Uxz_val, Uyz_val = compute_residual_time(model, x_f_val, y_f_val, t_f_val)
        loss_pde_val = torch.mean(res_val**2)
        u_bc_val = model(inp_bc_val)
        loss_bc_val = torch.mean((u_bc_val - g_b_val)**2)
        u_ic_pred_val = model(inp_ic_val)
        loss_ic_val = torch.mean((u_ic_pred_val - u0_val)**2)
        loss_zz_val = compute_zz_uN(model, t_b_crack_val)
        loss_yxz_val = compute_xyz_uN(model, x_b_crack_val, y_b_crack_val,  t_b_crack_val)
        loss_val = (
            loss_pde_val
            + lambda_bc * loss_bc_val
            + lambda_ic * loss_ic_val
            + lambda_zz * loss_zz_val
            + lambda_zz3 *  loss_yxz_val)
        val_history.append(loss_val.item())

        # training loss 細項
        res_f, _, _, _, _ = compute_residual_time(model, x_f, y_f, t_f)
        loss_pde = torch.mean(res_f**2)
        loss_bc = torch.mean((model(inp_bc) - g_b)**2)
        loss_ic = torch.mean((model(inp_ic) - u_ic)**2)
        loss_zz = compute_zz_uN(model, t_b_crack)
        loss_yxz = compute_xyz_uN(model, x_b_crack, y_b_crack, t_b_crack)
        

        # 
        print(
            f"Epoch {ep:4d} | "
            f"TrainLoss={loss.item():.3e} "
            f"(pde={loss_pde:.2e}, bc={loss_bc:.2e}, ic={loss_ic:.2e}, "
            f"zz={loss_zz:.2e}, yxz={loss_yxz:.2e}, ) | "
            f"ValLoss={loss_val.item():.3e} "
            f"(pde={loss_pde_val:.2e}, bc={loss_bc_val:.2e}, ic={loss_ic_val:.2e}, "
            f"zz={loss_zz_val:.2e}, yxz={loss_yxz_val:.2e}, )")



print("Training finished.")
# Out:
# Start training (time-dependent PINN)
# Epoch    0 | TrainLoss=1.381e+01 (pde=1.00e-01, bc=1.99e-01, ic=1.61e-01, zz=1.33e-02, yxz=3.12e-03, ) | ValLoss=5.660e-01 (pde=9.33e-02, bc=2.58e-01, ic=1.98e-01, zz=1.38e-02, yxz=3.05e-03, )
# Epoch   10 | TrainLoss=1.378e-02 (pde=9.73e-03, bc=1.97e-03, ic=7.26e-04, zz=4.92e-05, yxz=1.59e-04, ) | ValLoss=1.323e-02 (pde=1.04e-02, bc=2.00e-03, ic=6.06e-04, zz=4.17e-05, yxz=1.78e-04, )
# Epoch   20 | TrainLoss=1.010e-02 (pde=8.39e-03, bc=1.11e-03, ic=4.33e-04, zz=7.38e-06, yxz=5.82e-05, ) | ValLoss=1.056e-02 (pde=9.11e-03, bc=1.03e-03, ic=3.50e-04, zz=8.11e-06, yxz=6.62e-05, )
# Epoch   30 | TrainLoss=9.408e-03 (pde=8.11e-03, bc=9.19e-04, ic=3.12e-04, zz=6.19e-06, yxz=2.47e-05, ) | ValLoss=9.765e-03 (pde=8.65e-03, bc=8.20e-04, ic=2.59e-04, zz=7.59e-06, yxz=2.88e-05, )
# Epoch   40 | TrainLoss=9.095e-03 (pde=8.02e-03, bc=7.81e-04, ic=2.51e-04, zz=2.84e-06, yxz=2.64e-05, ) | ValLoss=9.330e-03 (pde=8.40e-03, bc=6.93e-04, ic=2.10e-04, zz=2.77e-06, yxz=2.23e-05, )
#
# [Resample] epoch 50: regenerating PDE/BC/IC points...
#
# Epoch   50 | TrainLoss=8.950e-03 (pde=7.82e-03, bc=7.24e-04, ic=2.12e-04, zz=1.88e-06, yxz=1.17e-05, ) | ValLoss=9.169e-03 (pde=8.33e-03, bc=6.38e-04, ic=1.84e-04, zz=1.79e-06, yxz=1.10e-05, )
# Epoch   60 | TrainLoss=8.612e-03 (pde=7.75e-03, bc=6.43e-04, ic=1.85e-04, zz=1.47e-06, yxz=2.17e-05, ) | ValLoss=8.876e-03 (pde=8.11e-03, bc=5.76e-04, ic=1.65e-04, zz=1.51e-06, yxz=2.27e-05, )
# Epoch   70 | TrainLoss=8.514e-03 (pde=7.74e-03, bc=5.88e-04, ic=1.58e-04, zz=1.47e-06, yxz=1.66e-05, ) | ValLoss=9.012e-03 (pde=8.33e-03, bc=5.21e-04, ic=1.44e-04, zz=1.39e-06, yxz=1.90e-05, )
# Epoch   80 | TrainLoss=8.441e-03 (pde=7.74e-03, bc=5.43e-04, ic=1.44e-04, zz=2.07e-06, yxz=7.94e-06, ) | ValLoss=8.722e-03 (pde=8.10e-03, bc=4.80e-04, ic=1.28e-04, zz=2.31e-06, yxz=9.34e-06, )
# Epoch   90 | TrainLoss=8.389e-03 (pde=7.73e-03, bc=5.20e-04, ic=1.24e-04, zz=1.03e-06, yxz=6.84e-06, ) | ValLoss=8.812e-03 (pde=8.24e-03, bc=4.54e-04, ic=1.11e-04, zz=1.17e-06, yxz=8.34e-06, )
#
# [Resample] epoch 100: regenerating PDE/BC/IC points...
#
# Epoch  100 | TrainLoss=8.351e-03 (pde=8.11e-03, bc=5.17e-04, ic=1.21e-04, zz=5.44e-07, yxz=7.38e-06, ) | ValLoss=8.794e-03 (pde=8.25e-03, bc=4.33e-04, ic=1.03e-04, zz=5.73e-07, yxz=7.82e-06, )
# Epoch  110 | TrainLoss=8.668e-03 (pde=8.02e-03, bc=5.08e-04, ic=1.32e-04, zz=2.26e-07, yxz=4.98e-06, ) | ValLoss=8.705e-03 (pde=8.17e-03, bc=4.23e-04, ic=1.09e-04, zz=2.22e-07, yxz=5.16e-06, )
# Epoch  120 | TrainLoss=8.631e-03 (pde=7.99e-03, bc=4.96e-04, ic=1.33e-04, zz=2.54e-07, yxz=4.18e-06, ) | ValLoss=8.726e-03 (pde=8.20e-03, bc=4.12e-04, ic=1.08e-04, zz=2.48e-07, yxz=4.21e-06, )
# Epoch  130 | TrainLoss=8.605e-03 (pde=7.99e-03, bc=4.83e-04, ic=1.26e-04, zz=3.82e-07, yxz=4.50e-06, ) | ValLoss=8.619e-03 (pde=8.11e-03, bc=4.02e-04, ic=1.03e-04, zz=3.94e-07, yxz=4.62e-06, )
# Epoch  140 | TrainLoss=8.584e-03 (pde=7.98e-03, bc=4.73e-04, ic=1.21e-04, zz=5.59e-07, yxz=4.11e-06, ) | ValLoss=8.619e-03 (pde=8.12e-03, bc=3.92e-04, ic=9.85e-05, zz=6.67e-07, yxz=4.55e-06, )
#
# [Resample] epoch 150: regenerating PDE/BC/IC points...
#
# Epoch  150 | TrainLoss=8.573e-03 (pde=8.42e-03, bc=4.69e-04, ic=1.21e-04, zz=2.73e-07, yxz=5.04e-06, ) | ValLoss=8.514e-03 (pde=8.03e-03, bc=3.86e-04, ic=9.60e-05, zz=3.10e-07, yxz=6.18e-06, )
# Epoch  160 | TrainLoss=8.957e-03 (pde=8.37e-03, bc=4.64e-04, ic=1.19e-04, zz=2.74e-07, yxz=5.48e-06, ) | ValLoss=8.611e-03 (pde=8.13e-03, bc=3.83e-04, ic=9.50e-05, zz=2.41e-07, yxz=6.72e-06, )
# Epoch  170 | TrainLoss=8.942e-03 (pde=8.37e-03, bc=4.53e-04, ic=1.14e-04, zz=2.11e-07, yxz=4.18e-06, ) | ValLoss=8.614e-03 (pde=8.14e-03, bc=3.73e-04, ic=9.14e-05, zz=2.30e-07, yxz=5.17e-06, )
# Epoch  180 | TrainLoss=8.933e-03 (pde=8.37e-03, bc=4.46e-04, ic=1.14e-04, zz=3.44e-07, yxz=3.52e-06, ) | ValLoss=8.646e-03 (pde=8.18e-03, bc=3.68e-04, ic=9.03e-05, zz=3.59e-07, yxz=4.27e-06, )
# Epoch  190 | TrainLoss=8.923e-03 (pde=8.37e-03, bc=4.41e-04, ic=1.09e-04, zz=1.53e-07, yxz=2.55e-06, ) | ValLoss=8.636e-03 (pde=8.18e-03, bc=3.64e-04, ic=8.73e-05, zz=1.65e-07, yxz=2.75e-06, )
#
# [Resample] epoch 200: regenerating PDE/BC/IC points...
#
# Epoch  200 | TrainLoss=8.913e-03 (pde=7.80e-03, bc=4.36e-04, ic=1.04e-04, zz=2.57e-07, yxz=2.45e-06, ) | ValLoss=8.622e-03 (pde=8.17e-03, bc=3.61e-04, ic=8.56e-05, zz=2.48e-07, yxz=2.40e-06, )
# Epoch  210 | TrainLoss=8.271e-03 (pde=7.72e-03, bc=4.49e-04, ic=1.01e-04, zz=1.75e-07, yxz=3.15e-06, ) | ValLoss=8.491e-03 (pde=8.04e-03, bc=3.69e-04, ic=8.38e-05, zz=1.71e-07, yxz=2.87e-06, )
# Epoch  220 | TrainLoss=8.259e-03 (pde=7.71e-03, bc=4.46e-04, ic=9.95e-05, zz=1.49e-07, yxz=2.72e-06, ) | ValLoss=8.503e-03 (pde=8.05e-03, bc=3.67e-04, ic=8.21e-05, zz=1.61e-07, yxz=2.82e-06, )
# Epoch  230 | TrainLoss=8.251e-03 (pde=7.71e-03, bc=4.41e-04, ic=9.78e-05, zz=1.52e-07, yxz=2.46e-06, ) | ValLoss=8.492e-03 (pde=8.05e-03, bc=3.62e-04, ic=8.06e-05, zz=1.61e-07, yxz=2.40e-06, )
# Epoch  240 | TrainLoss=8.245e-03 (pde=7.71e-03, bc=4.37e-04, ic=9.62e-05, zz=1.36e-07, yxz=2.50e-06, ) | ValLoss=8.525e-03 (pde=8.09e-03, bc=3.57e-04, ic=7.93e-05, zz=1.45e-07, yxz=2.50e-06, )
#
# [Resample] epoch 250: regenerating PDE/BC/IC points...
#
# Epoch  250 | TrainLoss=8.236e-03 (pde=7.86e-03, bc=4.40e-04, ic=9.47e-05, zz=4.76e-07, yxz=1.96e-06, ) | ValLoss=8.514e-03 (pde=8.08e-03, bc=3.56e-04, ic=7.91e-05, zz=5.14e-07, yxz=1.74e-06, )
# Epoch  260 | TrainLoss=8.276e-03 (pde=7.72e-03, bc=4.47e-04, ic=9.75e-05, zz=9.08e-07, yxz=4.18e-06, ) | ValLoss=8.633e-03 (pde=8.19e-03, bc=3.60e-04, ic=8.21e-05, zz=7.97e-07, yxz=4.04e-06, )
# Epoch  270 | TrainLoss=8.253e-03 (pde=7.70e-03, bc=4.39e-04, ic=1.04e-04, zz=9.74e-07, yxz=3.98e-06, ) | ValLoss=8.515e-03 (pde=8.07e-03, bc=3.57e-04, ic=8.60e-05, zz=9.32e-07, yxz=4.10e-06, )
# Epoch  280 | TrainLoss=8.240e-03 (pde=7.69e-03, bc=4.39e-04, ic=1.01e-04, zz=3.79e-07, yxz=4.86e-06, ) | ValLoss=8.497e-03 (pde=8.05e-03, bc=3.55e-04, ic=8.37e-05, zz=3.55e-07, yxz=5.78e-06, )
# Epoch  290 | TrainLoss=8.230e-03 (pde=7.69e-03, bc=4.39e-04, ic=1.00e-04, zz=4.25e-07, yxz=4.87e-06, ) | ValLoss=8.515e-03 (pde=8.07e-03, bc=3.54e-04, ic=8.37e-05, zz=4.32e-07, yxz=5.40e-06, )
#
# [Resample] epoch 300: regenerating PDE/BC/IC points...
#
# Epoch  300 | TrainLoss=8.221e-03 (pde=8.21e-03, bc=4.30e-04, ic=1.06e-04, zz=4.49e-07, yxz=4.31e-06, ) | ValLoss=8.512e-03 (pde=8.07e-03, bc=3.53e-04, ic=8.42e-05, zz=4.54e-07, yxz=4.49e-06, )
# Epoch  310 | TrainLoss=8.706e-03 (pde=8.17e-03, bc=4.29e-04, ic=1.01e-04, zz=2.63e-07, yxz=3.04e-06, ) | ValLoss=8.579e-03 (pde=8.14e-03, bc=3.53e-04, ic=8.11e-05, zz=2.53e-07, yxz=3.20e-06, )
# Epoch  320 | TrainLoss=8.699e-03 (pde=8.17e-03, bc=4.28e-04, ic=9.85e-05, zz=1.82e-07, yxz=2.99e-06, ) | ValLoss=8.550e-03 (pde=8.11e-03, bc=3.53e-04, ic=7.97e-05, zz=1.74e-07, yxz=3.01e-06, )
# Epoch  330 | TrainLoss=8.693e-03 (pde=8.17e-03, bc=4.28e-04, ic=9.56e-05, zz=4.05e-07, yxz=2.15e-06, ) | ValLoss=8.526e-03 (pde=8.09e-03, bc=3.53e-04, ic=7.88e-05, zz=3.85e-07, yxz=2.33e-06, )
# Epoch  340 | TrainLoss=8.688e-03 (pde=8.17e-03, bc=4.24e-04, ic=9.47e-05, zz=3.11e-07, yxz=2.25e-06, ) | ValLoss=8.477e-03 (pde=8.05e-03, bc=3.50e-04, ic=7.85e-05, zz=3.12e-07, yxz=2.66e-06, )
#
# [Resample] epoch 350: regenerating PDE/BC/IC points...
#
# Epoch  350 | TrainLoss=8.683e-03 (pde=8.20e-03, bc=4.25e-04, ic=9.15e-05, zz=6.01e-07, yxz=1.90e-06, ) | ValLoss=8.495e-03 (pde=8.06e-03, bc=3.51e-04, ic=7.83e-05, zz=6.08e-07, yxz=2.02e-06, )
# Epoch  360 | TrainLoss=8.699e-03 (pde=8.19e-03, bc=4.18e-04, ic=9.29e-05, zz=1.94e-07, yxz=1.84e-06, ) | ValLoss=8.514e-03 (pde=8.08e-03, bc=3.51e-04, ic=8.10e-05, zz=1.96e-07, yxz=1.87e-06, )
# Epoch  370 | TrainLoss=8.691e-03 (pde=8.18e-03, bc=4.10e-04, ic=9.32e-05, zz=2.17e-07, yxz=2.28e-06, ) | ValLoss=8.480e-03 (pde=8.05e-03, bc=3.45e-04, ic=8.15e-05, zz=2.31e-07, yxz=2.10e-06, )
# Epoch  380 | TrainLoss=8.685e-03 (pde=8.18e-03, bc=4.07e-04, ic=9.05e-05, zz=1.78e-07, yxz=2.40e-06, ) | ValLoss=8.483e-03 (pde=8.06e-03, bc=3.42e-04, ic=7.89e-05, zz=1.65e-07, yxz=2.26e-06, )
# Epoch  390 | TrainLoss=8.680e-03 (pde=8.18e-03, bc=4.05e-04, ic=8.92e-05, zz=2.21e-07, yxz=1.99e-06, ) | ValLoss=8.482e-03 (pde=8.06e-03, bc=3.40e-04, ic=7.67e-05, zz=2.28e-07, yxz=1.92e-06, )
#
# [Resample] epoch 400: regenerating PDE/BC/IC points...
#
# Epoch  400 | TrainLoss=8.676e-03 (pde=7.86e-03, bc=4.13e-04, ic=8.37e-05, zz=1.15e-07, yxz=1.96e-06, ) | ValLoss=8.509e-03 (pde=8.09e-03, bc=3.43e-04, ic=7.34e-05, zz=1.16e-07, yxz=1.96e-06, )
# Epoch  410 | TrainLoss=8.339e-03 (pde=7.84e-03, bc=4.13e-04, ic=8.52e-05, zz=1.42e-07, yxz=1.86e-06, ) | ValLoss=8.500e-03 (pde=8.08e-03, bc=3.40e-04, ic=7.38e-05, zz=1.50e-07, yxz=2.17e-06, )
# Epoch  420 | TrainLoss=8.334e-03 (pde=7.84e-03, bc=4.12e-04, ic=8.42e-05, zz=1.20e-07, yxz=1.92e-06, ) | ValLoss=8.497e-03 (pde=8.09e-03, bc=3.37e-04, ic=7.27e-05, zz=1.37e-07, yxz=1.91e-06, )
# Epoch  430 | TrainLoss=8.329e-03 (pde=7.83e-03, bc=4.08e-04, ic=8.44e-05, zz=2.13e-07, yxz=1.93e-06, ) | ValLoss=8.449e-03 (pde=8.04e-03, bc=3.34e-04, ic=7.24e-05, zz=2.13e-07, yxz=1.70e-06, )
# Epoch  440 | TrainLoss=8.325e-03 (pde=7.84e-03, bc=4.02e-04, ic=8.45e-05, zz=9.77e-08, yxz=1.88e-06, ) | ValLoss=8.450e-03 (pde=8.05e-03, bc=3.27e-04, ic=7.16e-05, zz=9.67e-08, yxz=1.80e-06, )
#
# [Resample] epoch 450: regenerating PDE/BC/IC points...
#
# Epoch  450 | TrainLoss=8.322e-03 (pde=8.10e-03, bc=4.05e-04, ic=8.22e-05, zz=1.13e-07, yxz=1.45e-06, ) | ValLoss=8.414e-03 (pde=8.01e-03, bc=3.28e-04, ic=7.07e-05, zz=1.25e-07, yxz=1.56e-06, )
# Epoch  460 | TrainLoss=8.557e-03 (pde=8.07e-03, bc=3.98e-04, ic=8.55e-05, zz=8.61e-08, yxz=1.50e-06, ) | ValLoss=8.434e-03 (pde=8.04e-03, bc=3.21e-04, ic=7.20e-05, zz=8.95e-08, yxz=1.52e-06, )
# Epoch  470 | TrainLoss=8.554e-03 (pde=8.07e-03, bc=3.98e-04, ic=8.48e-05, zz=1.67e-07, yxz=1.23e-06, ) | ValLoss=8.431e-03 (pde=8.04e-03, bc=3.20e-04, ic=7.16e-05, zz=1.63e-07, yxz=1.27e-06, )
# Epoch  480 | TrainLoss=8.551e-03 (pde=8.07e-03, bc=3.95e-04, ic=8.34e-05, zz=9.02e-08, yxz=1.23e-06, ) | ValLoss=8.432e-03 (pde=8.04e-03, bc=3.17e-04, ic=7.07e-05, zz=8.79e-08, yxz=1.34e-06, )
# Epoch  490 | TrainLoss=8.549e-03 (pde=8.07e-03, bc=3.93e-04, ic=8.38e-05, zz=9.26e-08, yxz=1.35e-06, ) | ValLoss=8.440e-03 (pde=8.05e-03, bc=3.16e-04, ic=7.10e-05, zz=9.83e-08, yxz=1.46e-06, )
#
# [Resample] epoch 500: regenerating PDE/BC/IC points...
#
# Epoch  500 | TrainLoss=8.547e-03 (pde=8.36e-03, bc=3.94e-04, ic=8.61e-05, zz=1.17e-07, yxz=1.08e-06, ) | ValLoss=8.468e-03 (pde=8.08e-03, bc=3.15e-04, ic=7.11e-05, zz=1.16e-07, yxz=1.17e-06, )
# Epoch  510 | TrainLoss=8.830e-03 (pde=8.35e-03, bc=3.99e-04, ic=8.36e-05, zz=1.48e-07, yxz=1.01e-06, ) | ValLoss=8.517e-03 (pde=8.12e-03, bc=3.21e-04, ic=7.07e-05, zz=1.63e-07, yxz=9.40e-07, )
# Epoch  520 | TrainLoss=8.827e-03 (pde=8.34e-03, bc=3.99e-04, ic=8.18e-05, zz=2.07e-07, yxz=1.22e-06, ) | ValLoss=8.495e-03 (pde=8.10e-03, bc=3.22e-04, ic=6.96e-05, zz=1.87e-07, yxz=1.30e-06, )
# Epoch  530 | TrainLoss=8.825e-03 (pde=8.34e-03, bc=3.98e-04, ic=8.29e-05, zz=1.29e-07, yxz=1.10e-06, ) | ValLoss=8.491e-03 (pde=8.10e-03, bc=3.21e-04, ic=7.08e-05, zz=1.37e-07, yxz=1.09e-06, )
# Epoch  540 | TrainLoss=8.823e-03 (pde=8.34e-03, bc=3.96e-04, ic=8.20e-05, zz=1.83e-07, yxz=9.99e-07, ) | ValLoss=8.483e-03 (pde=8.09e-03, bc=3.20e-04, ic=6.98e-05, zz=1.81e-07, yxz=9.23e-07, )
#
# [Resample] epoch 550: regenerating PDE/BC/IC points...
#
# Epoch  550 | TrainLoss=8.820e-03 (pde=8.15e-03, bc=3.93e-04, ic=8.16e-05, zz=1.50e-07, yxz=1.02e-06, ) | ValLoss=8.538e-03 (pde=8.15e-03, bc=3.18e-04, ic=6.86e-05, zz=1.32e-07, yxz=9.00e-07, )
# Epoch  560 | TrainLoss=8.583e-03 (pde=8.10e-03, bc=4.01e-04, ic=8.19e-05, zz=2.18e-07, yxz=1.32e-06, ) | ValLoss=8.471e-03 (pde=8.08e-03, bc=3.24e-04, ic=6.86e-05, zz=2.04e-07, yxz=1.06e-06, )
# Epoch  570 | TrainLoss=8.578e-03 (pde=8.09e-03, bc=4.03e-04, ic=8.13e-05, zz=1.09e-07, yxz=1.56e-06, ) | ValLoss=8.453e-03 (pde=8.06e-03, bc=3.25e-04, ic=6.79e-05, zz=1.06e-07, yxz=1.14e-06, )
# Epoch  580 | TrainLoss=8.575e-03 (pde=8.09e-03, bc=4.04e-04, ic=8.09e-05, zz=1.02e-07, yxz=1.54e-06, ) | ValLoss=8.451e-03 (pde=8.06e-03, bc=3.27e-04, ic=6.80e-05, zz=1.00e-07, yxz=1.17e-06, )
# Epoch  590 | TrainLoss=8.573e-03 (pde=8.09e-03, bc=4.03e-04, ic=8.08e-05, zz=9.39e-08, yxz=1.39e-06, ) | ValLoss=8.473e-03 (pde=8.08e-03, bc=3.26e-04, ic=6.79e-05, zz=8.44e-08, yxz=1.19e-06, )
#
# [Resample] epoch 600: regenerating PDE/BC/IC points...
#
# Epoch  600 | TrainLoss=8.570e-03 (pde=7.95e-03, bc=4.11e-04, ic=8.26e-05, zz=1.20e-07, yxz=1.31e-06, ) | ValLoss=8.490e-03 (pde=8.09e-03, bc=3.26e-04, ic=6.80e-05, zz=1.12e-07, yxz=1.30e-06, )
# Epoch  610 | TrainLoss=8.428e-03 (pde=7.94e-03, bc=3.96e-04, ic=8.64e-05, zz=1.34e-07, yxz=1.38e-06, ) | ValLoss=8.516e-03 (pde=8.13e-03, bc=3.16e-04, ic=7.10e-05, zz=1.23e-07, yxz=1.29e-06, )
# Epoch  620 | TrainLoss=8.424e-03 (pde=7.94e-03, bc=3.91e-04, ic=8.77e-05, zz=1.13e-07, yxz=1.44e-06, ) | ValLoss=8.503e-03 (pde=8.12e-03, bc=3.12e-04, ic=7.18e-05, zz=1.02e-07, yxz=1.34e-06, )
# Epoch  630 | TrainLoss=8.421e-03 (pde=7.94e-03, bc=3.89e-04, ic=8.80e-05, zz=1.52e-07, yxz=1.40e-06, ) | ValLoss=8.492e-03 (pde=8.11e-03, bc=3.09e-04, ic=7.21e-05, zz=1.34e-07, yxz=1.31e-06, )
# Epoch  640 | TrainLoss=8.419e-03 (pde=7.94e-03, bc=3.87e-04, ic=8.78e-05, zz=1.25e-07, yxz=1.53e-06, ) | ValLoss=8.472e-03 (pde=8.09e-03, bc=3.08e-04, ic=7.20e-05, zz=1.18e-07, yxz=1.46e-06, )
#
# [Resample] epoch 650: regenerating PDE/BC/IC points...
#
# Epoch  650 | TrainLoss=8.417e-03 (pde=7.90e-03, bc=3.84e-04, ic=8.05e-05, zz=1.25e-07, yxz=1.63e-06, ) | ValLoss=8.510e-03 (pde=8.13e-03, bc=3.06e-04, ic=7.19e-05, zz=1.21e-07, yxz=1.53e-06, )
# Epoch  660 | TrainLoss=8.335e-03 (pde=7.87e-03, bc=3.89e-04, ic=7.48e-05, zz=1.32e-07, yxz=1.09e-06, ) | ValLoss=8.507e-03 (pde=8.13e-03, bc=3.11e-04, ic=6.80e-05, zz=1.29e-07, yxz=1.05e-06, )
# Epoch  670 | TrainLoss=8.332e-03 (pde=7.87e-03, bc=3.88e-04, ic=7.40e-05, zz=1.08e-07, yxz=1.06e-06, ) | ValLoss=8.547e-03 (pde=8.17e-03, bc=3.10e-04, ic=6.69e-05, zz=1.16e-07, yxz=9.74e-07, )
# Epoch  680 | TrainLoss=8.329e-03 (pde=7.87e-03, bc=3.85e-04, ic=7.22e-05, zz=1.53e-07, yxz=1.18e-06, ) | ValLoss=8.591e-03 (pde=8.22e-03, bc=3.08e-04, ic=6.53e-05, zz=1.88e-07, yxz=1.06e-06, )
# Epoch  690 | TrainLoss=8.327e-03 (pde=7.87e-03, bc=3.84e-04, ic=7.08e-05, zz=1.16e-07, yxz=1.17e-06, ) | ValLoss=8.608e-03 (pde=8.24e-03, bc=3.07e-04, ic=6.40e-05, zz=1.27e-07, yxz=9.65e-07, )
#
# [Resample] epoch 700: regenerating PDE/BC/IC points...
#
# Epoch  700 | TrainLoss=8.326e-03 (pde=7.61e-03, bc=3.83e-04, ic=7.35e-05, zz=2.00e-07, yxz=1.24e-06, ) | ValLoss=8.673e-03 (pde=8.30e-03, bc=3.05e-04, ic=6.34e-05, zz=2.26e-07, yxz=1.06e-06, )
# Epoch  710 | TrainLoss=8.046e-03 (pde=7.57e-03, bc=3.91e-04, ic=7.87e-05, zz=1.97e-07, yxz=1.32e-06, ) | ValLoss=8.503e-03 (pde=8.12e-03, bc=3.11e-04, ic=6.73e-05, zz=2.21e-07, yxz=1.35e-06, )
# Epoch  720 | TrainLoss=8.043e-03 (pde=7.57e-03, bc=3.90e-04, ic=7.83e-05, zz=1.35e-07, yxz=1.32e-06, ) | ValLoss=8.541e-03 (pde=8.16e-03, bc=3.10e-04, ic=6.67e-05, zz=1.34e-07, yxz=1.32e-06, )
# Epoch  730 | TrainLoss=8.041e-03 (pde=7.57e-03, bc=3.92e-04, ic=7.75e-05, zz=1.27e-07, yxz=1.24e-06, ) | ValLoss=8.542e-03 (pde=8.16e-03, bc=3.11e-04, ic=6.62e-05, zz=1.27e-07, yxz=1.16e-06, )
# Epoch  740 | TrainLoss=8.040e-03 (pde=7.57e-03, bc=3.93e-04, ic=7.58e-05, zz=1.63e-07, yxz=1.31e-06, ) | ValLoss=8.557e-03 (pde=8.18e-03, bc=3.13e-04, ic=6.50e-05, zz=1.77e-07, yxz=1.22e-06, )
#
# [Resample] epoch 750: regenerating PDE/BC/IC points...
#
# Epoch  750 | TrainLoss=8.038e-03 (pde=7.74e-03, bc=3.92e-04, ic=7.85e-05, zz=1.18e-07, yxz=1.11e-06, ) | ValLoss=8.550e-03 (pde=8.17e-03, bc=3.12e-04, ic=6.49e-05, zz=1.17e-07, yxz=9.85e-07, )
# Epoch  760 | TrainLoss=8.195e-03 (pde=7.72e-03, bc=3.92e-04, ic=7.78e-05, zz=1.63e-07, yxz=9.79e-07, ) | ValLoss=8.491e-03 (pde=8.11e-03, bc=3.14e-04, ic=6.63e-05, zz=1.66e-07, yxz=9.19e-07, )
# Epoch  770 | TrainLoss=8.193e-03 (pde=7.72e-03, bc=3.91e-04, ic=7.76e-05, zz=1.29e-07, yxz=8.94e-07, ) | ValLoss=8.507e-03 (pde=8.13e-03, bc=3.13e-04, ic=6.64e-05, zz=1.32e-07, yxz=7.69e-07, )
# Epoch  780 | TrainLoss=8.192e-03 (pde=7.72e-03, bc=3.90e-04, ic=7.81e-05, zz=1.16e-07, yxz=8.97e-07, ) | ValLoss=8.536e-03 (pde=8.16e-03, bc=3.12e-04, ic=6.68e-05, zz=1.12e-07, yxz=8.11e-07, )
# Epoch  790 | TrainLoss=8.191e-03 (pde=7.72e-03, bc=3.90e-04, ic=7.80e-05, zz=1.26e-07, yxz=8.22e-07, ) | ValLoss=8.525e-03 (pde=8.15e-03, bc=3.12e-04, ic=6.65e-05, zz=1.17e-07, yxz=7.53e-07, )
#
# [Resample] epoch 800: regenerating PDE/BC/IC points...
#
# Epoch  800 | TrainLoss=8.190e-03 (pde=8.19e-03, bc=3.89e-04, ic=7.84e-05, zz=1.27e-07, yxz=8.22e-07, ) | ValLoss=8.551e-03 (pde=8.17e-03, bc=3.12e-04, ic=6.65e-05, zz=1.35e-07, yxz=7.74e-07, )
# Epoch  810 | TrainLoss=8.627e-03 (pde=8.15e-03, bc=3.93e-04, ic=7.76e-05, zz=1.42e-07, yxz=9.21e-07, ) | ValLoss=8.515e-03 (pde=8.13e-03, bc=3.16e-04, ic=6.59e-05, zz=1.55e-07, yxz=9.16e-07, )
# Epoch  820 | TrainLoss=8.625e-03 (pde=8.15e-03, bc=3.94e-04, ic=7.72e-05, zz=1.46e-07, yxz=8.97e-07, ) | ValLoss=8.497e-03 (pde=8.11e-03, bc=3.17e-04, ic=6.58e-05, zz=1.57e-07, yxz=8.79e-07, )
# Epoch  830 | TrainLoss=8.623e-03 (pde=8.15e-03, bc=3.93e-04, ic=7.76e-05, zz=1.39e-07, yxz=9.57e-07, ) | ValLoss=8.509e-03 (pde=8.13e-03, bc=3.16e-04, ic=6.61e-05, zz=1.59e-07, yxz=9.05e-07, )
# Epoch  840 | TrainLoss=8.623e-03 (pde=8.15e-03, bc=3.92e-04, ic=7.72e-05, zz=1.32e-07, yxz=8.73e-07, ) | ValLoss=8.503e-03 (pde=8.12e-03, bc=3.16e-04, ic=6.60e-05, zz=1.26e-07, yxz=9.07e-07, )
#
# [Resample] epoch 850: regenerating PDE/BC/IC points...
#
# Epoch  850 | TrainLoss=8.622e-03 (pde=7.26e-03, bc=3.94e-04, ic=7.30e-05, zz=1.39e-07, yxz=8.97e-07, ) | ValLoss=8.516e-03 (pde=8.13e-03, bc=3.16e-04, ic=6.60e-05, zz=1.38e-07, yxz=8.59e-07, )
# Epoch  860 | TrainLoss=7.706e-03 (pde=7.23e-03, bc=3.97e-04, ic=7.24e-05, zz=1.80e-07, yxz=9.69e-07, ) | ValLoss=8.496e-03 (pde=8.11e-03, bc=3.19e-04, ic=6.58e-05, zz=1.73e-07, yxz=8.01e-07, )
# Epoch  870 | TrainLoss=7.704e-03 (pde=7.23e-03, bc=3.97e-04, ic=7.25e-05, zz=1.56e-07, yxz=1.05e-06, ) | ValLoss=8.499e-03 (pde=8.11e-03, bc=3.19e-04, ic=6.58e-05, zz=1.46e-07, yxz=8.50e-07, )
# Epoch  880 | TrainLoss=7.703e-03 (pde=7.23e-03, bc=3.97e-04, ic=7.19e-05, zz=1.36e-07, yxz=1.03e-06, ) | ValLoss=8.499e-03 (pde=8.11e-03, bc=3.20e-04, ic=6.55e-05, zz=1.23e-07, yxz=7.94e-07, )
# Epoch  890 | TrainLoss=7.703e-03 (pde=7.23e-03, bc=3.97e-04, ic=7.13e-05, zz=1.41e-07, yxz=1.09e-06, ) | ValLoss=8.503e-03 (pde=8.12e-03, bc=3.19e-04, ic=6.52e-05, zz=1.31e-07, yxz=8.31e-07, )
#
# [Resample] epoch 900: regenerating PDE/BC/IC points...
#
# Epoch  900 | TrainLoss=7.702e-03 (pde=7.64e-03, bc=3.96e-04, ic=7.30e-05, zz=1.26e-07, yxz=1.15e-06, ) | ValLoss=8.501e-03 (pde=8.12e-03, bc=3.19e-04, ic=6.50e-05, zz=1.18e-07, yxz=8.03e-07, )
# Epoch  910 | TrainLoss=8.091e-03 (pde=7.63e-03, bc=3.87e-04, ic=7.44e-05, zz=1.45e-07, yxz=1.05e-06, ) | ValLoss=8.545e-03 (pde=8.17e-03, bc=3.10e-04, ic=6.46e-05, zz=1.35e-07, yxz=7.71e-07, )
# Epoch  920 | TrainLoss=8.089e-03 (pde=7.63e-03, bc=3.85e-04, ic=7.39e-05, zz=1.41e-07, yxz=9.59e-07, ) | ValLoss=8.578e-03 (pde=8.20e-03, bc=3.08e-04, ic=6.43e-05, zz=1.27e-07, yxz=7.76e-07, )
# Epoch  930 | TrainLoss=8.088e-03 (pde=7.63e-03, bc=3.85e-04, ic=7.36e-05, zz=1.09e-07, yxz=1.06e-06, ) | ValLoss=8.560e-03 (pde=8.19e-03, bc=3.08e-04, ic=6.41e-05, zz=1.04e-07, yxz=9.65e-07, )
# Epoch  940 | TrainLoss=8.088e-03 (pde=7.63e-03, bc=3.84e-04, ic=7.28e-05, zz=9.77e-08, yxz=1.13e-06, ) | ValLoss=8.588e-03 (pde=8.22e-03, bc=3.07e-04, ic=6.37e-05, zz=8.90e-08, yxz=9.42e-07, )
#
# [Resample] epoch 950: regenerating PDE/BC/IC points...
#
# Epoch  950 | TrainLoss=8.087e-03 (pde=7.91e-03, bc=3.85e-04, ic=7.40e-05, zz=1.16e-07, yxz=1.22e-06, ) | ValLoss=8.620e-03 (pde=8.25e-03, bc=3.08e-04, ic=6.34e-05, zz=9.75e-08, yxz=1.06e-06, )
# Epoch  960 | TrainLoss=8.356e-03 (pde=7.89e-03, bc=3.85e-04, ic=7.48e-05, zz=1.27e-07, yxz=1.13e-06, ) | ValLoss=8.583e-03 (pde=8.21e-03, bc=3.10e-04, ic=6.46e-05, zz=1.42e-07, yxz=1.08e-06, )
# Epoch  970 | TrainLoss=8.355e-03 (pde=7.90e-03, bc=3.83e-04, ic=7.48e-05, zz=1.22e-07, yxz=1.03e-06, ) | ValLoss=8.600e-03 (pde=8.23e-03, bc=3.09e-04, ic=6.46e-05, zz=1.11e-07, yxz=9.10e-07, )
# Epoch  980 | TrainLoss=8.353e-03 (pde=7.90e-03, bc=3.81e-04, ic=7.50e-05, zz=1.29e-07, yxz=1.09e-06, ) | ValLoss=8.630e-03 (pde=8.26e-03, bc=3.07e-04, ic=6.46e-05, zz=1.29e-07, yxz=8.49e-07, )
# Epoch  990 | TrainLoss=8.353e-03 (pde=7.90e-03, bc=3.80e-04, ic=7.49e-05, zz=1.18e-07, yxz=1.03e-06, ) | ValLoss=8.613e-03 (pde=8.24e-03, bc=3.07e-04, ic=6.45e-05, zz=1.12e-07, yxz=8.88e-07, )
#
# [Resample] epoch 1000: regenerating PDE/BC/IC points...
#
# Epoch 1000 | TrainLoss=8.352e-03 (pde=8.33e-03, bc=3.77e-04, ic=7.35e-05, zz=1.40e-07, yxz=8.66e-07, ) | ValLoss=8.624e-03 (pde=8.25e-03, bc=3.05e-04, ic=6.48e-05, zz=1.46e-07, yxz=6.95e-07, )
# Epoch 1010 | TrainLoss=8.750e-03 (pde=8.29e-03, bc=3.88e-04, ic=6.97e-05, zz=1.25e-07, yxz=9.14e-07, ) | ValLoss=8.538e-03 (pde=8.16e-03, bc=3.16e-04, ic=6.29e-05, zz=1.17e-07, yxz=7.07e-07, )
# Epoch 1020 | TrainLoss=8.748e-03 (pde=8.29e-03, bc=3.89e-04, ic=6.94e-05, zz=1.11e-07, yxz=1.10e-06, ) | ValLoss=8.534e-03 (pde=8.15e-03, bc=3.16e-04, ic=6.27e-05, zz=1.05e-07, yxz=8.32e-07, )
# Epoch 1030 | TrainLoss=8.747e-03 (pde=8.29e-03, bc=3.88e-04, ic=6.91e-05, zz=1.26e-07, yxz=1.14e-06, ) | ValLoss=8.530e-03 (pde=8.15e-03, bc=3.16e-04, ic=6.27e-05, zz=1.12e-07, yxz=8.61e-07, )
# Epoch 1040 | TrainLoss=8.747e-03 (pde=8.29e-03, bc=3.87e-04, ic=6.95e-05, zz=1.22e-07, yxz=1.06e-06, ) | ValLoss=8.537e-03 (pde=8.16e-03, bc=3.15e-04, ic=6.30e-05, zz=1.08e-07, yxz=7.33e-07, )
#
# [Resample] epoch 1050: regenerating PDE/BC/IC points...
#
# Epoch 1050 | TrainLoss=8.746e-03 (pde=8.18e-03, bc=3.88e-04, ic=7.30e-05, zz=1.41e-07, yxz=1.06e-06, ) | ValLoss=8.554e-03 (pde=8.18e-03, bc=3.15e-04, ic=6.29e-05, zz=1.15e-07, yxz=7.67e-07, )
# Epoch 1060 | TrainLoss=8.618e-03 (pde=8.15e-03, bc=3.89e-04, ic=7.67e-05, zz=1.34e-07, yxz=1.11e-06, ) | ValLoss=8.466e-03 (pde=8.08e-03, bc=3.16e-04, ic=6.54e-05, zz=1.26e-07, yxz=9.32e-07, )
# Epoch 1070 | TrainLoss=8.616e-03 (pde=8.15e-03, bc=3.88e-04, ic=7.74e-05, zz=1.79e-07, yxz=1.10e-06, ) | ValLoss=8.471e-03 (pde=8.09e-03, bc=3.15e-04, ic=6.58e-05, zz=1.72e-07, yxz=8.83e-07, )
# Epoch 1080 | TrainLoss=8.615e-03 (pde=8.15e-03, bc=3.89e-04, ic=7.68e-05, zz=1.57e-07, yxz=1.15e-06, ) | ValLoss=8.450e-03 (pde=8.07e-03, bc=3.16e-04, ic=6.55e-05, zz=1.42e-07, yxz=8.95e-07, )
# Epoch 1090 | TrainLoss=8.614e-03 (pde=8.15e-03, bc=3.88e-04, ic=7.75e-05, zz=1.89e-07, yxz=1.25e-06, ) | ValLoss=8.450e-03 (pde=8.07e-03, bc=3.15e-04, ic=6.61e-05, zz=1.87e-07, yxz=1.04e-06, )
#
# [Resample] epoch 1100: regenerating PDE/BC/IC points...
#
# Epoch 1100 | TrainLoss=8.614e-03 (pde=8.18e-03, bc=3.90e-04, ic=7.56e-05, zz=1.81e-07, yxz=1.27e-06, ) | ValLoss=8.451e-03 (pde=8.07e-03, bc=3.15e-04, ic=6.59e-05, zz=1.98e-07, yxz=1.00e-06, )
# Epoch 1110 | TrainLoss=8.606e-03 (pde=8.14e-03, bc=3.92e-04, ic=7.54e-05, zz=1.62e-07, yxz=1.17e-06, ) | ValLoss=8.505e-03 (pde=8.13e-03, bc=3.13e-04, ic=6.51e-05, zz=1.72e-07, yxz=8.65e-07, )
# Epoch 1120 | TrainLoss=8.605e-03 (pde=8.14e-03, bc=3.92e-04, ic=7.58e-05, zz=1.74e-07, yxz=1.15e-06, ) | ValLoss=8.491e-03 (pde=8.11e-03, bc=3.13e-04, ic=6.50e-05, zz=1.62e-07, yxz=9.33e-07, )
# Epoch 1130 | TrainLoss=8.603e-03 (pde=8.13e-03, bc=3.91e-04, ic=7.65e-05, zz=1.98e-07, yxz=1.09e-06, ) | ValLoss=8.497e-03 (pde=8.12e-03, bc=3.12e-04, ic=6.53e-05, zz=1.89e-07, yxz=8.87e-07, )
# Epoch 1140 | TrainLoss=8.602e-03 (pde=8.13e-03, bc=3.91e-04, ic=7.58e-05, zz=2.06e-07, yxz=1.04e-06, ) | ValLoss=8.493e-03 (pde=8.11e-03, bc=3.12e-04, ic=6.51e-05, zz=2.03e-07, yxz=9.05e-07, )
#
# [Resample] epoch 1150: regenerating PDE/BC/IC points...
#
# Epoch 1150 | TrainLoss=8.602e-03 (pde=8.48e-03, bc=3.90e-04, ic=7.32e-05, zz=2.41e-07, yxz=1.05e-06, ) | ValLoss=8.476e-03 (pde=8.10e-03, bc=3.12e-04, ic=6.48e-05, zz=2.26e-07, yxz=9.59e-07, )
# Epoch 1160 | TrainLoss=8.804e-03 (pde=8.33e-03, bc=3.98e-04, ic=7.49e-05, zz=6.49e-07, yxz=2.90e-06, ) | ValLoss=8.471e-03 (pde=8.08e-03, bc=3.19e-04, ic=6.66e-05, zz=6.17e-07, yxz=2.63e-06, )
# Epoch 1170 | TrainLoss=8.789e-03 (pde=8.31e-03, bc=4.00e-04, ic=7.54e-05, zz=2.45e-07, yxz=2.76e-06, ) | ValLoss=8.491e-03 (pde=8.10e-03, bc=3.20e-04, ic=6.76e-05, zz=2.24e-07, yxz=2.65e-06, )
# Epoch 1180 | TrainLoss=8.783e-03 (pde=8.30e-03, bc=4.02e-04, ic=7.43e-05, zz=1.31e-07, yxz=2.32e-06, ) | ValLoss=8.471e-03 (pde=8.08e-03, bc=3.24e-04, ic=6.66e-05, zz=1.23e-07, yxz=2.26e-06, )
# Epoch 1190 | TrainLoss=8.779e-03 (pde=8.30e-03, bc=4.01e-04, ic=7.51e-05, zz=1.02e-07, yxz=2.06e-06, ) | ValLoss=8.529e-03 (pde=8.14e-03, bc=3.22e-04, ic=6.69e-05, zz=9.93e-08, yxz=2.17e-06, )
#
# [Resample] epoch 1200: regenerating PDE/BC/IC points...
#
# Epoch 1200 | TrainLoss=8.777e-03 (pde=8.14e-03, bc=4.02e-04, ic=8.11e-05, zz=8.91e-08, yxz=2.17e-06, ) | ValLoss=8.527e-03 (pde=8.14e-03, bc=3.22e-04, ic=6.73e-05, zz=8.28e-08, yxz=2.20e-06, )
# Epoch 1210 | TrainLoss=8.579e-03 (pde=8.10e-03, bc=4.01e-04, ic=7.95e-05, zz=1.91e-07, yxz=1.99e-06, ) | ValLoss=8.469e-03 (pde=8.08e-03, bc=3.22e-04, ic=6.64e-05, zz=1.52e-07, yxz=1.83e-06, )
# Epoch 1220 | TrainLoss=8.575e-03 (pde=8.09e-03, bc=4.01e-04, ic=7.80e-05, zz=1.47e-07, yxz=1.64e-06, ) | ValLoss=8.498e-03 (pde=8.11e-03, bc=3.22e-04, ic=6.57e-05, zz=1.42e-07, yxz=1.63e-06, )
# Epoch 1230 | TrainLoss=8.573e-03 (pde=8.09e-03, bc=4.01e-04, ic=7.76e-05, zz=1.25e-07, yxz=1.38e-06, ) | ValLoss=8.483e-03 (pde=8.09e-03, bc=3.23e-04, ic=6.53e-05, zz=1.22e-07, yxz=1.31e-06, )
# Epoch 1240 | TrainLoss=8.572e-03 (pde=8.09e-03, bc=4.01e-04, ic=7.78e-05, zz=1.10e-07, yxz=1.30e-06, ) | ValLoss=8.506e-03 (pde=8.12e-03, bc=3.22e-04, ic=6.58e-05, zz=1.05e-07, yxz=1.22e-06, )
#
# [Resample] epoch 1250: regenerating PDE/BC/IC points...
#
# Epoch 1250 | TrainLoss=8.571e-03 (pde=8.16e-03, bc=4.01e-04, ic=7.68e-05, zz=1.07e-07, yxz=1.41e-06, ) | ValLoss=8.493e-03 (pde=8.10e-03, bc=3.21e-04, ic=6.58e-05, zz=1.06e-07, yxz=1.41e-06, )
# Epoch 1260 | TrainLoss=8.613e-03 (pde=8.13e-03, bc=3.99e-04, ic=7.84e-05, zz=2.26e-07, yxz=2.13e-06, ) | ValLoss=8.472e-03 (pde=8.08e-03, bc=3.19e-04, ic=6.63e-05, zz=2.27e-07, yxz=2.03e-06, )
# Epoch 1270 | TrainLoss=8.610e-03 (pde=8.13e-03, bc=3.98e-04, ic=7.88e-05, zz=1.71e-07, yxz=1.77e-06, ) | ValLoss=8.476e-03 (pde=8.09e-03, bc=3.18e-04, ic=6.67e-05, zz=1.55e-07, yxz=1.70e-06, )
# Epoch 1280 | TrainLoss=8.608e-03 (pde=8.13e-03, bc=3.97e-04, ic=7.85e-05, zz=1.78e-07, yxz=1.87e-06, ) | ValLoss=8.441e-03 (pde=8.05e-03, bc=3.18e-04, ic=6.64e-05, zz=1.78e-07, yxz=1.84e-06, )
# Epoch 1290 | TrainLoss=8.606e-03 (pde=8.13e-03, bc=3.97e-04, ic=7.85e-05, zz=1.17e-07, yxz=1.84e-06, ) | ValLoss=8.431e-03 (pde=8.04e-03, bc=3.18e-04, ic=6.66e-05, zz=1.16e-07, yxz=1.80e-06, )
#
# [Resample] epoch 1300: regenerating PDE/BC/IC points...
#
# Epoch 1300 | TrainLoss=8.605e-03 (pde=8.28e-03, bc=3.98e-04, ic=7.48e-05, zz=1.23e-07, yxz=2.13e-06, ) | ValLoss=8.432e-03 (pde=8.05e-03, bc=3.17e-04, ic=6.67e-05, zz=1.23e-07, yxz=2.01e-06, )
# Epoch 1310 | TrainLoss=8.640e-03 (pde=8.17e-03, bc=3.97e-04, ic=7.34e-05, zz=1.12e-07, yxz=1.18e-06, ) | ValLoss=8.510e-03 (pde=8.12e-03, bc=3.19e-04, ic=6.69e-05, zz=9.76e-08, yxz=1.16e-06, )
# Epoch 1320 | TrainLoss=8.637e-03 (pde=8.17e-03, bc=3.96e-04, ic=7.21e-05, zz=1.09e-07, yxz=1.08e-06, ) | ValLoss=8.532e-03 (pde=8.15e-03, bc=3.20e-04, ic=6.60e-05, zz=9.89e-08, yxz=1.07e-06, )
# Epoch 1330 | TrainLoss=8.636e-03 (pde=8.17e-03, bc=3.93e-04, ic=7.27e-05, zz=1.07e-07, yxz=1.06e-06, ) | ValLoss=8.527e-03 (pde=8.14e-03, bc=3.18e-04, ic=6.61e-05, zz=1.01e-07, yxz=9.97e-07, )
# Epoch 1340 | TrainLoss=8.635e-03 (pde=8.17e-03, bc=3.92e-04, ic=7.32e-05, zz=1.10e-07, yxz=1.01e-06, ) | ValLoss=8.511e-03 (pde=8.13e-03, bc=3.16e-04, ic=6.61e-05, zz=1.09e-07, yxz=8.58e-07, )
#
# [Resample] epoch 1350: regenerating PDE/BC/IC points...
#
# Epoch 1350 | TrainLoss=8.634e-03 (pde=8.01e-03, bc=3.91e-04, ic=7.13e-05, zz=1.13e-07, yxz=9.06e-07, ) | ValLoss=8.513e-03 (pde=8.13e-03, bc=3.17e-04, ic=6.57e-05, zz=1.02e-07, yxz=8.04e-07, )
# Epoch 1360 | TrainLoss=8.432e-03 (pde=7.96e-03, bc=3.97e-04, ic=7.34e-05, zz=1.15e-07, yxz=1.26e-06, ) | ValLoss=8.491e-03 (pde=8.10e-03, bc=3.21e-04, ic=6.63e-05, zz=1.00e-07, yxz=1.26e-06, )
# Epoch 1370 | TrainLoss=8.430e-03 (pde=7.96e-03, bc=3.97e-04, ic=7.38e-05, zz=1.07e-07, yxz=1.23e-06, ) | ValLoss=8.498e-03 (pde=8.11e-03, bc=3.19e-04, ic=6.67e-05, zz=9.43e-08, yxz=1.28e-06, )
# Epoch 1380 | TrainLoss=8.429e-03 (pde=7.96e-03, bc=3.96e-04, ic=7.43e-05, zz=1.12e-07, yxz=1.16e-06, ) | ValLoss=8.505e-03 (pde=8.12e-03, bc=3.19e-04, ic=6.72e-05, zz=9.52e-08, yxz=1.16e-06, )
# Epoch 1390 | TrainLoss=8.429e-03 (pde=7.96e-03, bc=3.96e-04, ic=7.43e-05, zz=1.06e-07, yxz=1.16e-06, ) | ValLoss=8.518e-03 (pde=8.13e-03, bc=3.19e-04, ic=6.72e-05, zz=9.23e-08, yxz=1.17e-06, )
#
# [Resample] epoch 1400: regenerating PDE/BC/IC points...
#
# Epoch 1400 | TrainLoss=8.429e-03 (pde=7.69e-03, bc=3.99e-04, ic=7.94e-05, zz=1.08e-07, yxz=1.22e-06, ) | ValLoss=8.518e-03 (pde=8.13e-03, bc=3.19e-04, ic=6.72e-05, zz=9.23e-08, yxz=1.17e-06, )
# Epoch 1410 | TrainLoss=8.145e-03 (pde=7.68e-03, bc=3.88e-04, ic=7.40e-05, zz=1.61e-07, yxz=1.06e-06, ) | ValLoss=8.530e-03 (pde=8.15e-03, bc=3.14e-04, ic=6.41e-05, zz=1.63e-07, yxz=8.67e-07, )
# Epoch 1420 | TrainLoss=8.142e-03 (pde=7.68e-03, bc=3.85e-04, ic=7.41e-05, zz=1.25e-07, yxz=9.45e-07, ) | ValLoss=8.555e-03 (pde=8.18e-03, bc=3.12e-04, ic=6.41e-05, zz=1.09e-07, yxz=8.14e-07, )
# Epoch 1430 | TrainLoss=8.141e-03 (pde=7.68e-03, bc=3.83e-04, ic=7.37e-05, zz=1.41e-07, yxz=1.07e-06, ) | ValLoss=8.562e-03 (pde=8.19e-03, bc=3.10e-04, ic=6.35e-05, zz=1.52e-07, yxz=9.17e-07, )
# Epoch 1440 | TrainLoss=8.140e-03 (pde=7.68e-03, bc=3.82e-04, ic=7.25e-05, zz=1.20e-07, yxz=9.86e-07, ) | ValLoss=8.598e-03 (pde=8.22e-03, bc=3.10e-04, ic=6.26e-05, zz=1.17e-07, yxz=8.85e-07, )
#
# [Resample] epoch 1450: regenerating PDE/BC/IC points...
#
# Epoch 1450 | TrainLoss=8.139e-03 (pde=8.42e-03, bc=3.83e-04, ic=7.63e-05, zz=1.15e-07, yxz=1.04e-06, ) | ValLoss=8.602e-03 (pde=8.23e-03, bc=3.10e-04, ic=6.23e-05, zz=1.07e-07, yxz=9.05e-07, )
# Epoch 1460 | TrainLoss=8.862e-03 (pde=8.39e-03, bc=3.89e-04, ic=7.86e-05, zz=1.02e-07, yxz=1.06e-06, ) | ValLoss=8.468e-03 (pde=8.09e-03, bc=3.13e-04, ic=6.41e-05, zz=1.00e-07, yxz=9.27e-07, )
# Epoch 1470 | TrainLoss=8.860e-03 (pde=8.39e-03, bc=3.88e-04, ic=7.89e-05, zz=1.22e-07, yxz=8.92e-07, ) | ValLoss=8.481e-03 (pde=8.10e-03, bc=3.11e-04, ic=6.44e-05, zz=1.25e-07, yxz=8.41e-07, )
# Epoch 1480 | TrainLoss=8.860e-03 (pde=8.39e-03, bc=3.88e-04, ic=7.81e-05, zz=1.29e-07, yxz=1.04e-06, ) | ValLoss=8.494e-03 (pde=8.12e-03, bc=3.11e-04, ic=6.38e-05, zz=1.31e-07, yxz=9.10e-07, )
# Epoch 1490 | TrainLoss=8.859e-03 (pde=8.39e-03, bc=3.87e-04, ic=7.79e-05, zz=1.49e-07, yxz=9.86e-07, ) | ValLoss=8.506e-03 (pde=8.13e-03, bc=3.10e-04, ic=6.38e-05, zz=1.49e-07, yxz=8.38e-07, )
#
# [Resample] epoch 1500: regenerating PDE/BC/IC points...
#
# Epoch 1500 | TrainLoss=8.858e-03 (pde=8.04e-03, bc=3.84e-04, ic=7.30e-05, zz=1.84e-07, yxz=9.34e-07, ) | ValLoss=8.497e-03 (pde=8.12e-03, bc=3.10e-04, ic=6.38e-05, zz=1.83e-07, yxz=8.67e-07, )
# Epoch 1510 | TrainLoss=8.460e-03 (pde=8.00e-03, bc=3.91e-04, ic=7.13e-05, zz=1.61e-07, yxz=9.82e-07, ) | ValLoss=8.481e-03 (pde=8.10e-03, bc=3.14e-04, ic=6.33e-05, zz=1.51e-07, yxz=8.89e-07, )
# Epoch 1520 | TrainLoss=8.459e-03 (pde=8.00e-03, bc=3.91e-04, ic=7.07e-05, zz=1.29e-07, yxz=9.91e-07, ) | ValLoss=8.484e-03 (pde=8.10e-03, bc=3.15e-04, ic=6.31e-05, zz=1.16e-07, yxz=9.54e-07, )
# Epoch 1530 | TrainLoss=8.458e-03 (pde=8.00e-03, bc=3.92e-04, ic=7.03e-05, zz=1.25e-07, yxz=1.01e-06, ) | ValLoss=8.483e-03 (pde=8.10e-03, bc=3.16e-04, ic=6.30e-05, zz=1.11e-07, yxz=9.55e-07, )
# Epoch 1540 | TrainLoss=8.458e-03 (pde=8.00e-03, bc=3.92e-04, ic=7.03e-05, zz=1.25e-07, yxz=1.01e-06, ) | ValLoss=8.483e-03 (pde=8.10e-03, bc=3.16e-04, ic=6.30e-05, zz=1.11e-07, yxz=9.55e-07, )
#
# [Resample] epoch 1550: regenerating PDE/BC/IC points...
#
# Epoch 1550 | TrainLoss=8.458e-03 (pde=8.08e-03, bc=3.93e-04, ic=6.73e-05, zz=1.18e-07, yxz=9.62e-07, ) | ValLoss=8.483e-03 (pde=8.10e-03, bc=3.16e-04, ic=6.30e-05, zz=1.11e-07, yxz=9.55e-07, )
# Epoch 1560 | TrainLoss=8.516e-03 (pde=8.07e-03, bc=3.75e-04, ic=6.54e-05, zz=1.74e-07, yxz=9.48e-07, ) | ValLoss=8.783e-03 (pde=8.41e-03, bc=3.08e-04, ic=6.17e-05, zz=1.60e-07, yxz=9.94e-07, )
# Epoch 1570 | TrainLoss=8.514e-03 (pde=8.07e-03, bc=3.74e-04, ic=6.41e-05, zz=2.08e-07, yxz=1.16e-06, ) | ValLoss=8.824e-03 (pde=8.45e-03, bc=3.09e-04, ic=6.11e-05, zz=2.14e-07, yxz=1.28e-06, )
# Epoch 1580 | TrainLoss=8.513e-03 (pde=8.08e-03, bc=3.71e-04, ic=6.40e-05, zz=1.91e-07, yxz=1.16e-06, ) | ValLoss=8.893e-03 (pde=8.52e-03, bc=3.06e-04, ic=6.09e-05, zz=2.04e-07, yxz=1.17e-06, )
# Epoch 1590 | TrainLoss=8.511e-03 (pde=8.08e-03, bc=3.70e-04, ic=6.30e-05, zz=2.36e-07, yxz=1.00e-06, ) | ValLoss=9.009e-03 (pde=8.64e-03, bc=3.05e-04, ic=6.02e-05, zz=2.30e-07, yxz=9.77e-07, )
#
# [Resample] epoch 1600: regenerating PDE/BC/IC points...
#
# Epoch 1600 | TrainLoss=8.511e-03 (pde=8.19e-03, bc=3.67e-04, ic=6.61e-05, zz=2.64e-07, yxz=1.08e-06, ) | ValLoss=9.033e-03 (pde=8.67e-03, bc=3.06e-04, ic=5.95e-05, zz=2.62e-07, yxz=9.34e-07, )
# Epoch 1610 | TrainLoss=8.505e-03 (pde=8.04e-03, bc=3.89e-04, ic=7.14e-05, zz=1.33e-07, yxz=1.18e-06, ) | ValLoss=8.431e-03 (pde=8.05e-03, bc=3.21e-04, ic=6.35e-05, zz=1.26e-07, yxz=1.51e-06, )
# Epoch 1620 | TrainLoss=8.502e-03 (pde=8.04e-03, bc=3.90e-04, ic=7.16e-05, zz=1.22e-07, yxz=1.16e-06, ) | ValLoss=8.473e-03 (pde=8.09e-03, bc=3.21e-04, ic=6.36e-05, zz=1.18e-07, yxz=1.14e-06, )
# Epoch 1630 | TrainLoss=8.501e-03 (pde=8.04e-03, bc=3.90e-04, ic=7.12e-05, zz=1.23e-07, yxz=1.25e-06, ) | ValLoss=8.480e-03 (pde=8.09e-03, bc=3.22e-04, ic=6.35e-05, zz=1.16e-07, yxz=1.10e-06, )
# Epoch 1640 | TrainLoss=8.501e-03 (pde=8.04e-03, bc=3.91e-04, ic=7.01e-05, zz=1.39e-07, yxz=1.20e-06, ) | ValLoss=8.471e-03 (pde=8.08e-03, bc=3.24e-04, ic=6.29e-05, zz=1.25e-07, yxz=1.12e-06, )
#
# [Resample] epoch 1650: regenerating PDE/BC/IC points...
#
# Epoch 1650 | TrainLoss=8.500e-03 (pde=7.76e-03, bc=3.95e-04, ic=6.69e-05, zz=1.40e-07, yxz=1.30e-06, ) | ValLoss=8.468e-03 (pde=8.08e-03, bc=3.24e-04, ic=6.25e-05, zz=1.22e-07, yxz=1.11e-06, )
# Epoch 1660 | TrainLoss=8.165e-03 (pde=7.70e-03, bc=3.91e-04, ic=7.09e-05, zz=1.80e-07, yxz=9.88e-07, ) | ValLoss=8.496e-03 (pde=8.11e-03, bc=3.17e-04, ic=6.45e-05, zz=1.68e-07, yxz=7.53e-07, )
# Epoch 1670 | TrainLoss=8.164e-03 (pde=7.70e-03, bc=3.90e-04, ic=7.08e-05, zz=1.69e-07, yxz=9.24e-07, ) | ValLoss=8.497e-03 (pde=8.12e-03, bc=3.16e-04, ic=6.43e-05, zz=1.44e-07, yxz=7.63e-07, )
# Epoch 1680 | TrainLoss=8.163e-03 (pde=7.70e-03, bc=3.90e-04, ic=7.10e-05, zz=1.61e-07, yxz=8.39e-07, ) | ValLoss=8.515e-03 (pde=8.13e-03, bc=3.16e-04, ic=6.45e-05, zz=1.49e-07, yxz=6.83e-07, )
# Epoch 1690 | TrainLoss=8.163e-03 (pde=7.70e-03, bc=3.90e-04, ic=7.09e-05, zz=1.53e-07, yxz=8.54e-07, ) | ValLoss=8.508e-03 (pde=8.13e-03, bc=3.16e-04, ic=6.45e-05, zz=1.53e-07, yxz=6.87e-07, )
#
# [Resample] epoch 1700: regenerating PDE/BC/IC points...
#
# Epoch 1700 | TrainLoss=8.163e-03 (pde=8.14e-03, bc=3.91e-04, ic=7.45e-05, zz=1.51e-07, yxz=8.60e-07, ) | ValLoss=8.508e-03 (pde=8.13e-03, bc=3.16e-04, ic=6.45e-05, zz=1.53e-07, yxz=6.87e-07, )
# Epoch 1710 | TrainLoss=8.543e-03 (pde=8.08e-03, bc=3.86e-04, ic=7.28e-05, zz=1.49e-07, yxz=9.86e-07, ) | ValLoss=8.549e-03 (pde=8.17e-03, bc=3.13e-04, ic=6.35e-05, zz=1.49e-07, yxz=8.27e-07, )
# Epoch 1720 | TrainLoss=8.542e-03 (pde=8.08e-03, bc=3.86e-04, ic=7.28e-05, zz=1.62e-07, yxz=9.18e-07, ) | ValLoss=8.549e-03 (pde=8.17e-03, bc=3.12e-04, ic=6.35e-05, zz=1.60e-07, yxz=7.13e-07, )
# Epoch 1730 | TrainLoss=8.542e-03 (pde=8.08e-03, bc=3.86e-04, ic=7.28e-05, zz=1.62e-07, yxz=9.18e-07, ) | ValLoss=8.549e-03 (pde=8.17e-03, bc=3.12e-04, ic=6.35e-05, zz=1.60e-07, yxz=7.13e-07, )
# Epoch 1740 | TrainLoss=8.542e-03 (pde=8.08e-03, bc=3.86e-04, ic=7.28e-05, zz=1.62e-07, yxz=9.18e-07, ) | ValLoss=8.549e-03 (pde=8.17e-03, bc=3.12e-04, ic=6.35e-05, zz=1.60e-07, yxz=7.13e-07, )
#
# [Resample] epoch 1750: regenerating PDE/BC/IC points...
#
# Epoch 1750 | TrainLoss=8.542e-03 (pde=8.06e-03, bc=3.88e-04, ic=7.87e-05, zz=1.68e-07, yxz=8.83e-07, ) | ValLoss=8.549e-03 (pde=8.17e-03, bc=3.12e-04, ic=6.35e-05, zz=1.60e-07, yxz=7.13e-07, )
# Epoch 1760 | TrainLoss=8.518e-03 (pde=8.06e-03, bc=3.78e-04, ic=7.83e-05, zz=2.11e-07, yxz=8.45e-07, ) | ValLoss=8.769e-03 (pde=8.40e-03, bc=3.06e-04, ic=6.37e-05, zz=1.97e-07, yxz=6.94e-07, )
# Epoch 1770 | TrainLoss=8.515e-03 (pde=8.06e-03, bc=3.76e-04, ic=7.79e-05, zz=2.12e-07, yxz=8.57e-07, ) | ValLoss=8.799e-03 (pde=8.43e-03, bc=3.05e-04, ic=6.30e-05, zz=1.93e-07, yxz=6.72e-07, )
# Epoch 1780 | TrainLoss=8.514e-03 (pde=8.06e-03, bc=3.73e-04, ic=7.81e-05, zz=2.15e-07, yxz=9.37e-07, ) | ValLoss=8.841e-03 (pde=8.47e-03, bc=3.03e-04, ic=6.33e-05, zz=2.09e-07, yxz=7.93e-07, )
# Epoch 1790 | TrainLoss=8.513e-03 (pde=8.06e-03, bc=3.72e-04, ic=7.73e-05, zz=2.20e-07, yxz=1.01e-06, ) | ValLoss=8.891e-03 (pde=8.52e-03, bc=3.02e-04, ic=6.25e-05, zz=2.00e-07, yxz=7.43e-07, )
#
# [Resample] epoch 1800: regenerating PDE/BC/IC points...
#
# Epoch 1800 | TrainLoss=8.512e-03 (pde=7.86e-03, bc=3.71e-04, ic=7.10e-05, zz=2.05e-07, yxz=8.79e-07, ) | ValLoss=8.964e-03 (pde=8.60e-03, bc=3.02e-04, ic=6.15e-05, zz=2.09e-07, yxz=7.40e-07, )
# Epoch 1810 | TrainLoss=8.256e-03 (pde=7.79e-03, bc=3.86e-04, ic=7.33e-05, zz=1.71e-07, yxz=1.00e-06, ) | ValLoss=8.516e-03 (pde=8.14e-03, bc=3.12e-04, ic=6.37e-05, zz=1.72e-07, yxz=7.94e-07, )
# Epoch 1820 | TrainLoss=8.254e-03 (pde=7.79e-03, bc=3.86e-04, ic=7.35e-05, zz=1.51e-07, yxz=9.61e-07, ) | ValLoss=8.524e-03 (pde=8.15e-03, bc=3.11e-04, ic=6.39e-05, zz=1.53e-07, yxz=8.23e-07, )
# Epoch 1830 | TrainLoss=8.254e-03 (pde=7.79e-03, bc=3.86e-04, ic=7.34e-05, zz=1.48e-07, yxz=9.59e-07, ) | ValLoss=8.521e-03 (pde=8.15e-03, bc=3.11e-04, ic=6.36e-05, zz=1.49e-07, yxz=7.73e-07, )
# Epoch 1840 | TrainLoss=8.254e-03 (pde=7.79e-03, bc=3.86e-04, ic=7.34e-05, zz=1.48e-07, yxz=9.59e-07, ) | ValLoss=8.521e-03 (pde=8.15e-03, bc=3.11e-04, ic=6.36e-05, zz=1.49e-07, yxz=7.73e-07, )
#
# [Resample] epoch 1850: regenerating PDE/BC/IC points...
#
# Epoch 1850 | TrainLoss=8.254e-03 (pde=8.67e-03, bc=3.87e-04, ic=7.04e-05, zz=1.49e-07, yxz=9.42e-07, ) | ValLoss=8.521e-03 (pde=8.15e-03, bc=3.11e-04, ic=6.36e-05, zz=1.49e-07, yxz=7.73e-07, )
# Epoch 1860 | TrainLoss=9.109e-03 (pde=8.66e-03, bc=3.81e-04, ic=6.93e-05, zz=2.05e-07, yxz=7.99e-07, ) | ValLoss=8.605e-03 (pde=8.24e-03, bc=3.07e-04, ic=6.25e-05, zz=2.02e-07, yxz=6.34e-07, )
# Epoch 1870 | TrainLoss=9.108e-03 (pde=8.66e-03, bc=3.80e-04, ic=6.81e-05, zz=1.59e-07, yxz=9.21e-07, ) | ValLoss=8.658e-03 (pde=8.29e-03, bc=3.07e-04, ic=6.14e-05, zz=1.62e-07, yxz=7.37e-07, )
# Epoch 1880 | TrainLoss=9.108e-03 (pde=8.66e-03, bc=3.79e-04, ic=6.72e-05, zz=1.50e-07, yxz=9.33e-07, ) | ValLoss=8.700e-03 (pde=8.33e-03, bc=3.06e-04, ic=6.06e-05, zz=1.48e-07, yxz=6.92e-07, )
# Epoch 1890 | TrainLoss=9.107e-03 (pde=8.66e-03, bc=3.77e-04, ic=6.73e-05, zz=1.49e-07, yxz=9.12e-07, ) | ValLoss=8.726e-03 (pde=8.36e-03, bc=3.04e-04, ic=6.05e-05, zz=1.49e-07, yxz=6.58e-07, )
#
# [Resample] epoch 1900: regenerating PDE/BC/IC points...
#
# Epoch 1900 | TrainLoss=9.107e-03 (pde=8.16e-03, bc=3.82e-04, ic=7.25e-05, zz=1.63e-07, yxz=9.30e-07, ) | ValLoss=8.703e-03 (pde=8.34e-03, bc=3.04e-04, ic=6.07e-05, zz=1.46e-07, yxz=6.85e-07, )
# Epoch 1910 | TrainLoss=8.593e-03 (pde=8.15e-03, bc=3.68e-04, ic=7.13e-05, zz=2.08e-07, yxz=1.23e-06, ) | ValLoss=9.279e-03 (pde=8.93e-03, bc=2.92e-04, ic=5.98e-05, zz=1.97e-07, yxz=8.51e-07, )
# Epoch 1920 | TrainLoss=8.590e-03 (pde=8.15e-03, bc=3.62e-04, ic=7.20e-05, zz=2.27e-07, yxz=1.16e-06, ) | ValLoss=9.387e-03 (pde=9.04e-03, bc=2.87e-04, ic=6.05e-05, zz=2.13e-07, yxz=1.01e-06, )
# Epoch 1930 | TrainLoss=8.588e-03 (pde=8.16e-03, bc=3.59e-04, ic=7.22e-05, zz=2.36e-07, yxz=1.08e-06, ) | ValLoss=9.363e-03 (pde=9.02e-03, bc=2.85e-04, ic=6.06e-05, zz=2.41e-07, yxz=9.16e-07, )
# Epoch 1940 | TrainLoss=8.587e-03 (pde=8.16e-03, bc=3.55e-04, ic=7.26e-05, zz=2.78e-07, yxz=9.25e-07, ) | ValLoss=9.481e-03 (pde=9.14e-03, bc=2.82e-04, ic=6.05e-05, zz=2.72e-07, yxz=8.09e-07, )
#
# [Resample] epoch 1950: regenerating PDE/BC/IC points...
#
# Epoch 1950 | TrainLoss=8.586e-03 (pde=7.94e-03, bc=3.50e-04, ic=6.98e-05, zz=3.26e-07, yxz=9.17e-07, ) | ValLoss=9.525e-03 (pde=9.18e-03, bc=2.80e-04, ic=6.06e-05, zz=3.36e-07, yxz=8.24e-07, )
# Epoch 1960 | TrainLoss=8.302e-03 (pde=7.85e-03, bc=3.80e-04, ic=6.95e-05, zz=2.10e-07, yxz=1.08e-06, ) | ValLoss=8.576e-03 (pde=8.21e-03, bc=3.05e-04, ic=6.19e-05, zz=2.14e-07, yxz=9.42e-07, )
# Epoch 1970 | TrainLoss=8.300e-03 (pde=7.85e-03, bc=3.82e-04, ic=6.94e-05, zz=1.81e-07, yxz=1.01e-06, ) | ValLoss=8.593e-03 (pde=8.22e-03, bc=3.06e-04, ic=6.18e-05, zz=1.74e-07, yxz=7.85e-07, )
# Epoch 1980 | TrainLoss=8.299e-03 (pde=7.85e-03, bc=3.81e-04, ic=6.99e-05, zz=2.02e-07, yxz=9.95e-07, ) | ValLoss=8.583e-03 (pde=8.21e-03, bc=3.06e-04, ic=6.22e-05, zz=1.93e-07, yxz=8.17e-07, )
# Epoch 1990 | TrainLoss=8.298e-03 (pde=7.85e-03, bc=3.80e-04, ic=7.04e-05, zz=2.45e-07, yxz=1.05e-06, ) | ValLoss=8.574e-03 (pde=8.21e-03, bc=3.05e-04, ic=6.25e-05, zz=2.39e-07, yxz=8.67e-07, )
#
# [Resample] epoch 2000: regenerating PDE/BC/IC points...
#
# Epoch 2000 | TrainLoss=8.298e-03 (pde=7.99e-03, bc=3.80e-04, ic=7.46e-05, zz=2.66e-07, yxz=1.06e-06, ) | ValLoss=8.574e-03 (pde=8.21e-03, bc=3.04e-04, ic=6.33e-05, zz=2.40e-07, yxz=8.74e-07, )
# Epoch 2010 | TrainLoss=8.439e-03 (pde=7.98e-03, bc=3.82e-04, ic=7.20e-05, zz=2.46e-07, yxz=1.03e-06, ) | ValLoss=8.618e-03 (pde=8.25e-03, bc=3.09e-04, ic=6.25e-05, zz=2.16e-07, yxz=9.37e-07, )
# Epoch 2020 | TrainLoss=8.438e-03 (pde=7.98e-03, bc=3.80e-04, ic=7.22e-05, zz=2.52e-07, yxz=9.99e-07, ) | ValLoss=8.670e-03 (pde=8.30e-03, bc=3.08e-04, ic=6.28e-05, zz=2.50e-07, yxz=7.53e-07, )
# Epoch 2030 | TrainLoss=8.437e-03 (pde=7.98e-03, bc=3.80e-04, ic=7.08e-05, zz=2.16e-07, yxz=1.08e-06, ) | ValLoss=8.704e-03 (pde=8.33e-03, bc=3.10e-04, ic=6.21e-05, zz=2.04e-07, yxz=9.17e-07, )
# Epoch 2040 | TrainLoss=8.436e-03 (pde=7.98e-03, bc=3.80e-04, ic=7.08e-05, zz=2.11e-07, yxz=1.27e-06, ) | ValLoss=8.709e-03 (pde=8.34e-03, bc=3.10e-04, ic=6.21e-05, zz=1.99e-07, yxz=1.00e-06, )
#
# [Resample] epoch 2050: regenerating PDE/BC/IC points...
#
# Epoch 2050 | TrainLoss=8.436e-03 (pde=8.15e-03, bc=3.76e-04, ic=7.06e-05, zz=1.93e-07, yxz=1.30e-06, ) | ValLoss=8.720e-03 (pde=8.35e-03, bc=3.09e-04, ic=6.17e-05, zz=1.86e-07, yxz=9.09e-07, )
# Epoch 2060 | TrainLoss=8.536e-03 (pde=8.07e-03, bc=3.88e-04, ic=7.47e-05, zz=4.35e-07, yxz=2.28e-06, ) | ValLoss=8.505e-03 (pde=8.12e-03, bc=3.16e-04, ic=6.38e-05, zz=4.36e-07, yxz=2.15e-06, )
# Epoch 2070 | TrainLoss=8.527e-03 (pde=8.06e-03, bc=3.90e-04, ic=7.45e-05, zz=2.81e-07, yxz=1.89e-06, ) | ValLoss=8.533e-03 (pde=8.15e-03, bc=3.18e-04, ic=6.41e-05, zz=2.36e-07, yxz=1.76e-06, )
# Epoch 2080 | TrainLoss=8.522e-03 (pde=8.05e-03, bc=3.93e-04, ic=7.32e-05, zz=1.57e-07, yxz=1.56e-06, ) | ValLoss=8.526e-03 (pde=8.14e-03, bc=3.24e-04, ic=6.35e-05, zz=1.26e-07, yxz=1.30e-06, )
# Epoch 2090 | TrainLoss=8.519e-03 (pde=8.05e-03, bc=3.93e-04, ic=7.31e-05, zz=1.22e-07, yxz=1.43e-06, ) | ValLoss=8.526e-03 (pde=8.14e-03, bc=3.24e-04, ic=6.35e-05, zz=1.01e-07, yxz=1.22e-06, )
#
# [Resample] epoch 2100: regenerating PDE/BC/IC points...
#
# Epoch 2100 | TrainLoss=8.518e-03 (pde=7.31e-03, bc=3.96e-04, ic=7.27e-05, zz=1.21e-07, yxz=1.28e-06, ) | ValLoss=8.546e-03 (pde=8.16e-03, bc=3.23e-04, ic=6.45e-05, zz=1.04e-07, yxz=1.14e-06, )
# Epoch 2110 | TrainLoss=7.762e-03 (pde=7.30e-03, bc=3.88e-04, ic=6.94e-05, zz=1.59e-07, yxz=1.04e-06, ) | ValLoss=8.529e-03 (pde=8.14e-03, bc=3.21e-04, ic=6.23e-05, zz=1.41e-07, yxz=8.08e-07, )
# Epoch 2120 | TrainLoss=7.760e-03 (pde=7.30e-03, bc=3.87e-04, ic=6.89e-05, zz=1.19e-07, yxz=1.04e-06, ) | ValLoss=8.500e-03 (pde=8.12e-03, bc=3.21e-04, ic=6.21e-05, zz=1.08e-07, yxz=7.99e-07, )
# Epoch 2130 | TrainLoss=7.759e-03 (pde=7.30e-03, bc=3.86e-04, ic=6.92e-05, zz=1.20e-07, yxz=1.01e-06, ) | ValLoss=8.515e-03 (pde=8.13e-03, bc=3.20e-04, ic=6.21e-05, zz=1.10e-07, yxz=7.87e-07, )
# Epoch 2140 | TrainLoss=7.759e-03 (pde=7.30e-03, bc=3.86e-04, ic=6.92e-05, zz=1.21e-07, yxz=1.03e-06, ) | ValLoss=8.516e-03 (pde=8.13e-03, bc=3.20e-04, ic=6.22e-05, zz=1.10e-07, yxz=8.08e-07, )
#
# [Resample] epoch 2150: regenerating PDE/BC/IC points...
#
# Epoch 2150 | TrainLoss=7.759e-03 (pde=8.09e-03, bc=3.91e-04, ic=6.69e-05, zz=1.21e-07, yxz=1.09e-06, ) | ValLoss=8.516e-03 (pde=8.13e-03, bc=3.20e-04, ic=6.22e-05, zz=1.10e-07, yxz=8.08e-07, )
# Epoch 2160 | TrainLoss=8.541e-03 (pde=8.08e-03, bc=3.94e-04, ic=6.72e-05, zz=1.29e-07, yxz=1.09e-06, ) | ValLoss=8.462e-03 (pde=8.08e-03, bc=3.20e-04, ic=6.24e-05, zz=1.16e-07, yxz=8.50e-07, )
# Epoch 2170 | TrainLoss=8.540e-03 (pde=8.08e-03, bc=3.92e-04, ic=6.81e-05, zz=1.58e-07, yxz=1.03e-06, ) | ValLoss=8.474e-03 (pde=8.09e-03, bc=3.19e-04, ic=6.29e-05, zz=1.48e-07, yxz=8.03e-07, )
# Epoch 2180 | TrainLoss=8.540e-03 (pde=8.08e-03, bc=3.92e-04, ic=6.82e-05, zz=1.47e-07, yxz=1.05e-06, ) | ValLoss=8.470e-03 (pde=8.09e-03, bc=3.18e-04, ic=6.29e-05, zz=1.34e-07, yxz=8.51e-07, )
# Epoch 2190 | TrainLoss=8.540e-03 (pde=8.08e-03, bc=3.92e-04, ic=6.82e-05, zz=1.47e-07, yxz=1.05e-06, ) | ValLoss=8.470e-03 (pde=8.09e-03, bc=3.18e-04, ic=6.29e-05, zz=1.34e-07, yxz=8.51e-07, )
#
# [Resample] epoch 2200: regenerating PDE/BC/IC points...
#
# Epoch 2200 | TrainLoss=8.540e-03 (pde=8.48e-03, bc=3.91e-04, ic=7.22e-05, zz=1.35e-07, yxz=9.98e-07, ) | ValLoss=8.470e-03 (pde=8.09e-03, bc=3.18e-04, ic=6.29e-05, zz=1.34e-07, yxz=8.51e-07, )
# Epoch 2210 | TrainLoss=8.907e-03 (pde=8.46e-03, bc=3.77e-04, ic=7.01e-05, zz=1.71e-07, yxz=1.00e-06, ) | ValLoss=8.777e-03 (pde=8.41e-03, bc=3.06e-04, ic=6.11e-05, zz=1.82e-07, yxz=8.75e-07, )
# Epoch 2220 | TrainLoss=8.905e-03 (pde=8.46e-03, bc=3.73e-04, ic=7.02e-05, zz=1.91e-07, yxz=9.98e-07, ) | ValLoss=8.862e-03 (pde=8.50e-03, bc=3.02e-04, ic=6.06e-05, zz=2.05e-07, yxz=8.72e-07, )
# Epoch 2230 | TrainLoss=8.904e-03 (pde=8.46e-03, bc=3.70e-04, ic=7.03e-05, zz=1.93e-07, yxz=1.03e-06, ) | ValLoss=8.954e-03 (pde=8.59e-03, bc=2.99e-04, ic=6.02e-05, zz=2.12e-07, yxz=8.62e-07, )
# Epoch 2240 | TrainLoss=8.903e-03 (pde=8.46e-03, bc=3.69e-04, ic=6.93e-05, zz=2.12e-07, yxz=9.64e-07, ) | ValLoss=9.044e-03 (pde=8.68e-03, bc=2.99e-04, ic=5.95e-05, zz=2.20e-07, yxz=8.08e-07, )
#
# [Resample] epoch 2250: regenerating PDE/BC/IC points...
#
# Epoch 2250 | TrainLoss=8.902e-03 (pde=8.48e-03, bc=3.70e-04, ic=6.42e-05, zz=2.37e-07, yxz=1.17e-06, ) | ValLoss=9.126e-03 (pde=8.77e-03, bc=2.99e-04, ic=5.88e-05, zz=2.26e-07, yxz=8.12e-07, )
# Epoch 2260 | TrainLoss=8.840e-03 (pde=8.39e-03, bc=3.83e-04, ic=6.70e-05, zz=1.87e-07, yxz=1.08e-06, ) | ValLoss=8.529e-03 (pde=8.15e-03, bc=3.12e-04, ic=6.16e-05, zz=1.75e-07, yxz=7.48e-07, )
# Epoch 2270 | TrainLoss=8.839e-03 (pde=8.39e-03, bc=3.84e-04, ic=6.68e-05, zz=1.43e-07, yxz=1.09e-06, ) | ValLoss=8.548e-03 (pde=8.17e-03, bc=3.12e-04, ic=6.14e-05, zz=1.32e-07, yxz=7.75e-07, )
# Epoch 2280 | TrainLoss=8.839e-03 (pde=8.39e-03, bc=3.84e-04, ic=6.68e-05, zz=1.47e-07, yxz=1.06e-06, ) | ValLoss=8.547e-03 (pde=8.17e-03, bc=3.12e-04, ic=6.14e-05, zz=1.31e-07, yxz=7.27e-07, )
# Epoch 2290 | TrainLoss=8.839e-03 (pde=8.39e-03, bc=3.84e-04, ic=6.69e-05, zz=1.46e-07, yxz=1.06e-06, ) | ValLoss=8.545e-03 (pde=8.17e-03, bc=3.12e-04, ic=6.15e-05, zz=1.29e-07, yxz=7.29e-07, )
#
# [Resample] epoch 2300: regenerating PDE/BC/IC points...
#
# Epoch 2300 | TrainLoss=8.839e-03 (pde=8.00e-03, bc=3.85e-04, ic=6.79e-05, zz=1.40e-07, yxz=1.10e-06, ) | ValLoss=8.545e-03 (pde=8.17e-03, bc=3.12e-04, ic=6.15e-05, zz=1.29e-07, yxz=7.29e-07, )
# Epoch 2310 | TrainLoss=8.436e-03 (pde=7.97e-03, bc=3.97e-04, ic=6.81e-05, zz=2.10e-07, yxz=1.34e-06, ) | ValLoss=8.448e-03 (pde=8.06e-03, bc=3.20e-04, ic=6.26e-05, zz=2.29e-07, yxz=9.45e-07, )
# Epoch 2320 | TrainLoss=8.434e-03 (pde=7.97e-03, bc=3.96e-04, ic=6.95e-05, zz=1.49e-07, yxz=1.26e-06, ) | ValLoss=8.470e-03 (pde=8.09e-03, bc=3.18e-04, ic=6.31e-05, zz=1.53e-07, yxz=9.80e-07, )
# Epoch 2330 | TrainLoss=8.433e-03 (pde=7.97e-03, bc=3.96e-04, ic=6.96e-05, zz=1.10e-07, yxz=1.26e-06, ) | ValLoss=8.475e-03 (pde=8.09e-03, bc=3.19e-04, ic=6.33e-05, zz=1.05e-07, yxz=9.74e-07, )
# Epoch 2340 | TrainLoss=8.433e-03 (pde=7.97e-03, bc=3.96e-04, ic=6.98e-05, zz=1.06e-07, yxz=1.21e-06, ) | ValLoss=8.462e-03 (pde=8.08e-03, bc=3.18e-04, ic=6.35e-05, zz=1.05e-07, yxz=8.94e-07, )
#
# [Resample] epoch 2350: regenerating PDE/BC/IC points...
#
# Epoch 2350 | TrainLoss=8.432e-03 (pde=8.04e-03, bc=3.96e-04, ic=7.03e-05, zz=1.03e-07, yxz=1.17e-06, ) | ValLoss=8.460e-03 (pde=8.08e-03, bc=3.18e-04, ic=6.35e-05, zz=1.03e-07, yxz=9.10e-07, )
# Epoch 2360 | TrainLoss=8.441e-03 (pde=7.99e-03, bc=3.82e-04, ic=7.08e-05, zz=1.35e-07, yxz=1.05e-06, ) | ValLoss=8.599e-03 (pde=8.23e-03, bc=3.08e-04, ic=6.30e-05, zz=1.35e-07, yxz=8.12e-07, )
# Epoch 2370 | TrainLoss=8.439e-03 (pde=7.99e-03, bc=3.78e-04, ic=7.10e-05, zz=1.43e-07, yxz=9.83e-07, ) | ValLoss=8.635e-03 (pde=8.27e-03, bc=3.05e-04, ic=6.29e-05, zz=1.41e-07, yxz=7.82e-07, )
# Epoch 2380 | TrainLoss=8.438e-03 (pde=7.99e-03, bc=3.77e-04, ic=7.13e-05, zz=1.47e-07, yxz=9.73e-07, ) | ValLoss=8.659e-03 (pde=8.29e-03, bc=3.03e-04, ic=6.29e-05, zz=1.41e-07, yxz=7.88e-07, )
# Epoch 2390 | TrainLoss=8.438e-03 (pde=7.99e-03, bc=3.76e-04, ic=7.11e-05, zz=1.50e-07, yxz=9.88e-07, ) | ValLoss=8.690e-03 (pde=8.32e-03, bc=3.02e-04, ic=6.28e-05, zz=1.48e-07, yxz=7.97e-07, )
#
# [Resample] epoch 2400: regenerating PDE/BC/IC points...
#
# Epoch 2400 | TrainLoss=8.438e-03 (pde=7.90e-03, bc=3.78e-04, ic=7.28e-05, zz=1.68e-07, yxz=1.03e-06, ) | ValLoss=8.688e-03 (pde=8.32e-03, bc=3.02e-04, ic=6.28e-05, zz=1.59e-07, yxz=8.17e-07, )
# Epoch 2410 | TrainLoss=8.254e-03 (pde=7.81e-03, bc=3.67e-04, ic=7.14e-05, zz=1.99e-07, yxz=1.29e-06, ) | ValLoss=9.104e-03 (pde=8.75e-03, bc=2.93e-04, ic=6.09e-05, zz=1.74e-07, yxz=8.33e-07, )
# Epoch 2420 | TrainLoss=8.251e-03 (pde=7.82e-03, bc=3.62e-04, ic=7.10e-05, zz=2.08e-07, yxz=1.05e-06, ) | ValLoss=9.197e-03 (pde=8.85e-03, bc=2.90e-04, ic=6.04e-05, zz=2.02e-07, yxz=9.82e-07, )
# Epoch 2430 | TrainLoss=8.250e-03 (pde=7.82e-03, bc=3.60e-04, ic=7.11e-05, zz=2.24e-07, yxz=1.05e-06, ) | ValLoss=9.282e-03 (pde=8.93e-03, bc=2.88e-04, ic=6.06e-05, zz=2.14e-07, yxz=8.67e-07, )
# Epoch 2440 | TrainLoss=8.248e-03 (pde=7.82e-03, bc=3.59e-04, ic=7.04e-05, zz=2.39e-07, yxz=1.06e-06, ) | ValLoss=9.369e-03 (pde=9.02e-03, bc=2.87e-04, ic=6.02e-05, zz=2.28e-07, yxz=9.36e-07, )
#
# [Resample] epoch 2450: regenerating PDE/BC/IC points...
#
# Epoch 2450 | TrainLoss=8.247e-03 (pde=8.16e-03, bc=3.51e-04, ic=6.94e-05, zz=2.45e-07, yxz=9.81e-07, ) | ValLoss=9.423e-03 (pde=9.08e-03, bc=2.85e-04, ic=6.02e-05, zz=2.32e-07, yxz=8.69e-07, )
# Epoch 2460 | TrainLoss=8.371e-03 (pde=7.91e-03, bc=3.89e-04, ic=6.99e-05, zz=1.61e-07, yxz=1.53e-06, ) | ValLoss=8.472e-03 (pde=8.09e-03, bc=3.19e-04, ic=6.25e-05, zz=1.59e-07, yxz=1.27e-06, )
# Epoch 2470 | TrainLoss=8.363e-03 (pde=7.90e-03, bc=3.90e-04, ic=6.80e-05, zz=1.29e-07, yxz=1.29e-06, ) | ValLoss=8.466e-03 (pde=8.08e-03, bc=3.23e-04, ic=6.19e-05, zz=1.26e-07, yxz=1.07e-06, )
# Epoch 2480 | TrainLoss=8.362e-03 (pde=7.90e-03, bc=3.90e-04, ic=6.77e-05, zz=1.21e-07, yxz=1.31e-06, ) | ValLoss=8.452e-03 (pde=8.07e-03, bc=3.23e-04, ic=6.19e-05, zz=1.22e-07, yxz=1.07e-06, )
# Epoch 2490 | TrainLoss=8.361e-03 (pde=7.90e-03, bc=3.91e-04, ic=6.71e-05, zz=1.31e-07, yxz=1.16e-06, ) | ValLoss=8.453e-03 (pde=8.07e-03, bc=3.24e-04, ic=6.20e-05, zz=1.35e-07, yxz=9.96e-07, )
# Epoch 2499 | TrainLoss=8.360e-03 (pde=7.90e-03, bc=3.90e-04, ic=6.72e-05, zz=1.15e-07, yxz=1.22e-06, ) | ValLoss=8.450e-03 (pde=8.06e-03, bc=3.24e-04, ic=6.21e-05, zz=1.11e-07, yxz=1.03e-06, )
# Training finished.

# %%
# test 
t0 = 0.14
nx = 100
xs = np.linspace(X_MIN, X_MAX, nx)
ys = np.linspace(Y_MIN, Y_MAX, nx)
Xg, Yg = np.meshgrid(xs, ys)

x_grid = torch.from_numpy(Xg.flatten()[:,None]).to(device).double()
y_grid = torch.from_numpy(Yg.flatten()[:,None]).to(device).double()
t_grid = torch.full_like(x_grid, t0).to(device)  # 全部時間都固定為 t0

def compute_phi(x, y, t):
    x = x.view(-1,1).to(device)
    y = y.view(-1,1).to(device)
    t = t.view(-1,1).to(device)
    angle = torch.tensor(np.pi * 0.0 / 4.0, dtype=x.dtype, device=x.device)
    #r = torch.sqrt(x**2 + y**2)
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=1e-12))
    inside = r - (x * torch.cos(angle) + y * torch.sin(angle))
    u_true = (r**2 + t**2)  * torch.sqrt( 0.5 * inside)
    return torch.sqrt( 0.5 * inside), u_true


with torch.no_grad():
    phi_grid, u_true_grid = compute_phi(x_grid, y_grid, t_grid)


# 預測 u
with torch.no_grad():
    inp_grid = torch.cat([x_grid, y_grid, phi_grid, t_grid], dim=1)
    u_pred = model(inp_grid)
    u_pred = u_pred.cpu().numpy().reshape(nx, nx)
    u_true_grid = u_true_grid.cpu().numpy().reshape(nx, nx)

# 逐點相對誤差
u_true_norm = np.max(np.abs(u_true_grid))   # 真實解的 inf norm
error_rel = np.abs(u_pred - u_true_grid) / (u_true_norm)
error_rel2 = np.abs(u_pred - u_true_grid) / np.linalg.norm(u_true_grid.flatten(), ord=2) # 分母是 true 的 L2 norm
error_abs = np.abs(u_pred - u_true_grid)

# 整體相對誤差 ||u_pred - u_true||_2 / ||u_true||_2
error_tensor = torch.from_numpy(np.abs(u_pred - u_true_grid)).double()
u_tensor = torch.from_numpy(np.abs(u_true_grid)).double()
relL2 = torch.norm(error_tensor) / torch.norm(u_tensor)
print("Relative L2 error (grid):", relL2.item())

# 畫圖
fig, axs = plt.subplots(1, 3, figsize=(18,5))

im0 = axs[0].contourf(Xg, Yg, u_pred, 50, cmap='viridis')
fig.colorbar(im0, ax=axs[0])
axs[0].set_title('PINN Prediction $u_N$')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')

im1 = axs[1].contourf(Xg, Yg, u_true_grid, 50, cmap='viridis')
fig.colorbar(im1, ax=axs[1])
axs[1].set_title('Analytical Solution $\\phi$')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')

im2 = axs[2].contourf(Xg, Yg, error_rel, 50, cmap='hot')
fig.colorbar(im2, ax=axs[2])
axs[2].set_title('Relative Error')
axs[2].set_xlabel('x')
axs[2].set_ylabel('y')

plt.tight_layout()
plt.show()
# Out:
# Relative L2 error (grid): 0.012879342910387219

# %%
# loss 
epochs_arr = np.arange(len(loss_history))
val_epochs = np.linspace(0, len(loss_history)-1, len(val_history))
plt.figure(figsize=(8,5))
plt.semilogy(epochs_arr, loss_history, label='Training Loss')
plt.semilogy(val_epochs, val_history, label='Validation Loss (every 10 ep)')
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
