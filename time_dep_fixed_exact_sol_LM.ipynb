# %% [markdown]
# 裂縫固定水平線, time-dependent heat equation, u = (x^2+y^2)*phi, f = - 6*phi.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc
rc('animation', html='jshtml')

torch.set_default_dtype(torch.float64)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

X_MIN, X_MAX = -1.0, 1.0
Y_MIN, Y_MAX = -1.0, 1.0
T_MIN, T_MAX = 0.0, 0.25

N_f = 500
N_b_outer = 500
N_b_crack = 500
epochs = 4000
max_trial = 1
lam = 10000
lam_up, lam_down = 3.0, 0.7

# MLP
class MLP(nn.Module):
    def __init__(self, layers):
        super().__init__()
        self.net = nn.ModuleList()
        for i in range(len(layers)-1):
            self.net.append(nn.Linear(layers[i], layers[i+1]))
        self.activation = torch.tanh
        for m in self.net:
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight) #????
                nn.init.zeros_(m.bias)

    def forward(self, inp):
        z = inp
        for layer in self.net[:-1]:
            z = self.activation(layer(z))
        z = self.net[-1](z)
        return z

layers = [4, 10, 10, 1]
model = MLP(layers).to(device)
# Out:
# Device: cpu

# %%
def compute_phi(x, y, t):
    x = x.view(-1,1).to(device)
    y = y.view(-1,1).to(device)
    t = t.view(-1,1).to(device)
    angle = torch.tensor(np.pi * 0.0 / 4.0, dtype=x.dtype, device=x.device)
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=1e-12))
    inside = r - (x * torch.cos(angle) + y * torch.sin(angle))
    u_true = (x**2 + y**2)  * torch.sqrt( 0.5 * inside)
    return torch.sqrt( 0.5 * inside), u_true

def compute_phi_and_derivs(x, y, t):
    x = x.view(-1, 1).to(device)
    y = y.view(-1, 1).to(device)
    t = t.view(-1, 1).to(device)
    angle = torch.tensor(np.pi * 0.0 / 4.0, dtype=x.dtype, device=x.device)
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=1e-12))
    inside = r - (x * torch.cos(angle) + y * torch.sin(angle))
    phi = torch.sqrt(0.5 * inside)
    sqrt_term = torch.sqrt(inside)
    phi_x = (torch.sqrt(torch.tensor(2.0, dtype=torch.float64)) *
             (x / r - torch.cos(angle))) / (4.0 * sqrt_term)
    phi_y = (torch.sqrt(torch.tensor(2.0, dtype=torch.float64)) *
             (y / r - torch.sin(angle))) / (4.0 * sqrt_term)
    u_true = (x**2 + y**2)  * phi

    return phi, phi_x, phi_y, u_true

def partials_U_wrt_inputs(model, x, y, phi, t):
    x = x.view(-1,1)
    y = y.view(-1,1)
    phi = phi.view(-1,1)
    t = t.view(-1,1)

    inp = torch.cat([x, y, phi, t], dim=1).to(device)
    inp.requires_grad_(True)
    U = model(inp)  # (N,1)

    grads = torch.autograd.grad(U, inp, grad_outputs=torch.ones_like(U),
                                create_graph=True, retain_graph=True)[0]  # (N,4)
    U_x = grads[:,0:1]
    U_y = grads[:,1:2]
    U_z = grads[:,2:3]
    U_t = grads[:,3:4]
    return U, inp, U_x, U_y, U_z, U_t

def second_partials_U(model, inp, U_x, U_y, U_z):
    grad_Ux = torch.autograd.grad(U_x, inp, grad_outputs=torch.ones_like(U_x),
                                  create_graph=True, retain_graph=True)[0]
    grad_Uy = torch.autograd.grad(U_y, inp, grad_outputs=torch.ones_like(U_y),
                                  create_graph=True, retain_graph=True)[0]
    grad_Uz = torch.autograd.grad(U_z, inp, grad_outputs=torch.ones_like(U_z),
                                  create_graph=True, retain_graph=True)[0]

    U_xx = grad_Ux[:,0:1]
    U_xz = grad_Ux[:,2:3]
    U_yy = grad_Uy[:,1:2]
    U_yz = grad_Uy[:,2:3]
    U_zz = grad_Uz[:,2:3]

    return U_xx, U_yy, U_xz, U_yz, U_zz


def compute_residual_time(model, x, y, t):
    x = x.clone().detach().requires_grad_(True).to(device)
    y = y.clone().detach().requires_grad_(True).to(device)
    t = t.clone().detach().requires_grad_(True).to(device)

    phi, phi_x, phi_y, _ = compute_phi_and_derivs(x, y, t)
    U, inp, U_x, U_y, U_z, U_t = partials_U_wrt_inputs(model, x, y, phi, t)
    U_xx, U_yy, U_xz, U_yz, U_zz = second_partials_U(model, inp, U_x, U_y, U_z)

    r = torch.sqrt(torch.clamp(x**2 + y**2, min=1e-12))
    laplace_U = U_xx + U_yy
    lap = laplace_U + 2.0 * (U_xz * phi_x + U_yz * phi_y) + (1/(4*r)) * U_zz
    ut =  U_t
    residual = ut - lap + 6.0 * phi
    return residual, U, U_zz, U_xz, U_yz

# sampling
def sample_collocation(N):
    x = torch.rand(N*2,1) * (X_MAX - X_MIN) + X_MIN
    y = torch.rand(N*2,1) * (Y_MAX - Y_MIN) + Y_MIN
    t = torch.rand(N*2,1) * (T_MAX - T_MIN) + T_MIN
    # 點到 y=0 的距離 : |y|
    dist_to_crack = torch.abs(y)
    # mask
    mask_crack = (dist_to_crack < 1e-8)
    x, y, t = x[~mask_crack][:N], y[~mask_crack][:N], t[~mask_crack][:N]
    return x.to(device), y.to(device), t.to(device)

def sample_outer_boundary(N):
    # Calculate how many points per side, ensuring enough total points to pick N from.
    # For N=50, (50 + 3) // 4 = 13. So 4 * 13 = 52 points will be generated initially.
    # This guarantees that we can always select N points.
    per_side_sufficient = (N + 3) // 4 # Ceiling division of N/4
    per_side = max(4, per_side_sufficient) # Ensure at least 4 points per side

    xs_all, ys_all = [], []

    # Sample points from each side, generating more than N points in total
    # Add points along X_MIN edge
    xs_all.append(torch.ones(per_side, 1) * X_MIN)
    ys_all.append(torch.linspace(Y_MIN, Y_MAX, per_side).unsqueeze(1))

    # Add points along X_MAX edge
    xs_all.append(torch.ones(per_side, 1) * X_MAX)
    ys_all.append(torch.linspace(Y_MIN, Y_MAX, per_side).unsqueeze(1))

    # Add points along Y_MIN edge (excluding corners to avoid duplicates if already covered by X_MIN/X_MAX lines)
    ys_all.append(torch.ones(per_side, 1) * Y_MIN)
    xs_all.append(torch.linspace(X_MIN + (X_MAX-X_MIN)/per_side, X_MAX - (X_MAX-X_MIN)/per_side, per_side-2 if per_side >=2 else 0).unsqueeze(1))

    # Add points along Y_MAX edge (excluding corners)
    ys_all.append(torch.ones(per_side, 1) * Y_MAX)
    xs_all.append(torch.linspace(X_MIN + (X_MAX-X_MIN)/per_side, X_MAX - (X_MAX-X_MIN)/per_side, per_side-2 if per_side >=2 else 0).unsqueeze(1))


    # Filter out empty tensors if per_side-2 results in 0 or less points
    xs_all = [t for t in xs_all if t.numel() > 0]
    ys_all = [t for t in ys_all if t.numel() > 0]

    # Concatenate all sampled points
    all_x = torch.cat(xs_all, dim=0)
    all_y = torch.cat(ys_all, dim=0)

    # Randomly select N points from the oversampled set
    indices = torch.randperm(all_x.shape[0])[:N]
    x = all_x[indices]
    y = all_y[indices]
    t = torch.rand_like(x) * (T_MAX - T_MIN) + T_MIN


    return x.to(device), y.to(device), t.to(device)

def sample_crack_boundary(N):
    t = torch.rand(N, 1, device=device, dtype=torch.float64) * (T_MAX - T_MIN) + T_MIN
    x_vals = torch.linspace(0, 1, N, device=device, dtype=torch.float64).unsqueeze(1)
    y_vals = x_vals * 0.0
    return x_vals, y_vals, t

def sampling_points(N_f, N_b_crack, N_b_outer):
    x_f, y_f, t_f = sample_collocation(N_f)
    x_b_out, y_b_out, t_b_out = sample_outer_boundary(N_b_outer)
    x_b_crack, y_b_crack, t_b_crack = sample_crack_boundary(N_b_crack)

    x_f = x_f.view(-1,1); y_f = y_f.view(-1,1); t_f = t_f.view(-1,1)
    x_b_out = x_b_out.view(-1,1); y_b_out = y_b_out.view(-1,1); t_b_out = t_b_out.view(-1,1)
    x_b_crack = x_b_crack.view(-1,1); y_b_crack = y_b_crack.view(-1,1); t_b_crack = t_b_crack.view(-1,1)

    x_b = torch.cat([x_b_out, x_b_crack], dim=0)
    y_b = torch.cat([y_b_out, y_b_crack], dim=0)
    t_b = torch.cat([t_b_out, t_b_crack], dim=0)

    phi_b, _, _, g_b = compute_phi_and_derivs(x_b, y_b, t_b)
    inp_bc = torch.cat([x_b, y_b, phi_b, t_b], dim=1)

    return x_f, y_f, t_f, x_b_out, y_b_out, t_b_out, x_b_crack, y_b_crack, t_b_crack, inp_bc, g_b

def sample_tip_and_crack(N_tip, N_b_crack):
    # crack 上（不含 tip）
    x_c = torch.linspace(1e-4, 1.0, N_b_crack, device=device).unsqueeze(1)
    y_c = torch.zeros_like(x_c)
    t_c = torch.rand(N_b_crack, 1, device=device) * (T_MAX - T_MIN)

    # tip
    x_t = torch.zeros(N_tip, 1, device=device)
    y_t = torch.zeros(N_tip, 1, device=device)
    t_t = torch.rand(N_tip, 1, device=device) * (T_MAX - T_MIN)

    return x_c, y_c, t_c, x_t, y_t, t_t


def compute_residual_vector_time(model, N_f, N_b_crack, N_b_outer):
    x_f, y_f, t_f, x_b_out, y_b_out, t_b_out, x_b_crack, y_b_crack, t_b_crack, inp_bc, g_b = sampling_points(N_f, N_b_crack, N_b_outer)
    # PDE residual
    r_f, _, _, _, _ = compute_residual_time(model, x_f, y_f, t_f)
    r_f = r_f.view(-1, 1)

    # boundary
    r_bc = model(inp_bc) - g_b

    r = torch.cat([r_f.view(-1), r_bc.view(-1)], dim=0)

    return r

def get_flat_params(model):
    return torch.cat([p.view(-1) for p in model.parameters()])

def set_flat_params(model, theta):
    idx = 0
    for p in model.parameters():
        n = p.numel()
        p.data.copy_(theta[idx:idx+n].view_as(p))
        idx += n

def compute_jacobian(r, model):
    r = r.view(-1) 
    n_res = r.numel()
    theta = get_flat_params(model)
    n_param = theta.numel()

    J = torch.zeros(n_res, n_param, device=device)

    for i in range(n_res):
        grads = torch.autograd.grad(
            r[i],
            model.parameters(),
            retain_graph=True,
            create_graph=False
        )
        J[i, :] = torch.cat([g.reshape(-1) for g in grads])

    return J

def lm_step_adaptive_time(
    model, data, lam, lam_up, lam_down, max_trial
):
    params = list(model.parameters())
    theta0 = [p.data.clone() for p in params]

    # residual & loss
    r0 = residual_vector_time(model, data)
    loss0 = 0.5 * torch.sum(r0**2)

    # Jacobian & LM system
    J = compute_jacobian(r0, model)
    A = J.T @ J + lam * torch.eye(J.shape[1], device=device)
    g = J.T @ r0.detach()

    delta = torch.linalg.solve(A, -g)

    for _ in range(max_trial):
        # trial update
        idx = 0
        for p, p0 in zip(params, theta0):
            n = p.numel()
            p.data = p0 + delta[idx:idx+n].view_as(p)
            idx += n

        r1 = residual_vector_time(model, data)
        loss1 = 0.5 * torch.sum(r1**2)

        if loss1 < loss0:
            lam = max(lam * lam_down, 1e-9)
            res = torch.sqrt(2 * loss1).item()
            return lam, True, res
        else:
            # rollback
            for p, p0 in zip(params, theta0):
                p.data = p0
            lam = min(lam * lam_up, 1e8)

    res = torch.sqrt(2 * loss0).item()
    return lam, False, res

def sample_all_time_dep(N_f, N_b_crack, N_b_outer):
    x_f, y_f, t_f, \
    x_b_out, y_b_out, t_b_out, \
    x_b_crack, y_b_crack, t_b_crack, \
    inp_bc, g_b = sampling_points(N_f, N_b_crack, N_b_outer)
    x_c, y_c, t_c, x_t, y_t, t_t = sample_tip_and_crack(N_tip=1, N_b_crack=N_b_crack)
    data = {
    "x_f": x_f,
    "y_f": y_f,
    "t_f": t_f,
    "inp_bc": inp_bc,
    "g_b": g_b,
    "x_crack": x_c,
    "y_crack": y_c,
    "t_crack": t_c,
    "x_tip": x_t,
    "y_tip": y_t,
    "t_tip": t_t
    }

    return data

def residual_vector_time(model, data):
    # PDE residual
    r_f, _, _, _, _ = compute_residual_time(
        model,
        data["x_f"],
        data["y_f"],
        data["t_f"]
    )
    r_f = r_f.view(-1)

    # Boundary condition
    r_bc = model(data["inp_bc"]) - data["g_b"]
    r_bc = r_bc.view(-1)
    # crack 上的 ∇_x U_z = 0
    _, _, _, U_xz_c, U_yz_c = compute_residual_time(
        model,
        data["x_crack"],
        data["y_crack"],
        data["t_crack"]
    )

    r_gradUz = torch.cat([
        U_xz_c.view(-1),
        U_yz_c.view(-1)
    ], dim=0)

    # tip 上的 U_zz = 0
    _, _, U_zz_t, _, _ = compute_residual_time(
        model,
        data["x_tip"],
        data["y_tip"],
        data["t_tip"]
    )

    r_tip = U_zz_t.view(-1)

    # -------- total residual --------
    r = torch.cat([
        r_f,
        r_bc,
        0*r_gradUz,
        r_tip
    ], dim=0)

    return r

# %%
data = sample_all_time_dep(N_f, N_b_crack, N_b_outer)

res_hist = []
lam = 1e-3

print("Start LM training (time-dependent)")

for it in range(epochs):
    lam, ok, res = lm_step_adaptive_time(
        model, data, lam, lam_up, lam_down, max_trial=1
    )
    res_hist.append(res)
    status = "✓" if ok else "✗"

    if it % 10 == 0:
        print(f"iter {it:04d} | residual = {res:.3e} | λ = {lam:.1e} | {status}")

print("Training finished.")
# Out:
# Start LM training (time-dependent)
# iter 0000 | residual = 9.953e+01 | λ = 3.0e-03 | ✗
# iter 0010 | residual = 9.736e+01 | λ = 4.1e+01 | ✗
# iter 0020 | residual = 3.139e+00 | λ = 5.0e+00 | ✓
# iter 0030 | residual = 1.971e-01 | λ = 1.4e-01 | ✓
# iter 0040 | residual = 6.484e-02 | λ = 7.3e-02 | ✗
# iter 0050 | residual = 4.338e-02 | λ = 3.8e-02 | ✓
# iter 0060 | residual = 2.979e-02 | λ = 2.0e-02 | ✓
# iter 0070 | residual = 2.135e-02 | λ = 1.0e-02 | ✓
# iter 0080 | residual = 1.751e-02 | λ = 5.3e-03 | ✓
# iter 0090 | residual = 1.432e-02 | λ = 1.2e-02 | ✓
# iter 0100 | residual = 1.241e-02 | λ = 6.1e-03 | ✓
# iter 0110 | residual = 1.111e-02 | λ = 3.2e-03 | ✓
# iter 0120 | residual = 1.000e-02 | λ = 7.1e-03 | ✗
# iter 0130 | residual = 8.628e-03 | λ = 3.7e-03 | ✓
# iter 0140 | residual = 7.641e-03 | λ = 1.9e-03 | ✓
# iter 0150 | residual = 6.763e-03 | λ = 9.9e-04 | ✓
# iter 0160 | residual = 6.069e-03 | λ = 2.2e-03 | ✗
# iter 0170 | residual = 5.508e-03 | λ = 1.1e-03 | ✓
# iter 0180 | residual = 5.210e-03 | λ = 2.5e-03 | ✗
# iter 0190 | residual = 4.954e-03 | λ = 1.3e-03 | ✓
# iter 0200 | residual = 4.721e-03 | λ = 6.8e-04 | ✓
# iter 0210 | residual = 4.522e-03 | λ = 1.5e-03 | ✓
# iter 0220 | residual = 4.371e-03 | λ = 7.9e-04 | ✓
# iter 0230 | residual = 4.243e-03 | λ = 1.7e-03 | ✗
# iter 0240 | residual = 4.077e-03 | λ = 9.1e-04 | ✓
# iter 0250 | residual = 3.964e-03 | λ = 4.7e-04 | ✓
# iter 0260 | residual = 3.812e-03 | λ = 1.0e-03 | ✓
# iter 0270 | residual = 3.693e-03 | λ = 5.4e-04 | ✓
# iter 0280 | residual = 3.569e-03 | λ = 1.2e-03 | ✗
# iter 0290 | residual = 3.432e-03 | λ = 6.3e-04 | ✓
# iter 0300 | residual = 3.314e-03 | λ = 3.3e-04 | ✓
# iter 0310 | residual = 3.185e-03 | λ = 7.2e-04 | ✓
# iter 0320 | residual = 3.059e-03 | λ = 3.8e-04 | ✓
# iter 0330 | residual = 2.944e-03 | λ = 8.3e-04 | ✗
# iter 0340 | residual = 2.820e-03 | λ = 4.3e-04 | ✓
# iter 0350 | residual = 2.710e-03 | λ = 2.2e-04 | ✓
# iter 0360 | residual = 2.588e-03 | λ = 5.0e-04 | ✓
# iter 0370 | residual = 2.490e-03 | λ = 2.6e-04 | ✓
# iter 0380 | residual = 2.404e-03 | λ = 5.8e-04 | ✗
# iter 0390 | residual = 2.290e-03 | λ = 3.0e-04 | ✓
# iter 0400 | residual = 2.217e-03 | λ = 1.6e-04 | ✓
# iter 0410 | residual = 2.114e-03 | λ = 3.4e-04 | ✓
# iter 0420 | residual = 2.041e-03 | λ = 1.8e-04 | ✓
# iter 0430 | residual = 1.979e-03 | λ = 4.0e-04 | ✗
# iter 0440 | residual = 1.899e-03 | λ = 2.1e-04 | ✓
# iter 0450 | residual = 1.850e-03 | λ = 4.6e-04 | ✗
# iter 0460 | residual = 1.786e-03 | λ = 2.4e-04 | ✓
# iter 0470 | residual = 1.734e-03 | λ = 1.2e-04 | ✓
# iter 0480 | residual = 1.691e-03 | λ = 2.7e-04 | ✓
# iter 0490 | residual = 1.640e-03 | λ = 1.4e-04 | ✓
# iter 0500 | residual = 1.601e-03 | λ = 3.2e-04 | ✗
# iter 0510 | residual = 1.560e-03 | λ = 1.6e-04 | ✓
# iter 0520 | residual = 1.523e-03 | λ = 8.5e-05 | ✓
# iter 0530 | residual = 1.482e-03 | λ = 1.9e-04 | ✓
# iter 0540 | residual = 1.450e-03 | λ = 9.8e-05 | ✓
# iter 0550 | residual = 1.421e-03 | λ = 2.2e-04 | ✗
# iter 0560 | residual = 1.381e-03 | λ = 1.1e-04 | ✓
# iter 0570 | residual = 1.355e-03 | λ = 2.5e-04 | ✗
# iter 0580 | residual = 1.324e-03 | λ = 1.3e-04 | ✓
# iter 0590 | residual = 1.296e-03 | λ = 6.8e-05 | ✓
# iter 0600 | residual = 1.269e-03 | λ = 1.5e-04 | ✓
# iter 0610 | residual = 1.247e-03 | λ = 7.8e-05 | ✓
# iter 0620 | residual = 1.224e-03 | λ = 1.7e-04 | ✗
# iter 0630 | residual = 1.197e-03 | λ = 9.0e-05 | ✓
# iter 0640 | residual = 1.179e-03 | λ = 2.0e-04 | ✗
# iter 0650 | residual = 1.157e-03 | λ = 1.0e-04 | ✓
# iter 0660 | residual = 1.137e-03 | λ = 5.4e-05 | ✓
# iter 0670 | residual = 1.118e-03 | λ = 1.2e-04 | ✓
# iter 0680 | residual = 1.102e-03 | λ = 6.2e-05 | ✓
# iter 0690 | residual = 1.085e-03 | λ = 1.4e-04 | ✗
# iter 0700 | residual = 1.064e-03 | λ = 7.2e-05 | ✓
# iter 0710 | residual = 1.051e-03 | λ = 1.6e-04 | ✗
# iter 0720 | residual = 1.036e-03 | λ = 8.3e-05 | ✓
# iter 0730 | residual = 1.021e-03 | λ = 4.3e-05 | ✓
# iter 0740 | residual = 1.005e-03 | λ = 9.6e-05 | ✓
# iter 0750 | residual = 9.924e-04 | λ = 5.0e-05 | ✓
# iter 0760 | residual = 9.812e-04 | λ = 1.1e-04 | ✓
# iter 0770 | residual = 9.672e-04 | λ = 5.7e-05 | ✓
# iter 0780 | residual = 9.560e-04 | λ = 1.3e-04 | ✗
# iter 0790 | residual = 9.430e-04 | λ = 6.6e-05 | ✓
# iter 0800 | residual = 9.338e-04 | λ = 1.5e-04 | ✗
# iter 0810 | residual = 9.223e-04 | λ = 7.6e-05 | ✓
# iter 0820 | residual = 9.113e-04 | λ = 4.0e-05 | ✓
# iter 0830 | residual = 9.002e-04 | λ = 8.8e-05 | ✓
# iter 0840 | residual = 8.909e-04 | λ = 4.6e-05 | ✓
# iter 0850 | residual = 8.824e-04 | λ = 1.0e-04 | ✓
# iter 0860 | residual = 8.746e-04 | λ = 5.3e-05 | ✓
# iter 0870 | residual = 8.662e-04 | λ = 1.2e-04 | ✗
# iter 0880 | residual = 8.556e-04 | λ = 6.1e-05 | ✓
# iter 0890 | residual = 8.484e-04 | λ = 1.4e-04 | ✗
# iter 0900 | residual = 8.401e-04 | λ = 7.0e-05 | ✓
# iter 0910 | residual = 8.340e-04 | λ = 1.6e-04 | ✗
# iter 0920 | residual = 8.273e-04 | λ = 8.1e-05 | ✓
# iter 0930 | residual = 8.199e-04 | λ = 4.2e-05 | ✓
# iter 0940 | residual = 8.122e-04 | λ = 9.3e-05 | ✓
# iter 0950 | residual = 8.057e-04 | λ = 4.8e-05 | ✓
# iter 0960 | residual = 7.996e-04 | λ = 1.1e-04 | ✓
# iter 0970 | residual = 7.940e-04 | λ = 5.6e-05 | ✓
# iter 0980 | residual = 7.899e-04 | λ = 1.2e-04 | ✗
# iter 0990 | residual = 7.819e-04 | λ = 6.5e-05 | ✓
# iter 1000 | residual = 7.767e-04 | λ = 1.4e-04 | ✗
# iter 1010 | residual = 7.704e-04 | λ = 7.4e-05 | ✓
# iter 1020 | residual = 7.658e-04 | λ = 1.7e-04 | ✗
# iter 1030 | residual = 7.608e-04 | λ = 8.6e-05 | ✓
# iter 1040 | residual = 7.552e-04 | λ = 4.5e-05 | ✓
# iter 1050 | residual = 7.493e-04 | λ = 9.9e-05 | ✓
# iter 1060 | residual = 7.443e-04 | λ = 5.1e-05 | ✓
# iter 1070 | residual = 7.396e-04 | λ = 1.1e-04 | ✓
# iter 1080 | residual = 7.353e-04 | λ = 5.9e-05 | ✓
# iter 1090 | residual = 7.314e-04 | λ = 1.3e-04 | ✗
# iter 1100 | residual = 7.253e-04 | λ = 6.8e-05 | ✓
# iter 1110 | residual = 7.212e-04 | λ = 1.5e-04 | ✗
# iter 1120 | residual = 7.164e-04 | λ = 7.9e-05 | ✓
# iter 1130 | residual = 7.128e-04 | λ = 1.8e-04 | ✗
# iter 1140 | residual = 7.077e-04 | λ = 9.1e-05 | ✓
# iter 1150 | residual = 7.032e-04 | λ = 4.7e-05 | ✓
# iter 1160 | residual = 6.987e-04 | λ = 1.1e-04 | ✓
# iter 1170 | residual = 6.948e-04 | λ = 5.5e-05 | ✓
# iter 1180 | residual = 6.918e-04 | λ = 1.2e-04 | ✗
# iter 1190 | residual = 6.861e-04 | λ = 6.3e-05 | ✓
# iter 1200 | residual = 6.823e-04 | λ = 1.4e-04 | ✗
# iter 1210 | residual = 6.778e-04 | λ = 7.3e-05 | ✓
# iter 1220 | residual = 6.745e-04 | λ = 1.6e-04 | ✗
# iter 1230 | residual = 6.697e-04 | λ = 8.4e-05 | ✓
# iter 1240 | residual = 6.655e-04 | λ = 4.3e-05 | ✓
# iter 1250 | residual = 6.614e-04 | λ = 9.7e-05 | ✓
# iter 1260 | residual = 6.577e-04 | λ = 5.0e-05 | ✓
# iter 1270 | residual = 6.550e-04 | λ = 1.1e-04 | ✗
# iter 1280 | residual = 6.497e-04 | λ = 5.8e-05 | ✓
# iter 1290 | residual = 6.462e-04 | λ = 1.3e-04 | ✗
# iter 1300 | residual = 6.421e-04 | λ = 6.7e-05 | ✓
# iter 1310 | residual = 6.390e-04 | λ = 1.5e-04 | ✗
# iter 1320 | residual = 6.346e-04 | λ = 7.7e-05 | ✓
# iter 1330 | residual = 6.308e-04 | λ = 4.0e-05 | ✓
# iter 1340 | residual = 6.270e-04 | λ = 8.9e-05 | ✓
# iter 1350 | residual = 6.236e-04 | λ = 4.6e-05 | ✓
# iter 1360 | residual = 6.205e-04 | λ = 1.0e-04 | ✗
# iter 1370 | residual = 6.157e-04 | λ = 5.3e-05 | ✓
# iter 1380 | residual = 6.124e-04 | λ = 1.2e-04 | ✗
# iter 1390 | residual = 6.087e-04 | λ = 6.1e-05 | ✓
# iter 1400 | residual = 6.052e-04 | λ = 3.2e-05 | ✓
# iter 1410 | residual = 6.009e-04 | λ = 7.1e-05 | ✓
# iter 1420 | residual = 5.973e-04 | λ = 3.7e-05 | ✓
# iter 1430 | residual = 5.939e-04 | λ = 8.2e-05 | ✓
# iter 1440 | residual = 5.903e-04 | λ = 4.2e-05 | ✓
# iter 1450 | residual = 5.868e-04 | λ = 9.4e-05 | ✗
# iter 1460 | residual = 5.826e-04 | λ = 4.9e-05 | ✓
# iter 1470 | residual = 5.796e-04 | λ = 1.1e-04 | ✗
# iter 1480 | residual = 5.757e-04 | λ = 5.6e-05 | ✓
# iter 1490 | residual = 5.719e-04 | λ = 2.9e-05 | ✓
# iter 1500 | residual = 5.681e-04 | λ = 6.5e-05 | ✓
# iter 1510 | residual = 5.648e-04 | λ = 3.4e-05 | ✓
# iter 1520 | residual = 5.617e-04 | λ = 7.5e-05 | ✗
# iter 1530 | residual = 5.569e-04 | λ = 3.9e-05 | ✓
# iter 1540 | residual = 5.537e-04 | λ = 8.6e-05 | ✗
# iter 1550 | residual = 5.500e-04 | λ = 4.5e-05 | ✓
# iter 1560 | residual = 5.465e-04 | λ = 2.3e-05 | ✓
# iter 1570 | residual = 5.422e-04 | λ = 5.2e-05 | ✓
# iter 1580 | residual = 5.387e-04 | λ = 2.7e-05 | ✓
# iter 1590 | residual = 5.354e-04 | λ = 6.0e-05 | ✓
# iter 1600 | residual = 5.317e-04 | λ = 3.1e-05 | ✓
# iter 1610 | residual = 5.283e-04 | λ = 6.9e-05 | ✗
# iter 1620 | residual = 5.241e-04 | λ = 3.6e-05 | ✓
# iter 1630 | residual = 5.211e-04 | λ = 7.9e-05 | ✗
# iter 1640 | residual = 5.173e-04 | λ = 4.1e-05 | ✓
# iter 1650 | residual = 5.135e-04 | λ = 2.1e-05 | ✓
# iter 1660 | residual = 5.097e-04 | λ = 4.8e-05 | ✓
# iter 1670 | residual = 5.064e-04 | λ = 2.5e-05 | ✓
# iter 1680 | residual = 5.034e-04 | λ = 5.5e-05 | ✓
# iter 1690 | residual = 4.996e-04 | λ = 2.8e-05 | ✓
# iter 1700 | residual = 4.964e-04 | λ = 6.3e-05 | ✗
# iter 1710 | residual = 4.926e-04 | λ = 3.3e-05 | ✓
# iter 1720 | residual = 4.898e-04 | λ = 7.3e-05 | ✗
# iter 1730 | residual = 4.862e-04 | λ = 3.8e-05 | ✓
# iter 1740 | residual = 4.827e-04 | λ = 2.0e-05 | ✓
# iter 1750 | residual = 4.792e-04 | λ = 4.4e-05 | ✓
# iter 1760 | residual = 4.761e-04 | λ = 2.3e-05 | ✓
# iter 1770 | residual = 4.733e-04 | λ = 5.0e-05 | ✓
# iter 1780 | residual = 4.697e-04 | λ = 2.6e-05 | ✓
# iter 1790 | residual = 4.667e-04 | λ = 5.8e-05 | ✗
# iter 1800 | residual = 4.631e-04 | λ = 3.0e-05 | ✓
# iter 1810 | residual = 4.604e-04 | λ = 6.7e-05 | ✗
# iter 1820 | residual = 4.571e-04 | λ = 3.5e-05 | ✓
# iter 1830 | residual = 4.538e-04 | λ = 1.8e-05 | ✓
# iter 1840 | residual = 4.505e-04 | λ = 4.0e-05 | ✓
# iter 1850 | residual = 4.475e-04 | λ = 2.1e-05 | ✓
# iter 1860 | residual = 4.449e-04 | λ = 4.6e-05 | ✓
# iter 1870 | residual = 4.414e-04 | λ = 2.4e-05 | ✓
# iter 1880 | residual = 4.386e-04 | λ = 5.3e-05 | ✗
# iter 1890 | residual = 4.352e-04 | λ = 2.8e-05 | ✓
# iter 1900 | residual = 4.327e-04 | λ = 6.2e-05 | ✗
# iter 1910 | residual = 4.295e-04 | λ = 3.2e-05 | ✓
# iter 1920 | residual = 4.263e-04 | λ = 1.7e-05 | ✓
# iter 1930 | residual = 4.231e-04 | λ = 3.7e-05 | ✓
# iter 1940 | residual = 4.203e-04 | λ = 1.9e-05 | ✓
# iter 1950 | residual = 4.178e-04 | λ = 4.3e-05 | ✓
# iter 1960 | residual = 4.145e-04 | λ = 2.2e-05 | ✓
# iter 1970 | residual = 4.118e-04 | λ = 4.9e-05 | ✗
# iter 1980 | residual = 4.085e-04 | λ = 2.5e-05 | ✓
# iter 1990 | residual = 4.061e-04 | λ = 5.7e-05 | ✗
# iter 2000 | residual = 4.031e-04 | λ = 2.9e-05 | ✓
# iter 2010 | residual = 4.001e-04 | λ = 1.5e-05 | ✓
# iter 2020 | residual = 3.971e-04 | λ = 3.4e-05 | ✓
# iter 2030 | residual = 3.944e-04 | λ = 1.8e-05 | ✓
# iter 2040 | residual = 3.920e-04 | λ = 3.9e-05 | ✓
# iter 2050 | residual = 3.889e-04 | λ = 2.0e-05 | ✓
# iter 2060 | residual = 3.863e-04 | λ = 4.5e-05 | ✗
# iter 2070 | residual = 3.832e-04 | λ = 2.3e-05 | ✓
# iter 2080 | residual = 3.810e-04 | λ = 5.2e-05 | ✗
# iter 2090 | residual = 3.781e-04 | λ = 2.7e-05 | ✓
# iter 2100 | residual = 3.753e-04 | λ = 1.4e-05 | ✓
# iter 2110 | residual = 3.724e-04 | λ = 3.1e-05 | ✓
# iter 2120 | residual = 3.699e-04 | λ = 1.6e-05 | ✓
# iter 2130 | residual = 3.680e-04 | λ = 3.6e-05 | ✗
# iter 2140 | residual = 3.643e-04 | λ = 1.9e-05 | ✓
# iter 2150 | residual = 3.619e-04 | λ = 4.2e-05 | ✗
# iter 2160 | residual = 3.591e-04 | λ = 2.2e-05 | ✓
# iter 2170 | residual = 3.570e-04 | λ = 4.8e-05 | ✗
# iter 2180 | residual = 3.540e-04 | λ = 2.5e-05 | ✓
# iter 2190 | residual = 3.513e-04 | λ = 1.3e-05 | ✓
# iter 2200 | residual = 3.487e-04 | λ = 2.9e-05 | ✓
# iter 2210 | residual = 3.464e-04 | λ = 1.5e-05 | ✓
# iter 2220 | residual = 3.442e-04 | λ = 3.3e-05 | ✗
# iter 2230 | residual = 3.410e-04 | λ = 1.7e-05 | ✓
# iter 2240 | residual = 3.387e-04 | λ = 3.8e-05 | ✗
# iter 2250 | residual = 3.362e-04 | λ = 2.0e-05 | ✓
# iter 2260 | residual = 3.338e-04 | λ = 1.0e-05 | ✓
# iter 2270 | residual = 3.309e-04 | λ = 2.3e-05 | ✓
# iter 2280 | residual = 3.284e-04 | λ = 1.2e-05 | ✓
# iter 2290 | residual = 3.261e-04 | λ = 2.6e-05 | ✓
# iter 2300 | residual = 3.237e-04 | λ = 1.4e-05 | ✓
# iter 2310 | residual = 3.213e-04 | λ = 3.0e-05 | ✗
# iter 2320 | residual = 3.185e-04 | λ = 1.6e-05 | ✓
# iter 2330 | residual = 3.165e-04 | λ = 3.5e-05 | ✗
# iter 2340 | residual = 3.139e-04 | λ = 1.8e-05 | ✓
# iter 2350 | residual = 3.114e-04 | λ = 9.4e-06 | ✓
# iter 2360 | residual = 3.089e-04 | λ = 2.1e-05 | ✓
# iter 2370 | residual = 3.067e-04 | λ = 1.1e-05 | ✓
# iter 2380 | residual = 3.050e-04 | λ = 2.4e-05 | ✗
# iter 2390 | residual = 3.019e-04 | λ = 1.3e-05 | ✓
# iter 2400 | residual = 2.998e-04 | λ = 2.8e-05 | ✗
# iter 2410 | residual = 2.974e-04 | λ = 1.4e-05 | ✓
# iter 2420 | residual = 2.956e-04 | λ = 7.5e-06 | ✓
# iter 2430 | residual = 2.927e-04 | λ = 1.7e-05 | ✓
# iter 2440 | residual = 2.905e-04 | λ = 8.7e-06 | ✓
# iter 2450 | residual = 2.883e-04 | λ = 1.9e-05 | ✓
# iter 2460 | residual = 2.863e-04 | λ = 1.0e-05 | ✓
# iter 2470 | residual = 2.842e-04 | λ = 2.2e-05 | ✗
# iter 2480 | residual = 2.815e-04 | λ = 1.2e-05 | ✓
# iter 2490 | residual = 2.796e-04 | λ = 2.6e-05 | ✗
# iter 2500 | residual = 2.775e-04 | λ = 1.3e-05 | ✓
# iter 2510 | residual = 2.756e-04 | λ = 6.9e-06 | ✓
# iter 2520 | residual = 2.731e-04 | λ = 1.5e-05 | ✓
# iter 2530 | residual = 2.711e-04 | λ = 8.0e-06 | ✓
# iter 2540 | residual = 2.692e-04 | λ = 1.8e-05 | ✓
# iter 2550 | residual = 2.674e-04 | λ = 9.2e-06 | ✓
# iter 2560 | residual = 2.655e-04 | λ = 2.0e-05 | ✗
# iter 2570 | residual = 2.631e-04 | λ = 1.1e-05 | ✓
# iter 2580 | residual = 2.614e-04 | λ = 2.4e-05 | ✗
# iter 2590 | residual = 2.595e-04 | λ = 1.2e-05 | ✓
# iter 2600 | residual = 2.580e-04 | λ = 6.3e-06 | ✓
# iter 2610 | residual = 2.557e-04 | λ = 1.4e-05 | ✓
# iter 2620 | residual = 2.539e-04 | λ = 7.3e-06 | ✓
# iter 2630 | residual = 2.521e-04 | λ = 1.6e-05 | ✓
# iter 2640 | residual = 2.505e-04 | λ = 8.5e-06 | ✓
# iter 2650 | residual = 2.493e-04 | λ = 1.9e-05 | ✗
# iter 2660 | residual = 2.471e-04 | λ = 9.7e-06 | ✓
# iter 2670 | residual = 2.455e-04 | λ = 2.2e-05 | ✗
# iter 2680 | residual = 2.437e-04 | λ = 1.1e-05 | ✓
# iter 2690 | residual = 2.424e-04 | λ = 2.5e-05 | ✗
# iter 2700 | residual = 2.408e-04 | λ = 1.3e-05 | ✓
# iter 2710 | residual = 2.391e-04 | λ = 6.7e-06 | ✓
# iter 2720 | residual = 2.374e-04 | λ = 1.5e-05 | ✓
# iter 2730 | residual = 2.360e-04 | λ = 7.8e-06 | ✓
# iter 2740 | residual = 2.347e-04 | λ = 1.7e-05 | ✓
# iter 2750 | residual = 2.332e-04 | λ = 9.0e-06 | ✓
# iter 2760 | residual = 2.318e-04 | λ = 2.0e-05 | ✗
# iter 2770 | residual = 2.301e-04 | λ = 1.0e-05 | ✓
# iter 2780 | residual = 2.289e-04 | λ = 2.3e-05 | ✗
# iter 2790 | residual = 2.275e-04 | λ = 1.2e-05 | ✓
# iter 2800 | residual = 2.261e-04 | λ = 6.2e-06 | ✓
# iter 2810 | residual = 2.245e-04 | λ = 1.4e-05 | ✓
# iter 2820 | residual = 2.232e-04 | λ = 7.1e-06 | ✓
# iter 2830 | residual = 2.219e-04 | λ = 1.6e-05 | ✓
# iter 2840 | residual = 2.208e-04 | λ = 8.2e-06 | ✓
# iter 2850 | residual = 2.195e-04 | λ = 1.8e-05 | ✗
# iter 2860 | residual = 2.180e-04 | λ = 9.5e-06 | ✓
# iter 2870 | residual = 2.169e-04 | λ = 2.1e-05 | ✗
# iter 2880 | residual = 2.156e-04 | λ = 1.1e-05 | ✓
# iter 2890 | residual = 2.145e-04 | λ = 5.7e-06 | ✓
# iter 2900 | residual = 2.130e-04 | λ = 1.3e-05 | ✓
# iter 2910 | residual = 2.118e-04 | λ = 6.6e-06 | ✓
# iter 2920 | residual = 2.107e-04 | λ = 1.5e-05 | ✓
# iter 2930 | residual = 2.097e-04 | λ = 7.6e-06 | ✓
# iter 2940 | residual = 2.085e-04 | λ = 1.7e-05 | ✗
# iter 2950 | residual = 2.071e-04 | λ = 8.7e-06 | ✓
# iter 2960 | residual = 2.061e-04 | λ = 1.9e-05 | ✗
# iter 2970 | residual = 2.050e-04 | λ = 1.0e-05 | ✓
# iter 2980 | residual = 2.039e-04 | λ = 5.2e-06 | ✓
# iter 2990 | residual = 2.026e-04 | λ = 1.2e-05 | ✓
# iter 3000 | residual = 2.015e-04 | λ = 6.0e-06 | ✓
# iter 3010 | residual = 2.005e-04 | λ = 1.3e-05 | ✓
# iter 3020 | residual = 1.995e-04 | λ = 7.0e-06 | ✓
# iter 3030 | residual = 1.986e-04 | λ = 1.5e-05 | ✗
# iter 3040 | residual = 1.973e-04 | λ = 8.0e-06 | ✓
# iter 3050 | residual = 1.964e-04 | λ = 1.8e-05 | ✗
# iter 3060 | residual = 1.954e-04 | λ = 9.3e-06 | ✓
# iter 3070 | residual = 1.945e-04 | λ = 4.8e-06 | ✓
# iter 3080 | residual = 1.933e-04 | λ = 1.1e-05 | ✓
# iter 3090 | residual = 1.923e-04 | λ = 5.5e-06 | ✓
# iter 3100 | residual = 1.913e-04 | λ = 1.2e-05 | ✓
# iter 3110 | residual = 1.905e-04 | λ = 6.4e-06 | ✓
# iter 3120 | residual = 1.897e-04 | λ = 1.4e-05 | ✗
# iter 3130 | residual = 1.884e-04 | λ = 7.4e-06 | ✓
# iter 3140 | residual = 1.876e-04 | λ = 1.6e-05 | ✗
# iter 3150 | residual = 1.866e-04 | λ = 8.5e-06 | ✓
# iter 3160 | residual = 1.859e-04 | λ = 4.4e-06 | ✓
# iter 3170 | residual = 1.847e-04 | λ = 9.8e-06 | ✓
# iter 3180 | residual = 1.838e-04 | λ = 5.1e-06 | ✓
# iter 3190 | residual = 1.829e-04 | λ = 1.1e-05 | ✓
# iter 3200 | residual = 1.821e-04 | λ = 5.9e-06 | ✓
# iter 3210 | residual = 1.815e-04 | λ = 1.3e-05 | ✗
# iter 3220 | residual = 1.803e-04 | λ = 6.8e-06 | ✓
# iter 3230 | residual = 1.795e-04 | λ = 1.5e-05 | ✗
# iter 3240 | residual = 1.786e-04 | λ = 7.8e-06 | ✓
# iter 3250 | residual = 1.780e-04 | λ = 1.7e-05 | ✗
# iter 3260 | residual = 1.770e-04 | λ = 9.0e-06 | ✓
# iter 3270 | residual = 1.761e-04 | λ = 4.7e-06 | ✓
# iter 3280 | residual = 1.753e-04 | λ = 1.0e-05 | ✓
# iter 3290 | residual = 1.745e-04 | λ = 5.4e-06 | ✓
# iter 3300 | residual = 1.740e-04 | λ = 1.2e-05 | ✗
# iter 3310 | residual = 1.729e-04 | λ = 6.2e-06 | ✓
# iter 3320 | residual = 1.722e-04 | λ = 1.4e-05 | ✗
# iter 3330 | residual = 1.713e-04 | λ = 7.2e-06 | ✓
# iter 3340 | residual = 1.707e-04 | λ = 1.6e-05 | ✗
# iter 3350 | residual = 1.698e-04 | λ = 8.3e-06 | ✓
# iter 3360 | residual = 1.690e-04 | λ = 4.3e-06 | ✓
# iter 3370 | residual = 1.682e-04 | λ = 9.6e-06 | ✓
# iter 3380 | residual = 1.675e-04 | λ = 5.0e-06 | ✓
# iter 3390 | residual = 1.669e-04 | λ = 1.1e-05 | ✗
# iter 3400 | residual = 1.659e-04 | λ = 5.7e-06 | ✓
# iter 3410 | residual = 1.652e-04 | λ = 1.3e-05 | ✗
# iter 3420 | residual = 1.644e-04 | λ = 6.6e-06 | ✓
# iter 3430 | residual = 1.638e-04 | λ = 1.5e-05 | ✗
# iter 3440 | residual = 1.630e-04 | λ = 7.6e-06 | ✓
# iter 3450 | residual = 1.622e-04 | λ = 4.0e-06 | ✓
# iter 3460 | residual = 1.615e-04 | λ = 8.8e-06 | ✓
# iter 3470 | residual = 1.608e-04 | λ = 4.6e-06 | ✓
# iter 3480 | residual = 1.603e-04 | λ = 1.0e-05 | ✗
# iter 3490 | residual = 1.594e-04 | λ = 5.3e-06 | ✓
# iter 3500 | residual = 1.587e-04 | λ = 1.2e-05 | ✗
# iter 3510 | residual = 1.580e-04 | λ = 6.1e-06 | ✓
# iter 3520 | residual = 1.574e-04 | λ = 3.1e-06 | ✓
# iter 3530 | residual = 1.565e-04 | λ = 7.0e-06 | ✓
# iter 3540 | residual = 1.558e-04 | λ = 3.6e-06 | ✓
# iter 3550 | residual = 1.551e-04 | λ = 8.1e-06 | ✓
# iter 3560 | residual = 1.545e-04 | λ = 4.2e-06 | ✓
# iter 3570 | residual = 1.539e-04 | λ = 9.3e-06 | ✗
# iter 3580 | residual = 1.530e-04 | λ = 4.8e-06 | ✓
# iter 3590 | residual = 1.524e-04 | λ = 1.1e-05 | ✗
# iter 3600 | residual = 1.517e-04 | λ = 5.6e-06 | ✓
# iter 3610 | residual = 1.512e-04 | λ = 2.9e-06 | ✓
# iter 3620 | residual = 1.504e-04 | λ = 6.4e-06 | ✓
# iter 3630 | residual = 1.497e-04 | λ = 3.3e-06 | ✓
# iter 3640 | residual = 1.491e-04 | λ = 7.4e-06 | ✓
# iter 3650 | residual = 1.485e-04 | λ = 3.9e-06 | ✓
# iter 3660 | residual = 1.478e-04 | λ = 8.6e-06 | ✗
# iter 3670 | residual = 1.470e-04 | λ = 4.4e-06 | ✓
# iter 3680 | residual = 1.464e-04 | λ = 9.9e-06 | ✗
# iter 3690 | residual = 1.458e-04 | λ = 5.1e-06 | ✓
# iter 3700 | residual = 1.451e-04 | λ = 2.7e-06 | ✓
# iter 3710 | residual = 1.444e-04 | λ = 5.9e-06 | ✓
# iter 3720 | residual = 1.437e-04 | λ = 3.1e-06 | ✓
# iter 3730 | residual = 1.432e-04 | λ = 6.8e-06 | ✓
# iter 3740 | residual = 1.425e-04 | λ = 3.5e-06 | ✓
# iter 3750 | residual = 1.419e-04 | λ = 7.9e-06 | ✗
# iter 3760 | residual = 1.411e-04 | λ = 4.1e-06 | ✓
# iter 3770 | residual = 1.406e-04 | λ = 9.1e-06 | ✗
# iter 3780 | residual = 1.400e-04 | λ = 4.7e-06 | ✓
# iter 3790 | residual = 1.393e-04 | λ = 2.4e-06 | ✓
# iter 3800 | residual = 1.386e-04 | λ = 5.4e-06 | ✓
# iter 3810 | residual = 1.380e-04 | λ = 2.8e-06 | ✓
# iter 3820 | residual = 1.374e-04 | λ = 6.3e-06 | ✓
# iter 3830 | residual = 1.367e-04 | λ = 3.3e-06 | ✓
# iter 3840 | residual = 1.361e-04 | λ = 7.2e-06 | ✗
# iter 3850 | residual = 1.354e-04 | λ = 3.8e-06 | ✓
# iter 3860 | residual = 1.349e-04 | λ = 8.3e-06 | ✗
# iter 3870 | residual = 1.342e-04 | λ = 4.3e-06 | ✓
# iter 3880 | residual = 1.336e-04 | λ = 2.2e-06 | ✓
# iter 3890 | residual = 1.329e-04 | λ = 5.0e-06 | ✓
# iter 3900 | residual = 1.324e-04 | λ = 2.6e-06 | ✓
# iter 3910 | residual = 1.319e-04 | λ = 5.8e-06 | ✗
# iter 3920 | residual = 1.311e-04 | λ = 3.0e-06 | ✓
# iter 3930 | residual = 1.305e-04 | λ = 6.6e-06 | ✗
# iter 3940 | residual = 1.299e-04 | λ = 3.4e-06 | ✓
# iter 3950 | residual = 1.294e-04 | λ = 7.7e-06 | ✗
# iter 3960 | residual = 1.287e-04 | λ = 4.0e-06 | ✓
# iter 3970 | residual = 1.281e-04 | λ = 2.1e-06 | ✓
# iter 3980 | residual = 1.275e-04 | λ = 4.6e-06 | ✓
# iter 3990 | residual = 1.269e-04 | λ = 2.4e-06 | ✓
# Training finished.

# %%
n_theta = sum(p.numel() for p in model.parameters())
print(n_theta)
# Out:
# 171

# %%
# test
t0 = 0.05
nx = 100
xs = np.linspace(X_MIN, X_MAX, nx)
ys = np.linspace(Y_MIN, Y_MAX, nx)
Xg, Yg = np.meshgrid(xs, ys)

x_grid = torch.from_numpy(Xg.flatten()[:,None]).to(device).double()
y_grid = torch.from_numpy(Yg.flatten()[:,None]).to(device).double()
t_grid = torch.full_like(x_grid, t0).to(device)  # 全部時間都固定為 t0



with torch.no_grad():
    phi_grid, u_true_grid = compute_phi(x_grid, y_grid, t_grid)


# 預測 u
with torch.no_grad():
    inp_grid = torch.cat([x_grid, y_grid, phi_grid, t_grid], dim=1)
    u_pred = model(inp_grid)
    u_pred = u_pred.cpu().numpy().reshape(nx, nx)
    u_true_grid = u_true_grid.cpu().numpy().reshape(nx, nx)

# 逐點相對誤差
u_true_norm = np.max(np.abs(u_true_grid))   # 真實解的 inf norm
error_rel = np.abs(u_pred - u_true_grid) / (u_true_norm)
#error_rel2 = np.abs(u_pred - u_true_grid) / np.linalg.norm(u_true_grid.flatten(), ord=2) # 分母是 true 的 L2 norm
#error_abs = np.abs(u_pred - u_true_grid)

# 整體相對誤差 ||u_pred - u_true||_2 / ||u_true||_2
error_tensor = torch.from_numpy(np.abs(u_pred - u_true_grid)).double()
u_tensor = torch.from_numpy(np.abs(u_true_grid)).double()
relL2 = torch.norm(error_tensor) / torch.norm(u_tensor)
print("Relative L2 error (grid):", relL2.item())
# 畫圖
fig, axs = plt.subplots(1, 3, figsize=(18,5))

im0 = axs[0].contourf(Xg, Yg, u_pred, 50, cmap='viridis')
fig.colorbar(im0, ax=axs[0])
axs[0].set_title('PINN Prediction $u_N$')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')

im1 = axs[1].contourf(Xg, Yg, u_true_grid, 50, cmap='viridis')
fig.colorbar(im1, ax=axs[1])
axs[1].set_title('Analytical Solution $\\phi$')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')

im2 = axs[2].contourf(Xg, Yg, error_rel, 50, cmap='hot')
fig.colorbar(im2, ax=axs[2])
axs[2].set_title('Relative Error')
axs[2].set_xlabel('x')
axs[2].set_ylabel('y')

plt.tight_layout()
plt.show()
# Out:
# Relative L2 error (grid): 1.1533048061104574e-06

# %%
# loss
epochs_arr = np.arange(len(res_hist))
plt.figure(figsize=(8,5))
plt.semilogy(epochs_arr, res_hist, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Resi (log scale)')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
