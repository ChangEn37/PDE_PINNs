# %% [markdown]
# f=1, g=0, crack: 0 degrees

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

# %%
# Settings
torch.set_default_dtype(torch.float64)   # use double for better derivative precision
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Domain: square [-1,1]^2 with crack along y=x starting from origin
X_MIN, X_MAX = -1.0, 1.0
Y_MIN, Y_MAX = -1.0, 1.0

# Training hyperparams
N_f = 50       # collocation points
N_b = 50  # boundary points on outer square
N_b_crack = 50  
N_tip = 20  
epochs = 1000
lam, lam_up, lam_down = 1e3, 3.0, 0.7

# %%
# Neural network
class MLP(nn.Module):
    def __init__(self, layers):
        super().__init__()
        self.net = nn.ModuleList()
        for i in range(len(layers)-1):
            self.net.append(nn.Linear(layers[i], layers[i+1]))
        self.activation = torch.tanh
        # init
        for m in self.net:
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight)
                nn.init.zeros_(m.bias)

    def forward(self, inp):
        z = inp
        for layer in self.net[:-1]:
            z = self.activation(layer(z))
        z = self.net[-1](z)  # no activation on last
        return z

# model
layers = [3, 30, 30, 1]
model = MLP(layers).to(device)

# %%
def compute_phi(x, y):
    eps = 1e-12
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=eps))
    phi = torch.sqrt(0.5 * (r - x))
    return phi.view(-1, 1)

def compute_phi_derivs(x, y):
    eps = 1e-12
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=eps))
    phi_x = (-0.5) * (0.5**0.5) * torch.sqrt(r - x) / r
    phi_y = (0.25) * (2**0.5) * (y/r)/ torch.sqrt(r - x)

    return phi_x.reshape(-1,1), phi_y.reshape(-1,1)

def first_derivs(model, x, y):
    phi = compute_phi(x, y)
    inp = torch.cat([x, y, phi], dim=1).requires_grad_(True)

    U = model(inp).view(-1, 1)

    grads = torch.autograd.grad(
        outputs=U.sum(),
        inputs=inp,
        create_graph=True
    )[0]

    return U, inp, grads[:,0:1], grads[:,1:2], grads[:,2:3]

def second_partials_U(inp, U_x, U_y, U_z):

    grad_Ux = torch.autograd.grad(
        outputs=U_x.sum(),
        inputs=inp,
        create_graph=True
    )[0]

    grad_Uy = torch.autograd.grad(
        outputs=U_y.sum(),
        inputs=inp,
        create_graph=True
    )[0]

    grad_Uz = torch.autograd.grad(
        outputs=U_z.sum(),
        inputs=inp,
        create_graph=True
    )[0]

    U_xx = grad_Ux[:, 0:1]
    U_xy = grad_Ux[:, 1:2]
    U_xz = grad_Ux[:, 2:3]

    U_yy = grad_Uy[:, 1:2]
    U_yz = grad_Uy[:, 2:3]

    U_zz = grad_Uz[:, 2:3]

    return U_xx, U_yy, U_xz, U_yz, U_zz

def laplace_u(model, x, y):
    phi_x, phi_y = compute_phi_derivs(x, y)
    U, inp, U_x, U_y, U_z = first_derivs(model, x, y)
    U_xx, U_yy, U_xz, U_yz, U_zz = second_partials_U(inp, U_x, U_y, U_z)

    eps = 1e-12
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=eps))

    lap = (U_xx + U_yy
           + 2*(U_xz * phi_x + U_yz * phi_y)
           + (1/(4*r))*U_zz)
    return lap

# sampling

def sample_collocation(N):
    x = torch.rand(N*2,1)*(X_MAX-X_MIN)+X_MIN
    y = torch.rand(N*2,1)*(Y_MAX-Y_MIN)+Y_MIN

    mask = ~((torch.abs(y) < 1e-8) & (x >= 0))
    idx = mask.squeeze(1)

    x = x[idx][:N]
    y = y[idx][:N]

    return x.to(device), y.to(device)

def sample_boundary(N):
    t = torch.linspace(-1,1,N).view(-1,1)
    xb = torch.cat([t, t, -torch.ones_like(t), torch.ones_like(t)])
    yb = torch.cat([-torch.ones_like(t), torch.ones_like(t), t, t])
    return xb.to(device), yb.to(device)

def sample_tip_and_crack(N_tip, N_b_crack):
    # crack 上（不含 tip）
    x_c = torch.linspace(1e-4, 1.0, N_b_crack, device=device).unsqueeze(1)
    y_c = torch.zeros_like(x_c)

    # tip neighborhood: small disk around (0,0)
    theta = torch.linspace(0, 2*np.pi, N_tip)
    r = 1e-3 * torch.ones_like(theta)
    x_t = (r * torch.cos(theta)).view(-1,1)
    y_t = (r * torch.sin(theta)).view(-1,1)

    return x_c, y_c, x_t, y_t

# Residual vector 
def residual_vector(model):
    res = []

    # PDE
    lap = laplace_u(model, x_f, y_f)
    res.append(lap.view(-1))

    # Boundary
    phi_b = compute_phi(x_b, y_b)
    inp_b = torch.cat([x_b, y_b, phi_b], dim=1)
    res.append((model(inp_b)).view(-1))

    # Crack-tip regularization
    x_c, y_c, x_t, y_t = sample_tip_and_crack(N_tip, N_b_crack)
    _, inp_tip, U_x_tip, U_y_tip, U_z_tip = first_derivs(model, x_t, y_t)
    _, _, U_xz_tip, U_yz_tip, U_zz_tip = second_partials_U(inp_tip, U_x_tip, U_y_tip, U_z_tip)
    _, inp_c, U_x_c, U_y_c, U_z_c = first_derivs(model, x_c, y_c)
    _, _, U_xz_c, U_yz_c, _ = second_partials_U(inp_c, U_x_c, U_y_c, U_z_c)

    res += [U_zz_tip.view(-1), U_xz_tip.view(-1), U_yz_tip.view(-1)] # 
    res += [U_xz_c.view(-1), U_yz_c.view(-1)] #

    return torch.cat(res)

# LM utilities
def flatten_params(model):
    return torch.cat([p.view(-1) for p in model.parameters()])

def set_params(model, theta):
    i = 0
    for p in model.parameters():
        n = p.numel()
        p.data.copy_(theta[i:i+n].view_as(p))
        i += n

def lm_step(model, lam):
    r = residual_vector(model)
    loss = torch.dot(r, r)

    theta = flatten_params(model)
    n, m = theta.numel(), r.numel()
    J = torch.zeros(m, n, device=device)

    for i in range(m):
        grads = torch.autograd.grad(r[i], model.parameters(), retain_graph=True)
        J[i] = torch.cat([g.view(-1) for g in grads])

    A = J.T @ J + lam * torch.eye(n, device=device)
    delta = torch.linalg.solve(A, -J.T @ r)

    set_params(model, theta + delta)
    return loss.item(), theta, delta

# %%
# Training
x_f, y_f = sample_collocation(N_f)
x_b, y_b = sample_boundary(N_b)
loss_history = []
lam_history = []

for ep in range(epochs):
    loss0, theta_old, delta = lm_step(model, lam)

    r_new = residual_vector(model)
    loss1 = torch.dot(r_new, r_new).item()

    if loss1 < loss0:
        #lam *= lam_down
        lam = max(lam * lam_down, 10**(-9))
        status = "accept"
    else:
        #lam *= lam_up
        lam = min(lam * lam_up, 10**8)
        set_params(model, theta_old)
        status = "reject"

    loss_history.append(loss1)
    lam_history.append(lam)

    print(f"LM {ep:02d} | loss {loss1:.3e} | λ={lam:.1e} | {status}")
# Out:
# LM 00 | loss 1.091e+01 | λ=7.0e+02 | accept
# LM 01 | loss 3.398e+00 | λ=4.9e+02 | accept
# LM 02 | loss 9.878e-01 | λ=3.4e+02 | accept
# LM 03 | loss 4.096e-01 | λ=2.4e+02 | accept
# LM 04 | loss 2.783e-01 | λ=1.7e+02 | accept
# LM 05 | loss 2.167e-01 | λ=1.2e+02 | accept
# LM 06 | loss 1.649e-01 | λ=8.2e+01 | accept
# LM 07 | loss 1.215e-01 | λ=5.8e+01 | accept
# LM 08 | loss 8.887e-02 | λ=4.0e+01 | accept
# LM 09 | loss 6.623e-02 | λ=2.8e+01 | accept
# LM 10 | loss 5.034e-02 | λ=2.0e+01 | accept
# LM 11 | loss 3.817e-02 | λ=1.4e+01 | accept
# LM 12 | loss 2.835e-02 | λ=9.7e+00 | accept
# LM 13 | loss 2.058e-02 | λ=6.8e+00 | accept
# LM 14 | loss 1.468e-02 | λ=4.7e+00 | accept
# LM 15 | loss 1.033e-02 | λ=3.3e+00 | accept
# LM 16 | loss 7.159e-03 | λ=2.3e+00 | accept
# LM 17 | loss 4.916e-03 | λ=1.6e+00 | accept
# LM 18 | loss 3.398e-03 | λ=1.1e+00 | accept
# LM 19 | loss 2.411e-03 | λ=8.0e-01 | accept
# LM 20 | loss 1.768e-03 | λ=5.6e-01 | accept
# LM 21 | loss 1.316e-03 | λ=3.9e-01 | accept
# LM 22 | loss 9.626e-04 | λ=2.7e-01 | accept
# LM 23 | loss 6.750e-04 | λ=1.9e-01 | accept
# LM 24 | loss 4.496e-04 | λ=1.3e-01 | accept
# LM 25 | loss 2.874e-04 | λ=9.4e-02 | accept
# LM 26 | loss 1.815e-04 | λ=6.6e-02 | accept
# LM 27 | loss 1.180e-04 | λ=4.6e-02 | accept
# LM 28 | loss 8.138e-05 | λ=3.2e-02 | accept
# LM 29 | loss 5.896e-05 | λ=2.3e-02 | accept
# LM 30 | loss 4.318e-05 | λ=1.6e-02 | accept
# LM 31 | loss 3.115e-05 | λ=1.1e-02 | accept
# LM 32 | loss 2.209e-05 | λ=7.7e-03 | accept
# LM 33 | loss 1.552e-05 | λ=5.4e-03 | accept
# LM 34 | loss 1.085e-05 | λ=3.8e-03 | accept
# LM 35 | loss 7.546e-06 | λ=2.7e-03 | accept
# LM 36 | loss 5.215e-06 | λ=1.9e-03 | accept
# LM 37 | loss 3.563e-06 | λ=1.3e-03 | accept
# LM 38 | loss 2.378e-06 | λ=9.1e-04 | accept
# LM 39 | loss 1.508e-06 | λ=6.4e-04 | accept
# LM 40 | loss 8.822e-07 | λ=4.5e-04 | accept
# LM 41 | loss 4.960e-07 | λ=3.1e-04 | accept
# LM 42 | loss 3.038e-07 | λ=2.2e-04 | accept
# LM 43 | loss 2.019e-07 | λ=1.5e-04 | accept
# LM 44 | loss 1.383e-07 | λ=1.1e-04 | accept
# LM 45 | loss 1.073e-07 | λ=7.5e-05 | accept
# LM 46 | loss 8.995e-08 | λ=5.2e-05 | accept
# LM 47 | loss 7.371e-08 | λ=3.7e-05 | accept
# LM 48 | loss 5.947e-08 | λ=2.6e-05 | accept
# LM 49 | loss 4.793e-08 | λ=1.8e-05 | accept
# LM 50 | loss 3.865e-08 | λ=1.3e-05 | accept
# LM 51 | loss 3.109e-08 | λ=8.8e-06 | accept
# LM 52 | loss 2.499e-08 | λ=6.2e-06 | accept
# LM 53 | loss 2.415e-08 | λ=4.3e-06 | accept
# LM 54 | loss 3.714e-08 | λ=1.3e-05 | reject
# LM 55 | loss 1.079e-08 | λ=9.1e-06 | accept
# LM 56 | loss 1.012e-08 | λ=6.3e-06 | accept
# LM 57 | loss 1.176e-08 | λ=1.9e-05 | reject
# LM 58 | loss 7.831e-09 | λ=1.3e-05 | accept
# LM 59 | loss 7.186e-09 | λ=9.3e-06 | accept
# LM 60 | loss 6.881e-09 | λ=6.5e-06 | accept
# LM 61 | loss 7.640e-09 | λ=2.0e-05 | reject
# LM 62 | loss 5.617e-09 | λ=1.4e-05 | accept
# LM 63 | loss 5.248e-09 | λ=9.6e-06 | accept
# LM 64 | loss 5.014e-09 | λ=6.7e-06 | accept
# LM 65 | loss 5.266e-09 | λ=2.0e-05 | reject
# LM 66 | loss 4.334e-09 | λ=1.4e-05 | accept
# LM 67 | loss 4.091e-09 | λ=9.9e-06 | accept
# LM 68 | loss 3.893e-09 | λ=6.9e-06 | accept
# LM 69 | loss 3.917e-09 | λ=2.1e-05 | reject
# LM 70 | loss 3.517e-09 | λ=1.5e-05 | accept
# LM 71 | loss 3.345e-09 | λ=1.0e-05 | accept
# LM 72 | loss 3.179e-09 | λ=7.1e-06 | accept
# LM 73 | loss 3.112e-09 | λ=5.0e-06 | accept
# LM 74 | loss 3.335e-09 | λ=1.5e-05 | reject
# LM 75 | loss 2.653e-09 | λ=1.0e-05 | accept
# LM 76 | loss 2.527e-09 | λ=7.3e-06 | accept
# LM 77 | loss 2.430e-09 | λ=5.1e-06 | accept
# LM 78 | loss 2.458e-09 | λ=1.5e-05 | reject
# LM 79 | loss 2.199e-09 | λ=1.1e-05 | accept
# LM 80 | loss 2.103e-09 | λ=7.5e-06 | accept
# LM 81 | loss 2.010e-09 | λ=5.3e-06 | accept
# LM 82 | loss 1.970e-09 | λ=3.7e-06 | accept
# LM 83 | loss 2.093e-09 | λ=1.1e-05 | reject
# LM 84 | loss 1.700e-09 | λ=7.8e-06 | accept
# LM 85 | loss 1.624e-09 | λ=5.4e-06 | accept
# LM 86 | loss 1.563e-09 | λ=3.8e-06 | accept
# LM 87 | loss 1.573e-09 | λ=1.1e-05 | reject
# LM 88 | loss 1.427e-09 | λ=8.0e-06 | accept
# LM 89 | loss 1.367e-09 | λ=5.6e-06 | accept
# LM 90 | loss 1.308e-09 | λ=3.9e-06 | accept
# LM 91 | loss 1.281e-09 | λ=2.7e-06 | accept
# LM 92 | loss 1.354e-09 | λ=8.2e-06 | reject
# LM 93 | loss 1.117e-09 | λ=5.7e-06 | accept
# LM 94 | loss 1.069e-09 | λ=4.0e-06 | accept
# LM 95 | loss 1.030e-09 | λ=2.8e-06 | accept
# LM 96 | loss 1.037e-09 | λ=8.4e-06 | reject
# LM 97 | loss 9.451e-10 | λ=5.9e-06 | accept
# LM 98 | loss 9.073e-10 | λ=4.1e-06 | accept
# LM 99 | loss 8.698e-10 | λ=2.9e-06 | accept
# LM 100 | loss 8.535e-10 | λ=2.0e-06 | accept
# LM 101 | loss 9.064e-10 | λ=6.1e-06 | reject
# LM 102 | loss 7.484e-10 | λ=4.3e-06 | accept
# LM 103 | loss 7.180e-10 | λ=3.0e-06 | accept
# LM 104 | loss 6.942e-10 | λ=2.1e-06 | accept
# LM 105 | loss 7.036e-10 | λ=6.3e-06 | reject
# LM 106 | loss 6.386e-10 | λ=4.4e-06 | accept
# LM 107 | loss 6.148e-10 | λ=3.1e-06 | accept
# LM 108 | loss 5.919e-10 | λ=2.1e-06 | accept
# LM 109 | loss 5.850e-10 | λ=1.5e-06 | accept
# LM 110 | loss 6.296e-10 | λ=4.5e-06 | reject
# LM 111 | loss 5.134e-10 | λ=3.2e-06 | accept
# LM 112 | loss 4.946e-10 | λ=2.2e-06 | accept
# LM 113 | loss 4.815e-10 | λ=1.5e-06 | accept
# LM 114 | loss 4.936e-10 | λ=4.6e-06 | reject
# LM 115 | loss 4.431e-10 | λ=3.2e-06 | accept
# LM 116 | loss 4.282e-10 | λ=2.3e-06 | accept
# LM 117 | loss 4.145e-10 | λ=1.6e-06 | accept
# LM 118 | loss 4.133e-10 | λ=1.1e-06 | accept
# LM 119 | loss 4.504e-10 | λ=3.3e-06 | reject
# LM 120 | loss 3.622e-10 | λ=2.3e-06 | accept
# LM 121 | loss 3.503e-10 | λ=1.6e-06 | accept
# LM 122 | loss 3.430e-10 | λ=1.1e-06 | accept
# LM 123 | loss 3.541e-10 | λ=3.4e-06 | reject
# LM 124 | loss 3.156e-10 | λ=2.4e-06 | accept
# LM 125 | loss 3.058e-10 | λ=1.7e-06 | accept
# LM 126 | loss 2.971e-10 | λ=1.2e-06 | accept
# LM 127 | loss 2.975e-10 | λ=3.5e-06 | reject
# LM 128 | loss 2.809e-10 | λ=2.5e-06 | accept
# LM 129 | loss 2.728e-10 | λ=1.7e-06 | accept
# LM 130 | loss 2.644e-10 | λ=1.2e-06 | accept
# LM 131 | loss 2.603e-10 | λ=8.5e-07 | accept
# LM 132 | loss 2.726e-10 | λ=2.5e-06 | reject
# LM 133 | loss 2.374e-10 | λ=1.8e-06 | accept
# LM 134 | loss 2.302e-10 | λ=1.2e-06 | accept
# LM 135 | loss 2.243e-10 | λ=8.7e-07 | accept
# LM 136 | loss 2.269e-10 | λ=2.6e-06 | reject
# LM 137 | loss 2.108e-10 | λ=1.8e-06 | accept
# LM 138 | loss 2.047e-10 | λ=1.3e-06 | accept
# LM 139 | loss 1.987e-10 | λ=9.0e-07 | accept
# LM 140 | loss 1.973e-10 | λ=6.3e-07 | accept
# LM 141 | loss 2.133e-10 | λ=1.9e-06 | reject
# LM 142 | loss 1.774e-10 | λ=1.3e-06 | accept
# LM 143 | loss 1.721e-10 | λ=9.3e-07 | accept
# LM 144 | loss 1.689e-10 | λ=6.5e-07 | accept
# LM 145 | loss 1.758e-10 | λ=1.9e-06 | reject
# LM 146 | loss 1.567e-10 | λ=1.4e-06 | accept
# LM 147 | loss 1.523e-10 | λ=9.5e-07 | accept
# LM 148 | loss 1.487e-10 | λ=6.7e-07 | accept
# LM 149 | loss 1.512e-10 | λ=2.0e-06 | reject
# LM 150 | loss 1.406e-10 | λ=1.4e-06 | accept
# LM 151 | loss 1.368e-10 | λ=9.8e-07 | accept
# LM 152 | loss 1.333e-10 | λ=6.9e-07 | accept
# LM 153 | loss 1.336e-10 | λ=2.1e-06 | reject
# LM 154 | loss 1.276e-10 | λ=1.4e-06 | accept
# LM 155 | loss 1.244e-10 | λ=1.0e-06 | accept
# LM 156 | loss 1.212e-10 | λ=7.1e-07 | accept
# LM 157 | loss 1.203e-10 | λ=4.9e-07 | accept
# LM 158 | loss 1.297e-10 | λ=1.5e-06 | reject
# LM 159 | loss 1.103e-10 | λ=1.0e-06 | accept
# LM 160 | loss 1.075e-10 | λ=7.3e-07 | accept
# LM 161 | loss 1.059e-10 | λ=5.1e-07 | accept
# LM 162 | loss 1.107e-10 | λ=1.5e-06 | reject
# LM 163 | loss 9.920e-11 | λ=1.1e-06 | accept
# LM 164 | loss 9.678e-11 | λ=7.5e-07 | accept
# LM 165 | loss 9.496e-11 | λ=5.2e-07 | accept
# LM 166 | loss 9.711e-11 | λ=1.6e-06 | reject
# LM 167 | loss 9.026e-11 | λ=1.1e-06 | accept
# LM 168 | loss 8.819e-11 | λ=7.7e-07 | accept
# LM 169 | loss 8.634e-11 | λ=5.4e-07 | accept
# LM 170 | loss 8.698e-11 | λ=1.6e-06 | reject
# LM 171 | loss 8.294e-11 | λ=1.1e-06 | accept
# LM 172 | loss 8.116e-11 | λ=7.9e-07 | accept
# LM 173 | loss 7.938e-11 | λ=5.5e-07 | accept
# LM 174 | loss 7.916e-11 | λ=3.9e-07 | accept
# LM 175 | loss 8.541e-11 | λ=1.2e-06 | reject
# LM 176 | loss 7.303e-11 | λ=8.1e-07 | accept
# LM 177 | loss 7.144e-11 | λ=5.7e-07 | accept
# LM 178 | loss 7.066e-11 | λ=4.0e-07 | accept
# LM 179 | loss 7.380e-11 | λ=1.2e-06 | reject
# LM 180 | loss 6.656e-11 | λ=8.4e-07 | accept
# LM 181 | loss 6.517e-11 | λ=5.9e-07 | accept
# LM 182 | loss 6.415e-11 | λ=4.1e-07 | accept
# LM 183 | loss 6.552e-11 | λ=1.2e-06 | reject
# LM 184 | loss 6.131e-11 | λ=8.6e-07 | accept
# LM 185 | loss 6.010e-11 | λ=6.0e-07 | accept
# LM 186 | loss 5.902e-11 | λ=4.2e-07 | accept
# LM 187 | loss 5.937e-11 | λ=1.3e-06 | reject
# LM 188 | loss 5.699e-11 | λ=8.9e-07 | accept
# LM 189 | loss 5.593e-11 | λ=6.2e-07 | accept
# LM 190 | loss 5.487e-11 | λ=4.3e-07 | accept
# LM 191 | loss 5.465e-11 | λ=3.0e-07 | accept
# LM 192 | loss 5.792e-11 | λ=9.1e-07 | reject
# LM 193 | loss 5.109e-11 | λ=6.4e-07 | accept
# LM 194 | loss 5.012e-11 | λ=4.5e-07 | accept
# LM 195 | loss 4.954e-11 | λ=3.1e-07 | accept
# LM 196 | loss 5.094e-11 | λ=9.4e-07 | reject
# LM 197 | loss 4.722e-11 | λ=6.6e-07 | accept
# LM 198 | loss 4.635e-11 | λ=4.6e-07 | accept
# LM 199 | loss 4.563e-11 | λ=3.2e-07 | accept
# LM 200 | loss 4.603e-11 | λ=9.7e-07 | reject
# LM 201 | loss 4.405e-11 | λ=6.8e-07 | accept
# LM 202 | loss 4.329e-11 | λ=4.7e-07 | accept
# LM 203 | loss 4.254e-11 | λ=3.3e-07 | accept
# LM 204 | loss 4.240e-11 | λ=2.3e-07 | accept
# LM 205 | loss 4.458e-11 | λ=7.0e-07 | reject
# LM 206 | loss 3.977e-11 | λ=4.9e-07 | accept
# LM 207 | loss 3.907e-11 | λ=3.4e-07 | accept
# LM 208 | loss 3.860e-11 | λ=2.4e-07 | accept
# LM 209 | loss 3.933e-11 | λ=7.2e-07 | reject
# LM 210 | loss 3.697e-11 | λ=5.0e-07 | accept
# LM 211 | loss 3.633e-11 | λ=3.5e-07 | accept
# LM 212 | loss 3.575e-11 | λ=2.5e-07 | accept
# LM 213 | loss 3.578e-11 | λ=7.4e-07 | reject
# LM 214 | loss 3.468e-11 | λ=5.2e-07 | accept
# LM 215 | loss 3.412e-11 | λ=3.6e-07 | accept
# LM 216 | loss 3.352e-11 | λ=2.5e-07 | accept
# LM 217 | loss 3.322e-11 | λ=1.8e-07 | accept
# LM 218 | loss 3.415e-11 | λ=5.3e-07 | reject
# LM 219 | loss 3.156e-11 | λ=3.7e-07 | accept
# LM 220 | loss 3.100e-11 | λ=2.6e-07 | accept
# LM 221 | loss 3.052e-11 | λ=1.8e-07 | accept
# LM 222 | loss 3.067e-11 | λ=5.5e-07 | reject
# LM 223 | loss 2.950e-11 | λ=3.8e-07 | accept
# LM 224 | loss 2.900e-11 | λ=2.7e-07 | accept
# LM 225 | loss 2.848e-11 | λ=1.9e-07 | accept
# LM 226 | loss 2.829e-11 | λ=1.3e-07 | accept
# LM 227 | loss 2.944e-11 | λ=3.9e-07 | reject
# LM 228 | loss 2.670e-11 | λ=2.8e-07 | accept
# LM 229 | loss 2.621e-11 | λ=1.9e-07 | accept
# LM 230 | loss 2.585e-11 | λ=1.4e-07 | accept
# LM 231 | loss 2.629e-11 | λ=4.1e-07 | reject
# LM 232 | loss 2.484e-11 | λ=2.8e-07 | accept
# LM 233 | loss 2.441e-11 | λ=2.0e-07 | accept
# LM 234 | loss 2.401e-11 | λ=1.4e-07 | accept
# LM 235 | loss 2.412e-11 | λ=4.2e-07 | reject
# LM 236 | loss 2.329e-11 | λ=2.9e-07 | accept
# LM 237 | loss 2.291e-11 | λ=2.0e-07 | accept
# LM 238 | loss 2.252e-11 | λ=1.4e-07 | accept
# LM 239 | loss 2.246e-11 | λ=1.0e-07 | accept
# LM 240 | loss 2.401e-11 | λ=3.0e-07 | reject
# LM 241 | loss 2.112e-11 | λ=2.1e-07 | accept
# LM 242 | loss 2.076e-11 | λ=1.5e-07 | accept
# LM 243 | loss 2.061e-11 | λ=1.0e-07 | accept
# LM 244 | loss 2.159e-11 | λ=3.1e-07 | reject
# LM 245 | loss 1.962e-11 | λ=2.2e-07 | accept
# LM 246 | loss 1.930e-11 | λ=1.5e-07 | accept
# LM 247 | loss 1.910e-11 | λ=1.1e-07 | accept
# LM 248 | loss 1.972e-11 | λ=3.2e-07 | reject
# LM 249 | loss 1.835e-11 | λ=2.2e-07 | accept
# LM 250 | loss 1.806e-11 | λ=1.6e-07 | accept
# LM 251 | loss 1.784e-11 | λ=1.1e-07 | accept
# LM 252 | loss 1.822e-11 | λ=3.3e-07 | reject
# LM 253 | loss 1.724e-11 | λ=2.3e-07 | accept
# LM 254 | loss 1.698e-11 | λ=1.6e-07 | accept
# LM 255 | loss 1.676e-11 | λ=1.1e-07 | accept
# LM 256 | loss 1.696e-11 | λ=3.4e-07 | reject
# LM 257 | loss 1.628e-11 | λ=2.4e-07 | accept
# LM 258 | loss 1.604e-11 | λ=1.7e-07 | accept
# LM 259 | loss 1.581e-11 | λ=1.2e-07 | accept
# LM 260 | loss 1.590e-11 | λ=3.5e-07 | reject
# LM 261 | loss 1.542e-11 | λ=2.4e-07 | accept
# LM 262 | loss 1.520e-11 | λ=1.7e-07 | accept
# LM 263 | loss 1.498e-11 | λ=1.2e-07 | accept
# LM 264 | loss 1.499e-11 | λ=3.6e-07 | reject
# LM 265 | loss 1.466e-11 | λ=2.5e-07 | accept
# LM 266 | loss 1.446e-11 | λ=1.7e-07 | accept
# LM 267 | loss 1.425e-11 | λ=1.2e-07 | accept
# LM 268 | loss 1.420e-11 | λ=8.6e-08 | accept
# LM 269 | loss 1.500e-11 | λ=2.6e-07 | reject
# LM 270 | loss 1.352e-11 | λ=1.8e-07 | accept
# LM 271 | loss 1.332e-11 | λ=1.3e-07 | accept
# LM 272 | loss 1.323e-11 | λ=8.8e-08 | accept
# LM 273 | loss 1.376e-11 | λ=2.6e-07 | reject
# LM 274 | loss 1.269e-11 | λ=1.8e-07 | accept
# LM 275 | loss 1.251e-11 | λ=1.3e-07 | accept
# LM 276 | loss 1.239e-11 | λ=9.1e-08 | accept
# LM 277 | loss 1.273e-11 | λ=2.7e-07 | reject
# LM 278 | loss 1.197e-11 | λ=1.9e-07 | accept
# LM 279 | loss 1.180e-11 | λ=1.3e-07 | accept
# LM 280 | loss 1.167e-11 | λ=9.3e-08 | accept
# LM 281 | loss 1.187e-11 | λ=2.8e-07 | reject
# LM 282 | loss 1.132e-11 | λ=2.0e-07 | accept
# LM 283 | loss 1.117e-11 | λ=1.4e-07 | accept
# LM 284 | loss 1.103e-11 | λ=9.6e-08 | accept
# LM 285 | loss 1.114e-11 | λ=2.9e-07 | reject
# LM 286 | loss 1.075e-11 | λ=2.0e-07 | accept
# LM 287 | loss 1.061e-11 | λ=1.4e-07 | accept
# LM 288 | loss 1.047e-11 | λ=9.9e-08 | accept
# LM 289 | loss 1.050e-11 | λ=3.0e-07 | reject
# LM 290 | loss 1.024e-11 | λ=2.1e-07 | accept
# LM 291 | loss 1.010e-11 | λ=1.5e-07 | accept
# LM 292 | loss 9.968e-12 | λ=1.0e-07 | accept
# LM 293 | loss 9.955e-12 | λ=7.1e-08 | accept
# LM 294 | loss 1.056e-11 | λ=2.1e-07 | reject
# LM 295 | loss 9.466e-12 | λ=1.5e-07 | accept
# LM 296 | loss 9.335e-12 | λ=1.0e-07 | accept
# LM 297 | loss 9.285e-12 | λ=7.3e-08 | accept
# LM 298 | loss 9.677e-12 | λ=2.2e-07 | reject
# LM 299 | loss 8.905e-12 | λ=1.5e-07 | accept
# LM 300 | loss 8.782e-12 | λ=1.1e-07 | accept
# LM 301 | loss 8.709e-12 | λ=7.5e-08 | accept
# LM 302 | loss 8.954e-12 | λ=2.3e-07 | reject
# LM 303 | loss 8.411e-12 | λ=1.6e-07 | accept
# LM 304 | loss 8.296e-12 | λ=1.1e-07 | accept
# LM 305 | loss 8.210e-12 | λ=7.8e-08 | accept
# LM 306 | loss 8.351e-12 | λ=2.3e-07 | reject
# LM 307 | loss 7.972e-12 | λ=1.6e-07 | accept
# LM 308 | loss 7.866e-12 | λ=1.1e-07 | accept
# LM 309 | loss 7.773e-12 | λ=8.0e-08 | accept
# LM 310 | loss 7.842e-12 | λ=2.4e-07 | reject
# LM 311 | loss 7.581e-12 | λ=1.7e-07 | accept
# LM 312 | loss 7.483e-12 | λ=1.2e-07 | accept
# LM 313 | loss 7.387e-12 | λ=8.2e-08 | accept
# LM 314 | loss 7.406e-12 | λ=2.5e-07 | reject
# LM 315 | loss 7.231e-12 | λ=1.7e-07 | accept
# LM 316 | loss 7.140e-12 | λ=1.2e-07 | accept
# LM 317 | loss 7.045e-12 | λ=8.4e-08 | accept
# LM 318 | loss 7.029e-12 | λ=5.9e-08 | accept
# LM 319 | loss 7.402e-12 | λ=1.8e-07 | reject
# LM 320 | loss 6.704e-12 | λ=1.2e-07 | accept
# LM 321 | loss 6.613e-12 | λ=8.7e-08 | accept
# LM 322 | loss 6.570e-12 | λ=6.1e-08 | accept
# LM 323 | loss 6.799e-12 | λ=1.8e-07 | reject
# LM 324 | loss 6.322e-12 | λ=1.3e-07 | accept
# LM 325 | loss 6.237e-12 | λ=8.9e-08 | accept
# LM 326 | loss 6.178e-12 | λ=6.3e-08 | accept
# LM 327 | loss 6.309e-12 | λ=1.9e-07 | reject
# LM 328 | loss 5.986e-12 | λ=1.3e-07 | accept
# LM 329 | loss 5.906e-12 | λ=9.2e-08 | accept
# LM 330 | loss 5.839e-12 | λ=6.4e-08 | accept
# LM 331 | loss 5.904e-12 | λ=1.9e-07 | reject
# LM 332 | loss 5.688e-12 | λ=1.4e-07 | accept
# LM 333 | loss 5.613e-12 | λ=9.5e-08 | accept
# LM 334 | loss 5.543e-12 | λ=6.6e-08 | accept
# LM 335 | loss 5.563e-12 | λ=2.0e-07 | reject
# LM 336 | loss 5.422e-12 | λ=1.4e-07 | accept
# LM 337 | loss 5.353e-12 | λ=9.7e-08 | accept
# LM 338 | loss 5.283e-12 | λ=6.8e-08 | accept
# LM 339 | loss 5.272e-12 | λ=4.8e-08 | accept
# LM 340 | loss 5.549e-12 | λ=1.4e-07 | reject
# LM 341 | loss 5.025e-12 | λ=1.0e-07 | accept
# LM 342 | loss 4.957e-12 | λ=7.0e-08 | accept
# LM 343 | loss 4.924e-12 | λ=4.9e-08 | accept
# LM 344 | loss 5.085e-12 | λ=1.5e-07 | reject
# LM 345 | loss 4.739e-12 | λ=1.0e-07 | accept
# LM 346 | loss 4.675e-12 | λ=7.2e-08 | accept
# LM 347 | loss 4.629e-12 | λ=5.1e-08 | accept
# LM 348 | loss 4.715e-12 | λ=1.5e-07 | reject
# LM 349 | loss 4.489e-12 | λ=1.1e-07 | accept
# LM 350 | loss 4.429e-12 | λ=7.4e-08 | accept
# LM 351 | loss 4.377e-12 | λ=5.2e-08 | accept
# LM 352 | loss 4.414e-12 | λ=1.6e-07 | reject
# LM 353 | loss 4.268e-12 | λ=1.1e-07 | accept
# LM 354 | loss 4.213e-12 | λ=7.6e-08 | accept
# LM 355 | loss 4.159e-12 | λ=5.4e-08 | accept
# LM 356 | loss 4.163e-12 | λ=1.6e-07 | reject
# LM 357 | loss 4.072e-12 | λ=1.1e-07 | accept
# LM 358 | loss 4.021e-12 | λ=7.9e-08 | accept
# LM 359 | loss 3.967e-12 | λ=5.5e-08 | accept
# LM 360 | loss 3.951e-12 | λ=3.9e-08 | accept
# LM 361 | loss 4.124e-12 | λ=1.2e-07 | reject
# LM 362 | loss 3.780e-12 | λ=8.1e-08 | accept
# LM 363 | loss 3.729e-12 | λ=5.7e-08 | accept
# LM 364 | loss 3.698e-12 | λ=4.0e-08 | accept
# LM 365 | loss 3.793e-12 | λ=1.2e-07 | reject
# LM 366 | loss 3.571e-12 | λ=8.3e-08 | accept
# LM 367 | loss 3.523e-12 | λ=5.8e-08 | accept
# LM 368 | loss 3.485e-12 | λ=4.1e-08 | accept
# LM 369 | loss 3.531e-12 | λ=1.2e-07 | reject
# LM 370 | loss 3.389e-12 | λ=8.6e-08 | accept
# LM 371 | loss 3.344e-12 | λ=6.0e-08 | accept
# LM 372 | loss 3.303e-12 | λ=4.2e-08 | accept
# LM 373 | loss 3.318e-12 | λ=1.3e-07 | reject
# LM 374 | loss 3.228e-12 | λ=8.8e-08 | accept
# LM 375 | loss 3.187e-12 | λ=6.2e-08 | accept
# LM 376 | loss 3.146e-12 | λ=4.3e-08 | accept
# LM 377 | loss 3.140e-12 | λ=3.0e-08 | accept
# LM 378 | loss 3.306e-12 | λ=9.1e-08 | reject
# LM 379 | loss 2.992e-12 | λ=6.4e-08 | accept
# LM 380 | loss 2.951e-12 | λ=4.4e-08 | accept
# LM 381 | loss 2.932e-12 | λ=3.1e-08 | accept
# LM 382 | loss 3.026e-12 | λ=9.3e-08 | reject
# LM 383 | loss 2.823e-12 | λ=6.5e-08 | accept
# LM 384 | loss 2.786e-12 | λ=4.6e-08 | accept
# LM 385 | loss 2.759e-12 | λ=3.2e-08 | accept
# LM 386 | loss 2.809e-12 | λ=9.6e-08 | reject
# LM 387 | loss 2.677e-12 | λ=6.7e-08 | accept
# LM 388 | loss 2.642e-12 | λ=4.7e-08 | accept
# LM 389 | loss 2.612e-12 | λ=3.3e-08 | accept
# LM 390 | loss 2.634e-12 | λ=9.9e-08 | reject
# LM 391 | loss 2.549e-12 | λ=6.9e-08 | accept
# LM 392 | loss 2.517e-12 | λ=4.8e-08 | accept
# LM 393 | loss 2.486e-12 | λ=3.4e-08 | accept
# LM 394 | loss 2.490e-12 | λ=1.0e-07 | reject
# LM 395 | loss 2.436e-12 | λ=7.1e-08 | accept
# LM 396 | loss 2.407e-12 | λ=5.0e-08 | accept
# LM 397 | loss 2.376e-12 | λ=3.5e-08 | accept
# LM 398 | loss 2.368e-12 | λ=2.4e-08 | accept
# LM 399 | loss 2.475e-12 | λ=7.3e-08 | reject
# LM 400 | loss 2.269e-12 | λ=5.1e-08 | accept
# LM 401 | loss 2.240e-12 | λ=3.6e-08 | accept
# LM 402 | loss 2.224e-12 | λ=2.5e-08 | accept
# LM 403 | loss 2.286e-12 | λ=7.5e-08 | reject
# LM 404 | loss 2.150e-12 | λ=5.3e-08 | accept
# LM 405 | loss 2.123e-12 | λ=3.7e-08 | accept
# LM 406 | loss 2.103e-12 | λ=2.6e-08 | accept
# LM 407 | loss 2.136e-12 | λ=7.8e-08 | reject
# LM 408 | loss 2.046e-12 | λ=5.4e-08 | accept
# LM 409 | loss 2.021e-12 | λ=3.8e-08 | accept
# LM 410 | loss 1.999e-12 | λ=2.7e-08 | accept
# LM 411 | loss 2.014e-12 | λ=8.0e-08 | reject
# LM 412 | loss 1.954e-12 | λ=5.6e-08 | accept
# LM 413 | loss 1.931e-12 | λ=3.9e-08 | accept
# LM 414 | loss 1.909e-12 | λ=2.7e-08 | accept
# LM 415 | loss 1.912e-12 | λ=8.2e-08 | reject
# LM 416 | loss 1.873e-12 | λ=5.8e-08 | accept
# LM 417 | loss 1.852e-12 | λ=4.0e-08 | accept
# LM 418 | loss 1.830e-12 | λ=2.8e-08 | accept
# LM 419 | loss 1.826e-12 | λ=2.0e-08 | accept
# LM 420 | loss 1.911e-12 | λ=5.9e-08 | reject
# LM 421 | loss 1.752e-12 | λ=4.1e-08 | accept
# LM 422 | loss 1.731e-12 | λ=2.9e-08 | accept
# LM 423 | loss 1.721e-12 | λ=2.0e-08 | accept
# LM 424 | loss 1.775e-12 | λ=6.1e-08 | reject
# LM 425 | loss 1.665e-12 | λ=4.3e-08 | accept
# LM 426 | loss 1.645e-12 | λ=3.0e-08 | accept
# LM 427 | loss 1.632e-12 | λ=2.1e-08 | accept
# LM 428 | loss 1.665e-12 | λ=6.3e-08 | reject
# LM 429 | loss 1.588e-12 | λ=4.4e-08 | accept
# LM 430 | loss 1.570e-12 | λ=3.1e-08 | accept
# LM 431 | loss 1.556e-12 | λ=2.1e-08 | accept
# LM 432 | loss 1.575e-12 | λ=6.4e-08 | reject
# LM 433 | loss 1.521e-12 | λ=4.5e-08 | accept
# LM 434 | loss 1.504e-12 | λ=3.2e-08 | accept
# LM 435 | loss 1.489e-12 | λ=2.2e-08 | accept
# LM 436 | loss 1.498e-12 | λ=6.6e-08 | reject
# LM 437 | loss 1.460e-12 | λ=4.6e-08 | accept
# LM 438 | loss 1.445e-12 | λ=3.3e-08 | accept
# LM 439 | loss 1.430e-12 | λ=2.3e-08 | accept
# LM 440 | loss 1.432e-12 | λ=6.8e-08 | reject
# LM 441 | loss 1.406e-12 | λ=4.8e-08 | accept
# LM 442 | loss 1.392e-12 | λ=3.3e-08 | accept
# LM 443 | loss 1.377e-12 | λ=2.3e-08 | accept
# LM 444 | loss 1.375e-12 | λ=1.6e-08 | accept
# LM 445 | loss 1.440e-12 | λ=4.9e-08 | reject
# LM 446 | loss 1.324e-12 | λ=3.4e-08 | accept
# LM 447 | loss 1.309e-12 | λ=2.4e-08 | accept
# LM 448 | loss 1.304e-12 | λ=1.7e-08 | accept
# LM 449 | loss 1.350e-12 | λ=5.1e-08 | reject
# LM 450 | loss 1.263e-12 | λ=3.5e-08 | accept
# LM 451 | loss 1.250e-12 | λ=2.5e-08 | accept
# LM 452 | loss 1.243e-12 | λ=1.7e-08 | accept
# LM 453 | loss 1.274e-12 | λ=5.2e-08 | reject
# LM 454 | loss 1.210e-12 | λ=3.6e-08 | accept
# LM 455 | loss 1.198e-12 | λ=2.6e-08 | accept
# LM 456 | loss 1.189e-12 | λ=1.8e-08 | accept
# LM 457 | loss 1.210e-12 | λ=5.4e-08 | reject
# LM 458 | loss 1.162e-12 | λ=3.8e-08 | accept
# LM 459 | loss 1.150e-12 | λ=2.6e-08 | accept
# LM 460 | loss 1.141e-12 | λ=1.8e-08 | accept
# LM 461 | loss 1.155e-12 | λ=5.5e-08 | reject
# LM 462 | loss 1.118e-12 | λ=3.9e-08 | accept
# LM 463 | loss 1.108e-12 | λ=2.7e-08 | accept
# LM 464 | loss 1.098e-12 | λ=1.9e-08 | accept
# LM 465 | loss 1.107e-12 | λ=5.7e-08 | reject
# LM 466 | loss 1.079e-12 | λ=4.0e-08 | accept
# LM 467 | loss 1.069e-12 | λ=2.8e-08 | accept
# LM 468 | loss 1.060e-12 | λ=1.9e-08 | accept
# LM 469 | loss 1.064e-12 | λ=5.8e-08 | reject
# LM 470 | loss 1.043e-12 | λ=4.1e-08 | accept
# LM 471 | loss 1.034e-12 | λ=2.9e-08 | accept
# LM 472 | loss 1.025e-12 | λ=2.0e-08 | accept
# LM 473 | loss 1.026e-12 | λ=6.0e-08 | reject
# LM 474 | loss 1.010e-12 | λ=4.2e-08 | accept
# LM 475 | loss 1.002e-12 | λ=2.9e-08 | accept
# LM 476 | loss 9.927e-13 | λ=2.1e-08 | accept
# LM 477 | loss 9.918e-13 | λ=1.4e-08 | accept
# LM 478 | loss 1.035e-12 | λ=4.3e-08 | reject
# LM 479 | loss 9.599e-13 | λ=3.0e-08 | accept
# LM 480 | loss 9.512e-13 | λ=2.1e-08 | accept
# LM 481 | loss 9.485e-13 | λ=1.5e-08 | accept
# LM 482 | loss 9.804e-13 | λ=4.5e-08 | reject
# LM 483 | loss 9.220e-13 | λ=3.1e-08 | accept
# LM 484 | loss 9.138e-13 | λ=2.2e-08 | accept
# LM 485 | loss 9.099e-13 | λ=1.5e-08 | accept
# LM 486 | loss 9.333e-13 | λ=4.6e-08 | reject
# LM 487 | loss 8.878e-13 | λ=3.2e-08 | accept
# LM 488 | loss 8.800e-13 | λ=2.2e-08 | accept
# LM 489 | loss 8.752e-13 | λ=1.6e-08 | accept
# LM 490 | loss 8.922e-13 | λ=4.7e-08 | reject
# LM 491 | loss 8.566e-13 | λ=3.3e-08 | accept
# LM 492 | loss 8.493e-13 | λ=2.3e-08 | accept
# LM 493 | loss 8.440e-13 | λ=1.6e-08 | accept
# LM 494 | loss 8.558e-13 | λ=4.9e-08 | reject
# LM 495 | loss 8.282e-13 | λ=3.4e-08 | accept
# LM 496 | loss 8.212e-13 | λ=2.4e-08 | accept
# LM 497 | loss 8.156e-13 | λ=1.7e-08 | accept
# LM 498 | loss 8.235e-13 | λ=5.0e-08 | reject
# LM 499 | loss 8.021e-13 | λ=3.5e-08 | accept
# LM 500 | loss 7.955e-13 | λ=2.4e-08 | accept
# LM 501 | loss 7.897e-13 | λ=1.7e-08 | accept
# LM 502 | loss 7.946e-13 | λ=5.1e-08 | reject
# LM 503 | loss 7.781e-13 | λ=3.6e-08 | accept
# LM 504 | loss 7.719e-13 | λ=2.5e-08 | accept
# LM 505 | loss 7.660e-13 | λ=1.8e-08 | accept
# LM 506 | loss 7.685e-13 | λ=5.3e-08 | reject
# LM 507 | loss 7.559e-13 | λ=3.7e-08 | accept
# LM 508 | loss 7.501e-13 | λ=2.6e-08 | accept
# LM 509 | loss 7.443e-13 | λ=1.8e-08 | accept
# LM 510 | loss 7.449e-13 | λ=5.4e-08 | reject
# LM 511 | loss 7.355e-13 | λ=3.8e-08 | accept
# LM 512 | loss 7.300e-13 | λ=2.7e-08 | accept
# LM 513 | loss 7.242e-13 | λ=1.9e-08 | accept
# LM 514 | loss 7.234e-13 | λ=1.3e-08 | accept
# LM 515 | loss 7.500e-13 | λ=3.9e-08 | reject
# LM 516 | loss 7.035e-13 | λ=2.7e-08 | accept
# LM 517 | loss 6.979e-13 | λ=1.9e-08 | accept
# LM 518 | loss 6.959e-13 | λ=1.3e-08 | accept
# LM 519 | loss 7.155e-13 | λ=4.0e-08 | reject
# LM 520 | loss 6.792e-13 | λ=2.8e-08 | accept
# LM 521 | loss 6.739e-13 | λ=2.0e-08 | accept
# LM 522 | loss 6.711e-13 | λ=1.4e-08 | accept
# LM 523 | loss 6.853e-13 | λ=4.1e-08 | reject
# LM 524 | loss 6.571e-13 | λ=2.9e-08 | accept
# LM 525 | loss 6.520e-13 | λ=2.0e-08 | accept
# LM 526 | loss 6.486e-13 | λ=1.4e-08 | accept
# LM 527 | loss 6.586e-13 | λ=4.3e-08 | reject
# LM 528 | loss 6.368e-13 | λ=3.0e-08 | accept
# LM 529 | loss 6.319e-13 | λ=2.1e-08 | accept
# LM 530 | loss 6.282e-13 | λ=1.5e-08 | accept
# LM 531 | loss 6.348e-13 | λ=4.4e-08 | reject
# LM 532 | loss 6.181e-13 | λ=3.1e-08 | accept
# LM 533 | loss 6.135e-13 | λ=2.2e-08 | accept
# LM 534 | loss 6.095e-13 | λ=1.5e-08 | accept
# LM 535 | loss 6.136e-13 | λ=4.5e-08 | reject
# LM 536 | loss 6.009e-13 | λ=3.2e-08 | accept
# LM 537 | loss 5.965e-13 | λ=2.2e-08 | accept
# LM 538 | loss 5.923e-13 | λ=1.6e-08 | accept
# LM 539 | loss 5.945e-13 | λ=4.7e-08 | reject
# LM 540 | loss 5.849e-13 | λ=3.3e-08 | accept
# LM 541 | loss 5.807e-13 | λ=2.3e-08 | accept
# LM 542 | loss 5.766e-13 | λ=1.6e-08 | accept
# LM 543 | loss 5.772e-13 | λ=4.8e-08 | reject
# LM 544 | loss 5.701e-13 | λ=3.4e-08 | accept
# LM 545 | loss 5.662e-13 | λ=2.3e-08 | accept
# LM 546 | loss 5.620e-13 | λ=1.6e-08 | accept
# LM 547 | loss 5.615e-13 | λ=1.1e-08 | accept
# LM 548 | loss 5.806e-13 | λ=3.4e-08 | reject
# LM 549 | loss 5.469e-13 | λ=2.4e-08 | accept
# LM 550 | loss 5.429e-13 | λ=1.7e-08 | accept
# LM 551 | loss 5.414e-13 | λ=1.2e-08 | accept
# LM 552 | loss 5.550e-13 | λ=3.5e-08 | reject
# LM 553 | loss 5.294e-13 | λ=2.5e-08 | accept
# LM 554 | loss 5.254e-13 | λ=1.7e-08 | accept
# LM 555 | loss 5.233e-13 | λ=1.2e-08 | accept
# LM 556 | loss 5.328e-13 | λ=3.7e-08 | reject
# LM 557 | loss 5.133e-13 | λ=2.6e-08 | accept
# LM 558 | loss 5.095e-13 | λ=1.8e-08 | accept
# LM 559 | loss 5.068e-13 | λ=1.3e-08 | accept
# LM 560 | loss 5.132e-13 | λ=3.8e-08 | reject
# LM 561 | loss 4.984e-13 | λ=2.6e-08 | accept
# LM 562 | loss 4.948e-13 | λ=1.8e-08 | accept
# LM 563 | loss 4.919e-13 | λ=1.3e-08 | accept
# LM 564 | loss 4.958e-13 | λ=3.9e-08 | reject
# LM 565 | loss 4.848e-13 | λ=2.7e-08 | accept
# LM 566 | loss 4.814e-13 | λ=1.9e-08 | accept
# LM 567 | loss 4.782e-13 | λ=1.3e-08 | accept
# LM 568 | loss 4.803e-13 | λ=4.0e-08 | reject
# LM 569 | loss 4.722e-13 | λ=2.8e-08 | accept
# LM 570 | loss 4.689e-13 | λ=1.9e-08 | accept
# LM 571 | loss 4.657e-13 | λ=1.4e-08 | accept
# LM 572 | loss 4.664e-13 | λ=4.1e-08 | reject
# LM 573 | loss 4.605e-13 | λ=2.9e-08 | accept
# LM 574 | loss 4.574e-13 | λ=2.0e-08 | accept
# LM 575 | loss 4.542e-13 | λ=1.4e-08 | accept
# LM 576 | loss 4.538e-13 | λ=9.8e-09 | accept
# LM 577 | loss 4.688e-13 | λ=2.9e-08 | reject
# LM 578 | loss 4.422e-13 | λ=2.1e-08 | accept
# LM 579 | loss 4.390e-13 | λ=1.4e-08 | accept
# LM 580 | loss 4.378e-13 | λ=1.0e-08 | accept
# LM 581 | loss 4.481e-13 | λ=3.0e-08 | reject
# LM 582 | loss 4.284e-13 | λ=2.1e-08 | accept
# LM 583 | loss 4.253e-13 | λ=1.5e-08 | accept
# LM 584 | loss 4.235e-13 | λ=1.0e-08 | accept
# LM 585 | loss 4.303e-13 | λ=3.1e-08 | reject
# LM 586 | loss 4.157e-13 | λ=2.2e-08 | accept
# LM 587 | loss 4.127e-13 | λ=1.5e-08 | accept
# LM 588 | loss 4.105e-13 | λ=1.1e-08 | accept
# LM 589 | loss 4.148e-13 | λ=3.2e-08 | reject
# LM 590 | loss 4.041e-13 | λ=2.2e-08 | accept
# LM 591 | loss 4.012e-13 | λ=1.6e-08 | accept
# LM 592 | loss 3.988e-13 | λ=1.1e-08 | accept
# LM 593 | loss 4.012e-13 | λ=3.3e-08 | reject
# LM 594 | loss 3.934e-13 | λ=2.3e-08 | accept
# LM 595 | loss 3.907e-13 | λ=1.6e-08 | accept
# LM 596 | loss 3.881e-13 | λ=1.1e-08 | accept
# LM 597 | loss 3.890e-13 | λ=3.4e-08 | reject
# LM 598 | loss 3.835e-13 | λ=2.4e-08 | accept
# LM 599 | loss 3.809e-13 | λ=1.7e-08 | accept
# LM 600 | loss 3.783e-13 | λ=1.2e-08 | accept
# LM 601 | loss 3.782e-13 | λ=8.2e-09 | accept
# LM 602 | loss 3.911e-13 | λ=2.4e-08 | reject
# LM 603 | loss 3.682e-13 | λ=1.7e-08 | accept
# LM 604 | loss 3.655e-13 | λ=1.2e-08 | accept
# LM 605 | loss 3.646e-13 | λ=8.4e-09 | accept
# LM 606 | loss 3.731e-13 | λ=2.5e-08 | reject
# LM 607 | loss 3.566e-13 | λ=1.8e-08 | accept
# LM 608 | loss 3.540e-13 | λ=1.2e-08 | accept
# LM 609 | loss 3.524e-13 | λ=8.6e-09 | accept
# LM 610 | loss 3.578e-13 | λ=2.6e-08 | reject
# LM 611 | loss 3.460e-13 | λ=1.8e-08 | accept
# LM 612 | loss 3.435e-13 | λ=1.3e-08 | accept
# LM 613 | loss 3.416e-13 | λ=8.9e-09 | accept
# LM 614 | loss 3.447e-13 | λ=2.7e-08 | reject
# LM 615 | loss 3.363e-13 | λ=1.9e-08 | accept
# LM 616 | loss 3.339e-13 | λ=1.3e-08 | accept
# LM 617 | loss 3.318e-13 | λ=9.2e-09 | accept
# LM 618 | loss 3.333e-13 | λ=2.7e-08 | reject
# LM 619 | loss 3.274e-13 | λ=1.9e-08 | accept
# LM 620 | loss 3.252e-13 | λ=1.3e-08 | accept
# LM 621 | loss 3.229e-13 | λ=9.4e-09 | accept
# LM 622 | loss 3.232e-13 | λ=2.8e-08 | reject
# LM 623 | loss 3.193e-13 | λ=2.0e-08 | accept
# LM 624 | loss 3.171e-13 | λ=1.4e-08 | accept
# LM 625 | loss 3.148e-13 | λ=9.7e-09 | accept
# LM 626 | loss 3.143e-13 | λ=6.8e-09 | accept
# LM 627 | loss 3.230e-13 | λ=2.0e-08 | reject
# LM 628 | loss 3.066e-13 | λ=1.4e-08 | accept
# LM 629 | loss 3.043e-13 | λ=1.0e-08 | accept
# LM 630 | loss 3.031e-13 | λ=7.0e-09 | accept
# LM 631 | loss 3.085e-13 | λ=2.1e-08 | reject
# LM 632 | loss 2.971e-13 | λ=1.5e-08 | accept
# LM 633 | loss 2.949e-13 | λ=1.0e-08 | accept
# LM 634 | loss 2.933e-13 | λ=7.2e-09 | accept
# LM 635 | loss 2.963e-13 | λ=2.2e-08 | reject
# LM 636 | loss 2.884e-13 | λ=1.5e-08 | accept
# LM 637 | loss 2.863e-13 | λ=1.1e-08 | accept
# LM 638 | loss 2.845e-13 | λ=7.4e-09 | accept
# LM 639 | loss 2.858e-13 | λ=2.2e-08 | reject
# LM 640 | loss 2.806e-13 | λ=1.6e-08 | accept
# LM 641 | loss 2.785e-13 | λ=1.1e-08 | accept
# LM 642 | loss 2.766e-13 | λ=7.6e-09 | accept
# LM 643 | loss 2.768e-13 | λ=2.3e-08 | reject
# LM 644 | loss 2.733e-13 | λ=1.6e-08 | accept
# LM 645 | loss 2.714e-13 | λ=1.1e-08 | accept
# LM 646 | loss 2.694e-13 | λ=7.8e-09 | accept
# LM 647 | loss 2.689e-13 | λ=5.5e-09 | accept
# LM 648 | loss 2.760e-13 | λ=1.6e-08 | reject
# LM 649 | loss 2.622e-13 | λ=1.2e-08 | accept
# LM 650 | loss 2.602e-13 | λ=8.1e-09 | accept
# LM 651 | loss 2.590e-13 | λ=5.6e-09 | accept
# LM 652 | loss 2.632e-13 | λ=1.7e-08 | reject
# LM 653 | loss 2.539e-13 | λ=1.2e-08 | accept
# LM 654 | loss 2.520e-13 | λ=8.3e-09 | accept
# LM 655 | loss 2.504e-13 | λ=5.8e-09 | accept
# LM 656 | loss 2.526e-13 | λ=1.7e-08 | reject
# LM 657 | loss 2.464e-13 | λ=1.2e-08 | accept
# LM 658 | loss 2.445e-13 | λ=8.5e-09 | accept
# LM 659 | loss 2.428e-13 | λ=6.0e-09 | accept
# LM 660 | loss 2.437e-13 | λ=1.8e-08 | reject
# LM 661 | loss 2.396e-13 | λ=1.3e-08 | accept
# LM 662 | loss 2.378e-13 | λ=8.8e-09 | accept
# LM 663 | loss 2.361e-13 | λ=6.1e-09 | accept
# LM 664 | loss 2.360e-13 | λ=4.3e-09 | accept
# LM 665 | loss 2.442e-13 | λ=1.3e-08 | reject
# LM 666 | loss 2.292e-13 | λ=9.0e-09 | accept
# LM 667 | loss 2.274e-13 | λ=6.3e-09 | accept
# LM 668 | loss 2.267e-13 | λ=4.4e-09 | accept
# LM 669 | loss 2.318e-13 | λ=1.3e-08 | reject
# LM 670 | loss 2.215e-13 | λ=9.3e-09 | accept
# LM 671 | loss 2.198e-13 | λ=6.5e-09 | accept
# LM 672 | loss 2.187e-13 | λ=4.6e-09 | accept
# LM 673 | loss 2.217e-13 | λ=1.4e-08 | reject
# LM 674 | loss 2.146e-13 | λ=9.6e-09 | accept
# LM 675 | loss 2.130e-13 | λ=6.7e-09 | accept
# LM 676 | loss 2.117e-13 | λ=4.7e-09 | accept
# LM 677 | loss 2.134e-13 | λ=1.4e-08 | reject
# LM 678 | loss 2.084e-13 | λ=9.8e-09 | accept
# LM 679 | loss 2.069e-13 | λ=6.9e-09 | accept
# LM 680 | loss 2.055e-13 | λ=4.8e-09 | accept
# LM 681 | loss 2.063e-13 | λ=1.4e-08 | reject
# LM 682 | loss 2.028e-13 | λ=1.0e-08 | accept
# LM 683 | loss 2.014e-13 | λ=7.1e-09 | accept
# LM 684 | loss 2.000e-13 | λ=5.0e-09 | accept
# LM 685 | loss 2.002e-13 | λ=1.5e-08 | reject
# LM 686 | loss 1.977e-13 | λ=1.0e-08 | accept
# LM 687 | loss 1.964e-13 | λ=7.3e-09 | accept
# LM 688 | loss 1.950e-13 | λ=5.1e-09 | accept
# LM 689 | loss 1.948e-13 | λ=3.6e-09 | accept
# LM 690 | loss 2.013e-13 | λ=1.1e-08 | reject
# LM 691 | loss 1.899e-13 | λ=7.5e-09 | accept
# LM 692 | loss 1.886e-13 | λ=5.3e-09 | accept
# LM 693 | loss 1.882e-13 | λ=3.7e-09 | accept
# LM 694 | loss 1.929e-13 | λ=1.1e-08 | reject
# LM 695 | loss 1.842e-13 | λ=7.7e-09 | accept
# LM 696 | loss 1.829e-13 | λ=5.4e-09 | accept
# LM 697 | loss 1.823e-13 | λ=3.8e-09 | accept
# LM 698 | loss 1.859e-13 | λ=1.1e-08 | reject
# LM 699 | loss 1.790e-13 | λ=7.9e-09 | accept
# LM 700 | loss 1.778e-13 | λ=5.6e-09 | accept
# LM 701 | loss 1.771e-13 | λ=3.9e-09 | accept
# LM 702 | loss 1.798e-13 | λ=1.2e-08 | reject
# LM 703 | loss 1.743e-13 | λ=8.2e-09 | accept
# LM 704 | loss 1.732e-13 | λ=5.7e-09 | accept
# LM 705 | loss 1.725e-13 | λ=4.0e-09 | accept
# LM 706 | loss 1.744e-13 | λ=1.2e-08 | reject
# LM 707 | loss 1.701e-13 | λ=8.4e-09 | accept
# LM 708 | loss 1.691e-13 | λ=5.9e-09 | accept
# LM 709 | loss 1.683e-13 | λ=4.1e-09 | accept
# LM 710 | loss 1.697e-13 | λ=1.2e-08 | reject
# LM 711 | loss 1.662e-13 | λ=8.7e-09 | accept
# LM 712 | loss 1.653e-13 | λ=6.1e-09 | accept
# LM 713 | loss 1.645e-13 | λ=4.2e-09 | accept
# LM 714 | loss 1.655e-13 | λ=1.3e-08 | reject
# LM 715 | loss 1.627e-13 | λ=8.9e-09 | accept
# LM 716 | loss 1.618e-13 | λ=6.2e-09 | accept
# LM 717 | loss 1.610e-13 | λ=4.4e-09 | accept
# LM 718 | loss 1.617e-13 | λ=1.3e-08 | reject
# LM 719 | loss 1.595e-13 | λ=9.2e-09 | accept
# LM 720 | loss 1.587e-13 | λ=6.4e-09 | accept
# LM 721 | loss 1.579e-13 | λ=4.5e-09 | accept
# LM 722 | loss 1.583e-13 | λ=1.3e-08 | reject
# LM 723 | loss 1.565e-13 | λ=9.4e-09 | accept
# LM 724 | loss 1.558e-13 | λ=6.6e-09 | accept
# LM 725 | loss 1.550e-13 | λ=4.6e-09 | accept
# LM 726 | loss 1.552e-13 | λ=1.4e-08 | reject
# LM 727 | loss 1.538e-13 | λ=9.7e-09 | accept
# LM 728 | loss 1.531e-13 | λ=6.8e-09 | accept
# LM 729 | loss 1.523e-13 | λ=4.8e-09 | accept
# LM 730 | loss 1.524e-13 | λ=1.4e-08 | reject
# LM 731 | loss 1.513e-13 | λ=1.0e-08 | accept
# LM 732 | loss 1.506e-13 | λ=7.0e-09 | accept
# LM 733 | loss 1.499e-13 | λ=4.9e-09 | accept
# LM 734 | loss 1.498e-13 | λ=3.4e-09 | accept
# LM 735 | loss 1.534e-13 | λ=1.0e-08 | reject
# LM 736 | loss 1.473e-13 | λ=7.2e-09 | accept
# LM 737 | loss 1.466e-13 | λ=5.0e-09 | accept
# LM 738 | loss 1.465e-13 | λ=3.5e-09 | accept
# LM 739 | loss 1.493e-13 | λ=1.1e-08 | reject
# LM 740 | loss 1.443e-13 | λ=7.4e-09 | accept
# LM 741 | loss 1.437e-13 | λ=5.2e-09 | accept
# LM 742 | loss 1.434e-13 | λ=3.6e-09 | accept
# LM 743 | loss 1.457e-13 | λ=1.1e-08 | reject
# LM 744 | loss 1.416e-13 | λ=7.6e-09 | accept
# LM 745 | loss 1.410e-13 | λ=5.3e-09 | accept
# LM 746 | loss 1.407e-13 | λ=3.7e-09 | accept
# LM 747 | loss 1.424e-13 | λ=1.1e-08 | reject
# LM 748 | loss 1.391e-13 | λ=7.8e-09 | accept
# LM 749 | loss 1.385e-13 | λ=5.5e-09 | accept
# LM 750 | loss 1.382e-13 | λ=3.8e-09 | accept
# LM 751 | loss 1.395e-13 | λ=1.2e-08 | reject
# LM 752 | loss 1.368e-13 | λ=8.1e-09 | accept
# LM 753 | loss 1.362e-13 | λ=5.6e-09 | accept
# LM 754 | loss 1.359e-13 | λ=4.0e-09 | accept
# LM 755 | loss 1.369e-13 | λ=1.2e-08 | reject
# LM 756 | loss 1.347e-13 | λ=8.3e-09 | accept
# LM 757 | loss 1.341e-13 | λ=5.8e-09 | accept
# LM 758 | loss 1.337e-13 | λ=4.1e-09 | accept
# LM 759 | loss 1.345e-13 | λ=1.2e-08 | reject
# LM 760 | loss 1.327e-13 | λ=8.5e-09 | accept
# LM 761 | loss 1.322e-13 | λ=6.0e-09 | accept
# LM 762 | loss 1.318e-13 | λ=4.2e-09 | accept
# LM 763 | loss 1.323e-13 | λ=1.3e-08 | reject
# LM 764 | loss 1.309e-13 | λ=8.8e-09 | accept
# LM 765 | loss 1.304e-13 | λ=6.2e-09 | accept
# LM 766 | loss 1.300e-13 | λ=4.3e-09 | accept
# LM 767 | loss 1.303e-13 | λ=1.3e-08 | reject
# LM 768 | loss 1.292e-13 | λ=9.0e-09 | accept
# LM 769 | loss 1.287e-13 | λ=6.3e-09 | accept
# LM 770 | loss 1.283e-13 | λ=4.4e-09 | accept
# LM 771 | loss 1.285e-13 | λ=1.3e-08 | reject
# LM 772 | loss 1.276e-13 | λ=9.3e-09 | accept
# LM 773 | loss 1.272e-13 | λ=6.5e-09 | accept
# LM 774 | loss 1.267e-13 | λ=4.6e-09 | accept
# LM 775 | loss 1.268e-13 | λ=1.4e-08 | reject
# LM 776 | loss 1.261e-13 | λ=9.6e-09 | accept
# LM 777 | loss 1.257e-13 | λ=6.7e-09 | accept
# LM 778 | loss 1.253e-13 | λ=4.7e-09 | accept
# LM 779 | loss 1.253e-13 | λ=3.3e-09 | accept
# LM 780 | loss 1.275e-13 | λ=9.9e-09 | reject
# LM 781 | loss 1.238e-13 | λ=6.9e-09 | accept
# LM 782 | loss 1.234e-13 | λ=4.8e-09 | accept
# LM 783 | loss 1.233e-13 | λ=3.4e-09 | accept
# LM 784 | loss 1.250e-13 | λ=1.0e-08 | reject
# LM 785 | loss 1.220e-13 | λ=7.1e-09 | accept
# LM 786 | loss 1.216e-13 | λ=5.0e-09 | accept
# LM 787 | loss 1.214e-13 | λ=3.5e-09 | accept
# LM 788 | loss 1.228e-13 | λ=1.0e-08 | reject
# LM 789 | loss 1.203e-13 | λ=7.3e-09 | accept
# LM 790 | loss 1.200e-13 | λ=5.1e-09 | accept
# LM 791 | loss 1.198e-13 | λ=3.6e-09 | accept
# LM 792 | loss 1.208e-13 | λ=1.1e-08 | reject
# LM 793 | loss 1.188e-13 | λ=7.5e-09 | accept
# LM 794 | loss 1.184e-13 | λ=5.3e-09 | accept
# LM 795 | loss 1.182e-13 | λ=3.7e-09 | accept
# LM 796 | loss 1.190e-13 | λ=1.1e-08 | reject
# LM 797 | loss 1.174e-13 | λ=7.7e-09 | accept
# LM 798 | loss 1.170e-13 | λ=5.4e-09 | accept
# LM 799 | loss 1.168e-13 | λ=3.8e-09 | accept
# LM 800 | loss 1.174e-13 | λ=1.1e-08 | reject
# LM 801 | loss 1.160e-13 | λ=8.0e-09 | accept
# LM 802 | loss 1.157e-13 | λ=5.6e-09 | accept
# LM 803 | loss 1.155e-13 | λ=3.9e-09 | accept
# LM 804 | loss 1.159e-13 | λ=1.2e-08 | reject
# LM 805 | loss 1.148e-13 | λ=8.2e-09 | accept
# LM 806 | loss 1.145e-13 | λ=5.7e-09 | accept
# LM 807 | loss 1.142e-13 | λ=4.0e-09 | accept
# LM 808 | loss 1.145e-13 | λ=1.2e-08 | reject
# LM 809 | loss 1.137e-13 | λ=8.4e-09 | accept
# LM 810 | loss 1.134e-13 | λ=5.9e-09 | accept
# LM 811 | loss 1.131e-13 | λ=4.1e-09 | accept
# LM 812 | loss 1.132e-13 | λ=1.2e-08 | reject
# LM 813 | loss 1.126e-13 | λ=8.7e-09 | accept
# LM 814 | loss 1.123e-13 | λ=6.1e-09 | accept
# LM 815 | loss 1.120e-13 | λ=4.2e-09 | accept
# LM 816 | loss 1.121e-13 | λ=1.3e-08 | reject
# LM 817 | loss 1.116e-13 | λ=8.9e-09 | accept
# LM 818 | loss 1.113e-13 | λ=6.2e-09 | accept
# LM 819 | loss 1.110e-13 | λ=4.4e-09 | accept
# LM 820 | loss 1.110e-13 | λ=1.3e-08 | reject
# LM 821 | loss 1.106e-13 | λ=9.2e-09 | accept
# LM 822 | loss 1.103e-13 | λ=6.4e-09 | accept
# LM 823 | loss 1.101e-13 | λ=4.5e-09 | accept
# LM 824 | loss 1.100e-13 | λ=3.1e-09 | accept
# LM 825 | loss 1.113e-13 | λ=9.4e-09 | reject
# LM 826 | loss 1.091e-13 | λ=6.6e-09 | accept
# LM 827 | loss 1.088e-13 | λ=4.6e-09 | accept
# LM 828 | loss 1.087e-13 | λ=3.2e-09 | accept
# LM 829 | loss 1.097e-13 | λ=9.7e-09 | reject
# LM 830 | loss 1.079e-13 | λ=6.8e-09 | accept
# LM 831 | loss 1.076e-13 | λ=4.8e-09 | accept
# LM 832 | loss 1.075e-13 | λ=3.3e-09 | accept
# LM 833 | loss 1.082e-13 | λ=1.0e-08 | reject
# LM 834 | loss 1.068e-13 | λ=7.0e-09 | accept
# LM 835 | loss 1.065e-13 | λ=4.9e-09 | accept
# LM 836 | loss 1.064e-13 | λ=3.4e-09 | accept
# LM 837 | loss 1.069e-13 | λ=1.0e-08 | reject
# LM 838 | loss 1.058e-13 | λ=7.2e-09 | accept
# LM 839 | loss 1.055e-13 | λ=5.0e-09 | accept
# LM 840 | loss 1.053e-13 | λ=3.5e-09 | accept
# LM 841 | loss 1.057e-13 | λ=1.1e-08 | reject
# LM 842 | loss 1.048e-13 | λ=7.4e-09 | accept
# LM 843 | loss 1.046e-13 | λ=5.2e-09 | accept
# LM 844 | loss 1.044e-13 | λ=3.6e-09 | accept
# LM 845 | loss 1.046e-13 | λ=1.1e-08 | reject
# LM 846 | loss 1.039e-13 | λ=7.6e-09 | accept
# LM 847 | loss 1.037e-13 | λ=5.3e-09 | accept
# LM 848 | loss 1.035e-13 | λ=3.7e-09 | accept
# LM 849 | loss 1.036e-13 | λ=1.1e-08 | reject
# LM 850 | loss 1.030e-13 | λ=7.8e-09 | accept
# LM 851 | loss 1.028e-13 | λ=5.5e-09 | accept
# LM 852 | loss 1.026e-13 | λ=3.8e-09 | accept
# LM 853 | loss 1.027e-13 | λ=1.2e-08 | reject
# LM 854 | loss 1.022e-13 | λ=8.1e-09 | accept
# LM 855 | loss 1.020e-13 | λ=5.7e-09 | accept
# LM 856 | loss 1.018e-13 | λ=4.0e-09 | accept
# LM 857 | loss 1.019e-13 | λ=1.2e-08 | reject
# LM 858 | loss 1.015e-13 | λ=8.3e-09 | accept
# LM 859 | loss 1.013e-13 | λ=5.8e-09 | accept
# LM 860 | loss 1.011e-13 | λ=4.1e-09 | accept
# LM 861 | loss 1.011e-13 | λ=2.9e-09 | accept
# LM 862 | loss 1.022e-13 | λ=8.6e-09 | reject
# LM 863 | loss 1.003e-13 | λ=6.0e-09 | accept
# LM 864 | loss 1.001e-13 | λ=4.2e-09 | accept
# LM 865 | loss 1.000e-13 | λ=2.9e-09 | accept
# LM 866 | loss 1.009e-13 | λ=8.8e-09 | reject
# LM 867 | loss 9.934e-14 | λ=6.2e-09 | accept
# LM 868 | loss 9.913e-14 | λ=4.3e-09 | accept
# LM 869 | loss 9.904e-14 | λ=3.0e-09 | accept
# LM 870 | loss 9.974e-14 | λ=9.1e-09 | reject
# LM 871 | loss 9.846e-14 | λ=6.3e-09 | accept
# LM 872 | loss 9.825e-14 | λ=4.4e-09 | accept
# LM 873 | loss 9.814e-14 | λ=3.1e-09 | accept
# LM 874 | loss 9.867e-14 | λ=9.3e-09 | reject
# LM 875 | loss 9.763e-14 | λ=6.5e-09 | accept
# LM 876 | loss 9.743e-14 | λ=4.6e-09 | accept
# LM 877 | loss 9.730e-14 | λ=3.2e-09 | accept
# LM 878 | loss 9.770e-14 | λ=9.6e-09 | reject
# LM 879 | loss 9.685e-14 | λ=6.7e-09 | accept
# LM 880 | loss 9.666e-14 | λ=4.7e-09 | accept
# LM 881 | loss 9.652e-14 | λ=3.3e-09 | accept
# LM 882 | loss 9.680e-14 | λ=9.9e-09 | reject
# LM 883 | loss 9.612e-14 | λ=6.9e-09 | accept
# LM 884 | loss 9.593e-14 | λ=4.8e-09 | accept
# LM 885 | loss 9.578e-14 | λ=3.4e-09 | accept
# LM 886 | loss 9.598e-14 | λ=1.0e-08 | reject
# LM 887 | loss 9.543e-14 | λ=7.1e-09 | accept
# LM 888 | loss 9.525e-14 | λ=5.0e-09 | accept
# LM 889 | loss 9.509e-14 | λ=3.5e-09 | accept
# LM 890 | loss 9.521e-14 | λ=1.0e-08 | reject
# LM 891 | loss 9.477e-14 | λ=7.3e-09 | accept
# LM 892 | loss 9.460e-14 | λ=5.1e-09 | accept
# LM 893 | loss 9.443e-14 | λ=3.6e-09 | accept
# LM 894 | loss 9.450e-14 | λ=1.1e-08 | reject
# LM 895 | loss 9.416e-14 | λ=7.5e-09 | accept
# LM 896 | loss 9.399e-14 | λ=5.3e-09 | accept
# LM 897 | loss 9.382e-14 | λ=3.7e-09 | accept
# LM 898 | loss 9.384e-14 | λ=1.1e-08 | reject
# LM 899 | loss 9.357e-14 | λ=7.7e-09 | accept
# LM 900 | loss 9.341e-14 | λ=5.4e-09 | accept
# LM 901 | loss 9.324e-14 | λ=3.8e-09 | accept
# LM 902 | loss 9.322e-14 | λ=2.7e-09 | accept
# LM 903 | loss 9.408e-14 | λ=8.0e-09 | reject
# LM 904 | loss 9.262e-14 | λ=5.6e-09 | accept
# LM 905 | loss 9.245e-14 | λ=3.9e-09 | accept
# LM 906 | loss 9.240e-14 | λ=2.7e-09 | accept
# LM 907 | loss 9.307e-14 | λ=8.2e-09 | reject
# LM 908 | loss 9.188e-14 | λ=5.7e-09 | accept
# LM 909 | loss 9.171e-14 | λ=4.0e-09 | accept
# LM 910 | loss 9.164e-14 | λ=2.8e-09 | accept
# LM 911 | loss 9.216e-14 | λ=8.4e-09 | reject
# LM 912 | loss 9.118e-14 | λ=5.9e-09 | accept
# LM 913 | loss 9.102e-14 | λ=4.1e-09 | accept
# LM 914 | loss 9.092e-14 | λ=2.9e-09 | accept
# LM 915 | loss 9.132e-14 | λ=8.7e-09 | reject
# LM 916 | loss 9.052e-14 | λ=6.1e-09 | accept
# LM 917 | loss 9.036e-14 | λ=4.3e-09 | accept
# LM 918 | loss 9.025e-14 | λ=3.0e-09 | accept
# LM 919 | loss 9.055e-14 | λ=8.9e-09 | reject
# LM 920 | loss 8.989e-14 | λ=6.3e-09 | accept
# LM 921 | loss 8.974e-14 | λ=4.4e-09 | accept
# LM 922 | loss 8.961e-14 | λ=3.1e-09 | accept
# LM 923 | loss 8.983e-14 | λ=9.2e-09 | reject
# LM 924 | loss 8.930e-14 | λ=6.4e-09 | accept
# LM 925 | loss 8.915e-14 | λ=4.5e-09 | accept
# LM 926 | loss 8.902e-14 | λ=3.2e-09 | accept
# LM 927 | loss 8.917e-14 | λ=9.5e-09 | reject
# LM 928 | loss 8.874e-14 | λ=6.6e-09 | accept
# LM 929 | loss 8.859e-14 | λ=4.6e-09 | accept
# LM 930 | loss 8.845e-14 | λ=3.2e-09 | accept
# LM 931 | loss 8.855e-14 | λ=9.7e-09 | reject
# LM 932 | loss 8.820e-14 | λ=6.8e-09 | accept
# LM 933 | loss 8.806e-14 | λ=4.8e-09 | accept
# LM 934 | loss 8.792e-14 | λ=3.3e-09 | accept
# LM 935 | loss 8.797e-14 | λ=1.0e-08 | reject
# LM 936 | loss 8.769e-14 | λ=7.0e-09 | accept
# LM 937 | loss 8.756e-14 | λ=4.9e-09 | accept
# LM 938 | loss 8.742e-14 | λ=3.4e-09 | accept
# LM 939 | loss 8.743e-14 | λ=1.0e-08 | reject
# LM 940 | loss 8.721e-14 | λ=7.2e-09 | accept
# LM 941 | loss 8.708e-14 | λ=5.1e-09 | accept
# LM 942 | loss 8.693e-14 | λ=3.5e-09 | accept
# LM 943 | loss 8.691e-14 | λ=2.5e-09 | accept
# LM 944 | loss 8.762e-14 | λ=7.4e-09 | reject
# LM 945 | loss 8.642e-14 | λ=5.2e-09 | accept
# LM 946 | loss 8.628e-14 | λ=3.6e-09 | accept
# LM 947 | loss 8.623e-14 | λ=2.5e-09 | accept
# LM 948 | loss 8.679e-14 | λ=7.6e-09 | reject
# LM 949 | loss 8.580e-14 | λ=5.3e-09 | accept
# LM 950 | loss 8.566e-14 | λ=3.7e-09 | accept
# LM 951 | loss 8.559e-14 | λ=2.6e-09 | accept
# LM 952 | loss 8.603e-14 | λ=7.9e-09 | reject
# LM 953 | loss 8.521e-14 | λ=5.5e-09 | accept
# LM 954 | loss 8.507e-14 | λ=3.9e-09 | accept
# LM 955 | loss 8.499e-14 | λ=2.7e-09 | accept
# LM 956 | loss 8.533e-14 | λ=8.1e-09 | reject
# LM 957 | loss 8.465e-14 | λ=5.7e-09 | accept
# LM 958 | loss 8.452e-14 | λ=4.0e-09 | accept
# LM 959 | loss 8.442e-14 | λ=2.8e-09 | accept
# LM 960 | loss 8.468e-14 | λ=8.3e-09 | reject
# LM 961 | loss 8.412e-14 | λ=5.8e-09 | accept
# LM 962 | loss 8.399e-14 | λ=4.1e-09 | accept
# LM 963 | loss 8.388e-14 | λ=2.9e-09 | accept
# LM 964 | loss 8.407e-14 | λ=8.6e-09 | reject
# LM 965 | loss 8.361e-14 | λ=6.0e-09 | accept
# LM 966 | loss 8.349e-14 | λ=4.2e-09 | accept
# LM 967 | loss 8.337e-14 | λ=2.9e-09 | accept
# LM 968 | loss 8.351e-14 | λ=8.8e-09 | reject
# LM 969 | loss 8.313e-14 | λ=6.2e-09 | accept
# LM 970 | loss 8.301e-14 | λ=4.3e-09 | accept
# LM 971 | loss 8.289e-14 | λ=3.0e-09 | accept
# LM 972 | loss 8.297e-14 | λ=9.1e-09 | reject
# LM 973 | loss 8.267e-14 | λ=6.3e-09 | accept
# LM 974 | loss 8.255e-14 | λ=4.4e-09 | accept
# LM 975 | loss 8.243e-14 | λ=3.1e-09 | accept
# LM 976 | loss 8.247e-14 | λ=9.3e-09 | reject
# LM 977 | loss 8.223e-14 | λ=6.5e-09 | accept
# LM 978 | loss 8.211e-14 | λ=4.6e-09 | accept
# LM 979 | loss 8.199e-14 | λ=3.2e-09 | accept
# LM 980 | loss 8.200e-14 | λ=9.6e-09 | reject
# LM 981 | loss 8.181e-14 | λ=6.7e-09 | accept
# LM 982 | loss 8.169e-14 | λ=4.7e-09 | accept
# LM 983 | loss 8.157e-14 | λ=3.3e-09 | accept
# LM 984 | loss 8.156e-14 | λ=2.3e-09 | accept
# LM 985 | loss 8.220e-14 | λ=6.9e-09 | reject
# LM 986 | loss 8.112e-14 | λ=4.8e-09 | accept
# LM 987 | loss 8.100e-14 | λ=3.4e-09 | accept
# LM 988 | loss 8.096e-14 | λ=2.4e-09 | accept
# LM 989 | loss 8.148e-14 | λ=7.1e-09 | reject
# LM 990 | loss 8.058e-14 | λ=5.0e-09 | accept
# LM 991 | loss 8.045e-14 | λ=3.5e-09 | accept
# LM 992 | loss 8.040e-14 | λ=2.4e-09 | accept
# LM 993 | loss 8.081e-14 | λ=7.3e-09 | reject
# LM 994 | loss 8.006e-14 | λ=5.1e-09 | accept
# LM 995 | loss 7.993e-14 | λ=3.6e-09 | accept
# LM 996 | loss 7.987e-14 | λ=2.5e-09 | accept
# LM 997 | loss 8.019e-14 | λ=7.5e-09 | reject
# LM 998 | loss 7.956e-14 | λ=5.3e-09 | accept
# LM 999 | loss 7.944e-14 | λ=3.7e-09 | accept

# %%
def eval_u(model, x, y):
    phi = compute_phi(x, y)
    inp = torch.cat([x, y, phi], dim=1)
    return model(inp)

def make_grid(N=100):
    x = torch.linspace(X_MIN, X_MAX, N)
    y = torch.linspace(Y_MIN, Y_MAX, N)
    X, Y = torch.meshgrid(x, y, indexing="ij")
    return X, Y

X, Y = make_grid(100)

xg = X.reshape(-1, 1).to(device)
yg = Y.reshape(-1, 1).to(device)

with torch.no_grad():
    Ug = eval_u(model, xg, yg)

U = Ug.reshape(X.shape).cpu().numpy()
Xn = X.cpu().numpy()
Yn = Y.cpu().numpy()

lap_u = laplace_u(model, xg, yg)
residual = -lap_u
abs_residual = torch.abs(residual).detach().cpu().numpy()
log_abs_residual = torch.log(torch.abs(residual)).detach().cpu().numpy()
abs_residual = abs_residual.reshape(X.shape)
log_abs_residual = log_abs_residual.reshape(X.shape)

fig, axs = plt.subplots(1, 2, figsize=(15,5))

im0 = axs[0].contourf(X, Y, abs_residual, 50, cmap='viridis')
fig.colorbar(im0, ax=axs[0])
axs[0].set_title('|Residual| = |-Δu|')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].set_aspect('equal')

im1 = axs[1].contourf(X, Y, log_abs_residual, 50, cmap='viridis')
fig.colorbar(im1, ax=axs[1])
axs[1].set_title('log|Residual| = log|-Δu|')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')
axs[1].set_aspect('equal')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.semilogy(loss_history, lw=2)
plt.xlabel("LM iteration")
plt.ylabel("loss")
plt.title("LM training loss")
plt.grid(True)
plt.tight_layout()
plt.show()
