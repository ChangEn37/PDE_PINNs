# %% [markdown]
# f=0, crack: origin to (1,0), with exact solution.

# %%
import torch
import torch.nn as nn
import numpy as np
import math
import matplotlib.pyplot as plt
torch.set_default_dtype(torch.float64)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

X_MIN, X_MAX = -1.0, 1.0
Y_MIN, Y_MAX = -1.0, 1.0
N_b = 20
N_f = 4 * N_b
N_tip = N_b
N_b_crack = N_b

lam, lam_up, lam_down = 1e3, 3.0, 0.7
epochs_LM = 1000

class MLP(nn.Module):
    def __init__(self, layers):
        super().__init__()
        self.layers = nn.ModuleList()

        for i in range(len(layers) - 1):
            #  最後一層不加 bias
            if i == len(layers) - 2:
                self.layers.append(
                    nn.Linear(layers[i], layers[i+1], bias=False)
                )
            else:
                self.layers.append(
                    nn.Linear(layers[i], layers[i+1], bias=True)
                )

        self.act = torch.tanh

        # initialization
        for m in self.layers:
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight)
                if m.bias is not None:  
                    nn.init.zeros_(m.bias)

    def forward(self, x):
        for l in self.layers[:-1]:
            x = self.act(l(x))
        return self.layers[-1](x)


model = MLP([3, 40, 1]).to(device)

# %%
def compute_phi(x, y):
    eps = 1e-12
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=eps))
    return torch.sqrt(0.5 * (r - x))

def compute_phi_derivs(x, y):
    eps = 1e-12
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=eps))
    sqrt = torch.sqrt(torch.clamp(r - x, min=eps))

    coef = math.sqrt(2) / 4
    phi_x = -coef * sqrt / r
    phi_y = coef * y / (r * sqrt)

    return phi_x, phi_y

def first_derivs(model, x, y):
    phi = compute_phi(x, y)
    inp = torch.cat([x, y, phi], dim=1).requires_grad_(True)

    U = model(inp).view(-1, 1)

    grads = torch.autograd.grad(
        outputs=U.sum(),
        inputs=inp,
        create_graph=True
    )[0]

    return U, inp, grads[:,0:1], grads[:,1:2], grads[:,2:3]

def second_partials_U(inp, U_x, U_y, U_z):

    grad_Ux = torch.autograd.grad(
        outputs=U_x.sum(),
        inputs=inp,
        create_graph=True
    )[0]

    grad_Uy = torch.autograd.grad(
        outputs=U_y.sum(),
        inputs=inp,
        create_graph=True
    )[0]

    grad_Uz = torch.autograd.grad(
        outputs=U_z.sum(),
        inputs=inp,
        create_graph=True
    )[0]

    U_xx = grad_Ux[:, 0:1]
    #U_xy = grad_Ux[:, 1:2]
    U_xz = grad_Ux[:, 2:3]

    U_yy = grad_Uy[:, 1:2]
    U_yz = grad_Uy[:, 2:3]

    U_zz = grad_Uz[:, 2:3]

    return U_xx, U_yy, U_xz, U_yz, U_zz

def laplace_u(model, x, y):
    phi_x, phi_y = compute_phi_derivs(x, y)
    U, inp, U_x, U_y, U_z = first_derivs(model, x, y)
    U_xx, U_yy, U_xz, U_yz, U_zz = second_partials_U(inp, U_x, U_y, U_z)

    eps = 1e-12
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=eps))

    lap = (U_xx + U_yy
           + 2*(U_xz * phi_x + U_yz * phi_y)
           + (1/(4*r))*U_zz)
    return lap

# functions for sampling
#def sample_tip(N, r=1e-3):
    theta = torch.linspace(0, 2*np.pi, N)
    x = (r * torch.cos(theta)).view(-1,1)
    y = (r * torch.sin(theta)).view(-1,1)
    return x.to(device), y.to(device)

def sample_collocation(N):
    x = torch.rand(N*2,1)*(X_MAX-X_MIN)+X_MIN
    y = torch.rand(N*2,1)*(Y_MAX-Y_MIN)+Y_MIN

    mask = ~((torch.abs(y) < 1e-8) & (x >= 0))
    idx = mask.squeeze(1)  

    x = x[idx][:N]
    y = y[idx][:N]

    return x.to(device), y.to(device)


def sample_boundary(N):
    t = torch.linspace(-1,1,N).view(-1,1)
    xb = torch.cat([t, t, -torch.ones_like(t), torch.ones_like(t)])
    yb = torch.cat([-torch.ones_like(t), torch.ones_like(t), t, t])
    return xb.to(device), yb.to(device)

def sample_tip_and_crack(N_tip, N_b_crack):
    # crack 上（不含 tip）
    x_c = torch.linspace(1e-4, 1.0, N_b_crack, device=device).unsqueeze(1)
    y_c = torch.zeros_like(x_c)

    # tip neighborhood: small disk around (0,0)
    theta = 2 * torch.pi * torch.rand(N_tip, 1, device=device)
    r = 1e-4 * torch.sqrt(torch.rand(N_tip, 1, device=device))  # uniform in disk

    x_t = r * torch.cos(theta)
    y_t = r * torch.sin(theta)

    return x_c, y_c, x_t, y_t

# Residual vector 
def residual_vector(model):
    res = []

    # PDE
    lap = laplace_u(model, x_f, y_f)
    res.append(lap.view(-1))

    # Boundary
    phi_b = compute_phi(x_b, y_b)
    inp_b = torch.cat([x_b, y_b, phi_b], dim=1)
    res.append((model(inp_b) - phi_b).view(-1))

    # Crack-tip regularization 
    x_c, y_c, x_t, y_t = sample_tip_and_crack(N_tip, N_b_crack)
    _, inp_tip, U_x_tip, U_y_tip, U_z_tip = first_derivs(model, x_t, y_t)
    _, _, U_xz_tip, U_yz_tip, U_zz_tip = second_partials_U(inp_tip, U_x_tip, U_y_tip, U_z_tip)
    _, inp_c, U_x_c, U_y_c, U_z_c = first_derivs(model, x_c, y_c)
    _, _, U_xz_c, U_yz_c, _ = second_partials_U(inp_c, U_x_c, U_y_c, U_z_c)

    res += [U_zz_tip.view(-1), U_xz_tip.view(-1), U_yz_tip.view(-1)] #只考慮這項結果較好
    #res += [U_xz_c.view(-1), U_yz_c.view(-1)]
    return torch.cat(res)

# LM utilities
def flatten_params(model):
    return torch.cat([p.view(-1) for p in model.parameters()])

def set_params(model, theta):
    i = 0
    for p in model.parameters():
        n = p.numel()
        p.data.copy_(theta[i:i+n].view_as(p))
        i += n

def lm_step(model, lam):
    r = residual_vector(model)
    loss = torch.dot(r, r)

    theta = flatten_params(model)
    n, m = theta.numel(), r.numel()
    J = torch.zeros(m, n, device=device)

    for i in range(m):
        grads = torch.autograd.grad(r[i], model.parameters(), retain_graph=True)
        J[i] = torch.cat([g.view(-1) for g in grads])

    A = J.T @ J + lam * torch.eye(n, device=device)
    delta = torch.linalg.solve(A, -J.T @ r)

    set_params(model, theta + delta)
    return loss.item(), theta, delta, m, n

# %%
# Training
# =========================
x_f, y_f = sample_collocation(N_f)
x_b, y_b = sample_boundary(N_b)
loss_history_LM = []
lam_history = []


for ep in range(epochs_LM):
    loss0, theta_old, delta, m, n = lm_step(model, lam)

    r_new = residual_vector(model)
    loss1 = torch.dot(r_new, r_new).item()

    if loss1 < loss0:
        lam *= lam_down
        status = "accept"
    else:
        lam *= lam_up
        set_params(model, theta_old)
        status = "reject"

    loss_history_LM.append(loss1)
    lam_history.append(lam)
    epochs_LM = np.arange(len(loss_history_LM))


    print(f"LM {ep:02d} | loss {loss1:.3e} | λ={lam:.1e} | {status}")
# Out:
# LM 00 | loss 3.922e+01 | λ=7.0e+02 | accept
# LM 01 | loss 2.274e+01 | λ=4.9e+02 | accept
# LM 02 | loss 1.142e+01 | λ=3.4e+02 | accept
# LM 03 | loss 5.214e+00 | λ=2.4e+02 | accept
# LM 04 | loss 2.628e+00 | λ=1.7e+02 | accept
# LM 05 | loss 1.775e+00 | λ=1.2e+02 | accept
# LM 06 | loss 1.461e+00 | λ=8.2e+01 | accept
# LM 07 | loss 1.246e+00 | λ=5.8e+01 | accept
# LM 08 | loss 1.035e+00 | λ=4.0e+01 | accept
# LM 09 | loss 8.251e-01 | λ=2.8e+01 | accept
# LM 10 | loss 6.301e-01 | λ=2.0e+01 | accept
# LM 11 | loss 4.620e-01 | λ=1.4e+01 | accept
# LM 12 | loss 3.265e-01 | λ=9.7e+00 | accept
# LM 13 | loss 2.227e-01 | λ=6.8e+00 | accept
# LM 14 | loss 1.455e-01 | λ=4.7e+00 | accept
# LM 15 | loss 8.961e-02 | λ=3.3e+00 | accept
# LM 16 | loss 5.188e-02 | λ=2.3e+00 | accept
# LM 17 | loss 2.972e-02 | λ=1.6e+00 | accept
# LM 18 | loss 1.844e-02 | λ=1.1e+00 | accept
# LM 19 | loss 1.283e-02 | λ=8.0e-01 | accept
# LM 20 | loss 9.647e-03 | λ=5.6e-01 | accept
# LM 21 | loss 7.397e-03 | λ=3.9e-01 | accept
# LM 22 | loss 5.708e-03 | λ=2.7e-01 | accept
# LM 23 | loss 4.351e-03 | λ=1.9e-01 | accept
# LM 24 | loss 3.220e-03 | λ=1.3e-01 | accept
# LM 25 | loss 2.315e-03 | λ=9.4e-02 | accept
# LM 26 | loss 1.637e-03 | λ=6.6e-02 | accept
# LM 27 | loss 1.193e-03 | λ=4.6e-02 | accept
# LM 28 | loss 9.031e-04 | λ=3.2e-02 | accept
# LM 29 | loss 6.903e-04 | λ=2.3e-02 | accept
# LM 30 | loss 5.277e-04 | λ=1.6e-02 | accept
# LM 31 | loss 3.975e-04 | λ=1.1e-02 | accept
# LM 32 | loss 3.005e-04 | λ=7.7e-03 | accept
# LM 33 | loss 2.326e-04 | λ=5.4e-03 | accept
# LM 34 | loss 1.868e-04 | λ=3.8e-03 | accept
# LM 35 | loss 1.564e-04 | λ=2.7e-03 | accept
# LM 36 | loss 1.398e-04 | λ=1.9e-03 | accept
# LM 37 | loss 1.381e-04 | λ=1.3e-03 | accept
# LM 38 | loss 1.470e-04 | λ=3.9e-03 | reject
# LM 39 | loss 7.388e-05 | λ=2.7e-03 | accept
# LM 40 | loss 6.840e-05 | λ=1.9e-03 | accept
# LM 41 | loss 6.416e-05 | λ=1.3e-03 | accept
# LM 42 | loss 6.454e-05 | λ=4.0e-03 | reject
# LM 43 | loss 5.152e-05 | λ=2.8e-03 | accept
# LM 44 | loss 4.778e-05 | λ=2.0e-03 | accept
# LM 45 | loss 4.387e-05 | λ=1.4e-03 | accept
# LM 46 | loss 4.142e-05 | λ=9.6e-04 | accept
# LM 47 | loss 4.025e-05 | λ=6.7e-04 | accept
# LM 48 | loss 4.004e-05 | λ=4.7e-04 | accept
# LM 49 | loss 3.803e-05 | λ=3.3e-04 | accept
# LM 50 | loss 2.953e-05 | λ=2.3e-04 | accept
# LM 51 | loss 1.542e-05 | λ=1.6e-04 | accept
# LM 52 | loss 5.753e-06 | λ=1.1e-04 | accept
# LM 53 | loss 2.847e-06 | λ=7.9e-05 | accept
# LM 54 | loss 1.370e-06 | λ=5.6e-05 | accept
# LM 55 | loss 4.455e-07 | λ=3.9e-05 | accept
# LM 56 | loss 1.474e-07 | λ=2.7e-05 | accept
# LM 57 | loss 9.714e-08 | λ=1.9e-05 | accept
# LM 58 | loss 8.557e-08 | λ=1.3e-05 | accept
# LM 59 | loss 6.151e-08 | λ=9.3e-06 | accept
# LM 60 | loss 3.903e-08 | λ=6.5e-06 | accept
# LM 61 | loss 2.549e-08 | λ=4.6e-06 | accept
# LM 62 | loss 1.735e-08 | λ=3.2e-06 | accept
# LM 63 | loss 1.300e-08 | λ=2.2e-06 | accept
# LM 64 | loss 1.306e-08 | λ=6.7e-06 | reject
# LM 65 | loss 5.579e-09 | λ=4.7e-06 | accept
# LM 66 | loss 5.282e-09 | λ=3.3e-06 | accept
# LM 67 | loss 5.323e-09 | λ=9.9e-06 | reject
# LM 68 | loss 4.607e-09 | λ=6.9e-06 | accept
# LM 69 | loss 4.354e-09 | λ=4.8e-06 | accept
# LM 70 | loss 4.121e-09 | λ=3.4e-06 | accept
# LM 71 | loss 4.010e-09 | λ=2.4e-06 | accept
# LM 72 | loss 4.199e-09 | λ=7.1e-06 | reject
# LM 73 | loss 3.369e-09 | λ=5.0e-06 | accept
# LM 74 | loss 3.195e-09 | λ=3.5e-06 | accept
# LM 75 | loss 3.045e-09 | λ=2.4e-06 | accept
# LM 76 | loss 2.990e-09 | λ=1.7e-06 | accept
# LM 77 | loss 3.134e-09 | λ=5.1e-06 | reject
# LM 78 | loss 2.442e-09 | λ=3.6e-06 | accept
# LM 79 | loss 2.315e-09 | λ=2.5e-06 | accept
# LM 80 | loss 2.206e-09 | λ=1.8e-06 | accept
# LM 81 | loss 2.174e-09 | λ=1.2e-06 | accept
# LM 82 | loss 2.340e-09 | λ=3.7e-06 | reject
# LM 83 | loss 1.752e-09 | λ=2.6e-06 | accept
# LM 84 | loss 1.663e-09 | λ=1.8e-06 | accept
# LM 85 | loss 1.597e-09 | λ=1.3e-06 | accept
# LM 86 | loss 1.647e-09 | λ=3.8e-06 | reject
# LM 87 | loss 1.423e-09 | λ=2.7e-06 | accept
# LM 88 | loss 1.356e-09 | λ=1.9e-06 | accept
# LM 89 | loss 1.297e-09 | λ=1.3e-06 | accept
# LM 90 | loss 1.303e-09 | λ=3.9e-06 | reject
# LM 91 | loss 1.197e-09 | λ=2.7e-06 | accept
# LM 92 | loss 1.149e-09 | λ=1.9e-06 | accept
# LM 93 | loss 1.101e-09 | λ=1.3e-06 | accept
# LM 94 | loss 1.093e-09 | λ=9.4e-07 | accept
# LM 95 | loss 1.210e-09 | λ=2.8e-06 | reject
# LM 96 | loss 9.512e-10 | λ=2.0e-06 | accept
# LM 97 | loss 9.145e-10 | λ=1.4e-06 | accept
# LM 98 | loss 8.942e-10 | λ=9.7e-07 | accept
# LM 99 | loss 9.470e-10 | λ=2.9e-06 | reject
# LM 100 | loss 8.095e-10 | λ=2.0e-06 | accept
# LM 101 | loss 7.849e-10 | λ=1.4e-06 | accept
# LM 102 | loss 7.621e-10 | λ=9.9e-07 | accept
# LM 103 | loss 7.820e-10 | λ=3.0e-06 | reject
# LM 104 | loss 7.126e-10 | λ=2.1e-06 | accept
# LM 105 | loss 6.901e-10 | λ=1.5e-06 | accept
# LM 106 | loss 6.736e-10 | λ=1.0e-06 | accept
# LM 107 | loss 6.744e-10 | λ=3.1e-06 | reject
# LM 108 | loss 6.384e-10 | λ=2.1e-06 | accept
# LM 109 | loss 6.191e-10 | λ=1.5e-06 | accept
# LM 110 | loss 5.981e-10 | λ=1.1e-06 | accept
# LM 111 | loss 5.933e-10 | λ=7.4e-07 | accept
# LM 112 | loss 6.301e-10 | λ=2.2e-06 | reject
# LM 113 | loss 5.394e-10 | λ=1.5e-06 | accept
# LM 114 | loss 5.205e-10 | λ=1.1e-06 | accept
# LM 115 | loss 5.127e-10 | λ=7.6e-07 | accept
# LM 116 | loss 5.290e-10 | λ=2.3e-06 | reject
# LM 117 | loss 4.804e-10 | λ=1.6e-06 | accept
# LM 118 | loss 4.707e-10 | λ=1.1e-06 | accept
# LM 119 | loss 4.544e-10 | λ=7.8e-07 | accept
# LM 120 | loss 4.499e-10 | λ=5.5e-07 | accept
# LM 121 | loss 5.032e-10 | λ=1.6e-06 | reject
# LM 122 | loss 4.065e-10 | λ=1.1e-06 | accept
# LM 123 | loss 3.985e-10 | λ=8.0e-07 | accept
# LM 124 | loss 3.901e-10 | λ=5.6e-07 | accept
# LM 125 | loss 3.979e-10 | λ=1.7e-06 | reject
# LM 126 | loss 3.656e-10 | λ=1.2e-06 | accept
# LM 127 | loss 3.552e-10 | λ=8.3e-07 | accept
# LM 128 | loss 3.436e-10 | λ=5.8e-07 | accept
# LM 129 | loss 3.386e-10 | λ=4.0e-07 | accept
# LM 130 | loss 3.650e-10 | λ=1.2e-06 | reject
# LM 131 | loss 3.115e-10 | λ=8.5e-07 | accept
# LM 132 | loss 2.962e-10 | λ=5.9e-07 | accept
# LM 133 | loss 2.949e-10 | λ=4.2e-07 | accept
# LM 134 | loss 2.956e-10 | λ=1.2e-06 | reject
# LM 135 | loss 2.764e-10 | λ=8.7e-07 | accept
# LM 136 | loss 2.680e-10 | λ=6.1e-07 | accept
# LM 137 | loss 2.601e-10 | λ=4.3e-07 | accept
# LM 138 | loss 2.531e-10 | λ=3.0e-07 | accept
# LM 139 | loss 2.656e-10 | λ=9.0e-07 | reject
# LM 140 | loss 2.337e-10 | λ=6.3e-07 | accept
# LM 141 | loss 2.293e-10 | λ=4.4e-07 | accept
# LM 142 | loss 2.180e-10 | λ=3.1e-07 | accept
# LM 143 | loss 2.202e-10 | λ=9.3e-07 | reject
# LM 144 | loss 2.107e-10 | λ=6.5e-07 | accept
# LM 145 | loss 1.973e-10 | λ=4.5e-07 | accept
# LM 146 | loss 2.008e-10 | λ=3.2e-07 | accept
# LM 147 | loss 1.941e-10 | λ=2.2e-07 | accept
# LM 148 | loss 1.974e-10 | λ=6.7e-07 | reject
# LM 149 | loss 1.763e-10 | λ=4.7e-07 | accept
# LM 150 | loss 1.744e-10 | λ=3.3e-07 | accept
# LM 151 | loss 1.657e-10 | λ=2.3e-07 | accept
# LM 152 | loss 1.669e-10 | λ=1.6e-07 | accept
# LM 153 | loss 1.853e-10 | λ=4.8e-07 | reject
# LM 154 | loss 1.474e-10 | λ=3.4e-07 | accept
# LM 155 | loss 1.454e-10 | λ=2.4e-07 | accept
# LM 156 | loss 1.356e-10 | λ=1.6e-07 | accept
# LM 157 | loss 1.525e-10 | λ=4.9e-07 | reject
# LM 158 | loss 1.275e-10 | λ=3.5e-07 | accept
# LM 159 | loss 1.297e-10 | λ=2.4e-07 | accept
# LM 160 | loss 1.226e-10 | λ=1.7e-07 | accept
# LM 161 | loss 1.251e-10 | λ=5.1e-07 | reject
# LM 162 | loss 1.161e-10 | λ=3.6e-07 | accept
# LM 163 | loss 1.128e-10 | λ=2.5e-07 | accept
# LM 164 | loss 1.106e-10 | λ=1.7e-07 | accept
# LM 165 | loss 1.101e-10 | λ=5.2e-07 | reject
# LM 166 | loss 1.058e-10 | λ=3.7e-07 | accept
# LM 167 | loss 1.026e-10 | λ=2.6e-07 | accept
# LM 168 | loss 9.898e-11 | λ=1.8e-07 | accept
# LM 169 | loss 9.811e-11 | λ=1.3e-07 | accept
# LM 170 | loss 1.062e-10 | λ=3.8e-07 | reject
# LM 171 | loss 8.958e-11 | λ=2.6e-07 | accept
# LM 172 | loss 8.931e-11 | λ=1.8e-07 | accept
# LM 173 | loss 8.869e-11 | λ=5.5e-07 | reject
# LM 174 | loss 8.739e-11 | λ=3.9e-07 | accept
# LM 175 | loss 8.477e-11 | λ=2.7e-07 | accept
# LM 176 | loss 8.295e-11 | λ=1.9e-07 | accept
# LM 177 | loss 7.942e-11 | λ=1.3e-07 | accept
# LM 178 | loss 7.899e-11 | λ=9.3e-08 | accept
# LM 179 | loss 9.545e-11 | λ=2.8e-07 | reject
# LM 180 | loss 7.238e-11 | λ=2.0e-07 | accept
# LM 181 | loss 7.114e-11 | λ=1.4e-07 | accept
# LM 182 | loss 6.989e-11 | λ=9.6e-08 | accept
# LM 183 | loss 7.593e-11 | λ=2.9e-07 | reject
# LM 184 | loss 6.595e-11 | λ=2.0e-07 | accept
# LM 185 | loss 6.310e-11 | λ=1.4e-07 | accept
# LM 186 | loss 6.387e-11 | λ=4.2e-07 | reject
# LM 187 | loss 6.300e-11 | λ=1.3e-06 | reject
# LM 188 | loss 6.198e-11 | λ=8.9e-07 | accept
# LM 189 | loss 6.098e-11 | λ=6.2e-07 | accept
# LM 190 | loss 6.176e-11 | λ=4.3e-07 | accept
# LM 191 | loss 6.016e-11 | λ=3.0e-07 | accept
# LM 192 | loss 5.985e-11 | λ=2.1e-07 | accept
# LM 193 | loss 5.924e-11 | λ=6.4e-07 | reject
# LM 194 | loss 5.947e-11 | λ=4.5e-07 | accept
# LM 195 | loss 5.846e-11 | λ=3.1e-07 | accept
# LM 196 | loss 5.723e-11 | λ=2.2e-07 | accept
# LM 197 | loss 5.629e-11 | λ=1.5e-07 | accept
# LM 198 | loss 5.591e-11 | λ=1.1e-07 | accept
# LM 199 | loss 5.584e-11 | λ=3.2e-07 | reject
# LM 200 | loss 5.368e-11 | λ=2.3e-07 | accept
# LM 201 | loss 5.219e-11 | λ=1.6e-07 | accept
# LM 202 | loss 5.129e-11 | λ=1.1e-07 | accept
# LM 203 | loss 5.251e-11 | λ=3.3e-07 | reject
# LM 204 | loss 5.049e-11 | λ=2.3e-07 | accept
# LM 205 | loss 5.061e-11 | λ=1.6e-07 | accept
# LM 206 | loss 5.027e-11 | λ=1.1e-07 | accept
# LM 207 | loss 4.824e-11 | λ=8.0e-08 | accept
# LM 208 | loss 5.088e-11 | λ=2.4e-07 | reject
# LM 209 | loss 4.654e-11 | λ=1.7e-07 | accept
# LM 210 | loss 4.646e-11 | λ=1.2e-07 | accept
# LM 211 | loss 4.502e-11 | λ=8.2e-08 | accept
# LM 212 | loss 4.652e-11 | λ=2.5e-07 | reject
# LM 213 | loss 4.406e-11 | λ=1.7e-07 | accept
# LM 214 | loss 4.395e-11 | λ=5.2e-07 | reject
# LM 215 | loss 4.398e-11 | λ=3.6e-07 | accept
# LM 216 | loss 4.361e-11 | λ=1.1e-06 | reject
# LM 217 | loss 4.371e-11 | λ=7.6e-07 | accept
# LM 218 | loss 4.366e-11 | λ=2.3e-06 | reject
# LM 219 | loss 4.496e-11 | λ=6.8e-06 | reject
# LM 220 | loss 4.435e-11 | λ=2.0e-05 | reject
# LM 221 | loss 4.378e-11 | λ=1.4e-05 | accept
# LM 222 | loss 4.321e-11 | λ=1.0e-05 | accept
# LM 223 | loss 4.352e-11 | λ=7.0e-06 | accept
# LM 224 | loss 4.373e-11 | λ=2.1e-05 | reject
# LM 225 | loss 4.408e-11 | λ=6.3e-05 | reject
# LM 226 | loss 4.319e-11 | λ=4.4e-05 | accept
# LM 227 | loss 4.319e-11 | λ=3.1e-05 | accept
# LM 228 | loss 4.332e-11 | λ=2.2e-05 | accept
# LM 229 | loss 4.349e-11 | λ=6.5e-05 | reject
# LM 230 | loss 4.368e-11 | λ=4.6e-05 | accept
# LM 231 | loss 4.297e-11 | λ=3.2e-05 | accept
# LM 232 | loss 4.389e-11 | λ=9.6e-05 | reject
# LM 233 | loss 4.369e-11 | λ=2.9e-04 | reject
# LM 234 | loss 4.350e-11 | λ=2.0e-04 | accept
# LM 235 | loss 4.323e-11 | λ=1.4e-04 | accept
# LM 236 | loss 4.425e-11 | λ=4.2e-04 | reject
# LM 237 | loss 4.374e-11 | λ=3.0e-04 | accept
# LM 238 | loss 4.391e-11 | λ=8.9e-04 | reject
# LM 239 | loss 4.357e-11 | λ=6.2e-04 | accept
# LM 240 | loss 4.369e-11 | λ=1.9e-03 | reject
# LM 241 | loss 4.421e-11 | λ=5.6e-03 | reject
# LM 242 | loss 4.340e-11 | λ=3.9e-03 | accept
# LM 243 | loss 4.317e-11 | λ=2.7e-03 | accept
# LM 244 | loss 4.362e-11 | λ=8.2e-03 | reject
# LM 245 | loss 4.308e-11 | λ=5.7e-03 | accept
# LM 246 | loss 4.348e-11 | λ=1.7e-02 | reject
# LM 247 | loss 4.360e-11 | λ=5.2e-02 | reject
# LM 248 | loss 4.355e-11 | λ=3.6e-02 | accept
# LM 249 | loss 4.339e-11 | λ=2.5e-02 | accept
# LM 250 | loss 4.372e-11 | λ=1.8e-02 | accept
# LM 251 | loss 4.372e-11 | λ=5.3e-02 | reject
# LM 252 | loss 4.397e-11 | λ=1.6e-01 | reject
# LM 253 | loss 4.368e-11 | λ=4.8e-01 | reject
# LM 254 | loss 4.433e-11 | λ=1.4e+00 | reject
# LM 255 | loss 4.320e-11 | λ=1.0e+00 | accept
# LM 256 | loss 4.370e-11 | λ=7.0e-01 | accept
# LM 257 | loss 4.323e-11 | λ=4.9e-01 | accept
# LM 258 | loss 4.348e-11 | λ=3.4e-01 | accept
# LM 259 | loss 4.320e-11 | λ=2.4e-01 | accept
# LM 260 | loss 4.369e-11 | λ=7.2e-01 | reject
# LM 261 | loss 4.357e-11 | λ=5.1e-01 | accept
# LM 262 | loss 4.325e-11 | λ=3.5e-01 | accept
# LM 263 | loss 4.399e-11 | λ=1.1e+00 | reject
# LM 264 | loss 4.339e-11 | λ=7.5e-01 | accept
# LM 265 | loss 4.357e-11 | λ=2.2e+00 | reject
# LM 266 | loss 4.351e-11 | λ=6.7e+00 | reject
# LM 267 | loss 4.374e-11 | λ=2.0e+01 | reject
# LM 268 | loss 4.298e-11 | λ=1.4e+01 | accept
# LM 269 | loss 4.330e-11 | λ=9.9e+00 | accept
# LM 270 | loss 4.312e-11 | λ=6.9e+00 | accept
# LM 271 | loss 4.322e-11 | λ=4.8e+00 | accept
# LM 272 | loss 4.362e-11 | λ=1.4e+01 | reject
# LM 273 | loss 4.354e-11 | λ=4.3e+01 | reject
# LM 274 | loss 4.330e-11 | λ=3.0e+01 | accept
# LM 275 | loss 4.360e-11 | λ=9.1e+01 | reject
# LM 276 | loss 4.373e-11 | λ=2.7e+02 | reject
# LM 277 | loss 4.364e-11 | λ=8.2e+02 | reject
# LM 278 | loss 4.341e-11 | λ=5.8e+02 | accept
# LM 279 | loss 4.344e-11 | λ=4.0e+02 | accept
# LM 280 | loss 4.328e-11 | λ=2.8e+02 | accept
# LM 281 | loss 4.327e-11 | λ=2.0e+02 | accept
# LM 282 | loss 4.401e-11 | λ=5.9e+02 | reject
# LM 283 | loss 4.362e-11 | λ=4.1e+02 | accept
# LM 284 | loss 4.337e-11 | λ=2.9e+02 | accept
# LM 285 | loss 4.349e-11 | λ=2.0e+02 | accept
# LM 286 | loss 4.390e-11 | λ=6.1e+02 | reject
# LM 287 | loss 4.303e-11 | λ=4.3e+02 | accept
# LM 288 | loss 4.399e-11 | λ=1.3e+03 | reject
# LM 289 | loss 4.376e-11 | λ=3.8e+03 | reject
# LM 290 | loss 4.359e-11 | λ=2.7e+03 | accept
# LM 291 | loss 4.349e-11 | λ=1.9e+03 | accept
# LM 292 | loss 4.384e-11 | λ=1.3e+03 | accept
# LM 293 | loss 4.366e-11 | λ=9.2e+02 | accept
# LM 294 | loss 4.326e-11 | λ=6.5e+02 | accept
# LM 295 | loss 4.302e-11 | λ=4.5e+02 | accept
# LM 296 | loss 4.398e-11 | λ=1.4e+03 | reject
# LM 297 | loss 4.307e-11 | λ=9.5e+02 | accept
# LM 298 | loss 4.334e-11 | λ=6.6e+02 | accept
# LM 299 | loss 4.330e-11 | λ=4.6e+02 | accept
# LM 300 | loss 4.368e-11 | λ=3.3e+02 | accept
# LM 301 | loss 4.322e-11 | λ=2.3e+02 | accept
# LM 302 | loss 4.337e-11 | λ=6.8e+02 | reject
# LM 303 | loss 4.331e-11 | λ=4.8e+02 | accept
# LM 304 | loss 4.317e-11 | λ=3.3e+02 | accept
# LM 305 | loss 4.383e-11 | λ=2.3e+02 | accept
# LM 306 | loss 4.310e-11 | λ=1.6e+02 | accept
# LM 307 | loss 4.383e-11 | λ=1.1e+02 | accept
# LM 308 | loss 4.403e-11 | λ=3.4e+02 | reject
# LM 309 | loss 4.396e-11 | λ=1.0e+03 | reject
# LM 310 | loss 4.352e-11 | λ=7.2e+02 | accept
# LM 311 | loss 4.361e-11 | λ=2.2e+03 | reject
# LM 312 | loss 4.376e-11 | λ=6.5e+03 | reject
# LM 313 | loss 4.353e-11 | λ=4.6e+03 | accept
# LM 314 | loss 4.349e-11 | λ=3.2e+03 | accept
# LM 315 | loss 4.332e-11 | λ=2.2e+03 | accept
# LM 316 | loss 4.362e-11 | λ=1.6e+03 | accept
# LM 317 | loss 4.391e-11 | λ=4.7e+03 | reject
# LM 318 | loss 4.346e-11 | λ=3.3e+03 | accept
# LM 319 | loss 4.285e-11 | λ=2.3e+03 | accept
# LM 320 | loss 4.357e-11 | λ=1.6e+03 | accept
# LM 321 | loss 4.367e-11 | λ=4.8e+03 | reject
# LM 322 | loss 4.322e-11 | λ=3.4e+03 | accept
# LM 323 | loss 4.366e-11 | λ=1.0e+04 | reject
# LM 324 | loss 4.301e-11 | λ=7.1e+03 | accept
# LM 325 | loss 4.388e-11 | λ=5.0e+03 | accept
# LM 326 | loss 4.370e-11 | λ=1.5e+04 | reject
# LM 327 | loss 4.390e-11 | λ=4.5e+04 | reject
# LM 328 | loss 4.346e-11 | λ=1.3e+05 | reject
# LM 329 | loss 4.342e-11 | λ=4.0e+05 | reject
# LM 330 | loss 4.323e-11 | λ=2.8e+05 | accept
# LM 331 | loss 4.352e-11 | λ=2.0e+05 | accept
# LM 332 | loss 4.390e-11 | λ=5.9e+05 | reject
# LM 333 | loss 4.377e-11 | λ=4.1e+05 | accept
# LM 334 | loss 4.365e-11 | λ=1.2e+06 | reject
# LM 335 | loss 4.336e-11 | λ=8.7e+05 | accept
# LM 336 | loss 4.324e-11 | λ=6.1e+05 | accept
# LM 337 | loss 4.302e-11 | λ=4.3e+05 | accept
# LM 338 | loss 4.365e-11 | λ=1.3e+06 | reject
# LM 339 | loss 4.347e-11 | λ=3.8e+06 | reject
# LM 340 | loss 4.400e-11 | λ=1.1e+07 | reject
# LM 341 | loss 4.409e-11 | λ=3.4e+07 | reject
# LM 342 | loss 4.406e-11 | λ=1.0e+08 | reject
# LM 343 | loss 4.426e-11 | λ=3.1e+08 | reject
# LM 344 | loss 4.377e-11 | λ=9.3e+08 | reject
# LM 345 | loss 4.330e-11 | λ=6.5e+08 | accept
# LM 346 | loss 4.354e-11 | λ=2.0e+09 | reject
# LM 347 | loss 4.397e-11 | λ=5.9e+09 | reject
# LM 348 | loss 4.367e-11 | λ=1.8e+10 | reject
# LM 349 | loss 4.382e-11 | λ=5.3e+10 | reject
# LM 350 | loss 4.414e-11 | λ=1.6e+11 | reject
# LM 351 | loss 4.334e-11 | λ=1.1e+11 | accept
# LM 352 | loss 4.308e-11 | λ=7.8e+10 | accept
# LM 353 | loss 4.338e-11 | λ=5.4e+10 | accept
# LM 354 | loss 4.363e-11 | λ=1.6e+11 | reject
# LM 355 | loss 4.341e-11 | λ=4.9e+11 | reject
# LM 356 | loss 4.356e-11 | λ=3.4e+11 | accept
# LM 357 | loss 4.362e-11 | λ=1.0e+12 | reject
# LM 358 | loss 4.320e-11 | λ=7.2e+11 | accept
# LM 359 | loss 4.332e-11 | λ=5.0e+11 | accept
# LM 360 | loss 4.366e-11 | λ=1.5e+12 | reject
# LM 361 | loss 4.383e-11 | λ=4.5e+12 | reject
# LM 362 | loss 4.309e-11 | λ=3.2e+12 | accept
# LM 363 | loss 4.372e-11 | λ=2.2e+12 | accept
# LM 364 | loss 4.371e-11 | λ=6.7e+12 | reject
# LM 365 | loss 4.346e-11 | λ=4.7e+12 | accept
# LM 366 | loss 4.363e-11 | λ=3.3e+12 | accept
# LM 367 | loss 4.387e-11 | λ=9.8e+12 | reject
# LM 368 | loss 4.327e-11 | λ=6.8e+12 | accept
# LM 369 | loss 4.312e-11 | λ=4.8e+12 | accept
# LM 370 | loss 4.358e-11 | λ=1.4e+13 | reject
# LM 371 | loss 4.317e-11 | λ=1.0e+13 | accept
# LM 372 | loss 4.340e-11 | λ=7.0e+12 | accept
# LM 373 | loss 4.358e-11 | λ=4.9e+12 | accept
# LM 374 | loss 4.364e-11 | λ=3.5e+12 | accept
# LM 375 | loss 4.357e-11 | λ=1.0e+13 | reject
# LM 376 | loss 4.367e-11 | λ=7.3e+12 | accept
# LM 377 | loss 4.359e-11 | λ=5.1e+12 | accept
# LM 378 | loss 4.411e-11 | λ=1.5e+13 | reject
# LM 379 | loss 4.424e-11 | λ=4.6e+13 | reject
# LM 380 | loss 4.383e-11 | λ=1.4e+14 | reject
# LM 381 | loss 4.357e-11 | λ=9.6e+13 | accept
# LM 382 | loss 4.343e-11 | λ=2.9e+14 | reject
# LM 383 | loss 4.378e-11 | λ=8.6e+14 | reject
# LM 384 | loss 4.414e-11 | λ=2.6e+15 | reject
# LM 385 | loss 4.319e-11 | λ=1.8e+15 | accept
# LM 386 | loss 4.387e-11 | λ=5.4e+15 | reject
# LM 387 | loss 4.377e-11 | λ=1.6e+16 | reject
# LM 388 | loss 4.348e-11 | λ=4.9e+16 | reject
# LM 389 | loss 4.346e-11 | λ=3.4e+16 | accept
# LM 390 | loss 4.378e-11 | λ=1.0e+17 | reject
# LM 391 | loss 4.324e-11 | λ=7.2e+16 | accept
# LM 392 | loss 4.319e-11 | λ=5.0e+16 | accept
# LM 393 | loss 4.377e-11 | λ=1.5e+17 | reject
# LM 394 | loss 4.376e-11 | λ=4.5e+17 | reject
# LM 395 | loss 4.372e-11 | λ=3.2e+17 | accept
# LM 396 | loss 4.320e-11 | λ=2.2e+17 | accept
# LM 397 | loss 4.345e-11 | λ=1.6e+17 | accept
# LM 398 | loss 4.412e-11 | λ=4.7e+17 | reject
# LM 399 | loss 4.375e-11 | λ=1.4e+18 | reject
# LM 400 | loss 4.377e-11 | λ=4.2e+18 | reject
# LM 401 | loss 4.316e-11 | λ=2.9e+18 | accept
# LM 402 | loss 4.365e-11 | λ=2.1e+18 | accept
# LM 403 | loss 4.369e-11 | λ=6.2e+18 | reject
# LM 404 | loss 4.373e-11 | λ=1.9e+19 | reject
# LM 405 | loss 4.339e-11 | λ=1.3e+19 | accept
# LM 406 | loss 4.364e-11 | λ=9.1e+18 | accept
# LM 407 | loss 4.372e-11 | λ=2.7e+19 | reject
# LM 408 | loss 4.316e-11 | λ=1.9e+19 | accept
# LM 409 | loss 4.295e-11 | λ=1.3e+19 | accept
# LM 410 | loss 4.340e-11 | λ=9.3e+18 | accept
# LM 411 | loss 4.350e-11 | λ=6.5e+18 | accept
# LM 412 | loss 4.377e-11 | λ=4.6e+18 | accept
# LM 413 | loss 4.324e-11 | λ=3.2e+18 | accept
# LM 414 | loss 4.346e-11 | λ=9.6e+18 | reject
# LM 415 | loss 4.336e-11 | λ=6.7e+18 | accept
# LM 416 | loss 4.357e-11 | λ=2.0e+19 | reject
# LM 417 | loss 4.359e-11 | λ=1.4e+19 | accept
# LM 418 | loss 4.343e-11 | λ=9.9e+18 | accept
# LM 419 | loss 4.420e-11 | λ=3.0e+19 | reject
# LM 420 | loss 4.319e-11 | λ=2.1e+19 | accept
# LM 421 | loss 4.415e-11 | λ=6.2e+19 | reject
# LM 422 | loss 4.382e-11 | λ=4.4e+19 | accept
# LM 423 | loss 4.342e-11 | λ=3.1e+19 | accept
# LM 424 | loss 4.351e-11 | λ=2.1e+19 | accept
# LM 425 | loss 4.333e-11 | λ=1.5e+19 | accept
# LM 426 | loss 4.347e-11 | λ=1.0e+19 | accept
# LM 427 | loss 4.380e-11 | λ=3.1e+19 | reject
# LM 428 | loss 4.378e-11 | λ=9.4e+19 | reject
# LM 429 | loss 4.338e-11 | λ=6.6e+19 | accept
# LM 430 | loss 4.308e-11 | λ=4.6e+19 | accept
# LM 431 | loss 4.410e-11 | λ=1.4e+20 | reject
# LM 432 | loss 4.346e-11 | λ=9.7e+19 | accept
# LM 433 | loss 4.355e-11 | λ=6.8e+19 | accept
# LM 434 | loss 4.345e-11 | λ=4.8e+19 | accept
# LM 435 | loss 4.370e-11 | λ=1.4e+20 | reject
# LM 436 | loss 4.383e-11 | λ=4.3e+20 | reject
# LM 437 | loss 4.354e-11 | λ=1.3e+21 | reject
# LM 438 | loss 4.393e-11 | λ=3.8e+21 | reject
# LM 439 | loss 4.359e-11 | λ=1.2e+22 | reject
# LM 440 | loss 4.338e-11 | λ=3.5e+22 | reject
# LM 441 | loss 4.361e-11 | λ=1.0e+23 | reject
# LM 442 | loss 4.434e-11 | λ=3.1e+23 | reject
# LM 443 | loss 4.347e-11 | λ=9.4e+23 | reject
# LM 444 | loss 4.347e-11 | λ=2.8e+24 | reject
# LM 445 | loss 4.310e-11 | λ=2.0e+24 | accept
# LM 446 | loss 4.381e-11 | λ=5.9e+24 | reject
# LM 447 | loss 4.340e-11 | λ=4.1e+24 | accept
# LM 448 | loss 4.339e-11 | λ=1.2e+25 | reject
# LM 449 | loss 4.344e-11 | λ=8.7e+24 | accept
# LM 450 | loss 4.408e-11 | λ=2.6e+25 | reject
# LM 451 | loss 4.396e-11 | λ=7.8e+25 | reject
# LM 452 | loss 4.358e-11 | λ=5.5e+25 | accept
# LM 453 | loss 4.308e-11 | λ=3.8e+25 | accept
# LM 454 | loss 4.400e-11 | λ=1.1e+26 | reject
# LM 455 | loss 4.382e-11 | λ=3.4e+26 | reject
# LM 456 | loss 4.369e-11 | λ=1.0e+27 | reject
# LM 457 | loss 4.332e-11 | λ=3.1e+27 | reject
# LM 458 | loss 4.330e-11 | λ=2.2e+27 | accept
# LM 459 | loss 4.356e-11 | λ=6.5e+27 | reject
# LM 460 | loss 4.354e-11 | λ=4.5e+27 | accept
# LM 461 | loss 4.350e-11 | λ=3.2e+27 | accept
# LM 462 | loss 4.351e-11 | λ=2.2e+27 | accept
# LM 463 | loss 4.375e-11 | λ=1.6e+27 | accept
# LM 464 | loss 4.335e-11 | λ=1.1e+27 | accept
# LM 465 | loss 4.383e-11 | λ=3.3e+27 | reject
# LM 466 | loss 4.348e-11 | λ=9.8e+27 | reject
# LM 467 | loss 4.366e-11 | λ=2.9e+28 | reject
# LM 468 | loss 4.345e-11 | λ=8.8e+28 | reject
# LM 469 | loss 4.365e-11 | λ=2.7e+29 | reject
# LM 470 | loss 4.398e-11 | λ=8.0e+29 | reject
# LM 471 | loss 4.411e-11 | λ=2.4e+30 | reject
# LM 472 | loss 4.366e-11 | λ=7.2e+30 | reject
# LM 473 | loss 4.382e-11 | λ=5.0e+30 | accept
# LM 474 | loss 4.350e-11 | λ=1.5e+31 | reject
# LM 475 | loss 4.367e-11 | λ=4.5e+31 | reject
# LM 476 | loss 4.372e-11 | λ=1.4e+32 | reject
# LM 477 | loss 4.355e-11 | λ=9.5e+31 | accept
# LM 478 | loss 4.411e-11 | λ=2.8e+32 | reject
# LM 479 | loss 4.359e-11 | λ=8.5e+32 | reject
# LM 480 | loss 4.361e-11 | λ=6.0e+32 | accept
# LM 481 | loss 4.348e-11 | λ=1.8e+33 | reject
# LM 482 | loss 4.317e-11 | λ=1.3e+33 | accept
# LM 483 | loss 4.340e-11 | λ=8.8e+32 | accept
# LM 484 | loss 4.399e-11 | λ=2.6e+33 | reject
# LM 485 | loss 4.390e-11 | λ=7.9e+33 | reject
# LM 486 | loss 4.320e-11 | λ=5.5e+33 | accept
# LM 487 | loss 4.346e-11 | λ=3.9e+33 | accept
# LM 488 | loss 4.350e-11 | λ=2.7e+33 | accept
# LM 489 | loss 4.369e-11 | λ=8.1e+33 | reject
# LM 490 | loss 4.297e-11 | λ=5.7e+33 | accept
# LM 491 | loss 4.395e-11 | λ=1.7e+34 | reject
# LM 492 | loss 4.370e-11 | λ=5.1e+34 | reject
# LM 493 | loss 4.398e-11 | λ=1.5e+35 | reject
# LM 494 | loss 4.343e-11 | λ=1.1e+35 | accept
# LM 495 | loss 4.382e-11 | λ=3.2e+35 | reject
# LM 496 | loss 4.418e-11 | λ=9.7e+35 | reject
# LM 497 | loss 4.395e-11 | λ=2.9e+36 | reject
# LM 498 | loss 4.386e-11 | λ=8.7e+36 | reject
# LM 499 | loss 4.312e-11 | λ=6.1e+36 | accept
# LM 500 | loss 4.367e-11 | λ=1.8e+37 | reject
# LM 501 | loss 4.339e-11 | λ=1.3e+37 | accept
# LM 502 | loss 4.390e-11 | λ=3.8e+37 | reject
# LM 503 | loss 4.357e-11 | λ=2.7e+37 | accept
# LM 504 | loss 4.391e-11 | λ=8.1e+37 | reject
# LM 505 | loss 4.363e-11 | λ=5.6e+37 | accept
# LM 506 | loss 4.385e-11 | λ=1.7e+38 | reject
# LM 507 | loss 4.357e-11 | λ=5.1e+38 | reject
# LM 508 | loss 4.367e-11 | λ=1.5e+39 | reject
# LM 509 | loss 4.408e-11 | λ=4.6e+39 | reject
# LM 510 | loss 4.345e-11 | λ=1.4e+40 | reject
# LM 511 | loss 4.388e-11 | λ=4.1e+40 | reject
# LM 512 | loss 4.352e-11 | λ=2.9e+40 | accept
# LM 513 | loss 4.299e-11 | λ=2.0e+40 | accept
# LM 514 | loss 4.324e-11 | λ=1.4e+40 | accept
# LM 515 | loss 4.338e-11 | λ=9.9e+39 | accept
# LM 516 | loss 4.369e-11 | λ=6.9e+39 | accept
# LM 517 | loss 4.313e-11 | λ=4.8e+39 | accept
# LM 518 | loss 4.362e-11 | λ=3.4e+39 | accept
# LM 519 | loss 4.367e-11 | λ=2.4e+39 | accept
# LM 520 | loss 4.348e-11 | λ=7.1e+39 | reject
# LM 521 | loss 4.393e-11 | λ=2.1e+40 | reject
# LM 522 | loss 4.334e-11 | λ=1.5e+40 | accept
# LM 523 | loss 4.346e-11 | λ=1.0e+40 | accept
# LM 524 | loss 4.331e-11 | λ=3.1e+40 | reject
# LM 525 | loss 4.336e-11 | λ=2.2e+40 | accept
# LM 526 | loss 4.325e-11 | λ=1.5e+40 | accept
# LM 527 | loss 4.318e-11 | λ=1.1e+40 | accept
# LM 528 | loss 4.367e-11 | λ=7.5e+39 | accept
# LM 529 | loss 4.353e-11 | λ=5.3e+39 | accept
# LM 530 | loss 4.356e-11 | λ=1.6e+40 | reject
# LM 531 | loss 4.346e-11 | λ=4.7e+40 | reject
# LM 532 | loss 4.381e-11 | λ=3.3e+40 | accept
# LM 533 | loss 4.379e-11 | λ=1.0e+41 | reject
# LM 534 | loss 4.379e-11 | λ=3.0e+41 | reject
# LM 535 | loss 4.371e-11 | λ=2.1e+41 | accept
# LM 536 | loss 4.380e-11 | λ=1.5e+41 | accept
# LM 537 | loss 4.313e-11 | λ=1.0e+41 | accept
# LM 538 | loss 4.432e-11 | λ=3.1e+41 | reject
# LM 539 | loss 4.373e-11 | λ=9.2e+41 | reject
# LM 540 | loss 4.356e-11 | λ=6.5e+41 | accept
# LM 541 | loss 4.374e-11 | λ=1.9e+42 | reject
# LM 542 | loss 4.354e-11 | λ=5.8e+42 | reject
# LM 543 | loss 4.327e-11 | λ=4.1e+42 | accept
# LM 544 | loss 4.377e-11 | λ=2.9e+42 | accept
# LM 545 | loss 4.264e-11 | λ=2.0e+42 | accept
# LM 546 | loss 4.406e-11 | λ=6.0e+42 | reject
# LM 547 | loss 4.337e-11 | λ=4.2e+42 | accept
# LM 548 | loss 4.356e-11 | λ=2.9e+42 | accept
# LM 549 | loss 4.309e-11 | λ=2.1e+42 | accept
# LM 550 | loss 4.364e-11 | λ=6.2e+42 | reject
# LM 551 | loss 4.311e-11 | λ=4.3e+42 | accept
# LM 552 | loss 4.390e-11 | λ=1.3e+43 | reject
# LM 553 | loss 4.313e-11 | λ=9.1e+42 | accept
# LM 554 | loss 4.366e-11 | λ=2.7e+43 | reject
# LM 555 | loss 4.352e-11 | λ=1.9e+43 | accept
# LM 556 | loss 4.436e-11 | λ=5.7e+43 | reject
# LM 557 | loss 4.351e-11 | λ=1.7e+44 | reject
# LM 558 | loss 4.359e-11 | λ=1.2e+44 | accept
# LM 559 | loss 4.363e-11 | λ=3.6e+44 | reject
# LM 560 | loss 4.365e-11 | λ=2.5e+44 | accept
# LM 561 | loss 4.367e-11 | λ=7.5e+44 | reject
# LM 562 | loss 4.368e-11 | λ=2.3e+45 | reject
# LM 563 | loss 4.391e-11 | λ=6.8e+45 | reject
# LM 564 | loss 4.347e-11 | λ=2.0e+46 | reject
# LM 565 | loss 4.370e-11 | λ=1.4e+46 | accept
# LM 566 | loss 4.385e-11 | λ=4.3e+46 | reject
# LM 567 | loss 4.384e-11 | λ=1.3e+47 | reject
# LM 568 | loss 4.336e-11 | λ=3.9e+47 | reject
# LM 569 | loss 4.332e-11 | λ=2.7e+47 | accept
# LM 570 | loss 4.369e-11 | λ=8.1e+47 | reject
# LM 571 | loss 4.360e-11 | λ=2.4e+48 | reject
# LM 572 | loss 4.383e-11 | λ=7.3e+48 | reject
# LM 573 | loss 4.395e-11 | λ=2.2e+49 | reject
# LM 574 | loss 4.356e-11 | λ=6.6e+49 | reject
# LM 575 | loss 4.378e-11 | λ=2.0e+50 | reject
# LM 576 | loss 4.417e-11 | λ=5.9e+50 | reject
# LM 577 | loss 4.406e-11 | λ=1.8e+51 | reject
# LM 578 | loss 4.324e-11 | λ=1.2e+51 | accept
# LM 579 | loss 4.335e-11 | λ=8.7e+50 | accept
# LM 580 | loss 4.364e-11 | λ=2.6e+51 | reject
# LM 581 | loss 4.343e-11 | λ=7.8e+51 | reject
# LM 582 | loss 4.339e-11 | λ=2.3e+52 | reject
# LM 583 | loss 4.355e-11 | λ=1.6e+52 | accept
# LM 584 | loss 4.368e-11 | λ=4.9e+52 | reject
# LM 585 | loss 4.346e-11 | λ=1.5e+53 | reject
# LM 586 | loss 4.397e-11 | λ=4.4e+53 | reject
# LM 587 | loss 4.366e-11 | λ=1.3e+54 | reject
# LM 588 | loss 4.285e-11 | λ=9.3e+53 | accept
# LM 589 | loss 4.382e-11 | λ=2.8e+54 | reject
# LM 590 | loss 4.350e-11 | λ=8.4e+54 | reject
# LM 591 | loss 4.382e-11 | λ=2.5e+55 | reject
# LM 592 | loss 4.341e-11 | λ=1.8e+55 | accept
# LM 593 | loss 4.309e-11 | λ=1.2e+55 | accept
# LM 594 | loss 4.344e-11 | λ=3.7e+55 | reject
# LM 595 | loss 4.367e-11 | λ=1.1e+56 | reject
# LM 596 | loss 4.332e-11 | λ=7.7e+55 | accept
# LM 597 | loss 4.377e-11 | λ=2.3e+56 | reject
# LM 598 | loss 4.319e-11 | λ=1.6e+56 | accept
# LM 599 | loss 4.354e-11 | λ=4.9e+56 | reject
# LM 600 | loss 4.315e-11 | λ=3.4e+56 | accept
# LM 601 | loss 4.356e-11 | λ=1.0e+57 | reject
# LM 602 | loss 4.395e-11 | λ=3.1e+57 | reject
# LM 603 | loss 4.382e-11 | λ=9.2e+57 | reject
# LM 604 | loss 4.423e-11 | λ=2.8e+58 | reject
# LM 605 | loss 4.345e-11 | λ=1.9e+58 | accept
# LM 606 | loss 4.356e-11 | λ=5.8e+58 | reject
# LM 607 | loss 4.348e-11 | λ=1.7e+59 | reject
# LM 608 | loss 4.378e-11 | λ=5.2e+59 | reject
# LM 609 | loss 4.391e-11 | λ=1.6e+60 | reject
# LM 610 | loss 4.323e-11 | λ=1.1e+60 | accept
# LM 611 | loss 4.349e-11 | λ=3.3e+60 | reject
# LM 612 | loss 4.379e-11 | λ=9.9e+60 | reject
# LM 613 | loss 4.346e-11 | λ=3.0e+61 | reject
# LM 614 | loss 4.358e-11 | λ=8.9e+61 | reject
# LM 615 | loss 4.405e-11 | λ=2.7e+62 | reject
# LM 616 | loss 4.272e-11 | λ=1.9e+62 | accept
# LM 617 | loss 4.372e-11 | λ=5.6e+62 | reject
# LM 618 | loss 4.330e-11 | λ=3.9e+62 | accept
# LM 619 | loss 4.350e-11 | λ=1.2e+63 | reject
# LM 620 | loss 4.306e-11 | λ=8.2e+62 | accept
# LM 621 | loss 4.338e-11 | λ=5.8e+62 | accept
# LM 622 | loss 4.361e-11 | λ=1.7e+63 | reject
# LM 623 | loss 4.316e-11 | λ=1.2e+63 | accept
# LM 624 | loss 4.327e-11 | λ=8.5e+62 | accept
# LM 625 | loss 4.333e-11 | λ=5.9e+62 | accept
# LM 626 | loss 4.358e-11 | λ=1.8e+63 | reject
# LM 627 | loss 4.370e-11 | λ=1.2e+63 | accept
# LM 628 | loss 4.339e-11 | λ=3.7e+63 | reject
# LM 629 | loss 4.365e-11 | λ=1.1e+64 | reject
# LM 630 | loss 4.379e-11 | λ=3.4e+64 | reject
# LM 631 | loss 4.370e-11 | λ=1.0e+65 | reject
# LM 632 | loss 4.349e-11 | λ=3.0e+65 | reject
# LM 633 | loss 4.381e-11 | λ=9.1e+65 | reject
# LM 634 | loss 4.358e-11 | λ=2.7e+66 | reject
# LM 635 | loss 4.345e-11 | λ=8.2e+66 | reject
# LM 636 | loss 4.361e-11 | λ=5.7e+66 | accept
# LM 637 | loss 4.360e-11 | λ=1.7e+67 | reject
# LM 638 | loss 4.350e-11 | λ=1.2e+67 | accept
# LM 639 | loss 4.349e-11 | λ=8.4e+66 | accept
# LM 640 | loss 4.400e-11 | λ=5.9e+66 | accept
# LM 641 | loss 4.355e-11 | λ=1.8e+67 | reject
# LM 642 | loss 4.319e-11 | λ=1.2e+67 | accept
# LM 643 | loss 4.365e-11 | λ=3.7e+67 | reject
# LM 644 | loss 4.325e-11 | λ=2.6e+67 | accept
# LM 645 | loss 4.347e-11 | λ=1.8e+67 | accept
# LM 646 | loss 4.360e-11 | λ=1.3e+67 | accept
# LM 647 | loss 4.378e-11 | λ=3.8e+67 | reject
# LM 648 | loss 4.360e-11 | λ=1.1e+68 | reject
# LM 649 | loss 4.371e-11 | λ=8.0e+67 | accept
# LM 650 | loss 4.384e-11 | λ=2.4e+68 | reject
# LM 651 | loss 4.341e-11 | λ=1.7e+68 | accept
# LM 652 | loss 4.388e-11 | λ=5.0e+68 | reject
# LM 653 | loss 4.393e-11 | λ=1.5e+69 | reject
# LM 654 | loss 4.348e-11 | λ=1.1e+69 | accept
# LM 655 | loss 4.368e-11 | λ=3.2e+69 | reject
# LM 656 | loss 4.374e-11 | λ=2.2e+69 | accept
# LM 657 | loss 4.318e-11 | λ=1.6e+69 | accept
# LM 658 | loss 4.337e-11 | λ=4.7e+69 | reject
# LM 659 | loss 4.344e-11 | λ=1.4e+70 | reject
# LM 660 | loss 4.368e-11 | λ=4.2e+70 | reject
# LM 661 | loss 4.363e-11 | λ=2.9e+70 | accept
# LM 662 | loss 4.322e-11 | λ=2.1e+70 | accept
# LM 663 | loss 4.350e-11 | λ=6.2e+70 | reject
# LM 664 | loss 4.376e-11 | λ=1.9e+71 | reject
# LM 665 | loss 4.363e-11 | λ=5.6e+71 | reject
# LM 666 | loss 4.367e-11 | λ=3.9e+71 | accept
# LM 667 | loss 4.356e-11 | λ=2.7e+71 | accept
# LM 668 | loss 4.366e-11 | λ=8.2e+71 | reject
# LM 669 | loss 4.399e-11 | λ=2.5e+72 | reject
# LM 670 | loss 4.329e-11 | λ=1.7e+72 | accept
# LM 671 | loss 4.335e-11 | λ=1.2e+72 | accept
# LM 672 | loss 4.343e-11 | λ=3.6e+72 | reject
# LM 673 | loss 4.337e-11 | λ=1.1e+73 | reject
# LM 674 | loss 4.349e-11 | λ=7.6e+72 | accept
# LM 675 | loss 4.444e-11 | λ=2.3e+73 | reject
# LM 676 | loss 4.340e-11 | λ=1.6e+73 | accept
# LM 677 | loss 4.347e-11 | λ=4.8e+73 | reject
# LM 678 | loss 4.362e-11 | λ=1.4e+74 | reject
# LM 679 | loss 4.366e-11 | λ=4.3e+74 | reject
# LM 680 | loss 4.340e-11 | λ=3.0e+74 | accept
# LM 681 | loss 4.376e-11 | λ=9.0e+74 | reject
# LM 682 | loss 4.356e-11 | λ=6.3e+74 | accept
# LM 683 | loss 4.320e-11 | λ=4.4e+74 | accept
# LM 684 | loss 4.354e-11 | λ=3.1e+74 | accept
# LM 685 | loss 4.373e-11 | λ=2.2e+74 | accept
# LM 686 | loss 4.293e-11 | λ=1.5e+74 | accept
# LM 687 | loss 4.410e-11 | λ=4.5e+74 | reject
# LM 688 | loss 4.381e-11 | λ=3.2e+74 | accept
# LM 689 | loss 4.354e-11 | λ=9.6e+74 | reject
# LM 690 | loss 4.391e-11 | λ=2.9e+75 | reject
# LM 691 | loss 4.419e-11 | λ=8.6e+75 | reject
# LM 692 | loss 4.377e-11 | λ=2.6e+76 | reject
# LM 693 | loss 4.403e-11 | λ=7.7e+76 | reject
# LM 694 | loss 4.385e-11 | λ=2.3e+77 | reject
# LM 695 | loss 4.331e-11 | λ=1.6e+77 | accept
# LM 696 | loss 4.441e-11 | λ=4.9e+77 | reject
# LM 697 | loss 4.379e-11 | λ=1.5e+78 | reject
# LM 698 | loss 4.425e-11 | λ=4.4e+78 | reject
# LM 699 | loss 4.340e-11 | λ=3.1e+78 | accept
# LM 700 | loss 4.394e-11 | λ=9.2e+78 | reject
# LM 701 | loss 4.386e-11 | λ=2.8e+79 | reject
# LM 702 | loss 4.367e-11 | λ=8.3e+79 | reject
# LM 703 | loss 4.347e-11 | λ=2.5e+80 | reject
# LM 704 | loss 4.345e-11 | λ=1.7e+80 | accept
# LM 705 | loss 4.330e-11 | λ=1.2e+80 | accept
# LM 706 | loss 4.387e-11 | λ=3.7e+80 | reject
# LM 707 | loss 4.333e-11 | λ=1.1e+81 | reject
# LM 708 | loss 4.305e-11 | λ=7.7e+80 | accept
# LM 709 | loss 4.307e-11 | λ=5.4e+80 | accept
# LM 710 | loss 4.344e-11 | λ=3.8e+80 | accept
# LM 711 | loss 4.318e-11 | λ=2.6e+80 | accept
# LM 712 | loss 4.345e-11 | λ=7.9e+80 | reject
# LM 713 | loss 4.354e-11 | λ=2.4e+81 | reject
# LM 714 | loss 4.363e-11 | λ=7.1e+81 | reject
# LM 715 | loss 4.385e-11 | λ=2.1e+82 | reject
# LM 716 | loss 4.354e-11 | λ=1.5e+82 | accept
# LM 717 | loss 4.404e-11 | λ=4.5e+82 | reject
# LM 718 | loss 4.403e-11 | λ=1.3e+83 | reject
# LM 719 | loss 4.354e-11 | λ=9.4e+82 | accept
# LM 720 | loss 4.363e-11 | λ=2.8e+83 | reject
# LM 721 | loss 4.372e-11 | λ=8.5e+83 | reject
# LM 722 | loss 4.366e-11 | λ=2.5e+84 | reject
# LM 723 | loss 4.378e-11 | λ=7.6e+84 | reject
# LM 724 | loss 4.348e-11 | λ=5.3e+84 | accept
# LM 725 | loss 4.359e-11 | λ=1.6e+85 | reject
# LM 726 | loss 4.385e-11 | λ=4.8e+85 | reject
# LM 727 | loss 4.371e-11 | λ=3.4e+85 | accept
# LM 728 | loss 4.334e-11 | λ=2.4e+85 | accept
# LM 729 | loss 4.369e-11 | λ=1.6e+85 | accept
# LM 730 | loss 4.393e-11 | λ=4.9e+85 | reject
# LM 731 | loss 4.321e-11 | λ=1.5e+86 | reject
# LM 732 | loss 4.360e-11 | λ=4.4e+86 | reject
# LM 733 | loss 4.341e-11 | λ=3.1e+86 | accept
# LM 734 | loss 4.356e-11 | λ=2.2e+86 | accept
# LM 735 | loss 4.401e-11 | λ=6.5e+86 | reject
# LM 736 | loss 4.391e-11 | λ=4.6e+86 | accept
# LM 737 | loss 4.321e-11 | λ=3.2e+86 | accept
# LM 738 | loss 4.380e-11 | λ=9.6e+86 | reject
# LM 739 | loss 4.348e-11 | λ=6.7e+86 | accept
# LM 740 | loss 4.404e-11 | λ=2.0e+87 | reject
# LM 741 | loss 4.363e-11 | λ=1.4e+87 | accept
# LM 742 | loss 4.318e-11 | λ=9.9e+86 | accept
# LM 743 | loss 4.408e-11 | λ=3.0e+87 | reject
# LM 744 | loss 4.400e-11 | λ=8.9e+87 | reject
# LM 745 | loss 4.354e-11 | λ=2.7e+88 | reject
# LM 746 | loss 4.409e-11 | λ=8.0e+88 | reject
# LM 747 | loss 4.339e-11 | λ=2.4e+89 | reject
# LM 748 | loss 4.355e-11 | λ=7.2e+89 | reject
# LM 749 | loss 4.368e-11 | λ=5.0e+89 | accept
# LM 750 | loss 4.352e-11 | λ=1.5e+90 | reject
# LM 751 | loss 4.308e-11 | λ=1.1e+90 | accept
# LM 752 | loss 4.357e-11 | λ=3.2e+90 | reject
# LM 753 | loss 4.332e-11 | λ=9.5e+90 | reject
# LM 754 | loss 4.337e-11 | λ=6.7e+90 | accept
# LM 755 | loss 4.298e-11 | λ=4.7e+90 | accept
# LM 756 | loss 4.373e-11 | λ=3.3e+90 | accept
# LM 757 | loss 4.382e-11 | λ=9.8e+90 | reject
# LM 758 | loss 4.303e-11 | λ=6.9e+90 | accept
# LM 759 | loss 4.359e-11 | λ=2.1e+91 | reject
# LM 760 | loss 4.371e-11 | λ=6.2e+91 | reject
# LM 761 | loss 4.331e-11 | λ=4.3e+91 | accept
# LM 762 | loss 4.347e-11 | λ=1.3e+92 | reject
# LM 763 | loss 4.347e-11 | λ=9.1e+91 | accept
# LM 764 | loss 4.339e-11 | λ=6.4e+91 | accept
# LM 765 | loss 4.366e-11 | λ=1.9e+92 | reject
# LM 766 | loss 4.390e-11 | λ=5.7e+92 | reject
# LM 767 | loss 4.328e-11 | λ=4.0e+92 | accept
# LM 768 | loss 4.366e-11 | λ=1.2e+93 | reject
# LM 769 | loss 4.353e-11 | λ=3.6e+93 | reject
# LM 770 | loss 4.336e-11 | λ=2.5e+93 | accept
# LM 771 | loss 4.364e-11 | λ=7.6e+93 | reject
# LM 772 | loss 4.379e-11 | λ=5.3e+93 | accept
# LM 773 | loss 4.379e-11 | λ=1.6e+94 | reject
# LM 774 | loss 4.387e-11 | λ=4.8e+94 | reject
# LM 775 | loss 4.331e-11 | λ=3.3e+94 | accept
# LM 776 | loss 4.330e-11 | λ=1.0e+95 | reject
# LM 777 | loss 4.410e-11 | λ=3.0e+95 | reject
# LM 778 | loss 4.329e-11 | λ=2.1e+95 | accept
# LM 779 | loss 4.329e-11 | λ=1.5e+95 | accept
# LM 780 | loss 4.369e-11 | λ=1.0e+95 | accept
# LM 781 | loss 4.386e-11 | λ=3.1e+95 | reject
# LM 782 | loss 4.369e-11 | λ=2.2e+95 | accept
# LM 783 | loss 4.330e-11 | λ=1.5e+95 | accept
# LM 784 | loss 4.375e-11 | λ=1.1e+95 | accept
# LM 785 | loss 4.387e-11 | λ=3.2e+95 | reject
# LM 786 | loss 4.397e-11 | λ=9.6e+95 | reject
# LM 787 | loss 4.353e-11 | λ=2.9e+96 | reject
# LM 788 | loss 4.378e-11 | λ=8.6e+96 | reject
# LM 789 | loss 4.343e-11 | λ=2.6e+97 | reject
# LM 790 | loss 4.324e-11 | λ=1.8e+97 | accept
# LM 791 | loss 4.332e-11 | λ=1.3e+97 | accept
# LM 792 | loss 4.333e-11 | λ=8.8e+96 | accept
# LM 793 | loss 4.370e-11 | λ=2.7e+97 | reject
# LM 794 | loss 4.349e-11 | λ=8.0e+97 | reject
# LM 795 | loss 4.383e-11 | λ=2.4e+98 | reject
# LM 796 | loss 4.322e-11 | λ=1.7e+98 | accept
# LM 797 | loss 4.329e-11 | λ=1.2e+98 | accept
# LM 798 | loss 4.362e-11 | λ=8.2e+97 | accept
# LM 799 | loss 4.367e-11 | λ=5.7e+97 | accept
# LM 800 | loss 4.396e-11 | λ=1.7e+98 | reject
# LM 801 | loss 4.337e-11 | λ=5.2e+98 | reject
# LM 802 | loss 4.329e-11 | λ=1.5e+99 | reject
# LM 803 | loss 4.383e-11 | λ=4.6e+99 | reject
# LM 804 | loss 4.375e-11 | λ=3.3e+99 | accept
# LM 805 | loss 4.326e-11 | λ=2.3e+99 | accept
# LM 806 | loss 4.340e-11 | λ=1.6e+99 | accept
# LM 807 | loss 4.355e-11 | λ=1.1e+99 | accept
# LM 808 | loss 4.358e-11 | λ=3.3e+99 | reject
# LM 809 | loss 4.343e-11 | λ=2.3e+99 | accept
# LM 810 | loss 4.369e-11 | λ=7.0e+99 | reject
# LM 811 | loss 4.371e-11 | λ=2.1e+100 | reject
# LM 812 | loss 4.352e-11 | λ=1.5e+100 | accept
# LM 813 | loss 4.351e-11 | λ=1.0e+100 | accept
# LM 814 | loss 4.373e-11 | λ=3.1e+100 | reject
# LM 815 | loss 4.369e-11 | λ=9.3e+100 | reject
# LM 816 | loss 4.370e-11 | λ=6.5e+100 | accept
# LM 817 | loss 4.399e-11 | λ=2.0e+101 | reject
# LM 818 | loss 4.342e-11 | λ=1.4e+101 | accept
# LM 819 | loss 4.356e-11 | λ=9.6e+100 | accept
# LM 820 | loss 4.385e-11 | λ=2.9e+101 | reject
# LM 821 | loss 4.402e-11 | λ=8.6e+101 | reject
# LM 822 | loss 4.322e-11 | λ=6.0e+101 | accept
# LM 823 | loss 4.386e-11 | λ=1.8e+102 | reject
# LM 824 | loss 4.425e-11 | λ=5.4e+102 | reject
# LM 825 | loss 4.350e-11 | λ=3.8e+102 | accept
# LM 826 | loss 4.327e-11 | λ=2.7e+102 | accept
# LM 827 | loss 4.381e-11 | λ=1.9e+102 | accept
# LM 828 | loss 4.367e-11 | λ=1.3e+102 | accept
# LM 829 | loss 4.299e-11 | λ=9.1e+101 | accept
# LM 830 | loss 4.390e-11 | λ=2.7e+102 | reject
# LM 831 | loss 4.335e-11 | λ=1.9e+102 | accept
# LM 832 | loss 4.364e-11 | λ=1.3e+102 | accept
# LM 833 | loss 4.361e-11 | λ=4.0e+102 | reject
# LM 834 | loss 4.355e-11 | λ=2.8e+102 | accept
# LM 835 | loss 4.297e-11 | λ=2.0e+102 | accept
# LM 836 | loss 4.324e-11 | λ=5.9e+102 | reject
# LM 837 | loss 4.369e-11 | λ=4.1e+102 | accept
# LM 838 | loss 4.338e-11 | λ=2.9e+102 | accept
# LM 839 | loss 4.370e-11 | λ=2.0e+102 | accept
# LM 840 | loss 4.289e-11 | λ=1.4e+102 | accept
# LM 841 | loss 4.361e-11 | λ=9.9e+101 | accept
# LM 842 | loss 4.389e-11 | λ=3.0e+102 | reject
# LM 843 | loss 4.418e-11 | λ=8.9e+102 | reject
# LM 844 | loss 4.363e-11 | λ=2.7e+103 | reject
# LM 845 | loss 4.353e-11 | λ=1.9e+103 | accept
# LM 846 | loss 4.361e-11 | λ=5.6e+103 | reject
# LM 847 | loss 4.363e-11 | λ=1.7e+104 | reject
# LM 848 | loss 4.339e-11 | λ=5.1e+104 | reject
# LM 849 | loss 4.398e-11 | λ=1.5e+105 | reject
# LM 850 | loss 4.393e-11 | λ=4.6e+105 | reject
# LM 851 | loss 4.378e-11 | λ=3.2e+105 | accept
# LM 852 | loss 4.350e-11 | λ=2.2e+105 | accept
# LM 853 | loss 4.415e-11 | λ=6.7e+105 | reject
# LM 854 | loss 4.362e-11 | λ=4.7e+105 | accept
# LM 855 | loss 4.344e-11 | λ=3.3e+105 | accept
# LM 856 | loss 4.362e-11 | λ=2.3e+105 | accept
# LM 857 | loss 4.321e-11 | λ=1.6e+105 | accept
# LM 858 | loss 4.382e-11 | λ=1.1e+105 | accept
# LM 859 | loss 4.356e-11 | λ=7.9e+104 | accept
# LM 860 | loss 4.357e-11 | λ=5.5e+104 | accept
# LM 861 | loss 4.352e-11 | λ=3.9e+104 | accept
# LM 862 | loss 4.414e-11 | λ=1.2e+105 | reject
# LM 863 | loss 4.319e-11 | λ=8.1e+104 | accept
# LM 864 | loss 4.408e-11 | λ=2.4e+105 | reject
# LM 865 | loss 4.378e-11 | λ=7.3e+105 | reject
# LM 866 | loss 4.391e-11 | λ=2.2e+106 | reject
# LM 867 | loss 4.351e-11 | λ=1.5e+106 | accept
# LM 868 | loss 4.421e-11 | λ=4.6e+106 | reject
# LM 869 | loss 4.363e-11 | λ=3.2e+106 | accept
# LM 870 | loss 4.334e-11 | λ=2.3e+106 | accept
# LM 871 | loss 4.378e-11 | λ=6.8e+106 | reject
# LM 872 | loss 4.325e-11 | λ=4.7e+106 | accept
# LM 873 | loss 4.395e-11 | λ=1.4e+107 | reject
# LM 874 | loss 4.368e-11 | λ=4.3e+107 | reject
# LM 875 | loss 4.433e-11 | λ=1.3e+108 | reject
# LM 876 | loss 4.311e-11 | λ=9.0e+107 | accept
# LM 877 | loss 4.365e-11 | λ=2.7e+108 | reject
# LM 878 | loss 4.364e-11 | λ=8.1e+108 | reject
# LM 879 | loss 4.346e-11 | λ=2.4e+109 | reject
# LM 880 | loss 4.407e-11 | λ=7.2e+109 | reject
# LM 881 | loss 4.314e-11 | λ=5.1e+109 | accept
# LM 882 | loss 4.366e-11 | λ=1.5e+110 | reject
# LM 883 | loss 4.343e-11 | λ=4.6e+110 | reject
# LM 884 | loss 4.322e-11 | λ=3.2e+110 | accept
# LM 885 | loss 4.346e-11 | λ=2.2e+110 | accept
# LM 886 | loss 4.338e-11 | λ=1.6e+110 | accept
# LM 887 | loss 4.311e-11 | λ=1.1e+110 | accept
# LM 888 | loss 4.294e-11 | λ=7.7e+109 | accept
# LM 889 | loss 4.367e-11 | λ=5.4e+109 | accept
# LM 890 | loss 4.366e-11 | λ=3.8e+109 | accept
# LM 891 | loss 4.315e-11 | λ=2.6e+109 | accept
# LM 892 | loss 4.335e-11 | λ=7.9e+109 | reject
# LM 893 | loss 4.402e-11 | λ=2.4e+110 | reject
# LM 894 | loss 4.383e-11 | λ=7.1e+110 | reject
# LM 895 | loss 4.323e-11 | λ=5.0e+110 | accept
# LM 896 | loss 4.305e-11 | λ=3.5e+110 | accept
# LM 897 | loss 4.430e-11 | λ=1.0e+111 | reject
# LM 898 | loss 4.380e-11 | λ=7.3e+110 | accept
# LM 899 | loss 4.357e-11 | λ=5.1e+110 | accept
# LM 900 | loss 4.367e-11 | λ=1.5e+111 | reject
# LM 901 | loss 4.333e-11 | λ=1.1e+111 | accept
# LM 902 | loss 4.367e-11 | λ=3.2e+111 | reject
# LM 903 | loss 4.295e-11 | λ=2.3e+111 | accept
# LM 904 | loss 4.317e-11 | λ=1.6e+111 | accept
# LM 905 | loss 4.355e-11 | λ=1.1e+111 | accept
# LM 906 | loss 4.400e-11 | λ=3.3e+111 | reject
# LM 907 | loss 4.402e-11 | λ=1.0e+112 | reject
# LM 908 | loss 4.376e-11 | λ=3.0e+112 | reject
# LM 909 | loss 4.355e-11 | λ=2.1e+112 | accept
# LM 910 | loss 4.371e-11 | λ=6.3e+112 | reject
# LM 911 | loss 4.345e-11 | λ=4.4e+112 | accept
# LM 912 | loss 4.312e-11 | λ=3.1e+112 | accept
# LM 913 | loss 4.398e-11 | λ=9.2e+112 | reject
# LM 914 | loss 4.355e-11 | λ=2.8e+113 | reject
# LM 915 | loss 4.346e-11 | λ=8.3e+113 | reject
# LM 916 | loss 4.360e-11 | λ=5.8e+113 | accept
# LM 917 | loss 4.363e-11 | λ=1.7e+114 | reject
# LM 918 | loss 4.353e-11 | λ=1.2e+114 | accept
# LM 919 | loss 4.315e-11 | λ=8.5e+113 | accept
# LM 920 | loss 4.402e-11 | λ=2.6e+114 | reject
# LM 921 | loss 4.308e-11 | λ=1.8e+114 | accept
# LM 922 | loss 4.321e-11 | λ=1.3e+114 | accept
# LM 923 | loss 4.375e-11 | λ=3.8e+114 | reject
# LM 924 | loss 4.338e-11 | λ=1.1e+115 | reject
# LM 925 | loss 4.370e-11 | λ=3.4e+115 | reject
# LM 926 | loss 4.376e-11 | λ=1.0e+116 | reject
# LM 927 | loss 4.361e-11 | λ=3.1e+116 | reject
# LM 928 | loss 4.368e-11 | λ=2.1e+116 | accept
# LM 929 | loss 4.358e-11 | λ=1.5e+116 | accept
# LM 930 | loss 4.360e-11 | λ=4.5e+116 | reject
# LM 931 | loss 4.359e-11 | λ=3.1e+116 | accept
# LM 932 | loss 4.339e-11 | λ=9.4e+116 | reject
# LM 933 | loss 4.367e-11 | λ=6.6e+116 | accept
# LM 934 | loss 4.425e-11 | λ=2.0e+117 | reject
# LM 935 | loss 4.353e-11 | λ=5.9e+117 | reject
# LM 936 | loss 4.344e-11 | λ=1.8e+118 | reject
# LM 937 | loss 4.310e-11 | λ=1.2e+118 | accept
# LM 938 | loss 4.314e-11 | λ=8.7e+117 | accept
# LM 939 | loss 4.391e-11 | λ=2.6e+118 | reject
# LM 940 | loss 4.343e-11 | λ=1.8e+118 | accept
# LM 941 | loss 4.359e-11 | λ=1.3e+118 | accept
# LM 942 | loss 4.403e-11 | λ=3.8e+118 | reject
# LM 943 | loss 4.379e-11 | λ=1.2e+119 | reject
# LM 944 | loss 4.335e-11 | λ=8.1e+118 | accept
# LM 945 | loss 4.336e-11 | λ=2.4e+119 | reject
# LM 946 | loss 4.327e-11 | λ=1.7e+119 | accept
# LM 947 | loss 4.353e-11 | λ=1.2e+119 | accept
# LM 948 | loss 4.336e-11 | λ=8.3e+118 | accept
# LM 949 | loss 4.382e-11 | λ=5.8e+118 | accept
# LM 950 | loss 4.366e-11 | λ=1.7e+119 | reject
# LM 951 | loss 4.349e-11 | λ=5.2e+119 | reject
# LM 952 | loss 4.319e-11 | λ=3.7e+119 | accept
# LM 953 | loss 4.394e-11 | λ=1.1e+120 | reject
# LM 954 | loss 4.342e-11 | λ=3.3e+120 | reject
# LM 955 | loss 4.398e-11 | λ=9.9e+120 | reject
# LM 956 | loss 4.335e-11 | λ=6.9e+120 | accept
# LM 957 | loss 4.317e-11 | λ=4.8e+120 | accept
# LM 958 | loss 4.383e-11 | λ=1.5e+121 | reject
# LM 959 | loss 4.317e-11 | λ=1.0e+121 | accept
# LM 960 | loss 4.402e-11 | λ=3.1e+121 | reject
# LM 961 | loss 4.369e-11 | λ=9.2e+121 | reject
# LM 962 | loss 4.341e-11 | λ=6.4e+121 | accept
# LM 963 | loss 4.369e-11 | λ=1.9e+122 | reject
# LM 964 | loss 4.311e-11 | λ=1.3e+122 | accept
# LM 965 | loss 4.334e-11 | λ=9.4e+121 | accept
# LM 966 | loss 4.308e-11 | λ=2.8e+122 | reject
# LM 967 | loss 4.359e-11 | λ=8.5e+122 | reject
# LM 968 | loss 4.377e-11 | λ=2.5e+123 | reject
# LM 969 | loss 4.334e-11 | λ=7.6e+123 | reject
# LM 970 | loss 4.339e-11 | λ=5.3e+123 | accept
# LM 971 | loss 4.346e-11 | λ=3.7e+123 | accept
# LM 972 | loss 4.331e-11 | λ=2.6e+123 | accept
# LM 973 | loss 4.363e-11 | λ=1.8e+123 | accept
# LM 974 | loss 4.393e-11 | λ=5.5e+123 | reject
# LM 975 | loss 4.345e-11 | λ=3.9e+123 | accept
# LM 976 | loss 4.320e-11 | λ=1.2e+124 | reject
# LM 977 | loss 4.318e-11 | λ=8.1e+123 | accept
# LM 978 | loss 4.337e-11 | λ=5.7e+123 | accept
# LM 979 | loss 4.360e-11 | λ=1.7e+124 | reject
# LM 980 | loss 4.369e-11 | λ=1.2e+124 | accept
# LM 981 | loss 4.338e-11 | λ=8.3e+123 | accept
# LM 982 | loss 4.372e-11 | λ=5.8e+123 | accept
# LM 983 | loss 4.339e-11 | λ=4.1e+123 | accept
# LM 984 | loss 4.353e-11 | λ=1.2e+124 | reject
# LM 985 | loss 4.315e-11 | λ=8.6e+123 | accept
# LM 986 | loss 4.313e-11 | λ=6.0e+123 | accept
# LM 987 | loss 4.347e-11 | λ=1.8e+124 | reject
# LM 988 | loss 4.324e-11 | λ=1.3e+124 | accept
# LM 989 | loss 4.329e-11 | λ=8.8e+123 | accept
# LM 990 | loss 4.394e-11 | λ=2.6e+124 | reject
# LM 991 | loss 4.340e-11 | λ=1.9e+124 | accept
# LM 992 | loss 4.352e-11 | λ=5.6e+124 | reject
# LM 993 | loss 4.338e-11 | λ=3.9e+124 | accept
# LM 994 | loss 4.367e-11 | λ=1.2e+125 | reject
# LM 995 | loss 4.383e-11 | λ=3.5e+125 | reject
# LM 996 | loss 4.322e-11 | λ=2.4e+125 | accept
# LM 997 | loss 4.371e-11 | λ=7.3e+125 | reject
# LM 998 | loss 4.357e-11 | λ=5.1e+125 | accept
# LM 999 | loss 4.354e-11 | λ=1.5e+126 | reject

# %%
def eval_u(model, x, y):
    phi = compute_phi(x, y)
    inp = torch.cat([x, y, phi], dim=1)
    return model(inp), phi

def make_grid(N=100):
    x = torch.linspace(X_MIN, X_MAX, N)
    y = torch.linspace(Y_MIN, Y_MAX, N)
    X, Y = torch.meshgrid(x, y, indexing="ij")
    return X, Y

X, Y = make_grid(100)

xg = X.reshape(-1, 1).to(device)
yg = Y.reshape(-1, 1).to(device)

with torch.no_grad():   
    Ug, U_ext = eval_u(model, xg, yg)

U = Ug.reshape(X.shape).cpu().numpy()
U_ext = U_ext.reshape(X.shape).cpu().numpy()
Xn = X.cpu().numpy()
Yn = Y.cpu().numpy()

# 逐點相對誤差
U_ext_inf_norm = np.max(np.abs(U_ext))   # 真實解的 inf norm
error_rel = np.abs(U - U_ext) / (U_ext_inf_norm)
# 整體相對誤差
diff = torch.from_numpy(np.abs(U - U_ext)).double()
u_ext_2_norm = torch.from_numpy(np.abs(U_ext)).double()
error_1 = torch.norm(diff) / torch.norm(u_ext_2_norm)
error_2 = torch.norm(diff, p=float('inf')) / U_ext_inf_norm  
print("Relative L2 error:", error_1.item())
print("Relative Infinity norm error:", error_2.item())
# 畫圖
fig, axs = plt.subplots(1, 3, figsize=(18,5))

im0 = axs[0].contourf(Xn, Yn, U, 50, cmap='viridis')
fig.colorbar(im0, ax=axs[0])
axs[0].set_title('PINN Prediction $u_N$')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')

im1 = axs[1].contourf(Xn, Yn, U_ext, 50, cmap='viridis')
fig.colorbar(im1, ax=axs[1])
axs[1].set_title('Analytical Solution $\\phi$')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')

im2 = axs[2].contourf(Xn, Yn, error_rel, 50, cmap='hot')
fig.colorbar(im2, ax=axs[2])
axs[2].set_title('Relative Error')
axs[2].set_xlabel('x')
axs[2].set_ylabel('y')

plt.tight_layout()
plt.show()
# Out:
# Relative L2 error: 9.181353563482223e-05
# Relative Infinity norm error: 0.00020569868822682225

# %%
n_theta = sum(p.numel() for p in model.parameters())
print(n_theta)
print(m)
print(n)
# Out:
# 200
# 220
# 200

# %%
lap_u = laplace_u(model, xg, yg) 
residual = -lap_u
abs_residual = torch.abs(residual).detach().cpu().numpy()
log_abs_residual = torch.log(torch.abs(residual)).detach().cpu().numpy()
abs_residual = abs_residual.reshape(X.shape)
log_abs_residual = log_abs_residual.reshape(X.shape)

fig, axs = plt.subplots(1, 2, figsize=(15,5))

im0 = axs[0].contourf(X, Y, abs_residual, 50, cmap='viridis')
fig.colorbar(im0, ax=axs[0])
axs[0].set_title('|Residual| = |-Δu|')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].set_aspect('equal')

im1 = axs[1].contourf(X, Y, log_abs_residual, 50, cmap='viridis')
fig.colorbar(im1, ax=axs[1])
axs[1].set_title('log|Residual| = log|-Δu|')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')
axs[1].set_aspect('equal')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.semilogy(loss_history_LM, lw=2)
plt.xlabel("LM iteration")
plt.ylabel("loss")
plt.title("LM training loss")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Save training loss for plotting later
np.savez(
    "lm_loss.npz",
    epoch=epochs_LM,
    loss=loss_history_LM
)
