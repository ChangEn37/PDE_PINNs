# %% [markdown]
# f=0, crack: origin to (1,0), with exact solution.

# %%
import torch
import torch.nn as nn
import numpy as np
import math
import matplotlib.pyplot as plt
torch.set_default_dtype(torch.float64)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

X_MIN, X_MAX = -1.0, 1.0
Y_MIN, Y_MAX = -1.0, 1.0
N_b = 20
N_f = 4 * N_b
N_tip = N_b
N_b_crack = N_b

lam, lam_up, lam_down = 1e3, 3.0, 0.7
epochs_LM = 1000

class MLP(nn.Module):
    def __init__(self, layers):
        super().__init__()
        self.layers = nn.ModuleList()

        for i in range(len(layers) - 1):
            #  最後一層不加 bias
            if i == len(layers) - 2:
                self.layers.append(
                    nn.Linear(layers[i], layers[i+1], bias=False)
                )
            else:
                self.layers.append(
                    nn.Linear(layers[i], layers[i+1], bias=True)
                )

        self.act = torch.tanh

        # initialization
        for m in self.layers:
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight)
                if m.bias is not None:  
                    nn.init.zeros_(m.bias)

    def forward(self, x):
        for l in self.layers[:-1]:
            x = self.act(l(x))
        return self.layers[-1](x)


model = MLP([3, 40, 1]).to(device)

# %%
def compute_phi(x, y):
    eps = 1e-12
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=eps))
    return torch.sqrt(0.5 * (r - x))

def compute_phi_derivs(x, y):
    eps = 1e-12
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=eps))
    sqrt = torch.sqrt(torch.clamp(r - x, min=eps))

    coef = math.sqrt(2) / 4
    phi_x = -coef * sqrt / r
    phi_y = coef * y / (r * sqrt)

    return phi_x, phi_y

def first_derivs(model, x, y):
    phi = compute_phi(x, y)
    inp = torch.cat([x, y, phi], dim=1).requires_grad_(True)

    U = model(inp).view(-1, 1)

    grads = torch.autograd.grad(
        outputs=U.sum(),
        inputs=inp,
        create_graph=True
    )[0]

    return U, inp, grads[:,0:1], grads[:,1:2], grads[:,2:3]

def second_partials_U(inp, U_x, U_y, U_z):

    grad_Ux = torch.autograd.grad(
        outputs=U_x.sum(),
        inputs=inp,
        create_graph=True
    )[0]

    grad_Uy = torch.autograd.grad(
        outputs=U_y.sum(),
        inputs=inp,
        create_graph=True
    )[0]

    grad_Uz = torch.autograd.grad(
        outputs=U_z.sum(),
        inputs=inp,
        create_graph=True
    )[0]

    U_xx = grad_Ux[:, 0:1]
    #U_xy = grad_Ux[:, 1:2]
    U_xz = grad_Ux[:, 2:3]

    U_yy = grad_Uy[:, 1:2]
    U_yz = grad_Uy[:, 2:3]

    U_zz = grad_Uz[:, 2:3]

    return U_xx, U_yy, U_xz, U_yz, U_zz

def laplace_u(model, x, y):
    phi_x, phi_y = compute_phi_derivs(x, y)
    U, inp, U_x, U_y, U_z = first_derivs(model, x, y)
    U_xx, U_yy, U_xz, U_yz, U_zz = second_partials_U(inp, U_x, U_y, U_z)

    eps = 1e-12
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=eps))

    lap = (U_xx + U_yy
           + 2*(U_xz * phi_x + U_yz * phi_y)
           + (1/(4*r))*U_zz)
    return lap

# functions for sampling

def sample_collocation(N):
    x = torch.rand(N*2,1)*(X_MAX-X_MIN)+X_MIN
    y = torch.rand(N*2,1)*(Y_MAX-Y_MIN)+Y_MIN

    mask = ~((torch.abs(y) < 1e-8) & (x >= 0))
    idx = mask.squeeze(1)  

    x = x[idx][:N]
    y = y[idx][:N]

    return x.to(device), y.to(device)


def sample_boundary(N):
    t = torch.linspace(-1,1,N).view(-1,1)
    xb = torch.cat([t, t, -torch.ones_like(t), torch.ones_like(t)])
    yb = torch.cat([-torch.ones_like(t), torch.ones_like(t), t, t])
    return xb.to(device), yb.to(device)

def sample_tip_and_crack(N_tip, N_b_crack):
    # crack 上（不含 tip）
    x_c = torch.linspace(1e-4, 1.0, N_b_crack, device=device).unsqueeze(1)
    y_c = torch.zeros_like(x_c)

    # tip neighborhood: small disk around (0,0)
    theta = torch.linspace(0, 2*np.pi, N_tip)
    r = 1e-3 * torch.ones_like(theta)
    x_t = (r * torch.cos(theta)).view(-1,1)
    y_t = (r * torch.sin(theta)).view(-1,1)

    return x_c, y_c, x_t, y_t

# Residual vector 
def residual_vector(model):
    res = []

    # PDE
    lap = laplace_u(model, x_f, y_f)
    res.append(lap.view(-1))

    # Boundary
    phi_b = compute_phi(x_b, y_b)
    inp_b = torch.cat([x_b, y_b, phi_b], dim=1)
    res.append((model(inp_b) - phi_b).view(-1))

    # Crack-tip regularization 
    x_c, y_c, x_t, y_t = sample_tip_and_crack(N_tip, N_b_crack)
    _, inp_tip, U_x_tip, U_y_tip, U_z_tip = first_derivs(model, x_t, y_t)
    _, _, U_xz_tip, U_yz_tip, U_zz_tip = second_partials_U(inp_tip, U_x_tip, U_y_tip, U_z_tip)
    _, inp_c, U_x_c, U_y_c, U_z_c = first_derivs(model, x_c, y_c)
    _, _, U_xz_c, U_yz_c, _ = second_partials_U(inp_c, U_x_c, U_y_c, U_z_c)

    res += [U_zz_tip.view(-1), U_xz_tip.view(-1), U_yz_tip.view(-1)] # 
    res += [U_xz_c.view(-1), U_yz_c.view(-1)] #
    return torch.cat(res)

# LM utilities
def flatten_params(model):
    return torch.cat([p.view(-1) for p in model.parameters()])

def set_params(model, theta):
    i = 0
    for p in model.parameters():
        n = p.numel()
        p.data.copy_(theta[i:i+n].view_as(p))
        i += n

def lm_step(model, lam):
    r = residual_vector(model)
    loss = torch.dot(r, r)

    theta = flatten_params(model)
    n, m = theta.numel(), r.numel()
    J = torch.zeros(m, n, device=device)

    for i in range(m):
        grads = torch.autograd.grad(r[i], model.parameters(), retain_graph=True)
        J[i] = torch.cat([g.view(-1) for g in grads])

    A = J.T @ J + lam * torch.eye(n, device=device)
    delta = torch.linalg.solve(A, -J.T @ r)

    set_params(model, theta + delta)
    return loss.item(), theta, delta, m, n

# %%
# Training
# =========================
x_f, y_f = sample_collocation(N_f)
x_b, y_b = sample_boundary(N_b)
loss_history_LM = []
lam_history = []


for ep in range(epochs_LM):
    loss0, theta_old, delta, m, n = lm_step(model, lam)

    r_new = residual_vector(model)
    loss1 = torch.dot(r_new, r_new).item()

    if loss1 < loss0:
        lam *= lam_down
        status = "accept"
    else:
        lam *= lam_up
        set_params(model, theta_old)
        status = "reject"

    loss_history_LM.append(loss1)
    lam_history.append(lam)
    epochs_LM = np.arange(len(loss_history_LM))


    print(f"LM {ep:02d} | loss {loss1:.3e} | λ={lam:.1e} | {status}")
# Out:
# LM 00 | loss 3.506e+01 | λ=7.0e+02 | accept
# LM 01 | loss 2.262e+01 | λ=4.9e+02 | accept
# LM 02 | loss 1.287e+01 | λ=3.4e+02 | accept
# LM 03 | loss 6.509e+00 | λ=2.4e+02 | accept
# LM 04 | loss 3.230e+00 | λ=1.7e+02 | accept
# LM 05 | loss 1.925e+00 | λ=1.2e+02 | accept
# LM 06 | loss 1.476e+00 | λ=8.2e+01 | accept
# LM 07 | loss 1.258e+00 | λ=5.8e+01 | accept
# LM 08 | loss 1.067e+00 | λ=4.0e+01 | accept
# LM 09 | loss 8.694e-01 | λ=2.8e+01 | accept
# LM 10 | loss 6.770e-01 | λ=2.0e+01 | accept
# LM 11 | loss 5.046e-01 | λ=1.4e+01 | accept
# LM 12 | loss 3.624e-01 | λ=9.7e+00 | accept
# LM 13 | loss 2.516e-01 | λ=6.8e+00 | accept
# LM 14 | loss 1.669e-01 | λ=4.7e+00 | accept
# LM 15 | loss 1.029e-01 | λ=3.3e+00 | accept
# LM 16 | loss 5.728e-02 | λ=2.3e+00 | accept
# LM 17 | loss 2.892e-02 | λ=1.6e+00 | accept
# LM 18 | loss 1.453e-02 | λ=1.1e+00 | accept
# LM 19 | loss 8.532e-03 | λ=8.0e-01 | accept
# LM 20 | loss 6.122e-03 | λ=5.6e-01 | accept
# LM 21 | loss 4.892e-03 | λ=3.9e-01 | accept
# LM 22 | loss 4.044e-03 | λ=2.7e-01 | accept
# LM 23 | loss 3.361e-03 | λ=1.9e-01 | accept
# LM 24 | loss 2.778e-03 | λ=1.3e-01 | accept
# LM 25 | loss 2.269e-03 | λ=9.4e-02 | accept
# LM 26 | loss 1.826e-03 | λ=6.6e-02 | accept
# LM 27 | loss 1.448e-03 | λ=4.6e-02 | accept
# LM 28 | loss 1.136e-03 | λ=3.2e-02 | accept
# LM 29 | loss 8.857e-04 | λ=2.3e-02 | accept
# LM 30 | loss 6.903e-04 | λ=1.6e-02 | accept
# LM 31 | loss 5.404e-04 | λ=1.1e-02 | accept
# LM 32 | loss 4.268e-04 | λ=7.7e-03 | accept
# LM 33 | loss 3.407e-04 | λ=5.4e-03 | accept
# LM 34 | loss 2.737e-04 | λ=3.8e-03 | accept
# LM 35 | loss 2.147e-04 | λ=2.7e-03 | accept
# LM 36 | loss 1.499e-04 | λ=1.9e-03 | accept
# LM 37 | loss 8.360e-05 | λ=1.3e-03 | accept
# LM 38 | loss 4.171e-05 | λ=9.1e-04 | accept
# LM 39 | loss 2.529e-05 | λ=6.4e-04 | accept
# LM 40 | loss 1.901e-05 | λ=4.5e-04 | accept
# LM 41 | loss 1.488e-05 | λ=3.1e-04 | accept
# LM 42 | loss 1.062e-05 | λ=2.2e-04 | accept
# LM 43 | loss 6.875e-06 | λ=1.5e-04 | accept
# LM 44 | loss 4.452e-06 | λ=1.1e-04 | accept
# LM 45 | loss 3.199e-06 | λ=7.5e-05 | accept
# LM 46 | loss 2.589e-06 | λ=5.2e-05 | accept
# LM 47 | loss 2.183e-06 | λ=3.7e-05 | accept
# LM 48 | loss 1.797e-06 | λ=2.6e-05 | accept
# LM 49 | loss 1.454e-06 | λ=1.8e-05 | accept
# LM 50 | loss 1.174e-06 | λ=1.3e-05 | accept
# LM 51 | loss 9.360e-07 | λ=8.8e-06 | accept
# LM 52 | loss 7.685e-07 | λ=6.2e-06 | accept
# LM 53 | loss 7.404e-07 | λ=4.3e-06 | accept
# LM 54 | loss 7.732e-07 | λ=1.3e-05 | reject
# LM 55 | loss 4.687e-08 | λ=9.1e-06 | accept
# LM 56 | loss 6.219e-08 | λ=2.7e-05 | reject
# LM 57 | loss 2.606e-08 | λ=1.9e-05 | accept
# LM 58 | loss 2.517e-08 | λ=1.3e-05 | accept
# LM 59 | loss 2.608e-08 | λ=4.0e-05 | reject
# LM 60 | loss 2.224e-08 | λ=2.8e-05 | accept
# LM 61 | loss 2.123e-08 | λ=2.0e-05 | accept
# LM 62 | loss 2.033e-08 | λ=1.4e-05 | accept
# LM 63 | loss 2.007e-08 | λ=9.6e-06 | accept
# LM 64 | loss 2.102e-08 | λ=2.9e-05 | reject
# LM 65 | loss 1.706e-08 | λ=2.0e-05 | accept
# LM 66 | loss 1.632e-08 | λ=1.4e-05 | accept
# LM 67 | loss 1.565e-08 | λ=9.9e-06 | accept
# LM 68 | loss 1.529e-08 | λ=6.9e-06 | accept
# LM 69 | loss 1.523e-08 | λ=4.8e-06 | accept
# LM 70 | loss 1.497e-08 | λ=3.4e-06 | accept
# LM 71 | loss 1.400e-08 | λ=2.4e-06 | accept
# LM 72 | loss 1.291e-08 | λ=1.7e-06 | accept
# LM 73 | loss 1.308e-08 | λ=5.0e-06 | reject
# LM 74 | loss 7.711e-09 | λ=3.5e-06 | accept
# LM 75 | loss 7.407e-09 | λ=2.4e-06 | accept
# LM 76 | loss 7.344e-09 | λ=1.7e-06 | accept
# LM 77 | loss 8.218e-09 | λ=5.1e-06 | reject
# LM 78 | loss 6.197e-09 | λ=3.6e-06 | accept
# LM 79 | loss 5.973e-09 | λ=2.5e-06 | accept
# LM 80 | loss 5.905e-09 | λ=1.8e-06 | accept
# LM 81 | loss 6.570e-09 | λ=5.3e-06 | reject
# LM 82 | loss 5.295e-09 | λ=3.7e-06 | accept
# LM 83 | loss 5.130e-09 | λ=2.6e-06 | accept
# LM 84 | loss 5.069e-09 | λ=1.8e-06 | accept
# LM 85 | loss 5.530e-09 | λ=5.4e-06 | reject
# LM 86 | loss 4.649e-09 | λ=3.8e-06 | accept
# LM 87 | loss 4.520e-09 | λ=2.7e-06 | accept
# LM 88 | loss 4.456e-09 | λ=1.9e-06 | accept
# LM 89 | loss 4.744e-09 | λ=5.6e-06 | reject
# LM 90 | loss 4.150e-09 | λ=3.9e-06 | accept
# LM 91 | loss 4.043e-09 | λ=2.7e-06 | accept
# LM 92 | loss 3.973e-09 | λ=1.9e-06 | accept
# LM 93 | loss 4.134e-09 | λ=5.7e-06 | reject
# LM 94 | loss 3.748e-09 | λ=4.0e-06 | accept
# LM 95 | loss 3.657e-09 | λ=2.8e-06 | accept
# LM 96 | loss 3.584e-09 | λ=2.0e-06 | accept
# LM 97 | loss 3.658e-09 | λ=5.9e-06 | reject
# LM 98 | loss 3.418e-09 | λ=4.1e-06 | accept
# LM 99 | loss 3.338e-09 | λ=2.9e-06 | accept
# LM 100 | loss 3.265e-09 | λ=2.0e-06 | accept
# LM 101 | loss 3.284e-09 | λ=6.1e-06 | reject
# LM 102 | loss 3.140e-09 | λ=4.3e-06 | accept
# LM 103 | loss 3.071e-09 | λ=3.0e-06 | accept
# LM 104 | loss 2.999e-09 | λ=2.1e-06 | accept
# LM 105 | loss 2.985e-09 | λ=1.5e-06 | accept
# LM 106 | loss 3.226e-09 | λ=4.4e-06 | reject
# LM 107 | loss 2.753e-09 | λ=3.1e-06 | accept
# LM 108 | loss 2.688e-09 | λ=2.1e-06 | accept
# LM 109 | loss 2.651e-09 | λ=1.5e-06 | accept
# LM 110 | loss 2.766e-09 | λ=4.5e-06 | reject
# LM 111 | loss 2.494e-09 | λ=3.2e-06 | accept
# LM 112 | loss 2.436e-09 | λ=2.2e-06 | accept
# LM 113 | loss 2.389e-09 | λ=1.5e-06 | accept
# LM 114 | loss 2.434e-09 | λ=4.6e-06 | reject
# LM 115 | loss 2.280e-09 | λ=3.2e-06 | accept
# LM 116 | loss 2.228e-09 | λ=2.3e-06 | accept
# LM 117 | loss 2.179e-09 | λ=1.6e-06 | accept
# LM 118 | loss 2.184e-09 | λ=4.8e-06 | reject
# LM 119 | loss 2.100e-09 | λ=3.3e-06 | accept
# LM 120 | loss 2.054e-09 | λ=2.3e-06 | accept
# LM 121 | loss 2.006e-09 | λ=1.6e-06 | accept
# LM 122 | loss 1.989e-09 | λ=1.1e-06 | accept
# LM 123 | loss 2.114e-09 | λ=3.4e-06 | reject
# LM 124 | loss 1.849e-09 | λ=2.4e-06 | accept
# LM 125 | loss 1.805e-09 | λ=1.7e-06 | accept
# LM 126 | loss 1.774e-09 | λ=1.2e-06 | accept
# LM 127 | loss 1.825e-09 | λ=3.5e-06 | reject
# LM 128 | loss 1.681e-09 | λ=2.5e-06 | accept
# LM 129 | loss 1.642e-09 | λ=1.7e-06 | accept
# LM 130 | loss 1.607e-09 | λ=1.2e-06 | accept
# LM 131 | loss 1.618e-09 | λ=3.6e-06 | reject
# LM 132 | loss 1.543e-09 | λ=2.5e-06 | accept
# LM 133 | loss 1.508e-09 | λ=1.8e-06 | accept
# LM 134 | loss 1.473e-09 | λ=1.2e-06 | accept
# LM 135 | loss 1.463e-09 | λ=8.7e-07 | accept
# LM 136 | loss 1.563e-09 | λ=2.6e-06 | reject
# LM 137 | loss 1.351e-09 | λ=1.8e-06 | accept
# LM 138 | loss 1.319e-09 | λ=1.3e-06 | accept
# LM 139 | loss 1.296e-09 | λ=9.0e-07 | accept
# LM 140 | loss 1.335e-09 | λ=2.7e-06 | reject
# LM 141 | loss 1.225e-09 | λ=1.9e-06 | accept
# LM 142 | loss 1.195e-09 | λ=1.3e-06 | accept
# LM 143 | loss 1.169e-09 | λ=9.3e-07 | accept
# LM 144 | loss 1.176e-09 | λ=2.8e-06 | reject
# LM 145 | loss 1.120e-09 | λ=1.9e-06 | accept
# LM 146 | loss 1.094e-09 | λ=1.4e-06 | accept
# LM 147 | loss 1.067e-09 | λ=9.5e-07 | accept
# LM 148 | loss 1.059e-09 | λ=6.7e-07 | accept
# LM 149 | loss 1.130e-09 | λ=2.0e-06 | reject
# LM 150 | loss 9.758e-10 | λ=1.4e-06 | accept
# LM 151 | loss 9.510e-10 | λ=9.8e-07 | accept
# LM 152 | loss 9.338e-10 | λ=6.9e-07 | accept
# LM 153 | loss 9.611e-10 | λ=2.1e-06 | reject
# LM 154 | loss 8.801e-10 | λ=1.4e-06 | accept
# LM 155 | loss 8.580e-10 | λ=1.0e-06 | accept
# LM 156 | loss 8.380e-10 | λ=7.1e-07 | accept
# LM 157 | loss 8.438e-10 | λ=2.1e-06 | reject
# LM 158 | loss 8.010e-10 | λ=1.5e-06 | accept
# LM 159 | loss 7.814e-10 | λ=1.0e-06 | accept
# LM 160 | loss 7.614e-10 | λ=7.3e-07 | accept
# LM 161 | loss 7.563e-10 | λ=5.1e-07 | accept
# LM 162 | loss 8.147e-10 | λ=1.5e-06 | reject
# LM 163 | loss 6.918e-10 | λ=1.1e-06 | accept
# LM 164 | loss 6.734e-10 | λ=7.5e-07 | accept
# LM 165 | loss 6.621e-10 | λ=5.2e-07 | accept
# LM 166 | loss 6.897e-10 | λ=1.6e-06 | reject
# LM 167 | loss 6.191e-10 | λ=1.1e-06 | accept
# LM 168 | loss 6.027e-10 | λ=7.7e-07 | accept
# LM 169 | loss 5.895e-10 | λ=5.4e-07 | accept
# LM 170 | loss 6.009e-10 | λ=1.6e-06 | reject
# LM 171 | loss 5.589e-10 | λ=1.1e-06 | accept
# LM 172 | loss 5.445e-10 | λ=7.9e-07 | accept
# LM 173 | loss 5.311e-10 | λ=5.5e-07 | accept
# LM 174 | loss 5.338e-10 | λ=1.7e-06 | reject
# LM 175 | loss 5.082e-10 | λ=1.2e-06 | accept
# LM 176 | loss 4.956e-10 | λ=8.1e-07 | accept
# LM 177 | loss 4.828e-10 | λ=5.7e-07 | accept
# LM 178 | loss 4.806e-10 | λ=4.0e-07 | accept
# LM 179 | loss 5.260e-10 | λ=1.2e-06 | reject
# LM 180 | loss 4.376e-10 | λ=8.4e-07 | accept
# LM 181 | loss 4.261e-10 | λ=5.9e-07 | accept
# LM 182 | loss 4.209e-10 | λ=4.1e-07 | accept
# LM 183 | loss 4.480e-10 | λ=1.2e-06 | reject
# LM 184 | loss 3.901e-10 | λ=8.6e-07 | accept
# LM 185 | loss 3.800e-10 | λ=6.0e-07 | accept
# LM 186 | loss 3.735e-10 | λ=4.2e-07 | accept
# LM 187 | loss 3.893e-10 | λ=1.3e-06 | reject
# LM 188 | loss 3.507e-10 | λ=8.9e-07 | accept
# LM 189 | loss 3.418e-10 | λ=6.2e-07 | accept
# LM 190 | loss 3.348e-10 | λ=4.3e-07 | accept
# LM 191 | loss 3.433e-10 | λ=1.3e-06 | reject
# LM 192 | loss 3.175e-10 | λ=9.1e-07 | accept
# LM 193 | loss 3.097e-10 | λ=6.4e-07 | accept
# LM 194 | loss 3.028e-10 | λ=4.5e-07 | accept
# LM 195 | loss 3.065e-10 | λ=1.3e-06 | reject
# LM 196 | loss 2.894e-10 | λ=9.4e-07 | accept
# LM 197 | loss 2.825e-10 | λ=6.6e-07 | accept
# LM 198 | loss 2.758e-10 | λ=4.6e-07 | accept
# LM 199 | loss 2.765e-10 | λ=1.4e-06 | reject
# LM 200 | loss 2.653e-10 | λ=9.7e-07 | accept
# LM 201 | loss 2.593e-10 | λ=6.8e-07 | accept
# LM 202 | loss 2.530e-10 | λ=4.7e-07 | accept
# LM 203 | loss 2.516e-10 | λ=3.3e-07 | accept
# LM 204 | loss 2.730e-10 | λ=1.0e-06 | reject
# LM 205 | loss 2.312e-10 | λ=7.0e-07 | accept
# LM 206 | loss 2.255e-10 | λ=4.9e-07 | accept
# LM 207 | loss 2.227e-10 | λ=3.4e-07 | accept
# LM 208 | loss 2.352e-10 | λ=1.0e-06 | reject
# LM 209 | loss 2.080e-10 | λ=7.2e-07 | accept
# LM 210 | loss 2.029e-10 | λ=5.0e-07 | accept
# LM 211 | loss 1.994e-10 | λ=3.5e-07 | accept
# LM 212 | loss 2.060e-10 | λ=1.1e-06 | reject
# LM 213 | loss 1.885e-10 | λ=7.4e-07 | accept
# LM 214 | loss 1.841e-10 | λ=5.2e-07 | accept
# LM 215 | loss 1.803e-10 | λ=3.6e-07 | accept
# LM 216 | loss 1.832e-10 | λ=1.1e-06 | reject
# LM 217 | loss 1.722e-10 | λ=7.6e-07 | accept
# LM 218 | loss 1.682e-10 | λ=5.3e-07 | accept
# LM 219 | loss 1.644e-10 | λ=3.7e-07 | accept
# LM 220 | loss 1.650e-10 | λ=1.1e-06 | reject
# LM 221 | loss 1.582e-10 | λ=7.8e-07 | accept
# LM 222 | loss 1.547e-10 | λ=5.5e-07 | accept
# LM 223 | loss 1.511e-10 | λ=3.8e-07 | accept
# LM 224 | loss 1.502e-10 | λ=2.7e-07 | accept
# LM 225 | loss 1.615e-10 | λ=8.0e-07 | reject
# LM 226 | loss 1.386e-10 | λ=5.6e-07 | accept
# LM 227 | loss 1.353e-10 | λ=3.9e-07 | accept
# LM 228 | loss 1.335e-10 | λ=2.8e-07 | accept
# LM 229 | loss 1.392e-10 | λ=8.3e-07 | reject
# LM 230 | loss 1.254e-10 | λ=5.8e-07 | accept
# LM 231 | loss 1.225e-10 | λ=4.1e-07 | accept
# LM 232 | loss 1.202e-10 | λ=2.8e-07 | accept
# LM 233 | loss 1.227e-10 | λ=8.5e-07 | reject
# LM 234 | loss 1.145e-10 | λ=6.0e-07 | accept
# LM 235 | loss 1.119e-10 | λ=4.2e-07 | accept
# LM 236 | loss 1.095e-10 | λ=2.9e-07 | accept
# LM 237 | loss 1.101e-10 | λ=8.8e-07 | reject
# LM 238 | loss 1.053e-10 | λ=6.1e-07 | accept
# LM 239 | loss 1.031e-10 | λ=4.3e-07 | accept
# LM 240 | loss 1.007e-10 | λ=3.0e-07 | accept
# LM 241 | loss 1.002e-10 | λ=2.1e-07 | accept
# LM 242 | loss 1.072e-10 | λ=6.3e-07 | reject
# LM 243 | loss 9.270e-11 | λ=4.4e-07 | accept
# LM 244 | loss 9.061e-11 | λ=3.1e-07 | accept
# LM 245 | loss 8.939e-11 | λ=2.2e-07 | accept
# LM 246 | loss 9.273e-11 | λ=6.5e-07 | reject
# LM 247 | loss 8.438e-11 | λ=4.5e-07 | accept
# LM 248 | loss 8.254e-11 | λ=3.2e-07 | accept
# LM 249 | loss 8.108e-11 | λ=2.2e-07 | accept
# LM 250 | loss 8.237e-11 | λ=6.7e-07 | reject
# LM 251 | loss 7.759e-11 | λ=4.7e-07 | accept
# LM 252 | loss 7.600e-11 | λ=3.3e-07 | accept
# LM 253 | loss 7.450e-11 | λ=2.3e-07 | accept
# LM 254 | loss 7.468e-11 | λ=6.9e-07 | reject
# LM 255 | loss 7.200e-11 | λ=4.8e-07 | accept
# LM 256 | loss 7.061e-11 | λ=3.4e-07 | accept
# LM 257 | loss 6.919e-11 | λ=2.4e-07 | accept
# LM 258 | loss 6.877e-11 | λ=1.7e-07 | accept
# LM 259 | loss 7.277e-11 | λ=5.0e-07 | reject
# LM 260 | loss 6.438e-11 | λ=3.5e-07 | accept
# LM 261 | loss 6.312e-11 | λ=2.4e-07 | accept
# LM 262 | loss 6.235e-11 | λ=1.7e-07 | accept
# LM 263 | loss 6.429e-11 | λ=5.1e-07 | reject
# LM 264 | loss 5.943e-11 | λ=3.6e-07 | accept
# LM 265 | loss 5.833e-11 | λ=2.5e-07 | accept
# LM 266 | loss 5.745e-11 | λ=1.7e-07 | accept
# LM 267 | loss 5.824e-11 | λ=5.2e-07 | reject
# LM 268 | loss 5.541e-11 | λ=3.7e-07 | accept
# LM 269 | loss 5.446e-11 | λ=2.6e-07 | accept
# LM 270 | loss 5.358e-11 | λ=1.8e-07 | accept
# LM 271 | loss 5.374e-11 | λ=5.4e-07 | reject
# LM 272 | loss 5.210e-11 | λ=3.8e-07 | accept
# LM 273 | loss 5.129e-11 | λ=2.6e-07 | accept
# LM 274 | loss 5.045e-11 | λ=1.8e-07 | accept
# LM 275 | loss 5.025e-11 | λ=1.3e-07 | accept
# LM 276 | loss 5.285e-11 | λ=3.9e-07 | reject
# LM 277 | loss 4.760e-11 | λ=2.7e-07 | accept
# LM 278 | loss 4.686e-11 | λ=1.9e-07 | accept
# LM 279 | loss 4.644e-11 | λ=1.3e-07 | accept
# LM 280 | loss 4.774e-11 | λ=4.0e-07 | reject
# LM 281 | loss 4.465e-11 | λ=2.8e-07 | accept
# LM 282 | loss 4.400e-11 | λ=2.0e-07 | accept
# LM 283 | loss 4.349e-11 | λ=1.4e-07 | accept
# LM 284 | loss 4.405e-11 | λ=4.1e-07 | reject
# LM 285 | loss 4.223e-11 | λ=2.9e-07 | accept
# LM 286 | loss 4.166e-11 | λ=2.0e-07 | accept
# LM 287 | loss 4.113e-11 | λ=1.4e-07 | accept
# LM 288 | loss 4.126e-11 | λ=4.2e-07 | reject
# LM 289 | loss 4.021e-11 | λ=3.0e-07 | accept
# LM 290 | loss 3.971e-11 | λ=2.1e-07 | accept
# LM 291 | loss 3.920e-11 | λ=1.5e-07 | accept
# LM 292 | loss 3.908e-11 | λ=1.0e-07 | accept
# LM 293 | loss 4.073e-11 | λ=3.0e-07 | reject
# LM 294 | loss 3.740e-11 | λ=2.1e-07 | accept
# LM 295 | loss 3.692e-11 | λ=1.5e-07 | accept
# LM 296 | loss 3.664e-11 | λ=1.0e-07 | accept
# LM 297 | loss 3.744e-11 | λ=3.1e-07 | reject
# LM 298 | loss 3.550e-11 | λ=2.2e-07 | accept
# LM 299 | loss 3.507e-11 | λ=1.5e-07 | accept
# LM 300 | loss 3.472e-11 | λ=1.1e-07 | accept
# LM 301 | loss 3.503e-11 | λ=3.2e-07 | reject
# LM 302 | loss 3.390e-11 | λ=2.3e-07 | accept
# LM 303 | loss 3.351e-11 | λ=1.6e-07 | accept
# LM 304 | loss 3.313e-11 | λ=1.1e-07 | accept
# LM 305 | loss 3.317e-11 | λ=3.3e-07 | reject
# LM 306 | loss 3.252e-11 | λ=2.3e-07 | accept
# LM 307 | loss 3.217e-11 | λ=1.6e-07 | accept
# LM 308 | loss 3.180e-11 | λ=1.1e-07 | accept
# LM 309 | loss 3.167e-11 | λ=8.0e-08 | accept
# LM 310 | loss 3.273e-11 | λ=2.4e-07 | reject
# LM 311 | loss 3.054e-11 | λ=1.7e-07 | accept
# LM 312 | loss 3.019e-11 | λ=1.2e-07 | accept
# LM 313 | loss 2.996e-11 | λ=8.2e-08 | accept
# LM 314 | loss 3.048e-11 | λ=2.5e-07 | reject
# LM 315 | loss 2.916e-11 | λ=1.7e-07 | accept
# LM 316 | loss 2.883e-11 | λ=1.2e-07 | accept
# LM 317 | loss 2.855e-11 | λ=8.4e-08 | accept
# LM 318 | loss 2.877e-11 | λ=2.5e-07 | reject
# LM 319 | loss 2.796e-11 | λ=1.8e-07 | accept
# LM 320 | loss 2.766e-11 | λ=1.2e-07 | accept
# LM 321 | loss 2.737e-11 | λ=8.7e-08 | accept
# LM 322 | loss 2.741e-11 | λ=2.6e-07 | reject
# LM 323 | loss 2.690e-11 | λ=1.8e-07 | accept
# LM 324 | loss 2.663e-11 | λ=1.3e-07 | accept
# LM 325 | loss 2.634e-11 | λ=8.9e-08 | accept
# LM 326 | loss 2.628e-11 | λ=6.3e-08 | accept
# LM 327 | loss 2.737e-11 | λ=1.9e-07 | reject
# LM 328 | loss 2.534e-11 | λ=1.3e-07 | accept
# LM 329 | loss 2.507e-11 | λ=9.2e-08 | accept
# LM 330 | loss 2.494e-11 | λ=6.4e-08 | accept
# LM 331 | loss 2.565e-11 | λ=1.9e-07 | reject
# LM 332 | loss 2.423e-11 | λ=1.4e-07 | accept
# LM 333 | loss 2.397e-11 | λ=9.5e-08 | accept
# LM 334 | loss 2.381e-11 | λ=6.6e-08 | accept
# LM 335 | loss 2.428e-11 | λ=2.0e-07 | reject
# LM 336 | loss 2.324e-11 | λ=1.4e-07 | accept
# LM 337 | loss 2.301e-11 | λ=9.7e-08 | accept
# LM 338 | loss 2.284e-11 | λ=6.8e-08 | accept
# LM 339 | loss 2.314e-11 | λ=2.0e-07 | reject
# LM 340 | loss 2.237e-11 | λ=1.4e-07 | accept
# LM 341 | loss 2.216e-11 | λ=1.0e-07 | accept
# LM 342 | loss 2.198e-11 | λ=7.0e-08 | accept
# LM 343 | loss 2.217e-11 | λ=2.1e-07 | reject
# LM 344 | loss 2.159e-11 | λ=1.5e-07 | accept
# LM 345 | loss 2.139e-11 | λ=1.0e-07 | accept
# LM 346 | loss 2.122e-11 | λ=7.2e-08 | accept
# LM 347 | loss 2.133e-11 | λ=2.2e-07 | reject
# LM 348 | loss 2.089e-11 | λ=1.5e-07 | accept
# LM 349 | loss 2.071e-11 | λ=1.1e-07 | accept
# LM 350 | loss 2.053e-11 | λ=7.4e-08 | accept
# LM 351 | loss 2.058e-11 | λ=2.2e-07 | reject
# LM 352 | loss 2.025e-11 | λ=1.6e-07 | accept
# LM 353 | loss 2.008e-11 | λ=1.1e-07 | accept
# LM 354 | loss 1.991e-11 | λ=7.6e-08 | accept
# LM 355 | loss 1.992e-11 | λ=2.3e-07 | reject
# LM 356 | loss 1.967e-11 | λ=1.6e-07 | accept
# LM 357 | loss 1.952e-11 | λ=1.1e-07 | accept
# LM 358 | loss 1.935e-11 | λ=7.9e-08 | accept
# LM 359 | loss 1.932e-11 | λ=5.5e-08 | accept
# LM 360 | loss 2.002e-11 | λ=1.7e-07 | reject
# LM 361 | loss 1.878e-11 | λ=1.2e-07 | accept
# LM 362 | loss 1.863e-11 | λ=8.1e-08 | accept
# LM 363 | loss 1.857e-11 | λ=5.7e-08 | accept
# LM 364 | loss 1.908e-11 | λ=1.7e-07 | reject
# LM 365 | loss 1.812e-11 | λ=1.2e-07 | accept
# LM 366 | loss 1.798e-11 | λ=8.3e-08 | accept
# LM 367 | loss 1.790e-11 | λ=5.8e-08 | accept
# LM 368 | loss 1.827e-11 | λ=1.7e-07 | reject
# LM 369 | loss 1.753e-11 | λ=1.2e-07 | accept
# LM 370 | loss 1.739e-11 | λ=8.6e-08 | accept
# LM 371 | loss 1.730e-11 | λ=6.0e-08 | accept
# LM 372 | loss 1.756e-11 | λ=1.8e-07 | reject
# LM 373 | loss 1.699e-11 | λ=1.3e-07 | accept
# LM 374 | loss 1.686e-11 | λ=8.8e-08 | accept
# LM 375 | loss 1.677e-11 | λ=6.2e-08 | accept
# LM 376 | loss 1.693e-11 | λ=1.9e-07 | reject
# LM 377 | loss 1.651e-11 | λ=1.3e-07 | accept
# LM 378 | loss 1.639e-11 | λ=9.1e-08 | accept
# LM 379 | loss 1.628e-11 | λ=6.4e-08 | accept
# LM 380 | loss 1.638e-11 | λ=1.9e-07 | reject
# LM 381 | loss 1.606e-11 | λ=1.3e-07 | accept
# LM 382 | loss 1.595e-11 | λ=9.3e-08 | accept
# LM 383 | loss 1.584e-11 | λ=6.5e-08 | accept
# LM 384 | loss 1.589e-11 | λ=2.0e-07 | reject
# LM 385 | loss 1.565e-11 | λ=1.4e-07 | accept
# LM 386 | loss 1.555e-11 | λ=9.6e-08 | accept
# LM 387 | loss 1.544e-11 | λ=6.7e-08 | accept
# LM 388 | loss 1.545e-11 | λ=2.0e-07 | reject
# LM 389 | loss 1.528e-11 | λ=1.4e-07 | accept
# LM 390 | loss 1.518e-11 | λ=9.9e-08 | accept
# LM 391 | loss 1.508e-11 | λ=6.9e-08 | accept
# LM 392 | loss 1.506e-11 | λ=4.8e-08 | accept
# LM 393 | loss 1.549e-11 | λ=1.5e-07 | reject
# LM 394 | loss 1.470e-11 | λ=1.0e-07 | accept
# LM 395 | loss 1.460e-11 | λ=7.1e-08 | accept
# LM 396 | loss 1.456e-11 | λ=5.0e-08 | accept
# LM 397 | loss 1.486e-11 | λ=1.5e-07 | reject
# LM 398 | loss 1.427e-11 | λ=1.0e-07 | accept
# LM 399 | loss 1.417e-11 | λ=7.3e-08 | accept
# LM 400 | loss 1.411e-11 | λ=5.1e-08 | accept
# LM 401 | loss 1.431e-11 | λ=1.5e-07 | reject
# LM 402 | loss 1.387e-11 | λ=1.1e-07 | accept
# LM 403 | loss 1.378e-11 | λ=7.5e-08 | accept
# LM 404 | loss 1.371e-11 | λ=5.3e-08 | accept
# LM 405 | loss 1.383e-11 | λ=1.6e-07 | reject
# LM 406 | loss 1.352e-11 | λ=1.1e-07 | accept
# LM 407 | loss 1.343e-11 | λ=7.8e-08 | accept
# LM 408 | loss 1.335e-11 | λ=5.4e-08 | accept
# LM 409 | loss 1.341e-11 | λ=1.6e-07 | reject
# LM 410 | loss 1.319e-11 | λ=1.1e-07 | accept
# LM 411 | loss 1.310e-11 | λ=8.0e-08 | accept
# LM 412 | loss 1.302e-11 | λ=5.6e-08 | accept
# LM 413 | loss 1.305e-11 | λ=1.7e-07 | reject
# LM 414 | loss 1.289e-11 | λ=1.2e-07 | accept
# LM 415 | loss 1.281e-11 | λ=8.2e-08 | accept
# LM 416 | loss 1.273e-11 | λ=5.8e-08 | accept
# LM 417 | loss 1.272e-11 | λ=4.0e-08 | accept
# LM 418 | loss 1.309e-11 | λ=1.2e-07 | reject
# LM 419 | loss 1.242e-11 | λ=8.5e-08 | accept
# LM 420 | loss 1.234e-11 | λ=5.9e-08 | accept
# LM 421 | loss 1.231e-11 | λ=4.1e-08 | accept
# LM 422 | loss 1.256e-11 | λ=1.2e-07 | reject
# LM 423 | loss 1.207e-11 | λ=8.7e-08 | accept
# LM 424 | loss 1.200e-11 | λ=6.1e-08 | accept
# LM 425 | loss 1.195e-11 | λ=4.3e-08 | accept
# LM 426 | loss 1.210e-11 | λ=1.3e-07 | reject
# LM 427 | loss 1.176e-11 | λ=9.0e-08 | accept
# LM 428 | loss 1.168e-11 | λ=6.3e-08 | accept
# LM 429 | loss 1.162e-11 | λ=4.4e-08 | accept
# LM 430 | loss 1.171e-11 | λ=1.3e-07 | reject
# LM 431 | loss 1.147e-11 | λ=9.2e-08 | accept
# LM 432 | loss 1.140e-11 | λ=6.4e-08 | accept
# LM 433 | loss 1.133e-11 | λ=4.5e-08 | accept
# LM 434 | loss 1.138e-11 | λ=1.4e-07 | reject
# LM 435 | loss 1.121e-11 | λ=9.5e-08 | accept
# LM 436 | loss 1.114e-11 | λ=6.6e-08 | accept
# LM 437 | loss 1.107e-11 | λ=4.6e-08 | accept
# LM 438 | loss 1.108e-11 | λ=1.4e-07 | reject
# LM 439 | loss 1.097e-11 | λ=9.8e-08 | accept
# LM 440 | loss 1.090e-11 | λ=6.8e-08 | accept
# LM 441 | loss 1.083e-11 | λ=4.8e-08 | accept
# LM 442 | loss 1.082e-11 | λ=3.3e-08 | accept
# LM 443 | loss 1.109e-11 | λ=1.0e-07 | reject
# LM 444 | loss 1.059e-11 | λ=7.0e-08 | accept
# LM 445 | loss 1.052e-11 | λ=4.9e-08 | accept
# LM 446 | loss 1.049e-11 | λ=3.4e-08 | accept
# LM 447 | loss 1.067e-11 | λ=1.0e-07 | reject
# LM 448 | loss 1.031e-11 | λ=7.2e-08 | accept
# LM 449 | loss 1.024e-11 | λ=5.1e-08 | accept
# LM 450 | loss 1.020e-11 | λ=3.5e-08 | accept
# LM 451 | loss 1.031e-11 | λ=1.1e-07 | reject
# LM 452 | loss 1.005e-11 | λ=7.4e-08 | accept
# LM 453 | loss 9.992e-12 | λ=5.2e-08 | accept
# LM 454 | loss 9.941e-12 | λ=3.6e-08 | accept
# LM 455 | loss 9.998e-12 | λ=1.1e-07 | reject
# LM 456 | loss 9.821e-12 | λ=7.7e-08 | accept
# LM 457 | loss 9.762e-12 | λ=5.4e-08 | accept
# LM 458 | loss 9.706e-12 | λ=3.8e-08 | accept
# LM 459 | loss 9.730e-12 | λ=1.1e-07 | reject
# LM 460 | loss 9.607e-12 | λ=7.9e-08 | accept
# LM 461 | loss 9.551e-12 | λ=5.5e-08 | accept
# LM 462 | loss 9.494e-12 | λ=3.9e-08 | accept
# LM 463 | loss 9.493e-12 | λ=2.7e-08 | accept
# LM 464 | loss 9.774e-12 | λ=8.1e-08 | reject
# LM 465 | loss 9.276e-12 | λ=5.7e-08 | accept
# LM 466 | loss 9.219e-12 | λ=4.0e-08 | accept
# LM 467 | loss 9.198e-12 | λ=2.8e-08 | accept
# LM 468 | loss 9.382e-12 | λ=8.3e-08 | reject
# LM 469 | loss 9.027e-12 | λ=5.8e-08 | accept
# LM 470 | loss 8.971e-12 | λ=4.1e-08 | accept
# LM 471 | loss 8.938e-12 | λ=2.9e-08 | accept
# LM 472 | loss 9.053e-12 | λ=8.6e-08 | reject
# LM 473 | loss 8.801e-12 | λ=6.0e-08 | accept
# LM 474 | loss 8.747e-12 | λ=4.2e-08 | accept
# LM 475 | loss 8.706e-12 | λ=2.9e-08 | accept
# LM 476 | loss 8.773e-12 | λ=8.8e-08 | reject
# LM 477 | loss 8.595e-12 | λ=6.2e-08 | accept
# LM 478 | loss 8.543e-12 | λ=4.3e-08 | accept
# LM 479 | loss 8.497e-12 | λ=3.0e-08 | accept
# LM 480 | loss 8.529e-12 | λ=9.1e-08 | reject
# LM 481 | loss 8.405e-12 | λ=6.4e-08 | accept
# LM 482 | loss 8.356e-12 | λ=4.5e-08 | accept
# LM 483 | loss 8.308e-12 | λ=3.1e-08 | accept
# LM 484 | loss 8.315e-12 | λ=9.4e-08 | reject
# LM 485 | loss 8.231e-12 | λ=6.5e-08 | accept
# LM 486 | loss 8.185e-12 | λ=4.6e-08 | accept
# LM 487 | loss 8.135e-12 | λ=3.2e-08 | accept
# LM 488 | loss 8.124e-12 | λ=2.2e-08 | accept
# LM 489 | loss 8.316e-12 | λ=6.7e-08 | reject
# LM 490 | loss 7.959e-12 | λ=4.7e-08 | accept
# LM 491 | loss 7.910e-12 | λ=3.3e-08 | accept
# LM 492 | loss 7.884e-12 | λ=2.3e-08 | accept
# LM 493 | loss 8.003e-12 | λ=6.9e-08 | reject
# LM 494 | loss 7.754e-12 | λ=4.9e-08 | accept
# LM 495 | loss 7.706e-12 | λ=3.4e-08 | accept
# LM 496 | loss 7.671e-12 | λ=2.4e-08 | accept
# LM 497 | loss 7.739e-12 | λ=7.1e-08 | reject
# LM 498 | loss 7.566e-12 | λ=5.0e-08 | accept
# LM 499 | loss 7.520e-12 | λ=3.5e-08 | accept
# LM 500 | loss 7.480e-12 | λ=2.4e-08 | accept
# LM 501 | loss 7.511e-12 | λ=7.3e-08 | reject
# LM 502 | loss 7.395e-12 | λ=5.1e-08 | accept
# LM 503 | loss 7.350e-12 | λ=3.6e-08 | accept
# LM 504 | loss 7.307e-12 | λ=2.5e-08 | accept
# LM 505 | loss 7.312e-12 | λ=7.6e-08 | reject
# LM 506 | loss 7.236e-12 | λ=5.3e-08 | accept
# LM 507 | loss 7.194e-12 | λ=3.7e-08 | accept
# LM 508 | loss 7.149e-12 | λ=2.6e-08 | accept
# LM 509 | loss 7.137e-12 | λ=1.8e-08 | accept
# LM 510 | loss 7.296e-12 | λ=5.4e-08 | reject
# LM 511 | loss 6.989e-12 | λ=3.8e-08 | accept
# LM 512 | loss 6.944e-12 | λ=2.7e-08 | accept
# LM 513 | loss 6.917e-12 | λ=1.9e-08 | accept
# LM 514 | loss 7.006e-12 | λ=5.6e-08 | reject
# LM 515 | loss 6.803e-12 | λ=3.9e-08 | accept
# LM 516 | loss 6.758e-12 | λ=2.7e-08 | accept
# LM 517 | loss 6.722e-12 | λ=1.9e-08 | accept
# LM 518 | loss 6.764e-12 | λ=5.8e-08 | reject
# LM 519 | loss 6.632e-12 | λ=4.0e-08 | accept
# LM 520 | loss 6.589e-12 | λ=2.8e-08 | accept
# LM 521 | loss 6.548e-12 | λ=2.0e-08 | accept
# LM 522 | loss 6.558e-12 | λ=5.9e-08 | reject
# LM 523 | loss 6.476e-12 | λ=4.1e-08 | accept
# LM 524 | loss 6.435e-12 | λ=2.9e-08 | accept
# LM 525 | loss 6.391e-12 | λ=2.0e-08 | accept
# LM 526 | loss 6.379e-12 | λ=1.4e-08 | accept
# LM 527 | loss 6.526e-12 | λ=4.3e-08 | reject
# LM 528 | loss 6.233e-12 | λ=3.0e-08 | accept
# LM 529 | loss 6.189e-12 | λ=2.1e-08 | accept
# LM 530 | loss 6.160e-12 | λ=1.5e-08 | accept
# LM 531 | loss 6.230e-12 | λ=4.4e-08 | reject
# LM 532 | loss 6.051e-12 | λ=3.1e-08 | accept
# LM 533 | loss 6.007e-12 | λ=2.2e-08 | accept
# LM 534 | loss 5.968e-12 | λ=1.5e-08 | accept
# LM 535 | loss 5.991e-12 | λ=4.5e-08 | reject
# LM 536 | loss 5.885e-12 | λ=3.2e-08 | accept
# LM 537 | loss 5.843e-12 | λ=2.2e-08 | accept
# LM 538 | loss 5.799e-12 | λ=1.6e-08 | accept
# LM 539 | loss 5.792e-12 | λ=1.1e-08 | accept
# LM 540 | loss 5.953e-12 | λ=3.3e-08 | reject
# LM 541 | loss 5.631e-12 | λ=2.3e-08 | accept
# LM 542 | loss 5.585e-12 | λ=1.6e-08 | accept
# LM 543 | loss 5.556e-12 | λ=1.1e-08 | accept
# LM 544 | loss 5.628e-12 | λ=3.4e-08 | reject
# LM 545 | loss 5.441e-12 | λ=2.3e-08 | accept
# LM 546 | loss 5.396e-12 | λ=1.6e-08 | accept
# LM 547 | loss 5.356e-12 | λ=1.1e-08 | accept
# LM 548 | loss 5.379e-12 | λ=3.4e-08 | reject
# LM 549 | loss 5.271e-12 | λ=2.4e-08 | accept
# LM 550 | loss 5.227e-12 | λ=1.7e-08 | accept
# LM 551 | loss 5.182e-12 | λ=1.2e-08 | accept
# LM 552 | loss 5.178e-12 | λ=8.3e-09 | accept
# LM 553 | loss 5.376e-12 | λ=2.5e-08 | reject
# LM 554 | loss 5.011e-12 | λ=1.7e-08 | accept
# LM 555 | loss 4.966e-12 | λ=1.2e-08 | accept
# LM 556 | loss 4.946e-12 | λ=8.5e-09 | accept
# LM 557 | loss 5.082e-12 | λ=2.6e-08 | reject
# LM 558 | loss 4.820e-12 | λ=1.8e-08 | accept
# LM 559 | loss 4.777e-12 | λ=1.3e-08 | accept
# LM 560 | loss 4.752e-12 | λ=8.8e-09 | accept
# LM 561 | loss 4.859e-12 | λ=2.6e-08 | reject
# LM 562 | loss 4.649e-12 | λ=1.8e-08 | accept
# LM 563 | loss 4.609e-12 | λ=1.3e-08 | accept
# LM 564 | loss 4.585e-12 | λ=9.0e-09 | accept
# LM 565 | loss 4.677e-12 | λ=2.7e-08 | reject
# LM 566 | loss 4.495e-12 | λ=1.9e-08 | accept
# LM 567 | loss 4.459e-12 | λ=1.3e-08 | accept
# LM 568 | loss 4.436e-12 | λ=9.3e-09 | accept
# LM 569 | loss 4.521e-12 | λ=2.8e-08 | reject
# LM 570 | loss 4.355e-12 | λ=1.9e-08 | accept
# LM 571 | loss 4.322e-12 | λ=1.4e-08 | accept
# LM 572 | loss 4.302e-12 | λ=9.6e-09 | accept
# LM 573 | loss 4.380e-12 | λ=2.9e-08 | reject
# LM 574 | loss 4.228e-12 | λ=2.0e-08 | accept
# LM 575 | loss 4.198e-12 | λ=1.4e-08 | accept
# LM 576 | loss 4.179e-12 | λ=9.8e-09 | accept
# LM 577 | loss 4.252e-12 | λ=2.9e-08 | reject
# LM 578 | loss 4.111e-12 | λ=2.1e-08 | accept
# LM 579 | loss 4.084e-12 | λ=1.4e-08 | accept
# LM 580 | loss 4.067e-12 | λ=1.0e-08 | accept
# LM 581 | loss 4.133e-12 | λ=3.0e-08 | reject
# LM 582 | loss 4.004e-12 | λ=2.1e-08 | accept
# LM 583 | loss 3.979e-12 | λ=1.5e-08 | accept
# LM 584 | loss 3.963e-12 | λ=1.0e-08 | accept
# LM 585 | loss 4.023e-12 | λ=3.1e-08 | reject
# LM 586 | loss 3.905e-12 | λ=2.2e-08 | accept
# LM 587 | loss 3.882e-12 | λ=1.5e-08 | accept
# LM 588 | loss 3.866e-12 | λ=1.1e-08 | accept
# LM 589 | loss 3.920e-12 | λ=3.2e-08 | reject
# LM 590 | loss 3.814e-12 | λ=2.2e-08 | accept
# LM 591 | loss 3.792e-12 | λ=1.6e-08 | accept
# LM 592 | loss 3.777e-12 | λ=1.1e-08 | accept
# LM 593 | loss 3.824e-12 | λ=3.3e-08 | reject
# LM 594 | loss 3.729e-12 | λ=2.3e-08 | accept
# LM 595 | loss 3.708e-12 | λ=1.6e-08 | accept
# LM 596 | loss 3.694e-12 | λ=1.1e-08 | accept
# LM 597 | loss 3.734e-12 | λ=3.4e-08 | reject
# LM 598 | loss 3.650e-12 | λ=2.4e-08 | accept
# LM 599 | loss 3.631e-12 | λ=1.7e-08 | accept
# LM 600 | loss 3.616e-12 | λ=1.2e-08 | accept
# LM 601 | loss 3.650e-12 | λ=3.5e-08 | reject
# LM 602 | loss 3.576e-12 | λ=2.4e-08 | accept
# LM 603 | loss 3.558e-12 | λ=1.7e-08 | accept
# LM 604 | loss 3.544e-12 | λ=1.2e-08 | accept
# LM 605 | loss 3.572e-12 | λ=3.6e-08 | reject
# LM 606 | loss 3.507e-12 | λ=2.5e-08 | accept
# LM 607 | loss 3.490e-12 | λ=1.8e-08 | accept
# LM 608 | loss 3.476e-12 | λ=1.2e-08 | accept
# LM 609 | loss 3.499e-12 | λ=3.7e-08 | reject
# LM 610 | loss 3.443e-12 | λ=2.6e-08 | accept
# LM 611 | loss 3.427e-12 | λ=1.8e-08 | accept
# LM 612 | loss 3.413e-12 | λ=1.3e-08 | accept
# LM 613 | loss 3.431e-12 | λ=3.8e-08 | reject
# LM 614 | loss 3.383e-12 | λ=2.7e-08 | accept
# LM 615 | loss 3.367e-12 | λ=1.9e-08 | accept
# LM 616 | loss 3.353e-12 | λ=1.3e-08 | accept
# LM 617 | loss 3.367e-12 | λ=3.9e-08 | reject
# LM 618 | loss 3.326e-12 | λ=2.7e-08 | accept
# LM 619 | loss 3.311e-12 | λ=1.9e-08 | accept
# LM 620 | loss 3.298e-12 | λ=1.3e-08 | accept
# LM 621 | loss 3.307e-12 | λ=4.0e-08 | reject
# LM 622 | loss 3.273e-12 | λ=2.8e-08 | accept
# LM 623 | loss 3.259e-12 | λ=2.0e-08 | accept
# LM 624 | loss 3.245e-12 | λ=1.4e-08 | accept
# LM 625 | loss 3.251e-12 | λ=4.2e-08 | reject
# LM 626 | loss 3.222e-12 | λ=2.9e-08 | accept
# LM 627 | loss 3.209e-12 | λ=2.0e-08 | accept
# LM 628 | loss 3.196e-12 | λ=1.4e-08 | accept
# LM 629 | loss 3.199e-12 | λ=4.3e-08 | reject
# LM 630 | loss 3.175e-12 | λ=3.0e-08 | accept
# LM 631 | loss 3.162e-12 | λ=2.1e-08 | accept
# LM 632 | loss 3.149e-12 | λ=1.5e-08 | accept
# LM 633 | loss 3.150e-12 | λ=4.4e-08 | reject
# LM 634 | loss 3.130e-12 | λ=3.1e-08 | accept
# LM 635 | loss 3.118e-12 | λ=2.2e-08 | accept
# LM 636 | loss 3.105e-12 | λ=1.5e-08 | accept
# LM 637 | loss 3.104e-12 | λ=1.1e-08 | accept
# LM 638 | loss 3.171e-12 | λ=3.2e-08 | reject
# LM 639 | loss 3.058e-12 | λ=2.2e-08 | accept
# LM 640 | loss 3.046e-12 | λ=1.6e-08 | accept
# LM 641 | loss 3.043e-12 | λ=1.1e-08 | accept
# LM 642 | loss 3.098e-12 | λ=3.3e-08 | reject
# LM 643 | loss 3.002e-12 | λ=2.3e-08 | accept
# LM 644 | loss 2.990e-12 | λ=1.6e-08 | accept
# LM 645 | loss 2.986e-12 | λ=1.1e-08 | accept
# LM 646 | loss 3.031e-12 | λ=3.4e-08 | reject
# LM 647 | loss 2.950e-12 | λ=2.3e-08 | accept
# LM 648 | loss 2.938e-12 | λ=1.6e-08 | accept
# LM 649 | loss 2.932e-12 | λ=1.2e-08 | accept
# LM 650 | loss 2.969e-12 | λ=3.5e-08 | reject
# LM 651 | loss 2.900e-12 | λ=2.4e-08 | accept
# LM 652 | loss 2.889e-12 | λ=1.7e-08 | accept
# LM 653 | loss 2.882e-12 | λ=1.2e-08 | accept
# LM 654 | loss 2.912e-12 | λ=3.6e-08 | reject
# LM 655 | loss 2.854e-12 | λ=2.5e-08 | accept
# LM 656 | loss 2.843e-12 | λ=1.7e-08 | accept
# LM 657 | loss 2.836e-12 | λ=1.2e-08 | accept
# LM 658 | loss 2.859e-12 | λ=3.7e-08 | reject
# LM 659 | loss 2.810e-12 | λ=2.6e-08 | accept
# LM 660 | loss 2.800e-12 | λ=1.8e-08 | accept
# LM 661 | loss 2.792e-12 | λ=1.3e-08 | accept
# LM 662 | loss 2.809e-12 | λ=3.8e-08 | reject
# LM 663 | loss 2.769e-12 | λ=2.6e-08 | accept
# LM 664 | loss 2.759e-12 | λ=1.8e-08 | accept
# LM 665 | loss 2.750e-12 | λ=1.3e-08 | accept
# LM 666 | loss 2.764e-12 | λ=3.9e-08 | reject
# LM 667 | loss 2.730e-12 | λ=2.7e-08 | accept
# LM 668 | loss 2.720e-12 | λ=1.9e-08 | accept
# LM 669 | loss 2.711e-12 | λ=1.3e-08 | accept
# LM 670 | loss 2.721e-12 | λ=4.0e-08 | reject
# LM 671 | loss 2.693e-12 | λ=2.8e-08 | accept
# LM 672 | loss 2.684e-12 | λ=2.0e-08 | accept
# LM 673 | loss 2.675e-12 | λ=1.4e-08 | accept
# LM 674 | loss 2.681e-12 | λ=4.1e-08 | reject
# LM 675 | loss 2.658e-12 | λ=2.9e-08 | accept
# LM 676 | loss 2.649e-12 | λ=2.0e-08 | accept
# LM 677 | loss 2.640e-12 | λ=1.4e-08 | accept
# LM 678 | loss 2.644e-12 | λ=4.2e-08 | reject
# LM 679 | loss 2.625e-12 | λ=3.0e-08 | accept
# LM 680 | loss 2.617e-12 | λ=2.1e-08 | accept
# LM 681 | loss 2.607e-12 | λ=1.4e-08 | accept
# LM 682 | loss 2.609e-12 | λ=4.3e-08 | reject
# LM 683 | loss 2.594e-12 | λ=3.0e-08 | accept
# LM 684 | loss 2.586e-12 | λ=2.1e-08 | accept
# LM 685 | loss 2.576e-12 | λ=1.5e-08 | accept
# LM 686 | loss 2.576e-12 | λ=1.0e-08 | accept
# LM 687 | loss 2.623e-12 | λ=3.1e-08 | reject
# LM 688 | loss 2.543e-12 | λ=2.2e-08 | accept
# LM 689 | loss 2.535e-12 | λ=1.5e-08 | accept
# LM 690 | loss 2.532e-12 | λ=1.1e-08 | accept
# LM 691 | loss 2.570e-12 | λ=3.2e-08 | reject
# LM 692 | loss 2.504e-12 | λ=2.3e-08 | accept
# LM 693 | loss 2.495e-12 | λ=1.6e-08 | accept
# LM 694 | loss 2.492e-12 | λ=1.1e-08 | accept
# LM 695 | loss 2.522e-12 | λ=3.3e-08 | reject
# LM 696 | loss 2.467e-12 | λ=2.3e-08 | accept
# LM 697 | loss 2.458e-12 | λ=1.6e-08 | accept
# LM 698 | loss 2.454e-12 | λ=1.1e-08 | accept
# LM 699 | loss 2.477e-12 | λ=3.4e-08 | reject
# LM 700 | loss 2.431e-12 | λ=2.4e-08 | accept
# LM 701 | loss 2.423e-12 | λ=1.7e-08 | accept
# LM 702 | loss 2.418e-12 | λ=1.2e-08 | accept
# LM 703 | loss 2.436e-12 | λ=3.5e-08 | reject
# LM 704 | loss 2.398e-12 | λ=2.5e-08 | accept
# LM 705 | loss 2.390e-12 | λ=1.7e-08 | accept
# LM 706 | loss 2.384e-12 | λ=1.2e-08 | accept
# LM 707 | loss 2.398e-12 | λ=3.6e-08 | reject
# LM 708 | loss 2.367e-12 | λ=2.5e-08 | accept
# LM 709 | loss 2.359e-12 | λ=1.8e-08 | accept
# LM 710 | loss 2.353e-12 | λ=1.2e-08 | accept
# LM 711 | loss 2.363e-12 | λ=3.7e-08 | reject
# LM 712 | loss 2.337e-12 | λ=2.6e-08 | accept
# LM 713 | loss 2.330e-12 | λ=1.8e-08 | accept
# LM 714 | loss 2.323e-12 | λ=1.3e-08 | accept
# LM 715 | loss 2.330e-12 | λ=3.8e-08 | reject
# LM 716 | loss 2.309e-12 | λ=2.7e-08 | accept
# LM 717 | loss 2.302e-12 | λ=1.9e-08 | accept
# LM 718 | loss 2.295e-12 | λ=1.3e-08 | accept
# LM 719 | loss 2.299e-12 | λ=3.9e-08 | reject
# LM 720 | loss 2.282e-12 | λ=2.8e-08 | accept
# LM 721 | loss 2.275e-12 | λ=1.9e-08 | accept
# LM 722 | loss 2.268e-12 | λ=1.3e-08 | accept
# LM 723 | loss 2.270e-12 | λ=4.0e-08 | reject
# LM 724 | loss 2.257e-12 | λ=2.8e-08 | accept
# LM 725 | loss 2.250e-12 | λ=2.0e-08 | accept
# LM 726 | loss 2.243e-12 | λ=1.4e-08 | accept
# LM 727 | loss 2.243e-12 | λ=4.2e-08 | reject
# LM 728 | loss 2.233e-12 | λ=2.9e-08 | accept
# LM 729 | loss 2.226e-12 | λ=2.0e-08 | accept
# LM 730 | loss 2.219e-12 | λ=1.4e-08 | accept
# LM 731 | loss 2.218e-12 | λ=1.0e-08 | accept
# LM 732 | loss 2.252e-12 | λ=3.0e-08 | reject
# LM 733 | loss 2.194e-12 | λ=2.1e-08 | accept
# LM 734 | loss 2.187e-12 | λ=1.5e-08 | accept
# LM 735 | loss 2.185e-12 | λ=1.0e-08 | accept
# LM 736 | loss 2.211e-12 | λ=3.1e-08 | reject
# LM 737 | loss 2.164e-12 | λ=2.2e-08 | accept
# LM 738 | loss 2.157e-12 | λ=1.5e-08 | accept
# LM 739 | loss 2.153e-12 | λ=1.1e-08 | accept
# LM 740 | loss 2.174e-12 | λ=3.2e-08 | reject
# LM 741 | loss 2.135e-12 | λ=2.2e-08 | accept
# LM 742 | loss 2.128e-12 | λ=1.6e-08 | accept
# LM 743 | loss 2.124e-12 | λ=1.1e-08 | accept
# LM 744 | loss 2.140e-12 | λ=3.3e-08 | reject
# LM 745 | loss 2.108e-12 | λ=2.3e-08 | accept
# LM 746 | loss 2.101e-12 | λ=1.6e-08 | accept
# LM 747 | loss 2.096e-12 | λ=1.1e-08 | accept
# LM 748 | loss 2.108e-12 | λ=3.4e-08 | reject
# LM 749 | loss 2.082e-12 | λ=2.4e-08 | accept
# LM 750 | loss 2.075e-12 | λ=1.6e-08 | accept
# LM 751 | loss 2.070e-12 | λ=1.2e-08 | accept
# LM 752 | loss 2.079e-12 | λ=3.5e-08 | reject
# LM 753 | loss 2.058e-12 | λ=2.4e-08 | accept
# LM 754 | loss 2.051e-12 | λ=1.7e-08 | accept
# LM 755 | loss 2.046e-12 | λ=1.2e-08 | accept
# LM 756 | loss 2.052e-12 | λ=3.6e-08 | reject
# LM 757 | loss 2.034e-12 | λ=2.5e-08 | accept
# LM 758 | loss 2.028e-12 | λ=1.7e-08 | accept
# LM 759 | loss 2.023e-12 | λ=1.2e-08 | accept
# LM 760 | loss 2.026e-12 | λ=3.7e-08 | reject
# LM 761 | loss 2.013e-12 | λ=2.6e-08 | accept
# LM 762 | loss 2.007e-12 | λ=1.8e-08 | accept
# LM 763 | loss 2.001e-12 | λ=1.3e-08 | accept
# LM 764 | loss 2.003e-12 | λ=3.8e-08 | reject
# LM 765 | loss 1.992e-12 | λ=2.6e-08 | accept
# LM 766 | loss 1.986e-12 | λ=1.8e-08 | accept
# LM 767 | loss 1.980e-12 | λ=1.3e-08 | accept
# LM 768 | loss 1.981e-12 | λ=3.9e-08 | reject
# LM 769 | loss 1.972e-12 | λ=2.7e-08 | accept
# LM 770 | loss 1.967e-12 | λ=1.9e-08 | accept
# LM 771 | loss 1.961e-12 | λ=1.3e-08 | accept
# LM 772 | loss 1.960e-12 | λ=9.3e-09 | accept
# LM 773 | loss 1.988e-12 | λ=2.8e-08 | reject
# LM 774 | loss 1.940e-12 | λ=2.0e-08 | accept
# LM 775 | loss 1.934e-12 | λ=1.4e-08 | accept
# LM 776 | loss 1.932e-12 | λ=9.6e-09 | accept
# LM 777 | loss 1.954e-12 | λ=2.9e-08 | reject
# LM 778 | loss 1.915e-12 | λ=2.0e-08 | accept
# LM 779 | loss 1.909e-12 | λ=1.4e-08 | accept
# LM 780 | loss 1.906e-12 | λ=9.9e-09 | accept
# LM 781 | loss 1.924e-12 | λ=3.0e-08 | reject
# LM 782 | loss 1.891e-12 | λ=2.1e-08 | accept
# LM 783 | loss 1.886e-12 | λ=1.4e-08 | accept
# LM 784 | loss 1.882e-12 | λ=1.0e-08 | accept
# LM 785 | loss 1.895e-12 | λ=3.0e-08 | reject
# LM 786 | loss 1.869e-12 | λ=2.1e-08 | accept
# LM 787 | loss 1.863e-12 | λ=1.5e-08 | accept
# LM 788 | loss 1.859e-12 | λ=1.0e-08 | accept
# LM 789 | loss 1.869e-12 | λ=3.1e-08 | reject
# LM 790 | loss 1.848e-12 | λ=2.2e-08 | accept
# LM 791 | loss 1.842e-12 | λ=1.5e-08 | accept
# LM 792 | loss 1.838e-12 | λ=1.1e-08 | accept
# LM 793 | loss 1.845e-12 | λ=3.2e-08 | reject
# LM 794 | loss 1.827e-12 | λ=2.3e-08 | accept
# LM 795 | loss 1.822e-12 | λ=1.6e-08 | accept
# LM 796 | loss 1.818e-12 | λ=1.1e-08 | accept
# LM 797 | loss 1.823e-12 | λ=3.3e-08 | reject
# LM 798 | loss 1.808e-12 | λ=2.3e-08 | accept
# LM 799 | loss 1.803e-12 | λ=1.6e-08 | accept
# LM 800 | loss 1.799e-12 | λ=1.1e-08 | accept
# LM 801 | loss 1.802e-12 | λ=3.4e-08 | reject
# LM 802 | loss 1.790e-12 | λ=2.4e-08 | accept
# LM 803 | loss 1.786e-12 | λ=1.7e-08 | accept
# LM 804 | loss 1.781e-12 | λ=1.2e-08 | accept
# LM 805 | loss 1.782e-12 | λ=3.5e-08 | reject
# LM 806 | loss 1.773e-12 | λ=2.5e-08 | accept
# LM 807 | loss 1.769e-12 | λ=1.7e-08 | accept
# LM 808 | loss 1.764e-12 | λ=1.2e-08 | accept
# LM 809 | loss 1.764e-12 | λ=3.6e-08 | reject
# LM 810 | loss 1.757e-12 | λ=2.5e-08 | accept
# LM 811 | loss 1.752e-12 | λ=1.8e-08 | accept
# LM 812 | loss 1.748e-12 | λ=1.2e-08 | accept
# LM 813 | loss 1.747e-12 | λ=8.7e-09 | accept
# LM 814 | loss 1.769e-12 | λ=2.6e-08 | reject
# LM 815 | loss 1.730e-12 | λ=1.8e-08 | accept
# LM 816 | loss 1.726e-12 | λ=1.3e-08 | accept
# LM 817 | loss 1.724e-12 | λ=8.9e-09 | accept
# LM 818 | loss 1.742e-12 | λ=2.7e-08 | reject
# LM 819 | loss 1.710e-12 | λ=1.9e-08 | accept
# LM 820 | loss 1.705e-12 | λ=1.3e-08 | accept
# LM 821 | loss 1.703e-12 | λ=9.2e-09 | accept
# LM 822 | loss 1.716e-12 | λ=2.8e-08 | reject
# LM 823 | loss 1.690e-12 | λ=1.9e-08 | accept
# LM 824 | loss 1.685e-12 | λ=1.3e-08 | accept
# LM 825 | loss 1.682e-12 | λ=9.4e-09 | accept
# LM 826 | loss 1.693e-12 | λ=2.8e-08 | reject
# LM 827 | loss 1.671e-12 | λ=2.0e-08 | accept
# LM 828 | loss 1.667e-12 | λ=1.4e-08 | accept
# LM 829 | loss 1.664e-12 | λ=9.7e-09 | accept
# LM 830 | loss 1.671e-12 | λ=2.9e-08 | reject
# LM 831 | loss 1.654e-12 | λ=2.0e-08 | accept
# LM 832 | loss 1.650e-12 | λ=1.4e-08 | accept
# LM 833 | loss 1.646e-12 | λ=1.0e-08 | accept
# LM 834 | loss 1.651e-12 | λ=3.0e-08 | reject
# LM 835 | loss 1.637e-12 | λ=2.1e-08 | accept
# LM 836 | loss 1.633e-12 | λ=1.5e-08 | accept
# LM 837 | loss 1.629e-12 | λ=1.0e-08 | accept
# LM 838 | loss 1.633e-12 | λ=3.1e-08 | reject
# LM 839 | loss 1.622e-12 | λ=2.2e-08 | accept
# LM 840 | loss 1.617e-12 | λ=1.5e-08 | accept
# LM 841 | loss 1.613e-12 | λ=1.1e-08 | accept
# LM 842 | loss 1.616e-12 | λ=3.2e-08 | reject
# LM 843 | loss 1.607e-12 | λ=2.2e-08 | accept
# LM 844 | loss 1.603e-12 | λ=1.6e-08 | accept
# LM 845 | loss 1.598e-12 | λ=1.1e-08 | accept
# LM 846 | loss 1.599e-12 | λ=3.3e-08 | reject
# LM 847 | loss 1.592e-12 | λ=2.3e-08 | accept
# LM 848 | loss 1.588e-12 | λ=1.6e-08 | accept
# LM 849 | loss 1.584e-12 | λ=1.1e-08 | accept
# LM 850 | loss 1.584e-12 | λ=7.8e-09 | accept
# LM 851 | loss 1.606e-12 | λ=2.4e-08 | reject
# LM 852 | loss 1.569e-12 | λ=1.6e-08 | accept
# LM 853 | loss 1.565e-12 | λ=1.2e-08 | accept
# LM 854 | loss 1.564e-12 | λ=8.1e-09 | accept
# LM 855 | loss 1.581e-12 | λ=2.4e-08 | reject
# LM 856 | loss 1.551e-12 | λ=1.7e-08 | accept
# LM 857 | loss 1.547e-12 | λ=1.2e-08 | accept
# LM 858 | loss 1.545e-12 | λ=8.3e-09 | accept
# LM 859 | loss 1.559e-12 | λ=2.5e-08 | reject
# LM 860 | loss 1.534e-12 | λ=1.7e-08 | accept
# LM 861 | loss 1.530e-12 | λ=1.2e-08 | accept
# LM 862 | loss 1.528e-12 | λ=8.6e-09 | accept
# LM 863 | loss 1.538e-12 | λ=2.6e-08 | reject
# LM 864 | loss 1.518e-12 | λ=1.8e-08 | accept
# LM 865 | loss 1.514e-12 | λ=1.3e-08 | accept
# LM 866 | loss 1.511e-12 | λ=8.8e-09 | accept
# LM 867 | loss 1.519e-12 | λ=2.6e-08 | reject
# LM 868 | loss 1.503e-12 | λ=1.8e-08 | accept
# LM 869 | loss 1.499e-12 | λ=1.3e-08 | accept
# LM 870 | loss 1.496e-12 | λ=9.1e-09 | accept
# LM 871 | loss 1.501e-12 | λ=2.7e-08 | reject
# LM 872 | loss 1.488e-12 | λ=1.9e-08 | accept
# LM 873 | loss 1.484e-12 | λ=1.3e-08 | accept
# LM 874 | loss 1.481e-12 | λ=9.3e-09 | accept
# LM 875 | loss 1.485e-12 | λ=2.8e-08 | reject
# LM 876 | loss 1.474e-12 | λ=2.0e-08 | accept
# LM 877 | loss 1.471e-12 | λ=1.4e-08 | accept
# LM 878 | loss 1.467e-12 | λ=9.6e-09 | accept
# LM 879 | loss 1.470e-12 | λ=2.9e-08 | reject
# LM 880 | loss 1.461e-12 | λ=2.0e-08 | accept
# LM 881 | loss 1.458e-12 | λ=1.4e-08 | accept
# LM 882 | loss 1.454e-12 | λ=9.9e-09 | accept
# LM 883 | loss 1.455e-12 | λ=3.0e-08 | reject
# LM 884 | loss 1.449e-12 | λ=2.1e-08 | accept
# LM 885 | loss 1.445e-12 | λ=1.5e-08 | accept
# LM 886 | loss 1.442e-12 | λ=1.0e-08 | accept
# LM 887 | loss 1.442e-12 | λ=3.0e-08 | reject
# LM 888 | loss 1.437e-12 | λ=2.1e-08 | accept
# LM 889 | loss 1.434e-12 | λ=1.5e-08 | accept
# LM 890 | loss 1.430e-12 | λ=1.0e-08 | accept
# LM 891 | loss 1.430e-12 | λ=7.3e-09 | accept
# LM 892 | loss 1.446e-12 | λ=2.2e-08 | reject
# LM 893 | loss 1.418e-12 | λ=1.5e-08 | accept
# LM 894 | loss 1.414e-12 | λ=1.1e-08 | accept
# LM 895 | loss 1.413e-12 | λ=7.5e-09 | accept
# LM 896 | loss 1.426e-12 | λ=2.3e-08 | reject
# LM 897 | loss 1.403e-12 | λ=1.6e-08 | accept
# LM 898 | loss 1.399e-12 | λ=1.1e-08 | accept
# LM 899 | loss 1.398e-12 | λ=7.7e-09 | accept
# LM 900 | loss 1.407e-12 | λ=2.3e-08 | reject
# LM 901 | loss 1.389e-12 | λ=1.6e-08 | accept
# LM 902 | loss 1.385e-12 | λ=1.1e-08 | accept
# LM 903 | loss 1.383e-12 | λ=8.0e-09 | accept
# LM 904 | loss 1.390e-12 | λ=2.4e-08 | reject
# LM 905 | loss 1.375e-12 | λ=1.7e-08 | accept
# LM 906 | loss 1.372e-12 | λ=1.2e-08 | accept
# LM 907 | loss 1.370e-12 | λ=8.2e-09 | accept
# LM 908 | loss 1.375e-12 | λ=2.5e-08 | reject
# LM 909 | loss 1.363e-12 | λ=1.7e-08 | accept
# LM 910 | loss 1.359e-12 | λ=1.2e-08 | accept
# LM 911 | loss 1.357e-12 | λ=8.4e-09 | accept
# LM 912 | loss 1.360e-12 | λ=2.5e-08 | reject
# LM 913 | loss 1.351e-12 | λ=1.8e-08 | accept
# LM 914 | loss 1.347e-12 | λ=1.2e-08 | accept
# LM 915 | loss 1.345e-12 | λ=8.7e-09 | accept
# LM 916 | loss 1.347e-12 | λ=2.6e-08 | reject
# LM 917 | loss 1.339e-12 | λ=1.8e-08 | accept
# LM 918 | loss 1.336e-12 | λ=1.3e-08 | accept
# LM 919 | loss 1.333e-12 | λ=8.9e-09 | accept
# LM 920 | loss 1.334e-12 | λ=2.7e-08 | reject
# LM 921 | loss 1.328e-12 | λ=1.9e-08 | accept
# LM 922 | loss 1.325e-12 | λ=1.3e-08 | accept
# LM 923 | loss 1.322e-12 | λ=9.2e-09 | accept
# LM 924 | loss 1.322e-12 | λ=2.8e-08 | reject
# LM 925 | loss 1.318e-12 | λ=1.9e-08 | accept
# LM 926 | loss 1.315e-12 | λ=1.4e-08 | accept
# LM 927 | loss 1.312e-12 | λ=9.5e-09 | accept
# LM 928 | loss 1.312e-12 | λ=6.6e-09 | accept
# LM 929 | loss 1.325e-12 | λ=2.0e-08 | reject
# LM 930 | loss 1.301e-12 | λ=1.4e-08 | accept
# LM 931 | loss 1.298e-12 | λ=9.7e-09 | accept
# LM 932 | loss 1.297e-12 | λ=6.8e-09 | accept
# LM 933 | loss 1.308e-12 | λ=2.0e-08 | reject
# LM 934 | loss 1.288e-12 | λ=1.4e-08 | accept
# LM 935 | loss 1.285e-12 | λ=1.0e-08 | accept
# LM 936 | loss 1.283e-12 | λ=7.0e-09 | accept
# LM 937 | loss 1.291e-12 | λ=2.1e-08 | reject
# LM 938 | loss 1.276e-12 | λ=1.5e-08 | accept
# LM 939 | loss 1.273e-12 | λ=1.0e-08 | accept
# LM 940 | loss 1.271e-12 | λ=7.2e-09 | accept
# LM 941 | loss 1.277e-12 | λ=2.2e-08 | reject
# LM 942 | loss 1.264e-12 | λ=1.5e-08 | accept
# LM 943 | loss 1.261e-12 | λ=1.1e-08 | accept
# LM 944 | loss 1.259e-12 | λ=7.4e-09 | accept
# LM 945 | loss 1.263e-12 | λ=2.2e-08 | reject
# LM 946 | loss 1.253e-12 | λ=1.6e-08 | accept
# LM 947 | loss 1.250e-12 | λ=1.1e-08 | accept
# LM 948 | loss 1.248e-12 | λ=7.6e-09 | accept
# LM 949 | loss 1.250e-12 | λ=2.3e-08 | reject
# LM 950 | loss 1.242e-12 | λ=1.6e-08 | accept
# LM 951 | loss 1.240e-12 | λ=1.1e-08 | accept
# LM 952 | loss 1.237e-12 | λ=7.9e-09 | accept
# LM 953 | loss 1.239e-12 | λ=2.4e-08 | reject
# LM 954 | loss 1.232e-12 | λ=1.7e-08 | accept
# LM 955 | loss 1.230e-12 | λ=1.2e-08 | accept
# LM 956 | loss 1.227e-12 | λ=8.1e-09 | accept
# LM 957 | loss 1.228e-12 | λ=2.4e-08 | reject
# LM 958 | loss 1.223e-12 | λ=1.7e-08 | accept
# LM 959 | loss 1.220e-12 | λ=1.2e-08 | accept
# LM 960 | loss 1.218e-12 | λ=8.3e-09 | accept
# LM 961 | loss 1.218e-12 | λ=5.8e-09 | accept
# LM 962 | loss 1.232e-12 | λ=1.7e-08 | reject
# LM 963 | loss 1.208e-12 | λ=1.2e-08 | accept
# LM 964 | loss 1.205e-12 | λ=8.6e-09 | accept
# LM 965 | loss 1.204e-12 | λ=6.0e-09 | accept
# LM 966 | loss 1.215e-12 | λ=1.8e-08 | reject
# LM 967 | loss 1.196e-12 | λ=1.3e-08 | accept
# LM 968 | loss 1.193e-12 | λ=8.8e-09 | accept
# LM 969 | loss 1.192e-12 | λ=6.2e-09 | accept
# LM 970 | loss 1.200e-12 | λ=1.9e-08 | reject
# LM 971 | loss 1.184e-12 | λ=1.3e-08 | accept
# LM 972 | loss 1.182e-12 | λ=9.1e-09 | accept
# LM 973 | loss 1.180e-12 | λ=6.3e-09 | accept
# LM 974 | loss 1.186e-12 | λ=1.9e-08 | reject
# LM 975 | loss 1.173e-12 | λ=1.3e-08 | accept
# LM 976 | loss 1.171e-12 | λ=9.3e-09 | accept
# LM 977 | loss 1.169e-12 | λ=6.5e-09 | accept
# LM 978 | loss 1.173e-12 | λ=2.0e-08 | reject
# LM 979 | loss 1.163e-12 | λ=1.4e-08 | accept
# LM 980 | loss 1.161e-12 | λ=9.6e-09 | accept
# LM 981 | loss 1.159e-12 | λ=6.7e-09 | accept
# LM 982 | loss 1.162e-12 | λ=2.0e-08 | reject
# LM 983 | loss 1.154e-12 | λ=1.4e-08 | accept
# LM 984 | loss 1.151e-12 | λ=9.9e-09 | accept
# LM 985 | loss 1.149e-12 | λ=6.9e-09 | accept
# LM 986 | loss 1.151e-12 | λ=2.1e-08 | reject
# LM 987 | loss 1.145e-12 | λ=1.5e-08 | accept
# LM 988 | loss 1.142e-12 | λ=1.0e-08 | accept
# LM 989 | loss 1.140e-12 | λ=7.1e-09 | accept
# LM 990 | loss 1.141e-12 | λ=2.1e-08 | reject
# LM 991 | loss 1.136e-12 | λ=1.5e-08 | accept
# LM 992 | loss 1.134e-12 | λ=1.0e-08 | accept
# LM 993 | loss 1.131e-12 | λ=7.3e-09 | accept
# LM 994 | loss 1.131e-12 | λ=2.2e-08 | reject
# LM 995 | loss 1.128e-12 | λ=1.5e-08 | accept
# LM 996 | loss 1.126e-12 | λ=1.1e-08 | accept
# LM 997 | loss 1.123e-12 | λ=7.5e-09 | accept
# LM 998 | loss 1.123e-12 | λ=5.3e-09 | accept
# LM 999 | loss 1.134e-12 | λ=1.6e-08 | reject

# %%
def eval_u(model, x, y):
    phi = compute_phi(x, y)
    inp = torch.cat([x, y, phi], dim=1)
    return model(inp), phi

def make_grid(N=100):
    x = torch.linspace(X_MIN, X_MAX, N)
    y = torch.linspace(Y_MIN, Y_MAX, N)
    X, Y = torch.meshgrid(x, y, indexing="ij")
    return X, Y

X, Y = make_grid(100)

xg = X.reshape(-1, 1).to(device)
yg = Y.reshape(-1, 1).to(device)

with torch.no_grad():   
    Ug, U_ext = eval_u(model, xg, yg)

U = Ug.reshape(X.shape).cpu().numpy()
U_ext = U_ext.reshape(X.shape).cpu().numpy()
Xn = X.cpu().numpy()
Yn = Y.cpu().numpy()

# 逐點相對誤差
U_ext_inf_norm = np.max(np.abs(U_ext))   # 真實解的 inf norm
error_rel = np.abs(U - U_ext) / (U_ext_inf_norm)
# 整體相對誤差
diff = torch.from_numpy(np.abs(U - U_ext)).double()
u_ext_2_norm = torch.from_numpy(np.abs(U_ext)).double()
error_1 = torch.norm(diff) / torch.norm(u_ext_2_norm)
error_2 = torch.norm(diff, p=float('inf')) / U_ext_inf_norm  
print("Relative L2 error:", error_1.item())
print("Relative Infinity norm error:", error_2.item())
# 畫圖
fig, axs = plt.subplots(1, 3, figsize=(18,5))

im0 = axs[0].contourf(Xn, Yn, U, 50, cmap='viridis')
fig.colorbar(im0, ax=axs[0])
axs[0].set_title('PINN Prediction $u_N$')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')

im1 = axs[1].contourf(Xn, Yn, U_ext, 50, cmap='viridis')
fig.colorbar(im1, ax=axs[1])
axs[1].set_title('Analytical Solution $\\phi$')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')

im2 = axs[2].contourf(Xn, Yn, error_rel, 50, cmap='hot')
fig.colorbar(im2, ax=axs[2])
axs[2].set_title('Relative Error')
axs[2].set_xlabel('x')
axs[2].set_ylabel('y')

plt.tight_layout()
plt.show()
# Out:
# Relative L2 error: 8.180723564408918e-08
# Relative Infinity norm error: 1.7187017351132826e-07

# %%
n_theta = sum(p.numel() for p in model.parameters())
print(n_theta)
print(m)
print(n)
# Out:
# 200
# 260
# 200

# %%
lap_u = laplace_u(model, xg, yg) 
residual = -lap_u
abs_residual = torch.abs(residual).detach().cpu().numpy()
log_abs_residual = torch.log(torch.abs(residual)).detach().cpu().numpy()
abs_residual = abs_residual.reshape(X.shape)
log_abs_residual = log_abs_residual.reshape(X.shape)

fig, axs = plt.subplots(1, 2, figsize=(15,5))

im0 = axs[0].contourf(X, Y, abs_residual, 50, cmap='viridis')
fig.colorbar(im0, ax=axs[0])
axs[0].set_title('|Residual| = |-Δu|')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].set_aspect('equal')

im1 = axs[1].contourf(X, Y, log_abs_residual, 50, cmap='viridis')
fig.colorbar(im1, ax=axs[1])
axs[1].set_title('log|Residual| = log|-Δu|')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')
axs[1].set_aspect('equal')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.semilogy(loss_history_LM, lw=2)
plt.xlabel("LM iteration")
plt.ylabel("loss")
plt.title("LM training loss")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Save training loss for plotting later
np.savez(
    "lm_loss.npz",
    epoch=epochs_LM,
    loss=loss_history_LM
)
