# %% [markdown]
# u(x,y,t)=(x^2+y^2)*phi. Domain: square [-1,1]^2 with moving crack from (0,0) to (1,alpha(t)). f = (r^2)*phi_t - 6phi

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FFMpegWriter

# Settings
torch.set_default_dtype(torch.float64)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

X_MIN, X_MAX = -1.0, 1.0
Y_MIN, Y_MAX = -1.0, 1.0
T_MIN, T_MAX = 0.0, 0.25  

N_f = 1000       
N_b_outer = 1000 
N_b_crack = 1000 
N_ic = 1000 # initial condition points on domain at t=0
N_ic_out = 1000  # initial condition points on domain at t=0
N_ic_crack = 1000   # initial condition points on domain at t=0
epochs = 2500
lambda_bc = 1.0
lambda_ic = 1.0
lambda_zz = 1.0
lambda_zz3 = 1.0
# Out:
# Device: cpu

# %%
# MLP 
class MLP(nn.Module):
    def __init__(self, layers):
        super().__init__()
        self.net = nn.ModuleList()
        for i in range(len(layers)-1):
            self.net.append(nn.Linear(layers[i], layers[i+1]))
        self.activation = torch.tanh
        for m in self.net:
            if isinstance(m, nn.Linear):
                nn.init.xavier_normal_(m.weight) #????
                nn.init.zeros_(m.bias)

    def forward(self, inp):
        z = inp
        for layer in self.net[:-1]:
            z = self.activation(layer(z))
        z = self.net[-1](z)
        return z

#
layers = [4, 64, 64, 1]
model = MLP(layers).to(device)   

# optimizer
optimizer = optim.LBFGS(model.parameters(), lr=1.0, max_iter=20, history_size=50, line_search_fn="strong_wolfe")

# %%
def alpha(t):
    return (np.pi / 4.0) * torch.sin(2.0 * np.pi * t)

def compute_phi_and_derivs(x, y, t):
    eps = 1e-12
    x = x.view(-1, 1).to(device)
    y = y.view(-1, 1).to(device)
    t = t.view(-1, 1).to(device)
    a = alpha(t)  # α(t)
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=eps))
    inside = torch.clamp(r - (x * torch.cos(a) + y * torch.sin(a)), min=eps)
    phi = torch.sqrt(0.5 * inside)
    sqrt_term = torch.sqrt(inside)
    phi_x = (torch.sqrt(torch.tensor(2.0, dtype=torch.float64)) *
             (x / r - torch.cos(a))) / (4.0 * sqrt_term)
    phi_y = (torch.sqrt(torch.tensor(2.0, dtype=torch.float64)) *
             (y / r - torch.sin(a))) / (4.0 * sqrt_term)
    phi_t = (torch.sqrt(torch.tensor(2.0, dtype=torch.float64)) / 4.0) * (x * torch.sin(a) - y * torch.cos(a)) / sqrt_term *(np.pi**2 / 2.0) * torch.cos(2 * np.pi * t)
    u_true = (x**2 + y**2) * phi
    return phi, phi_x, phi_y, phi_t, u_true

def partials_U_wrt_inputs(model, x, y, phi, t):
    # ensure column shapes
    x = x.view(-1,1)
    y = y.view(-1,1)
    phi = phi.view(-1,1)
    t = t.view(-1,1)

    inp = torch.cat([x, y, phi, t], dim=1).to(device)
    inp.requires_grad_(True)
    U = model(inp)  # (N,1)

    grads = torch.autograd.grad(U, inp, grad_outputs=torch.ones_like(U),
                                create_graph=True, retain_graph=True)[0]  # (N,4)
    U_x = grads[:,0:1]
    U_y = grads[:,1:2]
    U_z = grads[:,2:3]   
    U_t = grads[:,3:4]   
    return U, inp, U_x, U_y, U_z, U_t

def second_partials_U(model, inp, U_x, U_y, U_z):
    # inp shape (N,4)
    grad_Ux = torch.autograd.grad(U_x, inp, grad_outputs=torch.ones_like(U_x),
                                  create_graph=True, retain_graph=True)[0]
    grad_Uy = torch.autograd.grad(U_y, inp, grad_outputs=torch.ones_like(U_y),
                                  create_graph=True, retain_graph=True)[0]
    grad_Uz = torch.autograd.grad(U_z, inp, grad_outputs=torch.ones_like(U_z),
                                  create_graph=True, retain_graph=True)[0]

    U_xx = grad_Ux[:,0:1]
    U_xz = grad_Ux[:,2:3]
    U_yy = grad_Uy[:,1:2]
    U_yz = grad_Uy[:,2:3]
    U_zz = grad_Uz[:,2:3]

    return U_xx, U_yy, U_xz, U_yz, U_zz

def compute_residual_time(model, x, y, t):
    x = x.clone().detach().requires_grad_(True).to(device)
    y = y.clone().detach().requires_grad_(True).to(device)
    t = t.clone().detach().requires_grad_(True).to(device)

    phi, phi_x, phi_y, phi_t, _ = compute_phi_and_derivs(x, y, t)

    U, inp, U_x, U_y, U_z, U_t = partials_U_wrt_inputs(model, x, y, phi, t)
    U_xx, U_yy, U_xz, U_yz, U_zz = second_partials_U(model, inp, U_x, U_y, U_z)

    r = torch.sqrt(torch.clamp(x**2 + y**2, min=1e-12))
    laplace_U = U_xx + U_yy
    lap = laplace_U + 2.0 * (U_xz * phi_x + U_yz * phi_y) + (1/(4*r)) * U_zz
    ut = U_z * phi_t + U_t
    residual = ut - lap - r**2 * phi_t + 6.0 * phi
    return residual, U, U_zz, U_xz, U_yz

# compute tip constraint 
def compute_zz_uN(model, t):
    if not torch.is_tensor(t):
        t = torch.tensor([[t]], dtype=torch.float64, device=device)
    else:
        t = t.view(-1,1).to(dtype=torch.float64, device=device)

    x = torch.zeros_like(t)
    y = torch.zeros_like(t)

    phi, phi_x, phi_y, phi_t, _ = compute_phi_and_derivs(x, y, t)
    U, inp, U_x, U_y, U_z, U_t = partials_U_wrt_inputs(model, x, y, phi, t)

    grad_Uz = torch.autograd.grad(U_z, inp, grad_outputs=torch.ones_like(U_z),
                                  create_graph=True, retain_graph=True)[0]
    U_zz = grad_Uz[:,2:3]
    U_xz = grad_Uz[:,0:1]
    U_yz = grad_Uz[:,1:2]
    return torch.mean(U_zz**2 + U_xz**2 + U_yz**2) 

def compute_xyz_uN(model, x, y, t):
    phi, phi_x, phi_y, phi_t, _ = compute_phi_and_derivs(x, y, t)
    U, inp, U_x, U_y, U_z, U_t = partials_U_wrt_inputs(model, x, y, phi, t)
    grad_Uz = torch.autograd.grad(U_z, inp, grad_outputs=torch.ones_like(U_z),
                                  create_graph=True, retain_graph=True)[0]
    U_xz = grad_Uz[:,0:1]
    U_yz = grad_Uz[:,1:2]

    return torch.mean(U_xz**2+U_yz**2)  # shape (N,1)

def sample_collocation(N): 
    x = torch.rand(N*2,1) * (X_MAX - X_MIN) + X_MIN 
    y = torch.rand(N*2,1) * (Y_MAX - Y_MIN) + Y_MIN 
    t = torch.rand(N*2,1) * (T_MAX - T_MIN) + T_MIN 
    a = alpha(t) # shape (N*2,1) 
    # 裂縫 y = α(t)*x  點到直線距離 
    dist_to_crack = torch.abs(y - a * x) / torch.sqrt(1 + a**2) 
    # mask 
    mask_crack = (dist_to_crack < 1e-8) 
    x, y, t = x[~mask_crack][:N], y[~mask_crack][:N], t[~mask_crack][:N] 
    return x.to(device), y.to(device), t.to(device)

def sample_outer_boundary(N):
    per_side = max(4, N // 4)
    xs, ys = [], []

    ys.append(torch.linspace(Y_MIN, Y_MAX, per_side).unsqueeze(1)); xs.append(torch.ones_like(ys[-1]) * X_MIN)
    ys.append(torch.linspace(Y_MIN, Y_MAX, per_side).unsqueeze(1)); xs.append(torch.ones_like(ys[-1]) * X_MAX)
    xs.append(torch.linspace(X_MIN, X_MAX, per_side).unsqueeze(1)); ys.append(torch.ones_like(xs[-1]) * Y_MIN)
    xs.append(torch.linspace(X_MIN, X_MAX, per_side).unsqueeze(1)); ys.append(torch.ones_like(xs[-1]) * Y_MAX)

    x = torch.cat(xs, dim=0)[:N]
    y = torch.cat(ys, dim=0)[:N]
    t = torch.rand(N, 1, device=device, dtype=torch.float64) * (T_MAX - T_MIN) + T_MIN

    return x.to(device), y.to(device), t

def sample_crack_boundary(N):
    t = torch.rand(N, 1, device=device, dtype=torch.float64) * (T_MAX - T_MIN) + T_MIN
    x_vals = torch.linspace(0, 1, N, device=device, dtype=torch.float64).unsqueeze(1)
    y_vals = x_vals * alpha(t)
    return x_vals, y_vals, t

def sampling_points(N_f, N_b_crack, N_b_outer):
    x_f, y_f, t_f = sample_collocation(N_f)
    x_b_out, y_b_out, t_b_out = sample_outer_boundary(N_b_outer)
    x_b_crack, y_b_crack, t_b_crack = sample_crack_boundary(N_b_crack)

    x_f = x_f.view(-1,1); y_f = y_f.view(-1,1); t_f = t_f.view(-1,1)
    x_b_out = x_b_out.view(-1,1); y_b_out = y_b_out.view(-1,1); t_b_out = t_b_out.view(-1,1)
    x_b_crack = x_b_crack.view(-1,1); y_b_crack = y_b_crack.view(-1,1); t_b_crack = t_b_crack.view(-1,1)
    
    x_b = torch.cat([x_b_out, x_b_crack])
    y_b = torch.cat([y_b_out, y_b_crack])
    t_b = torch.cat([t_b_out, t_b_crack])

    phi_b, _, _, _, g_b = compute_phi_and_derivs(x_b, y_b, t_b)
    inp_bc = torch.cat([x_b, y_b, phi_b, t_b.detach()], dim=1)

    return x_f, y_f, t_f, x_b_out, y_b_out, t_b_out, x_b_crack, y_b_crack, t_b_crack, inp_bc, g_b 

# simpler phi (for inference / plotting, no grad) 
def compute_phi(x, y, t):
    eps = 1e-12
    x = x.view(-1,1).to(device)
    y = y.view(-1,1).to(device)
    t = t.view(-1,1).to(device)
    a = alpha(t)
    r = torch.sqrt(torch.clamp(x**2 + y**2, min=eps))
    inside = 0.5 * (r - (x * torch.cos(a) + y * torch.sin(a)))
    inside = torch.clamp(inside, min=1e-12)
    u_true = (x**2 + y**2) * torch.sqrt(inside)
    return torch.sqrt(inside), u_true

# %%
# training points 
x_f, y_f, t_f, x_b_out, y_b_out, t_b_out, x_b_crack, y_b_crack, t_b_crack, inp_bc, g_b = sampling_points(N_f, N_b_crack, N_b_outer)
x_ic_f, y_ic_f, _, x_ic_out, y_ic_out, _, _, _, _, _, _ = sampling_points(N_ic, N_ic_out, N_ic_crack)
x_ic = torch.cat([x_ic_f, x_ic_out]); y_ic = torch.cat([y_ic_f, y_ic_out]); t_ic = torch.zeros_like(x_ic)
phi_ic, _, _, _, g_ic = compute_phi_and_derivs(x_ic, y_ic, t_ic)
inp_ic = torch.cat([x_ic, y_ic, phi_ic, t_ic], dim=1)
(
    x_f_val, y_f_val, t_f_val,
    x_b_out_val, y_b_out_val, t_b_out_val,
    x_b_crack_val, y_b_crack_val, t_b_crack_val,
    inp_bc_val, g_b_val,
) = sampling_points(N_f, N_b_crack, N_b_outer)
x_ic_f_val, y_ic_f_val, _, x_ic_out_val, y_ic_out_val, _, _, _, _, _, _ = sampling_points(N_ic, N_ic_out, N_ic_crack)
x_ic_val = torch.cat([x_ic_f_val, x_ic_out_val]); y_ic_val = torch.cat([y_ic_f_val, y_ic_out_val]); t_ic_val = torch.zeros_like(x_ic_val)
phi_ic_val, _, _, _, g_ic_val = compute_phi_and_derivs(x_ic_val, y_ic_val, t_ic_val)
inp_ic_val = torch.cat([x_ic_val, y_ic_val, phi_ic_val, t_ic_val], dim=1)


print("Start training (time-dependent PINN)")

loss_history = []
val_history = []

for ep in range(epochs):
    def closure():
        optimizer.zero_grad()
        residual_f, _, _, _, _ = compute_residual_time(model, x_f, y_f, t_f)
        loss_pde = torch.mean(residual_f**2)
        u_bc = model(inp_bc)
        loss_bc = torch.mean((u_bc - g_b)**2)
        u_ic_pred = model(inp_ic)
        loss_ic = torch.mean((u_ic_pred - g_ic)**2)
        loss_zz = compute_zz_uN(model, t_b_crack)
        loss_yxz = compute_xyz_uN(model, x_b_crack, y_b_crack, t_b_crack)
        loss = (loss_pde
        + lambda_bc * loss_bc
        + lambda_ic * loss_ic
        + lambda_zz * loss_zz
        + lambda_zz3 * loss_yxz)
        loss.backward()
        return loss

    loss = optimizer.step(closure)
    loss_history.append(loss.item())
        # resampling 
    if ep % 50 == 0 and ep > 0:
        print(f"\n[Resample] epoch {ep}: regenerating PDE/BC/IC points...\n")

        x_f, y_f, t_f, x_b_out, y_b_out, t_b_out, x_b_crack, y_b_crack, t_b_crack, inp_bc, g_b = sampling_points(N_f, N_b_crack, N_b_outer)
        x_ic_f, y_ic_f, _, x_ic_out, y_ic_out, _, _, _, _, _, _ = sampling_points(N_ic, N_ic_out, N_ic_crack)
        x_ic = torch.cat([x_ic_f, x_ic_out], dim=0); y_ic = torch.cat([y_ic_f, y_ic_out], dim=0); t_ic = torch.zeros_like(x_ic)
        phi_ic, _, _, _, g_ic = compute_phi_and_derivs(x_ic, y_ic, t_ic)
        inp_ic = torch.cat([x_ic, y_ic, phi_ic, t_ic], dim=1)    

    if ep % 10 == 0 or ep == epochs-1:
        # validation 
            res_val, _, _, _, _ = compute_residual_time(model, x_f_val, y_f_val, t_f_val)
            loss_pde_val = torch.mean(res_val**2)
            u_bc_val = model(inp_bc_val)
            loss_bc_val = torch.mean((u_bc_val - g_b_val)**2)
            u_ic_pred_val = model(inp_ic_val)
            loss_ic_val = torch.mean((u_ic_pred_val - g_ic_val)**2)
            loss_zz_val = compute_zz_uN(model, t_b_crack_val)
            loss_yxz_val = compute_xyz_uN(model, x_b_crack_val, y_b_crack_val, t_b_crack_val)
            loss_val = (
                loss_pde_val
                + lambda_bc * loss_bc_val
                + lambda_ic * loss_ic_val
                + lambda_zz * loss_zz_val
                + lambda_zz3 * loss_yxz_val)
            val_history.append(loss_val.item())
            # training loss 細項, print 用
            res_f, _, _, _, _ = compute_residual_time(model, x_f, y_f, t_f)
            loss_pde = torch.mean(res_f**2)
            loss_bc = torch.mean((model(inp_bc) - g_b)**2)
            loss_ic = torch.mean((model(inp_ic) - g_ic)**2)
            loss_zz = compute_zz_uN(model, t_b_crack)
            loss_yxz = compute_xyz_uN(model, x_b_crack, y_b_crack, t_b_crack)

            print(
            f"Epoch {ep:4d} | "
            f"TrainLoss={loss.item():.3e} "
            f"(pde={loss_pde:.2e}, bc={loss_bc:.2e}, ic={loss_ic:.2e}, "
            f"zz={loss_zz:.2e}, yxz={loss_yxz:.2e},| "
            f"ValLoss={loss_val.item():.3e} "
            f"(pde={loss_pde_val:.2e}, bc={loss_bc_val:.2e}, ic={loss_ic_val:.2e}, "
            f"zz={loss_zz_val:.2e}, yxz={loss_yxz_val:.2e},)")            

print("Training finished.")
# Out:
# Start training (time-dependent PINN)
# Epoch    0 | TrainLoss=1.236e+01 (pde=3.17e-01, bc=1.53e-01, ic=1.62e-01, zz=1.14e-02, yxz=4.53e-03,| ValLoss=6.443e-01 (pde=2.93e-01, bc=1.72e-01, ic=1.64e-01, zz=1.14e-02, yxz=4.30e-03,)
# Epoch   10 | TrainLoss=4.020e-02 (pde=2.29e-02, bc=6.10e-03, ic=3.34e-03, zz=4.90e-04, yxz=4.37e-03,| ValLoss=3.936e-02 (pde=2.46e-02, bc=6.26e-03, ic=3.37e-03, zz=4.42e-04, yxz=4.66e-03,)
# Epoch   20 | TrainLoss=2.356e-02 (pde=1.42e-02, bc=4.19e-03, ic=1.83e-03, zz=2.89e-04, yxz=2.33e-03,| ValLoss=2.646e-02 (pde=1.74e-02, bc=4.24e-03, ic=1.80e-03, zz=2.85e-04, yxz=2.71e-03,)
# Epoch   30 | TrainLoss=1.765e-02 (pde=9.92e-03, bc=3.48e-03, ic=1.44e-03, zz=1.56e-04, yxz=2.23e-03,| ValLoss=1.978e-02 (pde=1.23e-02, bc=3.52e-03, ic=1.44e-03, zz=1.45e-04, yxz=2.37e-03,)
# Epoch   40 | TrainLoss=1.438e-02 (pde=7.51e-03, bc=3.53e-03, ic=1.11e-03, zz=3.18e-04, yxz=1.69e-03,| ValLoss=1.810e-02 (pde=1.12e-02, bc=3.61e-03, ic=1.09e-03, zz=3.06e-04, yxz=1.86e-03,)
#
# [Resample] epoch 50: regenerating PDE/BC/IC points...
#
# Epoch   50 | TrainLoss=1.236e-02 (pde=8.66e-03, bc=3.24e-03, ic=9.69e-04, zz=1.47e-04, yxz=1.68e-03,| ValLoss=1.622e-02 (pde=1.02e-02, bc=3.18e-03, ic=9.31e-04, zz=1.42e-04, yxz=1.79e-03,)
# Epoch   60 | TrainLoss=7.999e-03 (pde=4.48e-03, bc=1.77e-03, ic=6.22e-04, zz=5.92e-05, yxz=7.52e-04,| ValLoss=1.652e-02 (pde=1.34e-02, bc=1.75e-03, ic=6.06e-04, zz=5.90e-05, yxz=7.42e-04,)
# Epoch   70 | TrainLoss=5.854e-03 (pde=3.39e-03, bc=1.33e-03, ic=4.50e-04, zz=9.73e-05, yxz=4.48e-04,| ValLoss=1.578e-02 (pde=1.35e-02, bc=1.32e-03, ic=4.48e-04, zz=9.70e-05, yxz=4.33e-04,)
# Epoch   80 | TrainLoss=4.633e-03 (pde=2.83e-03, bc=1.08e-03, ic=3.08e-04, zz=5.90e-05, yxz=2.91e-04,| ValLoss=1.410e-02 (pde=1.24e-02, bc=1.07e-03, ic=3.05e-04, zz=5.69e-05, yxz=3.19e-04,)
# Epoch   90 | TrainLoss=3.902e-03 (pde=2.19e-03, bc=9.45e-04, ic=3.14e-04, zz=6.34e-05, yxz=3.14e-04,| ValLoss=1.393e-02 (pde=1.23e-02, bc=9.38e-04, ic=3.09e-04, zz=6.20e-05, yxz=3.42e-04,)
#
# [Resample] epoch 100: regenerating PDE/BC/IC points...
#
# Epoch  100 | TrainLoss=3.336e-03 (pde=1.45e-02, bc=8.82e-04, ic=3.19e-04, zz=2.90e-05, yxz=1.93e-04,| ValLoss=1.397e-02 (pde=1.26e-02, bc=8.65e-04, ic=3.13e-04, zz=2.91e-05, yxz=1.99e-04,)
# Epoch  110 | TrainLoss=7.667e-03 (pde=4.70e-03, bc=1.71e-03, ic=4.36e-04, zz=4.49e-05, yxz=5.97e-04,| ValLoss=1.537e-02 (pde=1.25e-02, bc=1.75e-03, ic=4.45e-04, zz=4.47e-05, yxz=6.00e-04,)
# Epoch  120 | TrainLoss=6.666e-03 (pde=3.76e-03, bc=1.57e-03, ic=4.67e-04, zz=5.79e-05, yxz=7.36e-04,| ValLoss=1.489e-02 (pde=1.19e-02, bc=1.62e-03, ic=4.88e-04, zz=5.87e-05, yxz=7.79e-04,)
# Epoch  130 | TrainLoss=6.043e-03 (pde=3.28e-03, bc=1.51e-03, ic=4.61e-04, zz=5.62e-05, yxz=7.05e-04,| ValLoss=1.429e-02 (pde=1.14e-02, bc=1.54e-03, ic=4.87e-04, zz=5.86e-05, yxz=7.82e-04,)
# Epoch  140 | TrainLoss=5.569e-03 (pde=3.00e-03, bc=1.43e-03, ic=4.21e-04, zz=6.71e-05, yxz=5.83e-04,| ValLoss=1.436e-02 (pde=1.17e-02, bc=1.46e-03, ic=4.48e-04, zz=6.94e-05, yxz=6.60e-04,)
#
# [Resample] epoch 150: regenerating PDE/BC/IC points...
#
# Epoch  150 | TrainLoss=5.051e-03 (pde=5.88e-03, bc=1.33e-03, ic=3.85e-04, zz=5.31e-05, yxz=5.27e-04,| ValLoss=1.457e-02 (pde=1.22e-02, bc=1.38e-03, ic=3.99e-04, zz=4.83e-05, yxz=5.16e-04,)
# Epoch  160 | TrainLoss=6.129e-03 (pde=3.44e-03, bc=1.53e-03, ic=4.80e-04, zz=4.58e-05, yxz=5.14e-04,| ValLoss=1.153e-02 (pde=8.81e-03, bc=1.62e-03, ic=4.80e-04, zz=4.39e-05, yxz=5.68e-04,)
# Epoch  170 | TrainLoss=5.384e-03 (pde=2.96e-03, bc=1.46e-03, ic=4.30e-04, zz=4.30e-05, yxz=4.48e-04,| ValLoss=1.111e-02 (pde=8.60e-03, bc=1.55e-03, ic=4.33e-04, zz=4.20e-05, yxz=4.90e-04,)
# Epoch  180 | TrainLoss=4.727e-03 (pde=2.38e-03, bc=1.27e-03, ic=4.45e-04, zz=5.27e-05, yxz=4.94e-04,| ValLoss=1.159e-02 (pde=9.21e-03, bc=1.34e-03, ic=4.48e-04, zz=4.99e-05, yxz=5.42e-04,)
# Epoch  190 | TrainLoss=4.080e-03 (pde=2.03e-03, bc=1.07e-03, ic=3.90e-04, zz=4.83e-05, yxz=4.94e-04,| ValLoss=1.254e-02 (pde=1.05e-02, bc=1.11e-03, ic=3.84e-04, zz=4.39e-05, yxz=5.20e-04,)
#
# [Resample] epoch 200: regenerating PDE/BC/IC points...
#
# Epoch  200 | TrainLoss=3.621e-03 (pde=5.83e-03, bc=1.03e-03, ic=3.06e-04, zz=6.21e-05, yxz=5.02e-04,| ValLoss=1.304e-02 (pde=1.12e-02, bc=1.02e-03, ic=3.17e-04, zz=5.94e-05, yxz=4.84e-04,)
# Epoch  210 | TrainLoss=4.038e-03 (pde=2.23e-03, bc=1.09e-03, ic=3.59e-04, zz=5.95e-05, yxz=2.28e-04,| ValLoss=7.563e-03 (pde=5.82e-03, bc=1.08e-03, ic=3.79e-04, zz=5.81e-05, yxz=2.24e-04,)
# Epoch  220 | TrainLoss=3.514e-03 (pde=1.94e-03, bc=9.97e-04, ic=3.09e-04, zz=6.26e-05, yxz=1.80e-04,| ValLoss=7.756e-03 (pde=6.22e-03, bc=9.84e-04, ic=3.24e-04, zz=6.01e-05, yxz=1.68e-04,)
# Epoch  230 | TrainLoss=3.306e-03 (pde=1.78e-03, bc=9.57e-04, ic=3.27e-04, zz=5.58e-05, yxz=1.69e-04,| ValLoss=1.093e-02 (pde=9.43e-03, bc=9.45e-04, ic=3.43e-04, zz=5.32e-05, yxz=1.60e-04,)
# Epoch  240 | TrainLoss=3.159e-03 (pde=1.69e-03, bc=9.27e-04, ic=3.41e-04, zz=4.85e-05, yxz=1.43e-04,| ValLoss=1.505e-02 (pde=1.36e-02, bc=9.16e-04, ic=3.60e-04, zz=4.60e-05, yxz=1.38e-04,)
#
# [Resample] epoch 250: regenerating PDE/BC/IC points...
#
# Epoch  250 | TrainLoss=3.045e-03 (pde=8.97e-03, bc=9.54e-04, ic=3.32e-04, zz=3.53e-05, yxz=1.56e-04,| ValLoss=1.627e-02 (pde=1.48e-02, bc=9.38e-04, ic=3.41e-04, zz=3.48e-05, yxz=1.52e-04,)
# Epoch  260 | TrainLoss=4.397e-03 (pde=2.17e-03, bc=1.25e-03, ic=4.97e-04, zz=4.48e-05, yxz=3.85e-04,| ValLoss=9.065e-03 (pde=6.86e-03, bc=1.26e-03, ic=5.04e-04, zz=4.42e-05, yxz=4.03e-04,)
# Epoch  270 | TrainLoss=3.944e-03 (pde=1.85e-03, bc=1.18e-03, ic=5.03e-04, zz=3.63e-05, yxz=3.27e-04,| ValLoss=9.613e-03 (pde=7.54e-03, bc=1.18e-03, ic=5.18e-04, zz=3.53e-05, yxz=3.36e-04,)
# Epoch  280 | TrainLoss=3.512e-03 (pde=1.63e-03, bc=1.09e-03, ic=4.48e-04, zz=2.67e-05, yxz=2.98e-04,| ValLoss=9.569e-03 (pde=7.68e-03, bc=1.09e-03, ic=4.65e-04, zz=2.62e-05, yxz=3.05e-04,)
# Epoch  290 | TrainLoss=3.229e-03 (pde=1.55e-03, bc=9.99e-04, ic=3.85e-04, zz=2.13e-05, yxz=2.40e-04,| ValLoss=1.037e-02 (pde=8.72e-03, bc=9.88e-04, ic=4.03e-04, zz=2.09e-05, yxz=2.37e-04,)
#
# [Resample] epoch 300: regenerating PDE/BC/IC points...
#
# Epoch  300 | TrainLoss=3.012e-03 (pde=7.90e-03, bc=9.18e-04, ic=3.77e-04, zz=2.52e-05, yxz=2.27e-04,| ValLoss=1.197e-02 (pde=1.04e-02, bc=9.36e-04, ic=4.01e-04, zz=2.25e-05, yxz=2.09e-04,)
# Epoch  310 | TrainLoss=3.694e-03 (pde=2.09e-03, bc=8.31e-04, ic=3.27e-04, zz=5.88e-05, yxz=3.14e-04,| ValLoss=8.900e-03 (pde=7.31e-03, bc=8.51e-04, ic=3.47e-04, zz=5.76e-05, yxz=3.32e-04,)
# Epoch  320 | TrainLoss=3.120e-03 (pde=1.70e-03, bc=7.46e-04, ic=2.49e-04, zz=2.73e-05, yxz=3.16e-04,| ValLoss=1.056e-02 (pde=9.15e-03, bc=7.70e-04, ic=2.62e-04, zz=2.46e-05, yxz=3.59e-04,)
# Epoch  330 | TrainLoss=2.641e-03 (pde=1.42e-03, bc=6.94e-04, ic=2.47e-04, zz=2.26e-05, yxz=2.30e-04,| ValLoss=1.037e-02 (pde=9.10e-03, bc=7.17e-04, ic=2.56e-04, zz=2.22e-05, yxz=2.70e-04,)
# Epoch  340 | TrainLoss=2.372e-03 (pde=1.23e-03, bc=6.52e-04, ic=2.59e-04, zz=1.80e-05, yxz=1.82e-04,| ValLoss=1.050e-02 (pde=9.35e-03, bc=6.74e-04, ic=2.63e-04, zz=1.73e-05, yxz=2.05e-04,)
#
# [Resample] epoch 350: regenerating PDE/BC/IC points...
#
# Epoch  350 | TrainLoss=2.172e-03 (pde=1.13e-02, bc=6.73e-04, ic=2.32e-04, zz=1.01e-05, yxz=1.98e-04,| ValLoss=9.593e-03 (pde=8.49e-03, bc=6.55e-04, ic=2.28e-04, zz=1.01e-05, yxz=2.10e-04,)
# Epoch  360 | TrainLoss=2.737e-03 (pde=1.34e-03, bc=6.78e-04, ic=2.98e-04, zz=5.69e-05, yxz=2.48e-04,| ValLoss=5.075e-03 (pde=3.81e-03, bc=6.60e-04, ic=2.92e-04, zz=5.78e-05, yxz=2.61e-04,)
# Epoch  370 | TrainLoss=2.039e-03 (pde=9.09e-04, bc=6.46e-04, ic=2.12e-04, zz=2.43e-05, yxz=2.13e-04,| ValLoss=4.965e-03 (pde=3.88e-03, bc=6.28e-04, ic=2.09e-04, zz=2.49e-05, yxz=2.20e-04,)
# Epoch  380 | TrainLoss=1.781e-03 (pde=7.51e-04, bc=6.30e-04, ic=2.09e-04, zz=2.60e-05, yxz=1.49e-04,| ValLoss=4.692e-03 (pde=3.68e-03, bc=6.23e-04, ic=2.07e-04, zz=2.65e-05, yxz=1.51e-04,)
# Epoch  390 | TrainLoss=1.610e-03 (pde=6.67e-04, bc=6.23e-04, ic=1.81e-04, zz=1.36e-05, yxz=1.07e-04,| ValLoss=4.627e-03 (pde=3.71e-03, bc=6.17e-04, ic=1.79e-04, zz=1.40e-05, yxz=1.06e-04,)
#
# [Resample] epoch 400: regenerating PDE/BC/IC points...
#
# Epoch  400 | TrainLoss=1.484e-03 (pde=1.30e-02, bc=5.98e-04, ic=1.70e-04, zz=9.56e-06, yxz=1.05e-04,| ValLoss=4.600e-03 (pde=3.71e-03, bc=5.99e-04, ic=1.67e-04, zz=9.48e-06, yxz=1.13e-04,)
# Epoch  410 | TrainLoss=3.472e-03 (pde=1.89e-03, bc=8.36e-04, ic=2.34e-04, zz=2.78e-05, yxz=3.67e-04,| ValLoss=9.666e-03 (pde=8.15e-03, bc=8.39e-04, ic=2.32e-04, zz=2.67e-05, yxz=4.14e-04,)
# Epoch  420 | TrainLoss=2.719e-03 (pde=1.47e-03, bc=6.71e-04, ic=2.25e-04, zz=9.35e-06, yxz=3.01e-04,| ValLoss=1.017e-02 (pde=8.92e-03, bc=6.64e-04, ic=2.25e-04, zz=8.61e-06, yxz=3.49e-04,)
# Epoch  430 | TrainLoss=2.343e-03 (pde=1.23e-03, bc=6.58e-04, ic=1.74e-04, zz=1.03e-05, yxz=2.32e-04,| ValLoss=1.046e-02 (pde=9.38e-03, bc=6.47e-04, ic=1.75e-04, zz=9.92e-06, yxz=2.55e-04,)
# Epoch  440 | TrainLoss=2.050e-03 (pde=1.02e-03, bc=6.09e-04, ic=1.83e-04, zz=8.30e-06, yxz=1.91e-04,| ValLoss=9.453e-03 (pde=8.47e-03, bc=5.91e-04, ic=1.86e-04, zz=7.97e-06, yxz=1.96e-04,)
#
# [Resample] epoch 450: regenerating PDE/BC/IC points...
#
# Epoch  450 | TrainLoss=1.791e-03 (pde=1.35e-02, bc=5.89e-04, ic=1.86e-04, zz=1.32e-05, yxz=1.52e-04,| ValLoss=8.814e-03 (pde=7.90e-03, bc=5.77e-04, ic=1.90e-04, zz=1.18e-05, yxz=1.37e-04,)
# Epoch  460 | TrainLoss=2.657e-03 (pde=1.44e-03, bc=6.47e-04, ic=2.18e-04, zz=2.65e-05, yxz=2.13e-04,| ValLoss=3.872e-03 (pde=2.76e-03, bc=6.59e-04, ic=2.15e-04, zz=2.58e-05, yxz=2.08e-04,)
# Epoch  470 | TrainLoss=2.241e-03 (pde=1.23e-03, bc=6.24e-04, ic=1.77e-04, zz=2.51e-05, yxz=1.80e-04,| ValLoss=3.920e-03 (pde=2.91e-03, bc=6.36e-04, ic=1.75e-04, zz=2.31e-05, yxz=1.74e-04,)
# Epoch  480 | TrainLoss=2.092e-03 (pde=1.12e-03, bc=6.16e-04, ic=1.74e-04, zz=2.36e-05, yxz=1.43e-04,| ValLoss=3.577e-03 (pde=2.61e-03, bc=6.29e-04, ic=1.72e-04, zz=2.26e-05, yxz=1.42e-04,)
# Epoch  490 | TrainLoss=1.913e-03 (pde=9.96e-04, bc=5.92e-04, ic=1.64e-04, zz=2.05e-05, yxz=1.26e-04,| ValLoss=3.423e-03 (pde=2.51e-03, bc=6.03e-04, ic=1.64e-04, zz=1.98e-05, yxz=1.29e-04,)
#
# [Resample] epoch 500: regenerating PDE/BC/IC points...
#
# Epoch  500 | TrainLoss=1.787e-03 (pde=1.09e-02, bc=5.92e-04, ic=1.51e-04, zz=1.46e-05, yxz=1.22e-04,| ValLoss=3.228e-03 (pde=2.36e-03, bc=5.81e-04, ic=1.54e-04, zz=1.46e-05, yxz=1.23e-04,)
# Epoch  510 | TrainLoss=2.590e-03 (pde=1.41e-03, bc=6.60e-04, ic=1.67e-04, zz=1.67e-05, yxz=2.67e-04,| ValLoss=5.160e-03 (pde=4.06e-03, bc=6.49e-04, ic=1.79e-04, zz=1.69e-05, yxz=2.52e-04,)
# Epoch  520 | TrainLoss=2.057e-03 (pde=1.02e-03, bc=5.96e-04, ic=1.49e-04, zz=2.73e-05, yxz=2.34e-04,| ValLoss=5.030e-03 (pde=4.04e-03, bc=5.87e-04, ic=1.59e-04, zz=2.67e-05, yxz=2.18e-04,)
# Epoch  530 | TrainLoss=1.776e-03 (pde=8.58e-04, bc=5.86e-04, ic=1.31e-04, zz=2.66e-05, yxz=1.52e-04,| ValLoss=5.008e-03 (pde=4.12e-03, bc=5.79e-04, ic=1.38e-04, zz=2.67e-05, yxz=1.40e-04,)
# Epoch  540 | TrainLoss=1.577e-03 (pde=7.28e-04, bc=5.62e-04, ic=1.37e-04, zz=2.06e-05, yxz=1.14e-04,| ValLoss=5.169e-03 (pde=4.35e-03, bc=5.53e-04, ic=1.44e-04, zz=2.06e-05, yxz=1.04e-04,)
#
# [Resample] epoch 550: regenerating PDE/BC/IC points...
#
# Epoch  550 | TrainLoss=1.437e-03 (pde=2.59e-03, bc=5.36e-04, ic=1.39e-04, zz=1.93e-05, yxz=9.81e-05,| ValLoss=5.199e-03 (pde=4.42e-03, bc=5.37e-04, ic=1.32e-04, zz=1.89e-05, yxz=9.43e-05,)
# Epoch  560 | TrainLoss=1.821e-03 (pde=9.62e-04, bc=5.74e-04, ic=1.51e-04, zz=2.27e-05, yxz=8.38e-05,| ValLoss=4.294e-03 (pde=3.47e-03, bc=5.73e-04, ic=1.43e-04, zz=2.32e-05, yxz=8.77e-05,)
# Epoch  570 | TrainLoss=1.606e-03 (pde=7.89e-04, bc=5.43e-04, ic=1.46e-04, zz=1.64e-05, yxz=8.60e-05,| ValLoss=4.370e-03 (pde=3.59e-03, bc=5.43e-04, ic=1.35e-04, zz=1.62e-05, yxz=8.97e-05,)
# Epoch  580 | TrainLoss=1.450e-03 (pde=6.78e-04, bc=5.32e-04, ic=1.33e-04, zz=1.92e-05, yxz=7.85e-05,| ValLoss=4.214e-03 (pde=3.46e-03, bc=5.30e-04, ic=1.22e-04, zz=1.89e-05, yxz=8.57e-05,)
# Epoch  590 | TrainLoss=1.360e-03 (pde=5.98e-04, bc=5.38e-04, ic=1.28e-04, zz=9.77e-06, yxz=7.79e-05,| ValLoss=4.141e-03 (pde=3.39e-03, bc=5.37e-04, ic=1.17e-04, zz=9.79e-06, yxz=8.35e-05,)
#
# [Resample] epoch 600: regenerating PDE/BC/IC points...
#
# Epoch  600 | TrainLoss=1.281e-03 (pde=2.03e-03, bc=5.42e-04, ic=1.17e-04, zz=7.18e-06, yxz=8.33e-05,| ValLoss=4.402e-03 (pde=3.67e-03, bc=5.38e-04, ic=1.10e-04, zz=7.84e-06, yxz=8.04e-05,)
# Epoch  610 | TrainLoss=1.690e-03 (pde=8.21e-04, bc=5.91e-04, ic=1.34e-04, zz=1.00e-05, yxz=1.12e-04,| ValLoss=4.412e-03 (pde=3.58e-03, bc=5.89e-04, ic=1.29e-04, zz=1.04e-05, yxz=1.07e-04,)
# Epoch  620 | TrainLoss=1.475e-03 (pde=5.99e-04, bc=5.74e-04, ic=1.60e-04, zz=9.79e-06, yxz=1.17e-04,| ValLoss=4.531e-03 (pde=3.68e-03, bc=5.67e-04, ic=1.53e-04, zz=1.05e-05, yxz=1.18e-04,)
# Epoch  630 | TrainLoss=1.363e-03 (pde=5.32e-04, bc=5.62e-04, ic=1.32e-04, zz=7.84e-06, yxz=1.16e-04,| ValLoss=4.564e-03 (pde=3.75e-03, bc=5.56e-04, ic=1.27e-04, zz=8.46e-06, yxz=1.21e-04,)
# Epoch  640 | TrainLoss=1.267e-03 (pde=4.68e-04, bc=5.40e-04, ic=1.24e-04, zz=6.30e-06, yxz=1.18e-04,| ValLoss=4.619e-03 (pde=3.84e-03, bc=5.36e-04, ic=1.18e-04, zz=6.64e-06, yxz=1.23e-04,)
#
# [Resample] epoch 650: regenerating PDE/BC/IC points...
#
# Epoch  650 | TrainLoss=1.194e-03 (pde=4.79e-03, bc=5.24e-04, ic=1.20e-04, zz=9.74e-06, yxz=1.43e-04,| ValLoss=4.715e-03 (pde=3.95e-03, bc=5.13e-04, ic=1.14e-04, zz=9.32e-06, yxz=1.24e-04,)
# Epoch  660 | TrainLoss=2.050e-03 (pde=9.29e-04, bc=6.59e-04, ic=1.87e-04, zz=2.15e-05, yxz=2.02e-04,| ValLoss=4.574e-03 (pde=3.50e-03, bc=6.50e-04, ic=1.81e-04, zz=2.15e-05, yxz=2.22e-04,)
# Epoch  670 | TrainLoss=1.708e-03 (pde=7.14e-04, bc=6.12e-04, ic=1.84e-04, zz=1.52e-05, yxz=1.66e-04,| ValLoss=4.579e-03 (pde=3.60e-03, bc=6.01e-04, ic=1.82e-04, zz=1.43e-05, yxz=1.87e-04,)
# Epoch  680 | TrainLoss=1.534e-03 (pde=6.02e-04, bc=5.91e-04, ic=1.79e-04, zz=2.09e-05, yxz=1.25e-04,| ValLoss=4.168e-03 (pde=3.25e-03, bc=5.79e-04, ic=1.77e-04, zz=2.07e-05, yxz=1.39e-04,)
# Epoch  690 | TrainLoss=1.429e-03 (pde=5.26e-04, bc=5.86e-04, ic=1.69e-04, zz=1.47e-05, yxz=1.24e-04,| ValLoss=3.942e-03 (pde=3.05e-03, bc=5.74e-04, ic=1.69e-04, zz=1.44e-05, yxz=1.36e-04,)
#
# [Resample] epoch 700: regenerating PDE/BC/IC points...
#
# Epoch  700 | TrainLoss=1.351e-03 (pde=2.20e-03, bc=5.63e-04, ic=1.70e-04, zz=8.91e-06, yxz=1.78e-04,| ValLoss=3.944e-03 (pde=3.07e-03, bc=5.56e-04, ic=1.65e-04, zz=8.72e-06, yxz=1.47e-04,)
# Epoch  710 | TrainLoss=1.463e-03 (pde=6.55e-04, bc=5.38e-04, ic=1.54e-04, zz=1.19e-05, yxz=9.15e-05,| ValLoss=4.109e-03 (pde=3.32e-03, bc=5.33e-04, ic=1.50e-04, zz=1.17e-05, yxz=9.05e-05,)
# Epoch  720 | TrainLoss=1.333e-03 (pde=5.91e-04, bc=5.17e-04, ic=1.36e-04, zz=6.15e-06, yxz=6.92e-05,| ValLoss=4.162e-03 (pde=3.45e-03, bc=5.11e-04, ic=1.31e-04, zz=6.00e-06, yxz=6.80e-05,)
# Epoch  730 | TrainLoss=1.232e-03 (pde=5.03e-04, bc=5.18e-04, ic=1.26e-04, zz=6.83e-06, yxz=6.90e-05,| ValLoss=4.469e-03 (pde=3.76e-03, bc=5.12e-04, ic=1.22e-04, zz=6.63e-06, yxz=7.24e-05,)
# Epoch  740 | TrainLoss=1.160e-03 (pde=4.36e-04, bc=5.23e-04, ic=1.19e-04, zz=5.74e-06, yxz=6.77e-05,| ValLoss=4.765e-03 (pde=4.06e-03, bc=5.18e-04, ic=1.15e-04, zz=5.54e-06, yxz=6.90e-05,)
#
# [Resample] epoch 750: regenerating PDE/BC/IC points...
#
# Epoch  750 | TrainLoss=1.113e-03 (pde=1.16e-03, bc=4.95e-04, ic=1.31e-04, zz=4.97e-06, yxz=6.87e-05,| ValLoss=4.840e-03 (pde=4.15e-03, bc=4.97e-04, ic=1.19e-04, zz=5.70e-06, yxz=6.74e-05,)
# Epoch  760 | TrainLoss=1.093e-03 (pde=3.93e-04, bc=4.87e-04, ic=1.23e-04, zz=6.45e-06, yxz=6.51e-05,| ValLoss=3.511e-03 (pde=2.84e-03, bc=4.89e-04, ic=1.14e-04, zz=7.13e-06, yxz=6.61e-05,)
# Epoch  770 | TrainLoss=9.914e-04 (pde=3.25e-04, bc=4.76e-04, ic=1.20e-04, zz=1.03e-05, yxz=5.44e-05,| ValLoss=3.423e-03 (pde=2.77e-03, bc=4.79e-04, ic=1.10e-04, zz=1.20e-05, yxz=5.34e-05,)
# Epoch  780 | TrainLoss=9.371e-04 (pde=2.90e-04, bc=4.70e-04, ic=1.16e-04, zz=6.76e-06, yxz=4.95e-05,| ValLoss=3.373e-03 (pde=2.74e-03, bc=4.72e-04, ic=1.07e-04, zz=7.82e-06, yxz=5.01e-05,)
# Epoch  790 | TrainLoss=8.995e-04 (pde=2.67e-04, bc=4.67e-04, ic=1.12e-04, zz=5.31e-06, yxz=4.50e-05,| ValLoss=3.288e-03 (pde=2.67e-03, bc=4.68e-04, ic=1.03e-04, zz=6.51e-06, yxz=4.45e-05,)
#
# [Resample] epoch 800: regenerating PDE/BC/IC points...
#
# Epoch  800 | TrainLoss=8.736e-04 (pde=1.53e-03, bc=4.65e-04, ic=1.05e-04, zz=5.05e-06, yxz=3.97e-05,| ValLoss=3.322e-03 (pde=2.71e-03, bc=4.61e-04, ic=1.01e-04, zz=5.68e-06, yxz=4.01e-05,)
# Epoch  810 | TrainLoss=1.076e-03 (pde=3.66e-04, bc=5.07e-04, ic=1.21e-04, zz=9.49e-06, yxz=5.31e-05,| ValLoss=3.790e-03 (pde=3.10e-03, bc=5.03e-04, ic=1.15e-04, zz=1.11e-05, yxz=5.54e-05,)
# Epoch  820 | TrainLoss=9.781e-04 (pde=3.15e-04, bc=4.92e-04, ic=1.14e-04, zz=5.36e-06, yxz=4.48e-05,| ValLoss=3.749e-03 (pde=3.10e-03, bc=4.86e-04, ic=1.08e-04, zz=6.27e-06, yxz=4.88e-05,)
# Epoch  830 | TrainLoss=9.264e-04 (pde=2.80e-04, bc=4.84e-04, ic=1.07e-04, zz=5.40e-06, yxz=4.65e-05,| ValLoss=3.958e-03 (pde=3.32e-03, bc=4.77e-04, ic=1.01e-04, zz=6.40e-06, yxz=5.42e-05,)
# Epoch  840 | TrainLoss=8.940e-04 (pde=2.60e-04, bc=4.82e-04, ic=9.91e-05, zz=4.55e-06, yxz=4.45e-05,| ValLoss=3.975e-03 (pde=3.35e-03, bc=4.74e-04, ic=9.37e-05, zz=5.44e-06, yxz=5.17e-05,)
#
# [Resample] epoch 850: regenerating PDE/BC/IC points...
#
# Epoch  850 | TrainLoss=8.517e-04 (pde=2.58e-03, bc=4.69e-04, ic=8.87e-05, zz=6.85e-06, yxz=5.82e-05,| ValLoss=3.793e-03 (pde=3.18e-03, bc=4.61e-04, ic=8.72e-05, zz=6.97e-06, yxz=5.77e-05,)
# Epoch  860 | TrainLoss=1.390e-03 (pde=7.06e-04, bc=4.78e-04, ic=1.08e-04, zz=1.38e-05, yxz=7.29e-05,| ValLoss=2.878e-03 (pde=2.22e-03, bc=4.71e-04, ic=1.03e-04, zz=1.40e-05, yxz=7.05e-05,)
# Epoch  870 | TrainLoss=1.252e-03 (pde=5.95e-04, bc=4.64e-04, ic=1.10e-04, zz=1.29e-05, yxz=6.27e-05,| ValLoss=2.828e-03 (pde=2.19e-03, bc=4.56e-04, ic=1.05e-04, zz=1.28e-05, yxz=6.13e-05,)
# Epoch  880 | TrainLoss=1.158e-03 (pde=5.18e-04, bc=4.69e-04, ic=8.91e-05, zz=1.38e-05, yxz=6.39e-05,| ValLoss=2.738e-03 (pde=2.11e-03, bc=4.61e-04, ic=8.77e-05, zz=1.37e-05, yxz=6.56e-05,)
# Epoch  890 | TrainLoss=1.090e-03 (pde=4.45e-04, bc=4.60e-04, ic=9.21e-05, zz=1.04e-05, yxz=7.53e-05,| ValLoss=2.641e-03 (pde=2.01e-03, bc=4.52e-04, ic=9.07e-05, zz=1.04e-05, yxz=7.60e-05,)
#
# [Resample] epoch 900: regenerating PDE/BC/IC points...
#
# Epoch  900 | TrainLoss=1.018e-03 (pde=2.20e-03, bc=4.47e-04, ic=9.43e-05, zz=1.04e-05, yxz=9.78e-05,| ValLoss=2.835e-03 (pde=2.20e-03, bc=4.35e-04, ic=9.48e-05, zz=9.91e-06, yxz=9.35e-05,)
# Epoch  910 | TrainLoss=1.200e-03 (pde=4.95e-04, bc=4.80e-04, ic=9.90e-05, zz=7.02e-06, yxz=9.95e-05,| ValLoss=3.129e-03 (pde=2.46e-03, bc=4.71e-04, ic=9.95e-05, zz=6.84e-06, yxz=9.17e-05,)
# Epoch  920 | TrainLoss=1.045e-03 (pde=3.54e-04, bc=4.74e-04, ic=9.63e-05, zz=7.50e-06, yxz=9.73e-05,| ValLoss=3.010e-03 (pde=2.35e-03, bc=4.63e-04, ic=9.78e-05, zz=7.23e-06, yxz=9.38e-05,)
# Epoch  930 | TrainLoss=9.510e-04 (pde=2.97e-04, bc=4.60e-04, ic=9.73e-05, zz=5.22e-06, yxz=8.52e-05,| ValLoss=3.043e-03 (pde=2.40e-03, bc=4.50e-04, ic=9.97e-05, zz=5.02e-06, yxz=8.50e-05,)
# Epoch  940 | TrainLoss=8.808e-04 (pde=2.56e-04, bc=4.40e-04, ic=9.61e-05, zz=3.72e-06, yxz=7.97e-05,| ValLoss=2.896e-03 (pde=2.28e-03, bc=4.32e-04, ic=9.86e-05, zz=3.58e-06, yxz=8.15e-05,)
#
# [Resample] epoch 950: regenerating PDE/BC/IC points...
#
# Epoch  950 | TrainLoss=8.296e-04 (pde=8.67e-04, bc=4.45e-04, ic=9.89e-05, zz=4.62e-06, yxz=7.32e-05,| ValLoss=2.859e-03 (pde=2.26e-03, bc=4.30e-04, ic=9.67e-05, zz=4.53e-06, yxz=6.92e-05,)
# Epoch  960 | TrainLoss=9.211e-04 (pde=3.27e-04, bc=4.21e-04, ic=8.24e-05, zz=6.24e-06, yxz=6.72e-05,| ValLoss=2.138e-03 (pde=1.58e-03, bc=4.05e-04, ic=7.96e-05, zz=6.13e-06, yxz=6.60e-05,)
# Epoch  970 | TrainLoss=8.242e-04 (pde=2.71e-04, bc=4.17e-04, ic=7.26e-05, zz=4.70e-06, yxz=5.42e-05,| ValLoss=2.828e-03 (pde=2.30e-03, bc=4.00e-04, ic=7.02e-05, zz=4.68e-06, yxz=5.47e-05,)
# Epoch  980 | TrainLoss=7.852e-04 (pde=2.45e-04, bc=4.14e-04, ic=6.30e-05, zz=4.03e-06, yxz=5.52e-05,| ValLoss=3.270e-03 (pde=2.75e-03, bc=3.99e-04, ic=6.07e-05, zz=3.96e-06, yxz=5.65e-05,)
# Epoch  990 | TrainLoss=7.480e-04 (pde=2.26e-04, bc=4.05e-04, ic=5.80e-05, zz=3.42e-06, yxz=5.33e-05,| ValLoss=3.813e-03 (pde=3.31e-03, bc=3.91e-04, ic=5.62e-05, zz=3.40e-06, yxz=5.50e-05,)
#
# [Resample] epoch 1000: regenerating PDE/BC/IC points...
#
# Epoch 1000 | TrainLoss=7.254e-04 (pde=4.65e-03, bc=3.75e-04, ic=5.59e-05, zz=3.84e-06, yxz=5.71e-05,| ValLoss=4.115e-03 (pde=3.62e-03, bc=3.83e-04, ic=5.49e-05, zz=3.86e-06, yxz=5.64e-05,)
# Epoch 1010 | TrainLoss=2.245e-03 (pde=1.33e-03, bc=5.54e-04, ic=1.33e-04, zz=6.88e-06, yxz=1.74e-04,| ValLoss=3.299e-03 (pde=2.40e-03, bc=5.67e-04, ic=1.33e-04, zz=6.96e-06, yxz=1.94e-04,)
# Epoch 1020 | TrainLoss=1.951e-03 (pde=1.06e-03, bc=5.34e-04, ic=1.61e-04, zz=1.41e-05, yxz=1.60e-04,| ValLoss=4.259e-03 (pde=3.36e-03, bc=5.51e-04, ic=1.62e-04, zz=1.44e-05, yxz=1.75e-04,)
# Epoch 1030 | TrainLoss=1.810e-03 (pde=9.61e-04, bc=5.22e-04, ic=1.54e-04, zz=1.30e-05, yxz=1.49e-04,| ValLoss=4.893e-03 (pde=4.02e-03, bc=5.42e-04, ic=1.56e-04, zz=1.31e-05, yxz=1.60e-04,)
# Epoch 1040 | TrainLoss=1.717e-03 (pde=8.91e-04, bc=5.01e-04, ic=1.47e-04, zz=1.14e-05, yxz=1.57e-04,| ValLoss=5.234e-03 (pde=4.39e-03, bc=5.19e-04, ic=1.48e-04, zz=1.14e-05, yxz=1.68e-04,)
#
# [Resample] epoch 1050: regenerating PDE/BC/IC points...
#
# Epoch 1050 | TrainLoss=1.612e-03 (pde=2.05e-02, bc=5.02e-04, ic=1.20e-04, zz=1.42e-05, yxz=2.44e-04,| ValLoss=5.400e-03 (pde=4.59e-03, bc=4.94e-04, ic=1.24e-04, zz=1.50e-05, yxz=1.76e-04,)
# Epoch 1060 | TrainLoss=1.443e-03 (pde=7.15e-04, bc=4.86e-04, ic=9.17e-05, zz=6.97e-06, yxz=1.11e-04,| ValLoss=1.997e-03 (pde=1.29e-03, bc=4.84e-04, ic=9.67e-05, zz=8.17e-06, yxz=1.18e-04,)
# Epoch 1070 | TrainLoss=1.239e-03 (pde=5.63e-04, bc=4.63e-04, ic=1.13e-04, zz=4.34e-06, yxz=8.45e-05,| ValLoss=1.844e-03 (pde=1.17e-03, bc=4.59e-04, ic=1.17e-04, zz=5.69e-06, yxz=9.29e-05,)
# Epoch 1080 | TrainLoss=1.126e-03 (pde=4.53e-04, bc=4.65e-04, ic=1.14e-04, zz=4.94e-06, yxz=7.98e-05,| ValLoss=1.808e-03 (pde=1.13e-03, bc=4.62e-04, ic=1.17e-04, zz=6.02e-06, yxz=8.93e-05,)
# Epoch 1090 | TrainLoss=1.057e-03 (pde=3.95e-04, bc=4.63e-04, ic=1.14e-04, zz=7.96e-06, yxz=7.18e-05,| ValLoss=1.844e-03 (pde=1.17e-03, bc=4.60e-04, ic=1.17e-04, zz=8.82e-06, yxz=8.28e-05,)
#
# [Resample] epoch 1100: regenerating PDE/BC/IC points...
#
# Epoch 1100 | TrainLoss=1.004e-03 (pde=1.61e-03, bc=4.66e-04, ic=1.14e-04, zz=1.00e-05, yxz=7.76e-05,| ValLoss=1.855e-03 (pde=1.21e-03, bc=4.51e-04, ic=1.08e-04, zz=9.37e-06, yxz=7.73e-05,)
# Epoch 1110 | TrainLoss=1.093e-03 (pde=4.44e-04, bc=4.54e-04, ic=9.19e-05, zz=7.75e-06, yxz=7.97e-05,| ValLoss=1.999e-03 (pde=1.38e-03, bc=4.45e-04, ic=8.81e-05, zz=7.54e-06, yxz=8.09e-05,)
# Epoch 1120 | TrainLoss=9.931e-04 (pde=3.91e-04, bc=4.43e-04, ic=7.88e-05, zz=6.24e-06, yxz=6.64e-05,| ValLoss=2.367e-03 (pde=1.79e-03, bc=4.34e-04, ic=7.59e-05, zz=5.95e-06, yxz=6.48e-05,)
# Epoch 1130 | TrainLoss=9.458e-04 (pde=3.59e-04, bc=4.30e-04, ic=8.49e-05, zz=6.61e-06, yxz=6.11e-05,| ValLoss=2.474e-03 (pde=1.90e-03, bc=4.22e-04, ic=8.29e-05, zz=6.25e-06, yxz=5.93e-05,)
# Epoch 1140 | TrainLoss=9.030e-04 (pde=3.39e-04, bc=4.11e-04, ic=7.84e-05, zz=7.48e-06, yxz=6.37e-05,| ValLoss=2.801e-03 (pde=2.25e-03, bc=4.08e-04, ic=7.67e-05, zz=7.21e-06, yxz=6.20e-05,)
#
# [Resample] epoch 1150: regenerating PDE/BC/IC points...
#
# Epoch 1150 | TrainLoss=8.803e-04 (pde=1.02e-03, bc=4.26e-04, ic=7.47e-05, zz=6.63e-06, yxz=6.54e-05,| ValLoss=2.894e-03 (pde=2.35e-03, bc=4.07e-04, ic=7.11e-05, zz=6.61e-06, yxz=6.28e-05,)
# Epoch 1160 | TrainLoss=1.087e-03 (pde=4.67e-04, bc=4.55e-04, ic=8.43e-05, zz=5.77e-06, yxz=6.41e-05,| ValLoss=2.237e-03 (pde=1.65e-03, bc=4.38e-04, ic=8.04e-05, zz=5.73e-06, yxz=6.20e-05,)
# Epoch 1170 | TrainLoss=1.026e-03 (pde=4.19e-04, bc=4.47e-04, ic=8.61e-05, zz=5.11e-06, yxz=6.27e-05,| ValLoss=2.221e-03 (pde=1.65e-03, bc=4.29e-04, ic=8.15e-05, zz=5.05e-06, yxz=5.97e-05,)
# Epoch 1180 | TrainLoss=9.745e-04 (pde=3.69e-04, bc=4.40e-04, ic=8.42e-05, zz=5.70e-06, yxz=7.23e-05,| ValLoss=2.415e-03 (pde=1.84e-03, bc=4.22e-04, ic=7.99e-05, zz=5.73e-06, yxz=7.01e-05,)
# Epoch 1190 | TrainLoss=9.413e-04 (pde=3.42e-04, bc=4.43e-04, ic=7.89e-05, zz=5.41e-06, yxz=6.89e-05,| ValLoss=2.522e-03 (pde=1.95e-03, bc=4.24e-04, ic=7.44e-05, zz=5.42e-06, yxz=6.58e-05,)
#
# [Resample] epoch 1200: regenerating PDE/BC/IC points...
#
# Epoch 1200 | TrainLoss=9.173e-04 (pde=8.44e-04, bc=4.30e-04, ic=7.44e-05, zz=5.00e-06, yxz=7.26e-05,| ValLoss=2.534e-03 (pde=1.96e-03, bc=4.22e-04, ic=7.23e-05, zz=5.33e-06, yxz=7.01e-05,)
# Epoch 1210 | TrainLoss=8.546e-04 (pde=2.66e-04, bc=4.35e-04, ic=7.76e-05, zz=5.77e-06, yxz=6.05e-05,| ValLoss=2.389e-03 (pde=1.82e-03, bc=4.28e-04, ic=7.56e-05, zz=6.52e-06, yxz=6.07e-05,)
# Epoch 1220 | TrainLoss=7.932e-04 (pde=2.19e-04, bc=4.36e-04, ic=7.74e-05, zz=5.60e-06, yxz=5.16e-05,| ValLoss=2.390e-03 (pde=1.82e-03, bc=4.29e-04, ic=7.59e-05, zz=6.08e-06, yxz=5.76e-05,)
# Epoch 1230 | TrainLoss=7.676e-04 (pde=1.99e-04, bc=4.33e-04, ic=7.81e-05, zz=4.53e-06, yxz=5.19e-05,| ValLoss=2.406e-03 (pde=1.84e-03, bc=4.27e-04, ic=7.64e-05, zz=5.07e-06, yxz=6.07e-05,)
# Epoch 1240 | TrainLoss=7.536e-04 (pde=1.89e-04, bc=4.27e-04, ic=8.16e-05, zz=3.26e-06, yxz=5.06e-05,| ValLoss=2.531e-03 (pde=1.97e-03, bc=4.21e-04, ic=7.99e-05, zz=3.81e-06, yxz=5.93e-05,)
#
# [Resample] epoch 1250: regenerating PDE/BC/IC points...
#
# Epoch 1250 | TrainLoss=7.378e-04 (pde=4.47e-03, bc=4.31e-04, ic=8.05e-05, zz=3.88e-06, yxz=6.04e-05,| ValLoss=2.677e-03 (pde=2.12e-03, bc=4.16e-04, ic=7.84e-05, zz=3.92e-06, yxz=6.02e-05,)
# Epoch 1260 | TrainLoss=1.964e-03 (pde=1.05e-03, bc=5.77e-04, ic=1.11e-04, zz=7.62e-06, yxz=1.58e-04,| ValLoss=3.131e-03 (pde=2.27e-03, bc=5.60e-04, ic=1.12e-04, zz=7.10e-06, yxz=1.82e-04,)
# Epoch 1270 | TrainLoss=1.615e-03 (pde=7.77e-04, bc=5.52e-04, ic=1.11e-04, zz=2.13e-05, yxz=1.28e-04,| ValLoss=3.416e-03 (pde=2.60e-03, bc=5.38e-04, ic=1.11e-04, zz=2.14e-05, yxz=1.51e-04,)
# Epoch 1280 | TrainLoss=1.431e-03 (pde=6.28e-04, bc=5.23e-04, ic=1.13e-04, zz=1.76e-05, yxz=1.32e-04,| ValLoss=3.723e-03 (pde=2.91e-03, bc=5.11e-04, ic=1.11e-04, zz=1.64e-05, yxz=1.71e-04,)
# Epoch 1290 | TrainLoss=1.255e-03 (pde=4.95e-04, bc=4.95e-04, ic=1.13e-04, zz=1.31e-05, yxz=1.29e-04,| ValLoss=4.081e-03 (pde=3.31e-03, bc=4.83e-04, ic=1.11e-04, zz=1.24e-05, yxz=1.66e-04,)
#
# [Resample] epoch 1300: regenerating PDE/BC/IC points...
#
# Epoch 1300 | TrainLoss=1.159e-03 (pde=2.02e-02, bc=4.63e-04, ic=1.15e-04, zz=1.15e-05, yxz=1.30e-04,| ValLoss=4.069e-03 (pde=3.33e-03, bc=4.65e-04, ic=1.11e-04, zz=1.13e-05, yxz=1.54e-04,)
# Epoch 1310 | TrainLoss=4.092e-03 (pde=2.79e-03, bc=6.91e-04, ic=1.62e-04, zz=3.39e-05, yxz=3.14e-04,| ValLoss=3.575e-03 (pde=2.37e-03, bc=6.84e-04, ic=1.54e-04, zz=3.44e-05, yxz=3.30e-04,)
# Epoch 1320 | TrainLoss=3.084e-03 (pde=1.74e-03, bc=7.05e-04, ic=2.40e-04, zz=2.62e-05, yxz=2.84e-04,| ValLoss=5.148e-03 (pde=3.86e-03, bc=7.17e-04, ic=2.29e-04, zz=2.61e-05, yxz=3.14e-04,)
# Epoch 1330 | TrainLoss=2.462e-03 (pde=1.29e-03, bc=5.74e-04, ic=2.40e-04, zz=4.75e-05, yxz=2.66e-04,| ValLoss=5.835e-03 (pde=4.68e-03, bc=5.80e-04, ic=2.29e-04, zz=4.82e-05, yxz=2.96e-04,)
# Epoch 1340 | TrainLoss=2.048e-03 (pde=9.73e-04, bc=5.54e-04, ic=1.91e-04, zz=3.05e-05, yxz=2.55e-04,| ValLoss=5.666e-03 (pde=4.62e-03, bc=5.63e-04, ic=1.80e-04, zz=3.07e-05, yxz=2.70e-04,)
#
# [Resample] epoch 1350: regenerating PDE/BC/IC points...
#
# Epoch 1350 | TrainLoss=1.700e-03 (pde=2.63e-03, bc=5.40e-04, ic=1.52e-04, zz=2.55e-05, yxz=2.11e-04,| ValLoss=7.252e-03 (pde=6.34e-03, bc=5.28e-04, ic=1.46e-04, zz=2.52e-05, yxz=2.16e-04,)
# Epoch 1360 | TrainLoss=1.019e-03 (pde=3.10e-04, bc=4.59e-04, ic=1.06e-04, zz=1.05e-05, yxz=7.93e-05,| ValLoss=2.776e-03 (pde=2.13e-03, bc=4.50e-04, ic=1.05e-04, zz=1.02e-05, yxz=8.30e-05,)
# Epoch 1370 | TrainLoss=7.860e-04 (pde=1.99e-04, bc=4.31e-04, ic=8.66e-05, zz=5.61e-06, yxz=5.33e-05,| ValLoss=2.795e-03 (pde=2.21e-03, bc=4.24e-04, ic=8.56e-05, zz=5.74e-06, yxz=7.20e-05,)
# Epoch 1380 | TrainLoss=7.337e-04 (pde=1.83e-04, bc=4.16e-04, ic=7.71e-05, zz=6.27e-06, yxz=4.51e-05,| ValLoss=3.012e-03 (pde=2.45e-03, bc=4.08e-04, ic=7.63e-05, zz=6.32e-06, yxz=7.01e-05,)
# Epoch 1390 | TrainLoss=6.920e-04 (pde=1.73e-04, bc=4.03e-04, ic=6.77e-05, zz=6.23e-06, yxz=3.85e-05,| ValLoss=3.368e-03 (pde=2.84e-03, bc=3.97e-04, ic=6.74e-05, zz=6.52e-06, yxz=6.16e-05,)
#
# [Resample] epoch 1400: regenerating PDE/BC/IC points...
#
# Epoch 1400 | TrainLoss=6.677e-04 (pde=6.31e-03, bc=3.94e-04, ic=6.61e-05, zz=3.85e-06, yxz=8.36e-05,| ValLoss=3.590e-03 (pde=3.08e-03, bc=3.89e-04, ic=6.31e-05, zz=3.98e-06, yxz=5.84e-05,)
# Epoch 1410 | TrainLoss=1.813e-03 (pde=9.28e-04, bc=5.37e-04, ic=1.42e-04, zz=2.80e-05, yxz=1.46e-04,| ValLoss=2.391e-03 (pde=1.56e-03, bc=5.29e-04, ic=1.35e-04, zz=2.65e-05, yxz=1.37e-04,)
# Epoch 1420 | TrainLoss=1.602e-03 (pde=7.80e-04, bc=4.95e-04, ic=1.71e-04, zz=7.46e-06, yxz=1.33e-04,| ValLoss=2.986e-03 (pde=2.21e-03, bc=4.88e-04, ic=1.64e-04, zz=6.69e-06, yxz=1.20e-04,)
# Epoch 1430 | TrainLoss=1.493e-03 (pde=7.05e-04, bc=4.96e-04, ic=1.57e-04, zz=6.87e-06, yxz=1.15e-04,| ValLoss=3.224e-03 (pde=2.47e-03, bc=4.90e-04, ic=1.51e-04, zz=6.33e-06, yxz=1.08e-04,)
# Epoch 1440 | TrainLoss=1.404e-03 (pde=6.73e-04, bc=4.82e-04, ic=1.37e-04, zz=6.20e-06, yxz=1.01e-04,| ValLoss=3.745e-03 (pde=3.03e-03, bc=4.76e-04, ic=1.32e-04, zz=6.17e-06, yxz=9.91e-05,)
#
# [Resample] epoch 1450: regenerating PDE/BC/IC points...
#
# Epoch 1450 | TrainLoss=1.355e-03 (pde=3.76e-03, bc=4.42e-04, ic=1.30e-04, zz=5.19e-06, yxz=1.09e-04,| ValLoss=3.872e-03 (pde=3.19e-03, bc=4.49e-04, ic=1.27e-04, zz=5.08e-06, yxz=9.92e-05,)
# Epoch 1460 | TrainLoss=1.143e-03 (pde=3.97e-04, bc=4.85e-04, ic=1.21e-04, zz=1.21e-05, yxz=9.41e-05,| ValLoss=4.795e-03 (pde=4.05e-03, bc=4.95e-04, ic=1.19e-04, zz=1.16e-05, yxz=1.19e-04,)
# Epoch 1470 | TrainLoss=9.580e-04 (pde=3.05e-04, bc=4.66e-04, ic=9.80e-05, zz=5.02e-06, yxz=7.04e-05,| ValLoss=4.740e-03 (pde=4.07e-03, bc=4.78e-04, ic=9.61e-05, zz=4.96e-06, yxz=9.38e-05,)
# Epoch 1480 | TrainLoss=8.650e-04 (pde=2.39e-04, bc=4.54e-04, ic=9.35e-05, zz=7.82e-06, yxz=6.56e-05,| ValLoss=4.860e-03 (pde=4.20e-03, bc=4.62e-04, ic=9.11e-05, zz=7.62e-06, yxz=1.01e-04,)
# Epoch 1490 | TrainLoss=8.148e-04 (pde=2.14e-04, bc=4.38e-04, ic=9.29e-05, zz=5.17e-06, yxz=5.94e-05,| ValLoss=5.074e-03 (pde=4.45e-03, bc=4.44e-04, ic=9.00e-05, zz=5.12e-06, yxz=8.90e-05,)
#
# [Resample] epoch 1500: regenerating PDE/BC/IC points...
#
# Epoch 1500 | TrainLoss=7.809e-04 (pde=1.43e-03, bc=4.43e-04, ic=8.82e-05, zz=3.66e-06, yxz=6.11e-05,| ValLoss=5.243e-03 (pde=4.65e-03, bc=4.36e-04, ic=8.48e-05, zz=3.78e-06, yxz=6.81e-05,)
# Epoch 1510 | TrainLoss=9.667e-04 (pde=2.96e-04, bc=4.60e-04, ic=1.13e-04, zz=5.05e-06, yxz=8.16e-05,| ValLoss=3.046e-03 (pde=2.38e-03, bc=4.53e-04, ic=1.09e-04, zz=5.20e-06, yxz=9.96e-05,)
# Epoch 1520 | TrainLoss=8.562e-04 (pde=2.19e-04, bc=4.40e-04, ic=1.19e-04, zz=4.23e-06, yxz=6.82e-05,| ValLoss=3.068e-03 (pde=2.43e-03, bc=4.34e-04, ic=1.15e-04, zz=4.38e-06, yxz=8.47e-05,)
# Epoch 1530 | TrainLoss=8.044e-04 (pde=1.91e-04, bc=4.30e-04, ic=1.17e-04, zz=5.40e-06, yxz=5.44e-05,| ValLoss=3.266e-03 (pde=2.65e-03, bc=4.23e-04, ic=1.13e-04, zz=5.60e-06, yxz=7.09e-05,)
# Epoch 1540 | TrainLoss=7.540e-04 (pde=1.67e-04, bc=4.26e-04, ic=1.08e-04, zz=4.78e-06, yxz=4.59e-05,| ValLoss=3.526e-03 (pde=2.94e-03, bc=4.20e-04, ic=1.05e-04, zz=5.10e-06, yxz=5.92e-05,)
#
# [Resample] epoch 1550: regenerating PDE/BC/IC points...
#
# Epoch 1550 | TrainLoss=7.274e-04 (pde=1.54e-03, bc=4.15e-04, ic=1.02e-04, zz=4.42e-06, yxz=5.67e-05,| ValLoss=3.805e-03 (pde=3.23e-03, bc=4.14e-04, ic=9.82e-05, zz=4.62e-06, yxz=5.70e-05,)
# Epoch 1560 | TrainLoss=9.383e-04 (pde=3.30e-04, bc=4.34e-04, ic=9.39e-05, zz=7.97e-06, yxz=5.72e-05,| ValLoss=2.593e-03 (pde=2.00e-03, bc=4.35e-04, ic=9.31e-05, zz=8.11e-06, yxz=5.60e-05,)
# Epoch 1570 | TrainLoss=8.368e-04 (pde=2.50e-04, bc=4.21e-04, ic=9.95e-05, zz=7.10e-06, yxz=5.40e-05,| ValLoss=2.619e-03 (pde=2.04e-03, bc=4.22e-04, ic=9.85e-05, zz=7.61e-06, yxz=5.17e-05,)
# Epoch 1580 | TrainLoss=7.884e-04 (pde=2.25e-04, bc=4.07e-04, ic=9.48e-05, zz=4.19e-06, yxz=5.35e-05,| ValLoss=2.705e-03 (pde=2.15e-03, bc=4.07e-04, ic=9.39e-05, zz=4.52e-06, yxz=5.10e-05,)
# Epoch 1590 | TrainLoss=7.572e-04 (pde=2.03e-04, bc=4.08e-04, ic=8.66e-05, zz=4.31e-06, yxz=5.27e-05,| ValLoss=2.698e-03 (pde=2.15e-03, bc=4.09e-04, ic=8.56e-05, zz=4.63e-06, yxz=4.98e-05,)
#
# [Resample] epoch 1600: regenerating PDE/BC/IC points...
#
# Epoch 1600 | TrainLoss=7.381e-04 (pde=4.09e-03, bc=4.09e-04, ic=8.46e-05, zz=5.29e-06, yxz=4.62e-05,| ValLoss=2.680e-03 (pde=2.14e-03, bc=4.02e-04, ic=8.82e-05, zz=4.88e-06, yxz=4.75e-05,)
# Epoch 1610 | TrainLoss=1.426e-03 (pde=6.76e-04, bc=4.71e-04, ic=9.58e-05, zz=8.35e-06, yxz=1.19e-04,| ValLoss=2.922e-03 (pde=2.23e-03, bc=4.72e-04, ic=9.82e-05, zz=8.15e-06, yxz=1.13e-04,)
# Epoch 1620 | TrainLoss=1.163e-03 (pde=4.83e-04, bc=4.53e-04, ic=8.72e-05, zz=9.25e-06, yxz=1.20e-04,| ValLoss=3.574e-03 (pde=2.90e-03, bc=4.51e-04, ic=9.06e-05, zz=8.90e-06, yxz=1.21e-04,)
# Epoch 1630 | TrainLoss=1.060e-03 (pde=3.97e-04, bc=4.40e-04, ic=9.20e-05, zz=7.84e-06, yxz=1.15e-04,| ValLoss=3.618e-03 (pde=2.96e-03, bc=4.38e-04, ic=9.55e-05, zz=7.62e-06, yxz=1.17e-04,)
# Epoch 1640 | TrainLoss=9.888e-04 (pde=3.42e-04, bc=4.25e-04, ic=9.37e-05, zz=5.61e-06, yxz=1.17e-04,| ValLoss=4.010e-03 (pde=3.36e-03, bc=4.23e-04, ic=9.64e-05, zz=5.10e-06, yxz=1.25e-04,)
#
# [Resample] epoch 1650: regenerating PDE/BC/IC points...
#
# Epoch 1650 | TrainLoss=9.339e-04 (pde=1.81e-03, bc=4.34e-04, ic=9.04e-05, zz=7.42e-06, yxz=1.85e-04,| ValLoss=3.970e-03 (pde=3.34e-03, bc=4.23e-04, ic=8.65e-05, zz=7.55e-06, yxz=1.13e-04,)
# Epoch 1660 | TrainLoss=1.131e-03 (pde=4.89e-04, bc=4.60e-04, ic=8.32e-05, zz=8.65e-06, yxz=6.80e-05,| ValLoss=1.824e-03 (pde=1.21e-03, bc=4.54e-04, ic=8.03e-05, zz=8.85e-06, yxz=6.67e-05,)
# Epoch 1670 | TrainLoss=9.874e-04 (pde=3.71e-04, bc=4.53e-04, ic=9.03e-05, zz=8.59e-06, yxz=5.56e-05,| ValLoss=1.940e-03 (pde=1.34e-03, bc=4.48e-04, ic=8.64e-05, zz=9.04e-06, yxz=5.81e-05,)
# Epoch 1680 | TrainLoss=9.172e-04 (pde=3.05e-04, bc=4.45e-04, ic=9.74e-05, zz=5.19e-06, yxz=5.97e-05,| ValLoss=2.083e-03 (pde=1.48e-03, bc=4.40e-04, ic=9.34e-05, zz=5.25e-06, yxz=6.15e-05,)
# Epoch 1690 | TrainLoss=8.668e-04 (pde=2.72e-04, bc=4.40e-04, ic=8.84e-05, zz=7.46e-06, yxz=5.62e-05,| ValLoss=2.544e-03 (pde=1.96e-03, bc=4.34e-04, ic=8.56e-05, zz=7.50e-06, yxz=5.84e-05,)
#
# [Resample] epoch 1700: regenerating PDE/BC/IC points...
#
# Epoch 1700 | TrainLoss=8.204e-04 (pde=2.54e-03, bc=4.21e-04, ic=7.59e-05, zz=6.91e-06, yxz=6.01e-05,| ValLoss=3.319e-03 (pde=2.77e-03, bc=4.21e-04, ic=7.01e-05, zz=6.64e-06, yxz=5.51e-05,)
# Epoch 1710 | TrainLoss=1.023e-03 (pde=4.29e-04, bc=4.04e-04, ic=8.55e-05, zz=6.49e-06, yxz=8.23e-05,| ValLoss=1.854e-03 (pde=1.28e-03, bc=4.04e-04, ic=8.02e-05, zz=6.05e-06, yxz=8.18e-05,)
# Epoch 1720 | TrainLoss=9.165e-04 (pde=3.48e-04, bc=4.06e-04, ic=8.10e-05, zz=5.95e-06, yxz=6.86e-05,| ValLoss=1.998e-03 (pde=1.44e-03, bc=4.05e-04, ic=7.68e-05, zz=5.77e-06, yxz=7.45e-05,)
# Epoch 1730 | TrainLoss=8.427e-04 (pde=2.95e-04, bc=4.04e-04, ic=6.80e-05, zz=5.45e-06, yxz=6.49e-05,| ValLoss=1.951e-03 (pde=1.41e-03, bc=4.02e-04, ic=6.47e-05, zz=5.12e-06, yxz=6.88e-05,)
# Epoch 1740 | TrainLoss=8.001e-04 (pde=2.65e-04, bc=3.92e-04, ic=7.25e-05, zz=4.84e-06, yxz=6.24e-05,| ValLoss=2.075e-03 (pde=1.55e-03, bc=3.90e-04, ic=6.88e-05, zz=4.64e-06, yxz=6.33e-05,)
#
# [Resample] epoch 1750: regenerating PDE/BC/IC points...
#
# Epoch 1750 | TrainLoss=7.720e-04 (pde=2.96e-03, bc=4.02e-04, ic=6.21e-05, zz=5.49e-06, yxz=5.99e-05,| ValLoss=2.097e-03 (pde=1.58e-03, bc=3.87e-04, ic=6.34e-05, zz=5.50e-06, yxz=6.06e-05,)
# Epoch 1760 | TrainLoss=1.160e-03 (pde=4.33e-04, bc=5.04e-04, ic=8.95e-05, zz=7.91e-06, yxz=9.68e-05,| ValLoss=2.837e-03 (pde=2.15e-03, bc=4.83e-04, ic=9.13e-05, zz=7.95e-06, yxz=1.05e-04,)
# Epoch 1770 | TrainLoss=9.922e-04 (pde=3.38e-04, bc=4.84e-04, ic=9.01e-05, zz=5.88e-06, yxz=6.69e-05,| ValLoss=3.141e-03 (pde=2.51e-03, bc=4.64e-04, ic=9.15e-05, zz=5.87e-06, yxz=7.37e-05,)
# Epoch 1780 | TrainLoss=9.224e-04 (pde=2.77e-04, bc=4.84e-04, ic=8.43e-05, zz=4.90e-06, yxz=6.72e-05,| ValLoss=3.311e-03 (pde=2.68e-03, bc=4.64e-04, ic=8.57e-05, zz=4.94e-06, yxz=7.65e-05,)
# Epoch 1790 | TrainLoss=8.763e-04 (pde=2.47e-04, bc=4.69e-04, ic=7.73e-05, zz=3.50e-06, yxz=7.54e-05,| ValLoss=3.405e-03 (pde=2.78e-03, bc=4.52e-04, ic=7.86e-05, zz=3.51e-06, yxz=8.79e-05,)
#
# [Resample] epoch 1800: regenerating PDE/BC/IC points...
#
# Epoch 1800 | TrainLoss=8.392e-04 (pde=3.24e-02, bc=4.56e-04, ic=7.98e-05, zz=4.15e-06, yxz=9.74e-05,| ValLoss=3.475e-03 (pde=2.86e-03, bc=4.47e-04, ic=7.80e-05, zz=3.97e-06, yxz=8.56e-05,)
# Epoch 1810 | TrainLoss=1.256e-03 (pde=5.94e-04, bc=4.13e-04, ic=7.81e-05, zz=1.51e-05, yxz=1.32e-04,| ValLoss=2.446e-03 (pde=1.82e-03, bc=4.04e-04, ic=7.85e-05, zz=1.49e-05, yxz=1.32e-04,)
# Epoch 1820 | TrainLoss=1.023e-03 (pde=4.46e-04, bc=3.99e-04, ic=6.83e-05, zz=7.11e-06, yxz=8.51e-05,| ValLoss=2.501e-03 (pde=1.95e-03, bc=3.90e-04, ic=6.91e-05, zz=7.26e-06, yxz=8.66e-05,)
# Epoch 1830 | TrainLoss=9.123e-04 (pde=3.58e-04, bc=4.06e-04, ic=5.78e-05, zz=5.38e-06, yxz=7.72e-05,| ValLoss=2.585e-03 (pde=2.04e-03, bc=3.99e-04, ic=5.94e-05, zz=5.28e-06, yxz=7.76e-05,)
# Epoch 1840 | TrainLoss=8.544e-04 (pde=3.13e-04, bc=4.03e-04, ic=6.41e-05, zz=3.94e-06, yxz=6.52e-05,| ValLoss=2.858e-03 (pde=2.33e-03, bc=3.95e-04, ic=6.45e-05, zz=3.74e-06, yxz=6.63e-05,)
#
# [Resample] epoch 1850: regenerating PDE/BC/IC points...
#
# Epoch 1850 | TrainLoss=8.081e-04 (pde=1.66e-03, bc=3.93e-04, ic=7.70e-05, zz=4.10e-06, yxz=6.83e-05,| ValLoss=2.823e-03 (pde=2.30e-03, bc=3.87e-04, ic=7.23e-05, zz=3.75e-06, yxz=6.04e-05,)
# Epoch 1860 | TrainLoss=1.061e-03 (pde=4.64e-04, bc=4.05e-04, ic=7.57e-05, zz=7.39e-06, yxz=8.37e-05,| ValLoss=2.514e-03 (pde=1.95e-03, bc=3.98e-04, ic=7.03e-05, zz=7.14e-06, yxz=8.70e-05,)
# Epoch 1870 | TrainLoss=9.403e-04 (pde=3.65e-04, bc=4.15e-04, ic=7.68e-05, zz=4.13e-06, yxz=7.29e-05,| ValLoss=2.634e-03 (pde=2.06e-03, bc=4.08e-04, ic=7.13e-05, zz=3.85e-06, yxz=9.05e-05,)
# Epoch 1880 | TrainLoss=8.742e-04 (pde=3.05e-04, bc=4.22e-04, ic=6.36e-05, zz=5.29e-06, yxz=7.44e-05,| ValLoss=2.989e-03 (pde=2.43e-03, bc=4.14e-04, ic=5.94e-05, zz=4.95e-06, yxz=8.51e-05,)
# Epoch 1890 | TrainLoss=8.284e-04 (pde=2.72e-04, bc=4.01e-04, ic=7.11e-05, zz=4.82e-06, yxz=7.80e-05,| ValLoss=3.437e-03 (pde=2.88e-03, bc=3.95e-04, ic=6.68e-05, zz=4.36e-06, yxz=9.53e-05,)
#
# [Resample] epoch 1900: regenerating PDE/BC/IC points...
#
# Epoch 1900 | TrainLoss=8.081e-04 (pde=3.02e-03, bc=4.18e-04, ic=6.44e-05, zz=4.21e-06, yxz=1.06e-04,| ValLoss=3.512e-03 (pde=2.95e-03, bc=4.02e-04, ic=6.29e-05, zz=4.35e-06, yxz=8.78e-05,)
# Epoch 1910 | TrainLoss=1.194e-03 (pde=5.31e-04, bc=4.62e-04, ic=6.25e-05, zz=9.06e-06, yxz=9.78e-05,| ValLoss=3.145e-03 (pde=2.52e-03, bc=4.51e-04, ic=6.27e-05, zz=9.50e-06, yxz=1.02e-04,)
# Epoch 1920 | TrainLoss=1.003e-03 (pde=4.10e-04, bc=4.11e-04, ic=7.22e-05, zz=8.47e-06, yxz=9.11e-05,| ValLoss=3.978e-03 (pde=3.41e-03, bc=3.97e-04, ic=7.05e-05, zz=8.70e-06, yxz=9.38e-05,)
# Epoch 1930 | TrainLoss=9.055e-04 (pde=3.35e-04, bc=4.03e-04, ic=6.36e-05, zz=7.16e-06, yxz=8.73e-05,| ValLoss=4.435e-03 (pde=3.88e-03, bc=3.90e-04, ic=6.25e-05, zz=7.26e-06, yxz=9.35e-05,)
# Epoch 1940 | TrainLoss=8.457e-04 (pde=2.91e-04, bc=3.98e-04, ic=6.61e-05, zz=7.25e-06, yxz=7.98e-05,| ValLoss=4.822e-03 (pde=4.28e-03, bc=3.84e-04, ic=6.55e-05, zz=7.50e-06, yxz=8.48e-05,)
#
# [Resample] epoch 1950: regenerating PDE/BC/IC points...
#
# Epoch 1950 | TrainLoss=8.134e-04 (pde=1.21e-02, bc=3.91e-04, ic=5.78e-05, zz=4.83e-06, yxz=9.31e-05,| ValLoss=5.195e-03 (pde=4.67e-03, bc=3.82e-04, ic=5.57e-05, zz=5.08e-06, yxz=8.40e-05,)
# Epoch 1960 | TrainLoss=1.225e-03 (pde=5.41e-04, bc=4.47e-04, ic=9.96e-05, zz=1.26e-05, yxz=1.08e-04,| ValLoss=2.551e-03 (pde=1.90e-03, bc=4.42e-04, ic=9.27e-05, zz=1.24e-05, yxz=1.01e-04,)
# Epoch 1970 | TrainLoss=1.065e-03 (pde=4.20e-04, bc=4.36e-04, ic=9.65e-05, zz=1.19e-05, yxz=8.79e-05,| ValLoss=2.289e-03 (pde=1.67e-03, bc=4.37e-04, ic=8.92e-05, zz=1.22e-05, yxz=8.42e-05,)
# Epoch 1980 | TrainLoss=9.578e-04 (pde=3.48e-04, bc=4.19e-04, ic=9.54e-05, zz=8.70e-06, yxz=7.77e-05,| ValLoss=2.155e-03 (pde=1.56e-03, bc=4.20e-04, ic=8.95e-05, zz=9.08e-06, yxz=7.24e-05,)
# Epoch 1990 | TrainLoss=8.921e-04 (pde=3.13e-04, bc=4.11e-04, ic=8.61e-05, zz=6.54e-06, yxz=7.03e-05,| ValLoss=2.237e-03 (pde=1.66e-03, bc=4.15e-04, ic=8.19e-05, zz=6.91e-06, yxz=7.11e-05,)
#
# [Resample] epoch 2000: regenerating PDE/BC/IC points...
#
# Epoch 2000 | TrainLoss=8.468e-04 (pde=8.79e-04, bc=4.13e-04, ic=7.54e-05, zz=6.74e-06, yxz=6.93e-05,| ValLoss=2.291e-03 (pde=1.73e-03, bc=4.07e-04, ic=7.42e-05, zz=6.83e-06, yxz=6.87e-05,)
# Epoch 2010 | TrainLoss=9.107e-04 (pde=3.37e-04, bc=4.06e-04, ic=8.10e-05, zz=5.53e-06, yxz=6.91e-05,| ValLoss=2.428e-03 (pde=1.87e-03, bc=4.03e-04, ic=7.88e-05, zz=5.53e-06, yxz=6.96e-05,)
# Epoch 2020 | TrainLoss=8.364e-04 (pde=2.87e-04, bc=4.00e-04, ic=7.49e-05, zz=5.05e-06, yxz=6.30e-05,| ValLoss=2.790e-03 (pde=2.25e-03, bc=3.95e-04, ic=7.28e-05, zz=5.11e-06, yxz=6.63e-05,)
# Epoch 2030 | TrainLoss=7.825e-04 (pde=2.46e-04, bc=4.01e-04, ic=7.38e-05, zz=5.45e-06, yxz=5.33e-05,| ValLoss=3.138e-03 (pde=2.61e-03, bc=3.95e-04, ic=7.16e-05, zz=5.59e-06, yxz=5.82e-05,)
# Epoch 2040 | TrainLoss=7.566e-04 (pde=2.29e-04, bc=3.93e-04, ic=7.47e-05, zz=5.01e-06, yxz=5.15e-05,| ValLoss=3.185e-03 (pde=2.66e-03, bc=3.88e-04, ic=7.25e-05, zz=5.11e-06, yxz=5.53e-05,)
#
# [Resample] epoch 2050: regenerating PDE/BC/IC points...
#
# Epoch 2050 | TrainLoss=7.338e-04 (pde=7.68e-03, bc=3.84e-04, ic=7.48e-05, zz=5.03e-06, yxz=5.90e-05,| ValLoss=3.369e-03 (pde=2.86e-03, bc=3.82e-04, ic=7.26e-05, zz=5.00e-06, yxz=5.25e-05,)
# Epoch 2060 | TrainLoss=1.373e-03 (pde=6.70e-04, bc=4.72e-04, ic=8.63e-05, zz=1.76e-05, yxz=9.84e-05,| ValLoss=2.145e-03 (pde=1.47e-03, bc=4.66e-04, ic=8.36e-05, zz=1.71e-05, yxz=1.10e-04,)
# Epoch 2070 | TrainLoss=1.193e-03 (pde=5.66e-04, bc=4.33e-04, ic=8.94e-05, zz=1.32e-05, yxz=8.05e-05,| ValLoss=2.218e-03 (pde=1.60e-03, bc=4.29e-04, ic=8.69e-05, zz=1.29e-05, yxz=9.36e-05,)
# Epoch 2080 | TrainLoss=1.110e-03 (pde=4.86e-04, bc=4.40e-04, ic=8.24e-05, zz=1.20e-05, yxz=8.48e-05,| ValLoss=2.155e-03 (pde=1.53e-03, bc=4.35e-04, ic=8.00e-05, zz=1.19e-05, yxz=9.41e-05,)
# Epoch 2090 | TrainLoss=1.062e-03 (pde=4.51e-04, bc=4.26e-04, ic=9.07e-05, zz=1.11e-05, yxz=7.91e-05,| ValLoss=2.103e-03 (pde=1.49e-03, bc=4.20e-04, ic=8.84e-05, zz=1.07e-05, yxz=8.98e-05,)
#
# [Resample] epoch 2100: regenerating PDE/BC/IC points...
#
# Epoch 2100 | TrainLoss=1.015e-03 (pde=2.34e-03, bc=4.24e-04, ic=8.28e-05, zz=1.19e-05, yxz=8.10e-05,| ValLoss=2.214e-03 (pde=1.62e-03, bc=4.18e-04, ic=7.90e-05, zz=1.13e-05, yxz=8.70e-05,)
# Epoch 2110 | TrainLoss=9.982e-04 (pde=4.17e-04, bc=4.03e-04, ic=7.05e-05, zz=1.36e-05, yxz=7.69e-05,| ValLoss=2.308e-03 (pde=1.75e-03, bc=3.96e-04, ic=6.72e-05, zz=1.30e-05, yxz=8.12e-05,)
# Epoch 2120 | TrainLoss=8.967e-04 (pde=3.63e-04, bc=3.89e-04, ic=5.94e-05, zz=9.14e-06, yxz=6.98e-05,| ValLoss=2.666e-03 (pde=2.14e-03, bc=3.84e-04, ic=5.62e-05, zz=8.70e-06, yxz=7.67e-05,)
# Epoch 2130 | TrainLoss=8.483e-04 (pde=3.20e-04, bc=3.89e-04, ic=5.86e-05, zz=1.00e-05, yxz=6.71e-05,| ValLoss=2.694e-03 (pde=2.17e-03, bc=3.84e-04, ic=5.56e-05, zz=9.50e-06, yxz=7.20e-05,)
# Epoch 2140 | TrainLoss=8.180e-04 (pde=2.93e-04, bc=3.80e-04, ic=6.34e-05, zz=9.91e-06, yxz=6.95e-05,| ValLoss=2.880e-03 (pde=2.36e-03, bc=3.76e-04, ic=6.03e-05, zz=9.36e-06, yxz=7.42e-05,)
#
# [Resample] epoch 2150: regenerating PDE/BC/IC points...
#
# Epoch 2150 | TrainLoss=7.923e-04 (pde=1.99e-03, bc=3.80e-04, ic=5.89e-05, zz=9.63e-06, yxz=8.34e-05,| ValLoss=2.800e-03 (pde=2.29e-03, bc=3.75e-04, ic=5.66e-05, zz=9.06e-06, yxz=6.79e-05,)
# Epoch 2160 | TrainLoss=1.094e-03 (pde=4.73e-04, bc=4.40e-04, ic=7.76e-05, zz=7.93e-06, yxz=7.85e-05,| ValLoss=2.233e-03 (pde=1.64e-03, bc=4.37e-04, ic=7.52e-05, zz=7.40e-06, yxz=7.33e-05,)
# Epoch 2170 | TrainLoss=9.381e-04 (pde=3.21e-04, bc=4.49e-04, ic=7.44e-05, zz=6.44e-06, yxz=7.61e-05,| ValLoss=2.833e-03 (pde=2.23e-03, bc=4.47e-04, ic=7.34e-05, zz=6.49e-06, yxz=7.31e-05,)
# Epoch 2180 | TrainLoss=8.498e-04 (pde=2.59e-04, bc=4.36e-04, ic=7.33e-05, zz=5.04e-06, yxz=6.76e-05,| ValLoss=3.295e-03 (pde=2.71e-03, bc=4.34e-04, ic=7.18e-05, zz=5.13e-06, yxz=7.04e-05,)
# Epoch 2190 | TrainLoss=8.049e-04 (pde=2.41e-04, bc=4.27e-04, ic=6.83e-05, zz=4.43e-06, yxz=6.12e-05,| ValLoss=3.437e-03 (pde=2.88e-03, bc=4.25e-04, ic=6.65e-05, zz=4.55e-06, yxz=6.32e-05,)
#
# [Resample] epoch 2200: regenerating PDE/BC/IC points...
#
# Epoch 2200 | TrainLoss=7.753e-04 (pde=5.25e-03, bc=4.22e-04, ic=7.41e-05, zz=4.08e-06, yxz=6.20e-05,| ValLoss=3.595e-03 (pde=3.04e-03, bc=4.18e-04, ic=7.06e-05, zz=4.22e-06, yxz=6.15e-05,)
# Epoch 2210 | TrainLoss=9.076e-04 (pde=3.67e-04, bc=3.95e-04, ic=6.00e-05, zz=7.33e-06, yxz=6.39e-05,| ValLoss=2.065e-03 (pde=1.54e-03, bc=3.94e-04, ic=5.82e-05, zz=7.01e-06, yxz=6.96e-05,)
# Epoch 2220 | TrainLoss=8.205e-04 (pde=2.96e-04, bc=3.94e-04, ic=6.51e-05, zz=4.70e-06, yxz=5.62e-05,| ValLoss=2.062e-03 (pde=1.54e-03, bc=3.92e-04, ic=6.27e-05, zz=4.69e-06, yxz=6.60e-05,)
# Epoch 2230 | TrainLoss=7.814e-04 (pde=2.58e-04, bc=3.97e-04, ic=5.95e-05, zz=5.99e-06, yxz=5.89e-05,| ValLoss=2.274e-03 (pde=1.75e-03, bc=3.95e-04, ic=5.74e-05, zz=6.24e-06, yxz=6.83e-05,)
# Epoch 2240 | TrainLoss=7.575e-04 (pde=2.42e-04, bc=3.91e-04, ic=5.99e-05, zz=4.60e-06, yxz=5.74e-05,| ValLoss=2.402e-03 (pde=1.88e-03, bc=3.89e-04, ic=5.77e-05, zz=4.80e-06, yxz=6.71e-05,)
#
# [Resample] epoch 2250: regenerating PDE/BC/IC points...
#
# Epoch 2250 | TrainLoss=7.311e-04 (pde=6.40e-03, bc=3.69e-04, ic=5.99e-05, zz=4.39e-06, yxz=7.07e-05,| ValLoss=2.688e-03 (pde=2.18e-03, bc=3.74e-04, ic=6.03e-05, zz=4.76e-06, yxz=6.93e-05,)
# Epoch 2260 | TrainLoss=2.165e-03 (pde=1.39e-03, bc=4.88e-04, ic=9.52e-05, zz=6.69e-06, yxz=1.48e-04,| ValLoss=3.250e-03 (pde=2.51e-03, bc=4.88e-04, ic=9.31e-05, zz=6.85e-06, yxz=1.54e-04,)
# Epoch 2270 | TrainLoss=1.913e-03 (pde=1.16e-03, bc=4.93e-04, ic=1.11e-04, zz=5.77e-06, yxz=1.25e-04,| ValLoss=3.576e-03 (pde=2.84e-03, bc=4.90e-04, ic=1.08e-04, zz=5.77e-06, yxz=1.30e-04,)
# Epoch 2280 | TrainLoss=1.768e-03 (pde=1.02e-03, bc=4.93e-04, ic=1.11e-04, zz=9.59e-06, yxz=1.18e-04,| ValLoss=3.635e-03 (pde=2.91e-03, bc=4.92e-04, ic=1.09e-04, zz=9.74e-06, yxz=1.17e-04,)
# Epoch 2290 | TrainLoss=1.684e-03 (pde=9.60e-04, bc=4.78e-04, ic=1.06e-04, zz=5.74e-06, yxz=1.29e-04,| ValLoss=4.056e-03 (pde=3.34e-03, bc=4.77e-04, ic=1.04e-04, zz=5.82e-06, yxz=1.24e-04,)
#
# [Resample] epoch 2300: regenerating PDE/BC/IC points...
#
# Epoch 2300 | TrainLoss=1.611e-03 (pde=3.83e-03, bc=4.85e-04, ic=1.18e-04, zz=6.67e-06, yxz=1.74e-04,| ValLoss=4.238e-03 (pde=3.50e-03, bc=4.74e-04, ic=1.18e-04, zz=6.46e-06, yxz=1.37e-04,)
# Epoch 2310 | TrainLoss=1.132e-03 (pde=3.93e-04, bc=5.13e-04, ic=1.08e-04, zz=6.69e-06, yxz=8.76e-05,| ValLoss=4.085e-03 (pde=3.38e-03, bc=4.98e-04, ic=1.09e-04, zz=6.72e-06, yxz=8.66e-05,)
# Epoch 2320 | TrainLoss=9.879e-04 (pde=3.09e-04, bc=4.93e-04, ic=9.34e-05, zz=5.79e-06, yxz=7.80e-05,| ValLoss=3.672e-03 (pde=3.02e-03, bc=4.77e-04, ic=9.35e-05, zz=5.72e-06, yxz=7.41e-05,)
# Epoch 2330 | TrainLoss=9.275e-04 (pde=2.64e-04, bc=4.85e-04, ic=9.74e-05, zz=4.07e-06, yxz=7.31e-05,| ValLoss=3.533e-03 (pde=2.89e-03, bc=4.70e-04, ic=9.69e-05, zz=4.10e-06, yxz=6.96e-05,)
# Epoch 2340 | TrainLoss=8.887e-04 (pde=2.44e-04, bc=4.85e-04, ic=9.05e-05, zz=2.75e-06, yxz=6.40e-05,| ValLoss=3.562e-03 (pde=2.93e-03, bc=4.70e-04, ic=9.07e-05, zz=2.74e-06, yxz=6.60e-05,)
#
# [Resample] epoch 2350: regenerating PDE/BC/IC points...
#
# Epoch 2350 | TrainLoss=8.668e-04 (pde=1.38e-03, bc=4.67e-04, ic=9.50e-05, zz=3.31e-06, yxz=5.88e-05,| ValLoss=3.544e-03 (pde=2.92e-03, bc=4.63e-04, ic=9.47e-05, zz=3.30e-06, yxz=5.84e-05,)
# Epoch 2360 | TrainLoss=1.022e-03 (pde=4.32e-04, bc=4.14e-04, ic=8.11e-05, zz=7.14e-06, yxz=7.14e-05,| ValLoss=2.354e-03 (pde=1.77e-03, bc=4.17e-04, ic=8.07e-05, zz=7.13e-06, yxz=7.47e-05,)
# Epoch 2370 | TrainLoss=9.043e-04 (pde=3.41e-04, bc=3.99e-04, ic=7.77e-05, zz=3.97e-06, yxz=7.06e-05,| ValLoss=2.742e-03 (pde=2.19e-03, bc=4.02e-04, ic=7.69e-05, zz=4.01e-06, yxz=6.78e-05,)
# Epoch 2380 | TrainLoss=8.278e-04 (pde=2.77e-04, bc=3.92e-04, ic=7.56e-05, zz=3.70e-06, yxz=7.48e-05,| ValLoss=3.032e-03 (pde=2.49e-03, bc=3.97e-04, ic=7.47e-05, zz=3.66e-06, yxz=7.01e-05,)
# Epoch 2390 | TrainLoss=7.741e-04 (pde=2.44e-04, bc=3.82e-04, ic=7.51e-05, zz=3.06e-06, yxz=6.44e-05,| ValLoss=3.213e-03 (pde=2.69e-03, bc=3.86e-04, ic=7.40e-05, zz=3.07e-06, yxz=6.07e-05,)
#
# [Resample] epoch 2400: regenerating PDE/BC/IC points...
#
# Epoch 2400 | TrainLoss=7.291e-04 (pde=3.96e-03, bc=3.84e-04, ic=6.37e-05, zz=3.37e-06, yxz=6.80e-05,| ValLoss=3.329e-03 (pde=2.81e-03, bc=3.90e-04, ic=6.44e-05, zz=3.44e-06, yxz=5.83e-05,)
# Epoch 2410 | TrainLoss=1.030e-03 (pde=4.45e-04, bc=4.12e-04, ic=6.33e-05, zz=1.23e-05, yxz=8.12e-05,| ValLoss=1.936e-03 (pde=1.36e-03, bc=4.17e-04, ic=6.48e-05, zz=1.23e-05, yxz=8.00e-05,)
# Epoch 2420 | TrainLoss=9.170e-04 (pde=3.92e-04, bc=3.96e-04, ic=5.37e-05, zz=4.98e-06, yxz=5.96e-05,| ValLoss=2.025e-03 (pde=1.50e-03, bc=4.02e-04, ic=5.50e-05, zz=5.13e-06, yxz=5.98e-05,)
# Epoch 2430 | TrainLoss=8.598e-04 (pde=3.43e-04, bc=3.90e-04, ic=5.36e-05, zz=6.36e-06, yxz=6.31e-05,| ValLoss=2.139e-03 (pde=1.62e-03, bc=3.96e-04, ic=5.51e-05, zz=6.44e-06, yxz=6.20e-05,)
# Epoch 2440 | TrainLoss=8.233e-04 (pde=3.15e-04, bc=3.80e-04, ic=5.44e-05, zz=5.19e-06, yxz=6.65e-05,| ValLoss=2.239e-03 (pde=1.73e-03, bc=3.85e-04, ic=5.57e-05, zz=5.26e-06, yxz=6.47e-05,)
#
# [Resample] epoch 2450: regenerating PDE/BC/IC points...
#
# Epoch 2450 | TrainLoss=7.939e-04 (pde=2.65e-03, bc=3.70e-04, ic=6.02e-05, zz=5.64e-06, yxz=7.09e-05,| ValLoss=2.260e-03 (pde=1.76e-03, bc=3.75e-04, ic=5.81e-05, zz=5.66e-06, yxz=6.32e-05,)
# Epoch 2460 | TrainLoss=9.786e-04 (pde=3.78e-04, bc=4.20e-04, ic=8.27e-05, zz=8.52e-06, yxz=7.26e-05,| ValLoss=2.684e-03 (pde=2.10e-03, bc=4.24e-04, ic=7.92e-05, zz=8.20e-06, yxz=6.87e-05,)
# Epoch 2470 | TrainLoss=8.811e-04 (pde=3.19e-04, bc=4.06e-04, ic=8.23e-05, zz=5.76e-06, yxz=6.25e-05,| ValLoss=2.871e-03 (pde=2.32e-03, bc=4.12e-04, ic=7.86e-05, zz=5.73e-06, yxz=5.74e-05,)
# Epoch 2480 | TrainLoss=8.256e-04 (pde=2.70e-04, bc=4.13e-04, ic=7.66e-05, zz=5.66e-06, yxz=5.42e-05,| ValLoss=3.214e-03 (pde=2.67e-03, bc=4.20e-04, ic=7.30e-05, zz=5.60e-06, yxz=4.97e-05,)
# Epoch 2490 | TrainLoss=7.812e-04 (pde=2.54e-04, bc=4.09e-04, ic=6.80e-05, zz=6.22e-06, yxz=4.07e-05,| ValLoss=3.623e-03 (pde=3.10e-03, bc=4.15e-04, ic=6.52e-05, zz=6.20e-06, yxz=3.77e-05,)
# Epoch 2499 | TrainLoss=7.462e-04 (pde=2.19e-04, bc=4.04e-04, ic=7.44e-05, zz=5.79e-06, yxz=3.96e-05,| ValLoss=3.848e-03 (pde=3.32e-03, bc=4.09e-04, ic=7.05e-05, zz=5.79e-06, yxz=3.80e-05,)
# Training finished.

# %%
# test 
t0 = 0.0
nx = 100
xs = np.linspace(X_MIN, X_MAX, nx)
ys = np.linspace(Y_MIN, Y_MAX, nx)
Xg, Yg = np.meshgrid(xs, ys)

x_grid = torch.from_numpy(Xg.flatten()[:,None]).to(device).double()
y_grid = torch.from_numpy(Yg.flatten()[:,None]).to(device).double()
t_grid = torch.full_like(x_grid, t0).to(device)  # 全部時間都固定為 t0

with torch.no_grad():
    phi_grid, u_true = compute_phi(x_grid, y_grid, t_grid)

# 預測 u
with torch.no_grad():
    inp_grid = torch.cat([x_grid, y_grid, phi_grid, t_grid], dim=1)
    u_pred = model(inp_grid).cpu().numpy().reshape(nx, nx)
    u_true = u_true.cpu().numpy().reshape(nx, nx)

# 逐點相對誤差
u_true_norm = np.max(np.abs(u_true))   # 真實解的 inf norm
error_rel = np.abs(u_pred - u_true) / (u_true_norm)
error_rel2 = np.abs(u_pred - u_true) / np.linalg.norm(u_true.flatten(), ord=2) # 分母是 true 的 L2 norm
error_abs = np.abs(u_pred - u_true)

# 整體相對誤差 ||u_pred - u_true||_2 / ||u_true||_2
error_tensor = torch.from_numpy(np.abs(u_pred - u_true)).double()
u_tensor = torch.from_numpy(np.abs(u_true)).double()
relL2 = torch.norm(error_tensor) / torch.norm(u_tensor)
print("Relative L2 error (grid):", relL2.item())

# 畫圖
fig, axs = plt.subplots(1, 3, figsize=(18,5))

im0 = axs[0].contourf(Xg, Yg, u_pred, 50, cmap='viridis')
fig.colorbar(im0, ax=axs[0])
axs[0].set_title('PINN Prediction $u_N$')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')

im1 = axs[1].contourf(Xg, Yg, u_true, 50, cmap='viridis')
fig.colorbar(im1, ax=axs[1])
axs[1].set_title('Analytical Solution $\\phi$')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')

im2 = axs[2].contourf(Xg, Yg, error_rel, 50, cmap='hot')
fig.colorbar(im2, ax=axs[2])
axs[2].set_title('Relative Error')
axs[2].set_xlabel('x')
axs[2].set_ylabel('y')

plt.tight_layout()
plt.show()
# Out:
# Relative L2 error (grid): 0.012814448908128643

# %%
fig, axs = plt.subplots(1, 3, figsize=(18,5))

im0 = axs[0].contourf(Xg, Yg, u_pred, 50, cmap='viridis')
fig.colorbar(im0, ax=axs[0])
axs[0].set_title(f'Prediction $u_N(x,y,t={t0:.2f})$')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].set_aspect('equal')


ax1 = fig.add_subplot(132, projection='3d')
ax1.plot_surface(Xg, Yg, u_pred, cmap='viridis', edgecolor='none')
ax1.set_title(f'Surface view ($t={t0:.2f}$)')
ax1.set_xlabel('x'); ax1.set_ylabel('y')
ax1.view_init(elev=70, azim=45)
#ax1.set_zlim(0, 0.2)

ax2 = fig.add_subplot(133, projection='3d')
ax2.contour3D(Xg, Yg, u_pred, 50, cmap='viridis')
ax2.set_title(f'3D contours ($t={t0:.2f}$)')
ax2.set_xlabel('x'); ax2.set_ylabel('y')
ax2.view_init(elev=70, azim=45)
#ax2.set_zlim(0, 0.2)

plt.tight_layout()
plt.show()

# %%
# loss 
epochs_arr = np.arange(len(loss_history))
val_epochs = np.linspace(0, len(loss_history)-1, len(val_history))
plt.figure(figsize=(8,5))
plt.semilogy(epochs_arr, loss_history, label='Training Loss')
plt.semilogy(val_epochs, val_history, label='Validation Loss (every 10 ep)')
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
